# %%
import math

import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import random

# %% [markdown]
# # The Game of Frogger
#
# ## The game of Frogger is a simple game where a frog starts at one side of a stream and tries to get to the other side of the stream. The stream has within it N lily pads. The frog starts, effectively, on pad 0 and can jump to pad 1, 2, 3, ..., N+1. The frog is equally likely to jump to any of the pads 1, 2, 3, ..., N+1.  The frog gets to the other side when she reaches pad N+1.
#
# ## The question is, on average, how many jumps does it take for the frog to get to the other side of the stream?

# %% [markdown]
# ## Analytic Solution
#
# ### The expectation value for a discrete random variable is defined as:
#
# ### $E = \sum_{i=0}^{n} x_i p_i$
#
# ### where $x_i$ is the value of the random variable and $p_i$ is the probability of the random variable taking on the value $x_i$.
#
# ### Let's consider some simple cases:
#
# ### n = 0
#
# ### $E_0 = x_0 p_0 = 1 \cdot 1 = 1$
#
# ### n = 1
#
# ### $E_1 = \frac{1}{2} (1) + \frac{1}{2} (2) = 1 + \frac{1}{2} (1) = \frac{3}{2}$ = 1.5
#
# ### n = 2
#
# ### $E_2 = \frac{1}{3} (1) + \frac{1}{3} (\frac{1}{2} (2) + \frac{1}{2} (3)) + \frac{1}{3} (2)  = 1 + \frac{1}{3} (\frac{3}{2}) + \frac{1}{3} (1) = \frac{11}{6} = 1.8333$
#
# ### We can observe a pattern now ... for each value of $n$, we can break down the problem into a sum of the previous problems (for smaller n values).  We see that for any value of n, the expectation value is:
#
# ### $E_n = 1 + \frac{1}{n+1} \sum_{i=1}^{n} E_{n-i}$
#
# ### So, we can calculate the expectation value for any value of n by calculating the expectation value for all smaller values of n.  A recursive solution to this problem seems appropriate.
#
# ## Harmonic Mean
#
# ### The harmonic mean is defined as:
#
# ### $H = \frac{n}{\sum_{i=1}^{n} \frac{1}{x_i}}$
#
# ### where $x_i$ is the value of the random variable and $n$ is the number of values of $x_i$.
#
# ### The harmonic mean is the appropriate mean to use when the values of the random variable are rates (e.g. miles per gallon).  In this case, the values of the random variable are the number of jumps it takes for the frog to get to the other side of the stream.  So, the harmonic mean is the appropriate mean to use.

# %% [markdown]
# ### Set the number of lilypads

# %%
n = 100

# %% [markdown]
# ### seed the random number generator

# %%
random.seed(1)

# %%
start = 0 # start at lilypad 0
jumpsum = 0 # keep track of the number of jumps per simulation
total_jumps = 0 # keep track of the total number of jumps for all simulations
n_trys = 10000 # number of simulations to run

x = [] # array for the number of lilypads for plotting
y = [] # array for the expectation value for plotting
eval = [] # array for the analytic solution
eval_harmonic = [] # array for the analytic solution
x_harmonic = [] # array for the harmonic mean
sigma = [] # array for the error on the expectation value

# %%
#
# Evaluate the analytic solution shown above
#
# loop over the number of lilypads (it's n+1 so that we actually do the npad=n_max case)
for npad in range(0,n+1): 

    if (npad == 0):
        eval.append(1)
    else:
        sum = 1.0
        for i in range(0,npad):
            #print(i,npad,npad-i)
            #print(eval[npad-i-1])
            sum = sum + 1.0/(npad+1)*(eval[npad-i-1])
        eval.append(sum)
    #print("Theory: ",npad,eval[npad])

# %%
#
# Run the simulation
#
# (also, evaluate the harmonic mean along the way)
#
for npad in range(0,n+1):
    
    x_harmonic.append(npad+1)
    x.append(npad)
    
    sum2 = (npad+1.0)/stats.hmean(x_harmonic)
    eval_harmonic.append(sum2)
    
    #print ("Harmonic mean for npad = ",npad," = ", sum2)
    
    end = npad+1
    current_paddle = start
    
    # run the simulation n_trys times
    for j in range(n_trys):
        
        # run the simulation until the frog reaches the other side
        while current_paddle < end:
            # choose a random jump size between 1 and the number of lilypads left to jump
            jump = int(random.uniform(1,(end-current_paddle+1)))
            #print ("Jump = ",jump)
            
            # jump ahead
            current_paddle = current_paddle + jump
            #print ("Now at ",current_paddle)
            
            # keep track of the number of jumps
            jumpsum = jumpsum + 1
            
        # reset the frog to the start for the next simulation
        current_paddle = start
        #print ("j = %d, Total_jumps = %d" % (j,jumpsum))
        
        # keep track of the total number of jumps for all simulations
        total_jumps = total_jumps + jumpsum
        
        # reset the jumpsum for the next simulation
        jumpsum = 0
    
    #print (npad,total_jumps,n_trys)

    # calculate the expectation value
    expectation_value = total_jumps/n_trys*1.0
    
    # store the expectation value and the error on the expectation value for plotting
    y.append(expectation_value)
    sigma.append(expectation_value*1/np.sqrt(n_trys))
    
    # reset the total number of jumps for all simulations, for the next value of npad
    total_jumps = 0
    
    print ("Expectation value for n = %d is %f" % (npad,expectation_value))
# Out:
# Expectation value for n = 0 is 1.000000
# Expectation value for n = 1 is 1.500900
# Expectation value for n = 2 is 1.836400
# Expectation value for n = 3 is 2.077400
# Expectation value for n = 4 is 2.286100
# Expectation value for n = 5 is 2.457800
# Expectation value for n = 6 is 2.580900
# Expectation value for n = 7 is 2.719300
# Expectation value for n = 8 is 2.827100
# Expectation value for n = 9 is 2.937900
# Expectation value for n = 10 is 3.026300
# Expectation value for n = 11 is 3.112800
# Expectation value for n = 12 is 3.172100
# Expectation value for n = 13 is 3.246400
# Expectation value for n = 14 is 3.298400
# Expectation value for n = 15 is 3.391100
# Expectation value for n = 16 is 3.469200
# Expectation value for n = 17 is 3.512800
# Expectation value for n = 18 is 3.529600
# Expectation value for n = 19 is 3.583100
# Expectation value for n = 20 is 3.642400
# Expectation value for n = 21 is 3.695700
# Expectation value for n = 22 is 3.720600
# Expectation value for n = 23 is 3.770700
# Expectation value for n = 24 is 3.804500
# Expectation value for n = 25 is 3.842600
# Expectation value for n = 26 is 3.881700
# Expectation value for n = 27 is 3.932800
# Expectation value for n = 28 is 3.956400
# Expectation value for n = 29 is 4.034200
# Expectation value for n = 30 is 4.010300
# Expectation value for n = 31 is 4.067000
# Expectation value for n = 32 is 4.120900
# Expectation value for n = 33 is 4.118200
# Expectation value for n = 34 is 4.135800
# Expectation value for n = 35 is 4.168900
# Expectation value for n = 36 is 4.229500
# Expectation value for n = 37 is 4.215000
# Expectation value for n = 38 is 4.264600
# Expectation value for n = 39 is 4.289000
# Expectation value for n = 40 is 4.297400
# Expectation value for n = 41 is 4.319400
# Expectation value for n = 42 is 4.349200
# Expectation value for n = 43 is 4.380500
# Expectation value for n = 44 is 4.391700
# Expectation value for n = 45 is 4.413600
# Expectation value for n = 46 is 4.459600
# Expectation value for n = 47 is 4.479300
# Expectation value for n = 48 is 4.495500
# Expectation value for n = 49 is 4.467300
# Expectation value for n = 50 is 4.520800
# Expectation value for n = 51 is 4.521800
# Expectation value for n = 52 is 4.541800
# Expectation value for n = 53 is 4.565200
# Expectation value for n = 54 is 4.603700
# Expectation value for n = 55 is 4.612500
# Expectation value for n = 56 is 4.656600
# Expectation value for n = 57 is 4.632500
# Expectation value for n = 58 is 4.638600
# Expectation value for n = 59 is 4.660400
# Expectation value for n = 60 is 4.691800
# Expectation value for n = 61 is 4.705200
# Expectation value for n = 62 is 4.744500
# Expectation value for n = 63 is 4.765700
# Expectation value for n = 64 is 4.774500
# Expectation value for n = 65 is 4.763800
# Expectation value for n = 66 is 4.802600
# Expectation value for n = 67 is 4.817300
# Expectation value for n = 68 is 4.795400
# Expectation value for n = 69 is 4.832500
# Expectation value for n = 70 is 4.867900
# Expectation value for n = 71 is 4.897200
# Expectation value for n = 72 is 4.868900
# Expectation value for n = 73 is 4.878600
# Expectation value for n = 74 is 4.926100
# Expectation value for n = 75 is 4.925000
# Expectation value for n = 76 is 4.901600
# Expectation value for n = 77 is 4.963300
# Expectation value for n = 78 is 4.946200
# Expectation value for n = 79 is 4.957200
# Expectation value for n = 80 is 4.941700
# Expectation value for n = 81 is 4.997900
# Expectation value for n = 82 is 5.007600
# Expectation value for n = 83 is 4.990600
# Expectation value for n = 84 is 5.035600
# Expectation value for n = 85 is 5.057300
# Expectation value for n = 86 is 5.074500
# Expectation value for n = 87 is 5.084200
# Expectation value for n = 88 is 5.107100
# Expectation value for n = 89 is 5.087700
# Expectation value for n = 90 is 5.113300
# Expectation value for n = 91 is 5.099900
# Expectation value for n = 92 is 5.122500
# Expectation value for n = 93 is 5.115900
# Expectation value for n = 94 is 5.158800
# Expectation value for n = 95 is 5.124700
# Expectation value for n = 96 is 5.184700
# Expectation value for n = 97 is 5.166400
# Expectation value for n = 98 is 5.177300
# Expectation value for n = 99 is 5.176600
# Expectation value for n = 100 is 5.208700

# %%
# plot the results

fig = plt.figure(figsize=(15,12))
ax1 = fig.add_subplot(111)

ax1.set_title("Frog Problem")
ax1.set_xlabel('N')
ax1.set_ylabel('Expected Number of Jumps / N')
ax1.set_xlim(-1,n+1)
#ax1.set_yscale("log")
#ax1.set_xscale("log")
ax1.grid(True)

ax1.errorbar(x,y,yerr=sigma,fmt='o')
ax1.plot(x,eval,'r--')
ax1.plot(x,eval_harmonic,'g--')

# %% [markdown]
# ## Frog can move backwards or forwards

# %%
x = [] # array for the number of lilypads for plotting
y = [] # array for the expectation value for plotting
sigma = [] # array for the error on the expectation value

# Run the simulation
#
# (also, evaluate the harmonic mean along the way)
#
for npad in range(0,n+1):
    x.append(npad)
    
    end = npad+1
    current_paddle = start
    
    # run the simulation n_trys times
    for j in range(n_trys):
        
        # run the simulation until the frog reaches the other side
        while current_paddle < end:
            # choose a random jump size between -current_paddle and the number of lilypads left to jump
            # make sure he can't jump 0 pads
            jump = 0
            while (jump == 0):
                jump = int(random.uniform((start-current_paddle),(end-current_paddle+1)))
            # print ("Jump = ",jump)
            
            # jump ahead
            current_paddle = current_paddle + jump
            # print ("Now at ",current_paddle)
            
            # keep track of the number of jumps
            jumpsum = jumpsum + 1
            
        # reset the frog to the start for the next simulation
        current_paddle = start
        #print ("j = %d, Total_jumps = %d" % (j,jumpsum))
        
        # keep track of the total number of jumps for all simulations
        total_jumps = total_jumps + jumpsum
        
        # reset the jumpsum for the next simulation
        jumpsum = 0
    
    #print (npad,total_jumps,n_trys)

    # calculate the expectation value
    expectation_value = total_jumps/n_trys*1.0
    
    # store the expectation value and the error on the expectation value for plotting
    y.append(expectation_value)
    sigma.append(expectation_value*1/np.sqrt(n_trys))
    
    # reset the total number of jumps for all simulations, for the next value of npad
    total_jumps = 0
    
    print ("Expectation value for n = %d is %f" % (npad,expectation_value))
# Out:
# Expectation value for n = 0 is 1.000000
# Expectation value for n = 1 is 1.498600
# Expectation value for n = 2 is 2.343100
# Expectation value for n = 3 is 3.238500
# Expectation value for n = 4 is 4.185000
# Expectation value for n = 5 is 5.252600
# Expectation value for n = 6 is 6.168500
# Expectation value for n = 7 is 7.190900
# Expectation value for n = 8 is 8.152400
# Expectation value for n = 9 is 9.222300
# Expectation value for n = 10 is 10.023100
# Expectation value for n = 11 is 11.165200
# Expectation value for n = 12 is 11.990500
# Expectation value for n = 13 is 12.965100
# Expectation value for n = 14 is 13.968700
# Expectation value for n = 15 is 15.228700
# Expectation value for n = 16 is 16.228600
# Expectation value for n = 17 is 17.474700
# Expectation value for n = 18 is 17.849000
# Expectation value for n = 19 is 18.989900
# Expectation value for n = 20 is 20.193000
# Expectation value for n = 21 is 21.036600
# Expectation value for n = 22 is 22.131400
# Expectation value for n = 23 is 23.028900
# Expectation value for n = 24 is 23.841800
# Expectation value for n = 25 is 25.162200
# Expectation value for n = 26 is 25.718100
# Expectation value for n = 27 is 27.063900
# Expectation value for n = 28 is 28.235500
# Expectation value for n = 29 is 29.251900
# Expectation value for n = 30 is 30.139300
# Expectation value for n = 31 is 30.996600
# Expectation value for n = 32 is 32.026200
# Expectation value for n = 33 is 33.384100
# Expectation value for n = 34 is 34.041400
# Expectation value for n = 35 is 34.411600
# Expectation value for n = 36 is 36.535500
# Expectation value for n = 37 is 37.746400
# Expectation value for n = 38 is 38.451700
# Expectation value for n = 39 is 38.310500
# Expectation value for n = 40 is 40.000700
# Expectation value for n = 41 is 40.673200
# Expectation value for n = 42 is 42.289700
# Expectation value for n = 43 is 42.848300
# Expectation value for n = 44 is 44.639800
# Expectation value for n = 45 is 45.473300
# Expectation value for n = 46 is 47.198900
# Expectation value for n = 47 is 47.010500
# Expectation value for n = 48 is 48.620300
# Expectation value for n = 49 is 48.942400
# Expectation value for n = 50 is 50.168400
# Expectation value for n = 51 is 51.141400
# Expectation value for n = 52 is 52.438800
# Expectation value for n = 53 is 52.574200
# Expectation value for n = 54 is 53.998000
# Expectation value for n = 55 is 54.807600
# Expectation value for n = 56 is 56.911800
# Expectation value for n = 57 is 57.175700
# Expectation value for n = 58 is 57.658500
# Expectation value for n = 59 is 59.470800
# Expectation value for n = 60 is 60.488900
# Expectation value for n = 61 is 60.302400
# Expectation value for n = 62 is 61.823900
# Expectation value for n = 63 is 62.651600
# Expectation value for n = 64 is 64.290700
# Expectation value for n = 65 is 65.639300
# Expectation value for n = 66 is 66.091600
# Expectation value for n = 67 is 67.239600
# Expectation value for n = 68 is 67.520400
# Expectation value for n = 69 is 69.321300
# Expectation value for n = 70 is 69.956100
# Expectation value for n = 71 is 70.012400
# Expectation value for n = 72 is 71.216900
# Expectation value for n = 73 is 73.638100
# Expectation value for n = 74 is 73.176900
# Expectation value for n = 75 is 75.406700
# Expectation value for n = 76 is 75.689200
# Expectation value for n = 77 is 77.405000
# Expectation value for n = 78 is 78.518200
# Expectation value for n = 79 is 78.180500
# Expectation value for n = 80 is 80.443000
# Expectation value for n = 81 is 81.231500
# Expectation value for n = 82 is 81.766300
# Expectation value for n = 83 is 84.392800
# Expectation value for n = 84 is 84.060400
# Expectation value for n = 85 is 84.647700
# Expectation value for n = 86 is 85.380600
# Expectation value for n = 87 is 87.530200
# Expectation value for n = 88 is 89.620900
# Expectation value for n = 89 is 89.930400
# Expectation value for n = 90 is 89.541300
# Expectation value for n = 91 is 92.977800
# Expectation value for n = 92 is 92.297500
# Expectation value for n = 93 is 92.015900
# Expectation value for n = 94 is 94.228800
# Expectation value for n = 95 is 93.937700
# Expectation value for n = 96 is 97.016300
# Expectation value for n = 97 is 94.035300
# Expectation value for n = 98 is 98.601900
# Expectation value for n = 99 is 99.193200
# Expectation value for n = 100 is 100.399100

# %%
# plot the results

fig = plt.figure(figsize=(15,12))
ax1 = fig.add_subplot(111)

ax1.set_title("Frog can move backwards or forwards")
ax1.set_xlabel('N')
ax1.set_ylabel('Expected Number of Jumps / N')
ax1.set_xlim(-1,n+1)
#ax1.set_yscale("log")
#ax1.set_xscale("log")
ax1.grid(True)

ax1.errorbar(x,y,yerr=sigma,fmt='o')
ax1.plot(x,eval_harmonic,'g--')

# %% [markdown]
# The relationship between the number of lilypads and the expected number of jumps taken by the frog is linear because the probability of jumping to any given lilypad is the same.

# %% [markdown]
# ## Frog can only move forwards, but chance of jumping is not uniform

# %%
x = [] # array for the number of lilypads for plotting
y = [] # array for the expectation value for plotting
eval = [] # array for the analytic solution
eval_harmonic = [] # array for the analytic solution
x_harmonic = [] # array for the harmonic mean
sigma = [] # array for the error on the expectation value

# Run the simulation
#
# (also, evaluate the harmonic mean along the way)
#
for npad in range(0,n+1):
    
    probability = (1/np.linspace(1,npad,npad+1))/np.sum((1/np.linspace(1,npad,npad+1)))
    # print(probability)
    x_harmonic.append(npad+1)
    x.append(npad)
    
    sum2 = (npad+1.0)/stats.hmean(x_harmonic)
    eval_harmonic.append(sum2)
    
    #print ("Harmonic mean for npad = ",npad," = ", sum2)
    
    end = npad+1
    current_paddle = start
    
    # run the simulation n_trys times
    for j in range(n_trys):
        
        # run the simulation until the frog reaches the other side
        while current_paddle < end:
            # choose a random jump size between -current_paddle and the number of lilypads left to jump
            # make sure he can't jump 0 pads
            jump = 0
            while (jump == 0):
                jump = np.random.choice(np.linspace(1, (end-current_paddle+1),npad+1), p=probability)
                # jump = int(random.uniform(0,(end-current_paddle+1)))
            # print ("Jump = ",jump)
            
            # jump ahead
            current_paddle = current_paddle + jump
            # print ("Now at ",current_paddle)
            
            # keep track of the number of jumps
            jumpsum = jumpsum + 1
            
        # reset the frog to the start for the next simulation
        current_paddle = start
        #print ("j = %d, Total_jumps = %d" % (j,jumpsum))
        
        # keep track of the total number of jumps for all simulations
        total_jumps = total_jumps + jumpsum
        
        # reset the jumpsum for the next simulation
        jumpsum = 0
    
    #print (npad,total_jumps,n_trys)

    # calculate the expectation value
    expectation_value = total_jumps/n_trys*1.0
    
    # store the expectation value and the error on the expectation value for plotting
    y.append(expectation_value)
    sigma.append(expectation_value*1/np.sqrt(n_trys))
    
    # reset the total number of jumps for all simulations, for the next value of npad
    total_jumps = 0
    
    print ("Expectation value for n = %d is %f" % (npad,expectation_value))
# Out:
# Expectation value for n = 0 is 1.371600
# Expectation value for n = 1 is 1.670100
# Expectation value for n = 2 is 2.201100
# Expectation value for n = 3 is 2.607600
# Expectation value for n = 4 is 2.963800
# Expectation value for n = 5 is 3.286800
# Expectation value for n = 6 is 3.594300
# Expectation value for n = 7 is 3.832100
# Expectation value for n = 8 is 4.076600
# Expectation value for n = 9 is 4.307400
# Expectation value for n = 10 is 4.502400
# Expectation value for n = 11 is 4.702500
# Expectation value for n = 12 is 4.885200
# Expectation value for n = 13 is 5.058900
# Expectation value for n = 14 is 5.250000
# Expectation value for n = 15 is 5.370000
# Expectation value for n = 16 is 5.518000
# Expectation value for n = 17 is 5.683100
# Expectation value for n = 18 is 5.800700
# Expectation value for n = 19 is 5.947100
# Expectation value for n = 20 is 6.113800
# Expectation value for n = 21 is 6.179900
# Expectation value for n = 22 is 6.303200
# Expectation value for n = 23 is 6.453400
# Expectation value for n = 24 is 6.544300
# Expectation value for n = 25 is 6.611200
# Expectation value for n = 26 is 6.726300
# Expectation value for n = 27 is 6.860200
# Expectation value for n = 28 is 6.935900
# Expectation value for n = 29 is 7.003800
# Expectation value for n = 30 is 7.091900
# Expectation value for n = 31 is 7.201500
# Expectation value for n = 32 is 7.344800
# Expectation value for n = 33 is 7.397100
# Expectation value for n = 34 is 7.483500
# Expectation value for n = 35 is 7.567100
# Expectation value for n = 36 is 7.642100
# Expectation value for n = 37 is 7.733000
# Expectation value for n = 38 is 7.867600
# Expectation value for n = 39 is 7.903800
# Expectation value for n = 40 is 7.940300
# Expectation value for n = 41 is 7.976200
# Expectation value for n = 42 is 8.083200
# Expectation value for n = 43 is 8.186900
# Expectation value for n = 44 is 8.213400
# Expectation value for n = 45 is 8.277900
# Expectation value for n = 46 is 8.385400
# Expectation value for n = 47 is 8.484400
# Expectation value for n = 48 is 8.534500
# Expectation value for n = 49 is 8.617800
# Expectation value for n = 50 is 8.554300
# Expectation value for n = 51 is 8.728600
# Expectation value for n = 52 is 8.739100
# Expectation value for n = 53 is 8.793100
# Expectation value for n = 54 is 8.838600
# Expectation value for n = 55 is 8.910700
# Expectation value for n = 56 is 8.985800
# Expectation value for n = 57 is 8.992900
# Expectation value for n = 58 is 9.101400
# Expectation value for n = 59 is 9.195500
# Expectation value for n = 60 is 9.259600
# Expectation value for n = 61 is 9.246600
# Expectation value for n = 62 is 9.278200
# Expectation value for n = 63 is 9.391500
# Expectation value for n = 64 is 9.357600
# Expectation value for n = 65 is 9.420800
# Expectation value for n = 66 is 9.548000
# Expectation value for n = 67 is 9.548700
# Expectation value for n = 68 is 9.593700
# Expectation value for n = 69 is 9.718700
# Expectation value for n = 70 is 9.657500
# Expectation value for n = 71 is 9.760800
# Expectation value for n = 72 is 9.766300
# Expectation value for n = 73 is 9.862900
# Expectation value for n = 74 is 9.818500
# Expectation value for n = 75 is 9.920300
# Expectation value for n = 76 is 10.076000
# Expectation value for n = 77 is 10.026900
# Expectation value for n = 78 is 10.113700
# Expectation value for n = 79 is 10.098800
# Expectation value for n = 80 is 10.176800
# Expectation value for n = 81 is 10.205200
# Expectation value for n = 82 is 10.250200
# Expectation value for n = 83 is 10.227000
# Expectation value for n = 84 is 10.365900
# Expectation value for n = 85 is 10.365000
# Expectation value for n = 86 is 10.435600
# Expectation value for n = 87 is 10.426500
# Expectation value for n = 88 is 10.495000
# Expectation value for n = 89 is 10.516800
# Expectation value for n = 90 is 10.551800
# Expectation value for n = 91 is 10.543300
# Expectation value for n = 92 is 10.624900
# Expectation value for n = 93 is 10.723600
# Expectation value for n = 94 is 10.674200
# Expectation value for n = 95 is 10.807800
# Expectation value for n = 96 is 10.815000
# Expectation value for n = 97 is 10.855100
# Expectation value for n = 98 is 10.925800
# Expectation value for n = 99 is 10.899500
# Expectation value for n = 100 is 10.981700

# %%
# plot the results

fig = plt.figure(figsize=(15,12))
ax1 = fig.add_subplot(111)

ax1.set_title("Frog un-uniform distribution")
ax1.set_xlabel('N')
ax1.set_ylabel('Expected Number of Jumps / N')
ax1.set_xlim(-1,n+1)
#ax1.set_yscale("log")
#ax1.set_xscale("log")
ax1.grid(True)

ax1.errorbar(x,y,yerr=sigma,fmt='o')
#ax1.plot(x,eval,'r--')
ax1.plot(x,eval_harmonic,'g--')

# %% [markdown]
# The frog, on average, takes longer to get to the other side compared to the uniform distribution since it favors shorter jumps
