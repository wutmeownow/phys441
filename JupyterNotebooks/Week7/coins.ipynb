# %% [markdown]
# # Coin Systems
#
# Most coin systemx are designed to mimimize the $number$ of coins needed to make change for any amount.  For example, the coin system for the United States is {1, 5, 10, 25, 50, 100}.  Thus, it is a six-coin system.  Of course, the U.S. also has a one-dollar bill, and so the dollar coin is rarely used.  The same is true for the 50 cent coin, and so in practice, the U.S. has a four-coin system that is used for amounts less than one dollar.
#
# The coin system for the Euro is {1, 2, 5, 10, 20, 50, 100, 200}. Thus, it is an eight-coin system.  The smallest Euro note is 5 Euros, and so coind are used in practice for amounts less than 5 Euros.

# %%
# The coin system for the United States

us_coins = [25, 10, 5, 1]

# The coin system for the Euro
euro_coins = [200, 100, 50, 20, 10, 5, 2, 1]

n_coins_us = []
n_coins_euro = []
cost_array = []

for cost in range(1,500):
    cost_array.append(cost)
    
    n_coins = 0
    remaining = cost%100
    #print ("Starting cost", cost)
    for coin in us_coins:
        while remaining >= coin:
            n_coins += 1
            remaining -= coin
            #print("Coin", coin, "remaining", remaining)
    print("Cost", cost, " in U.S. requires", n_coins, "coins")
    n_coins_us.append(n_coins)
    
    n_coins = 0
    remaining = cost
    #print ("Starting cost", cost)
    for coin in euro_coins:
        while remaining >= coin:
            n_coins += 1
            remaining -= coin
            #print("Coin", coin, "remaining", remaining)
    print("Cost", cost, "in Europe requires", n_coins, "coins")
    n_coins_euro.append(n_coins)
# Out:
# Cost 1  in U.S. requires 1 coins
# Cost 1 in Europe requires 1 coins
# Cost 2  in U.S. requires 2 coins
# Cost 2 in Europe requires 1 coins
# Cost 3  in U.S. requires 3 coins
# Cost 3 in Europe requires 2 coins
# Cost 4  in U.S. requires 4 coins
# Cost 4 in Europe requires 2 coins
# Cost 5  in U.S. requires 1 coins
# Cost 5 in Europe requires 1 coins
# Cost 6  in U.S. requires 2 coins
# Cost 6 in Europe requires 2 coins
# Cost 7  in U.S. requires 3 coins
# Cost 7 in Europe requires 2 coins
# Cost 8  in U.S. requires 4 coins
# Cost 8 in Europe requires 3 coins
# Cost 9  in U.S. requires 5 coins
# Cost 9 in Europe requires 3 coins
# Cost 10  in U.S. requires 1 coins
# Cost 10 in Europe requires 1 coins
# Cost 11  in U.S. requires 2 coins
# Cost 11 in Europe requires 2 coins
# Cost 12  in U.S. requires 3 coins
# Cost 12 in Europe requires 2 coins
# Cost 13  in U.S. requires 4 coins
# Cost 13 in Europe requires 3 coins
# Cost 14  in U.S. requires 5 coins
# Cost 14 in Europe requires 3 coins
# Cost 15  in U.S. requires 2 coins
# Cost 15 in Europe requires 2 coins
# Cost 16  in U.S. requires 3 coins
# Cost 16 in Europe requires 3 coins
# Cost 17  in U.S. requires 4 coins
# Cost 17 in Europe requires 3 coins
# Cost 18  in U.S. requires 5 coins
# Cost 18 in Europe requires 4 coins
# Cost 19  in U.S. requires 6 coins
# Cost 19 in Europe requires 4 coins
# Cost 20  in U.S. requires 2 coins
# Cost 20 in Europe requires 1 coins
# Cost 21  in U.S. requires 3 coins
# Cost 21 in Europe requires 2 coins
# Cost 22  in U.S. requires 4 coins
# Cost 22 in Europe requires 2 coins
# Cost 23  in U.S. requires 5 coins
# Cost 23 in Europe requires 3 coins
# Cost 24  in U.S. requires 6 coins
# Cost 24 in Europe requires 3 coins
# Cost 25  in U.S. requires 1 coins
# Cost 25 in Europe requires 2 coins
# Cost 26  in U.S. requires 2 coins
# Cost 26 in Europe requires 3 coins
# Cost 27  in U.S. requires 3 coins
# Cost 27 in Europe requires 3 coins
# Cost 28  in U.S. requires 4 coins
# Cost 28 in Europe requires 4 coins
# Cost 29  in U.S. requires 5 coins
# Cost 29 in Europe requires 4 coins
# Cost 30  in U.S. requires 2 coins
# Cost 30 in Europe requires 2 coins
# Cost 31  in U.S. requires 3 coins
# Cost 31 in Europe requires 3 coins
# Cost 32  in U.S. requires 4 coins
# Cost 32 in Europe requires 3 coins
# Cost 33  in U.S. requires 5 coins
# Cost 33 in Europe requires 4 coins
# Cost 34  in U.S. requires 6 coins
# Cost 34 in Europe requires 4 coins
# Cost 35  in U.S. requires 2 coins
# Cost 35 in Europe requires 3 coins
# Cost 36  in U.S. requires 3 coins
# Cost 36 in Europe requires 4 coins
# Cost 37  in U.S. requires 4 coins
# Cost 37 in Europe requires 4 coins
# Cost 38  in U.S. requires 5 coins
# Cost 38 in Europe requires 5 coins
# Cost 39  in U.S. requires 6 coins
# Cost 39 in Europe requires 5 coins
# Cost 40  in U.S. requires 3 coins
# Cost 40 in Europe requires 2 coins
# Cost 41  in U.S. requires 4 coins
# Cost 41 in Europe requires 3 coins
# Cost 42  in U.S. requires 5 coins
# Cost 42 in Europe requires 3 coins
# Cost 43  in U.S. requires 6 coins
# Cost 43 in Europe requires 4 coins
# Cost 44  in U.S. requires 7 coins
# Cost 44 in Europe requires 4 coins
# Cost 45  in U.S. requires 3 coins
# Cost 45 in Europe requires 3 coins
# Cost 46  in U.S. requires 4 coins
# Cost 46 in Europe requires 4 coins
# Cost 47  in U.S. requires 5 coins
# Cost 47 in Europe requires 4 coins
# Cost 48  in U.S. requires 6 coins
# Cost 48 in Europe requires 5 coins
# Cost 49  in U.S. requires 7 coins
# Cost 49 in Europe requires 5 coins
# Cost 50  in U.S. requires 2 coins
# Cost 50 in Europe requires 1 coins
# Cost 51  in U.S. requires 3 coins
# Cost 51 in Europe requires 2 coins
# Cost 52  in U.S. requires 4 coins
# Cost 52 in Europe requires 2 coins
# Cost 53  in U.S. requires 5 coins
# Cost 53 in Europe requires 3 coins
# Cost 54  in U.S. requires 6 coins
# Cost 54 in Europe requires 3 coins
# Cost 55  in U.S. requires 3 coins
# Cost 55 in Europe requires 2 coins
# Cost 56  in U.S. requires 4 coins
# Cost 56 in Europe requires 3 coins
# Cost 57  in U.S. requires 5 coins
# Cost 57 in Europe requires 3 coins
# Cost 58  in U.S. requires 6 coins
# Cost 58 in Europe requires 4 coins
# Cost 59  in U.S. requires 7 coins
# Cost 59 in Europe requires 4 coins
# Cost 60  in U.S. requires 3 coins
# Cost 60 in Europe requires 2 coins
# Cost 61  in U.S. requires 4 coins
# Cost 61 in Europe requires 3 coins
# Cost 62  in U.S. requires 5 coins
# Cost 62 in Europe requires 3 coins
# Cost 63  in U.S. requires 6 coins
# Cost 63 in Europe requires 4 coins
# Cost 64  in U.S. requires 7 coins
# Cost 64 in Europe requires 4 coins
# Cost 65  in U.S. requires 4 coins
# Cost 65 in Europe requires 3 coins
# Cost 66  in U.S. requires 5 coins
# Cost 66 in Europe requires 4 coins
# Cost 67  in U.S. requires 6 coins
# Cost 67 in Europe requires 4 coins
# Cost 68  in U.S. requires 7 coins
# Cost 68 in Europe requires 5 coins
# Cost 69  in U.S. requires 8 coins
# Cost 69 in Europe requires 5 coins
# Cost 70  in U.S. requires 4 coins
# Cost 70 in Europe requires 2 coins
# Cost 71  in U.S. requires 5 coins
# Cost 71 in Europe requires 3 coins
# Cost 72  in U.S. requires 6 coins
# Cost 72 in Europe requires 3 coins
# Cost 73  in U.S. requires 7 coins
# Cost 73 in Europe requires 4 coins
# Cost 74  in U.S. requires 8 coins
# Cost 74 in Europe requires 4 coins
# Cost 75  in U.S. requires 3 coins
# Cost 75 in Europe requires 3 coins
# Cost 76  in U.S. requires 4 coins
# Cost 76 in Europe requires 4 coins
# Cost 77  in U.S. requires 5 coins
# Cost 77 in Europe requires 4 coins
# Cost 78  in U.S. requires 6 coins
# Cost 78 in Europe requires 5 coins
# Cost 79  in U.S. requires 7 coins
# Cost 79 in Europe requires 5 coins
# Cost 80  in U.S. requires 4 coins
# Cost 80 in Europe requires 3 coins
# Cost 81  in U.S. requires 5 coins
# Cost 81 in Europe requires 4 coins
# Cost 82  in U.S. requires 6 coins
# Cost 82 in Europe requires 4 coins
# Cost 83  in U.S. requires 7 coins
# Cost 83 in Europe requires 5 coins
# Cost 84  in U.S. requires 8 coins
# Cost 84 in Europe requires 5 coins
# Cost 85  in U.S. requires 4 coins
# Cost 85 in Europe requires 4 coins
# Cost 86  in U.S. requires 5 coins
# Cost 86 in Europe requires 5 coins
# Cost 87  in U.S. requires 6 coins
# Cost 87 in Europe requires 5 coins
# Cost 88  in U.S. requires 7 coins
# Cost 88 in Europe requires 6 coins
# Cost 89  in U.S. requires 8 coins
# Cost 89 in Europe requires 6 coins
# Cost 90  in U.S. requires 5 coins
# Cost 90 in Europe requires 3 coins
# Cost 91  in U.S. requires 6 coins
# Cost 91 in Europe requires 4 coins
# Cost 92  in U.S. requires 7 coins
# Cost 92 in Europe requires 4 coins
# Cost 93  in U.S. requires 8 coins
# Cost 93 in Europe requires 5 coins
# Cost 94  in U.S. requires 9 coins
# Cost 94 in Europe requires 5 coins
# Cost 95  in U.S. requires 5 coins
# Cost 95 in Europe requires 4 coins
# Cost 96  in U.S. requires 6 coins
# Cost 96 in Europe requires 5 coins
# Cost 97  in U.S. requires 7 coins
# Cost 97 in Europe requires 5 coins
# Cost 98  in U.S. requires 8 coins
# Cost 98 in Europe requires 6 coins
# Cost 99  in U.S. requires 9 coins
# Cost 99 in Europe requires 6 coins
# Cost 100  in U.S. requires 0 coins
# Cost 100 in Europe requires 1 coins
# Cost 101  in U.S. requires 1 coins
# Cost 101 in Europe requires 2 coins
# Cost 102  in U.S. requires 2 coins
# Cost 102 in Europe requires 2 coins
# Cost 103  in U.S. requires 3 coins
# Cost 103 in Europe requires 3 coins
# Cost 104  in U.S. requires 4 coins
# Cost 104 in Europe requires 3 coins
# Cost 105  in U.S. requires 1 coins
# Cost 105 in Europe requires 2 coins
# Cost 106  in U.S. requires 2 coins
# Cost 106 in Europe requires 3 coins
# Cost 107  in U.S. requires 3 coins
# Cost 107 in Europe requires 3 coins
# Cost 108  in U.S. requires 4 coins
# Cost 108 in Europe requires 4 coins
# Cost 109  in U.S. requires 5 coins
# Cost 109 in Europe requires 4 coins
# Cost 110  in U.S. requires 1 coins
# Cost 110 in Europe requires 2 coins
# Cost 111  in U.S. requires 2 coins
# Cost 111 in Europe requires 3 coins
# Cost 112  in U.S. requires 3 coins
# Cost 112 in Europe requires 3 coins
# Cost 113  in U.S. requires 4 coins
# Cost 113 in Europe requires 4 coins
# Cost 114  in U.S. requires 5 coins
# Cost 114 in Europe requires 4 coins
# Cost 115  in U.S. requires 2 coins
# Cost 115 in Europe requires 3 coins
# Cost 116  in U.S. requires 3 coins
# Cost 116 in Europe requires 4 coins
# Cost 117  in U.S. requires 4 coins
# Cost 117 in Europe requires 4 coins
# Cost 118  in U.S. requires 5 coins
# Cost 118 in Europe requires 5 coins
# Cost 119  in U.S. requires 6 coins
# Cost 119 in Europe requires 5 coins
# Cost 120  in U.S. requires 2 coins
# Cost 120 in Europe requires 2 coins
# Cost 121  in U.S. requires 3 coins
# Cost 121 in Europe requires 3 coins
# Cost 122  in U.S. requires 4 coins
# Cost 122 in Europe requires 3 coins
# Cost 123  in U.S. requires 5 coins
# Cost 123 in Europe requires 4 coins
# Cost 124  in U.S. requires 6 coins
# Cost 124 in Europe requires 4 coins
# Cost 125  in U.S. requires 1 coins
# Cost 125 in Europe requires 3 coins
# Cost 126  in U.S. requires 2 coins
# Cost 126 in Europe requires 4 coins
# Cost 127  in U.S. requires 3 coins
# Cost 127 in Europe requires 4 coins
# Cost 128  in U.S. requires 4 coins
# Cost 128 in Europe requires 5 coins
# Cost 129  in U.S. requires 5 coins
# Cost 129 in Europe requires 5 coins
# Cost 130  in U.S. requires 2 coins
# Cost 130 in Europe requires 3 coins
# Cost 131  in U.S. requires 3 coins
# Cost 131 in Europe requires 4 coins
# Cost 132  in U.S. requires 4 coins
# Cost 132 in Europe requires 4 coins
# Cost 133  in U.S. requires 5 coins
# Cost 133 in Europe requires 5 coins
# Cost 134  in U.S. requires 6 coins
# Cost 134 in Europe requires 5 coins
# Cost 135  in U.S. requires 2 coins
# Cost 135 in Europe requires 4 coins
# Cost 136  in U.S. requires 3 coins
# Cost 136 in Europe requires 5 coins
# Cost 137  in U.S. requires 4 coins
# Cost 137 in Europe requires 5 coins
# Cost 138  in U.S. requires 5 coins
# Cost 138 in Europe requires 6 coins
# Cost 139  in U.S. requires 6 coins
# Cost 139 in Europe requires 6 coins
# Cost 140  in U.S. requires 3 coins
# Cost 140 in Europe requires 3 coins
# Cost 141  in U.S. requires 4 coins
# Cost 141 in Europe requires 4 coins
# Cost 142  in U.S. requires 5 coins
# Cost 142 in Europe requires 4 coins
# Cost 143  in U.S. requires 6 coins
# Cost 143 in Europe requires 5 coins
# Cost 144  in U.S. requires 7 coins
# Cost 144 in Europe requires 5 coins
# Cost 145  in U.S. requires 3 coins
# Cost 145 in Europe requires 4 coins
# Cost 146  in U.S. requires 4 coins
# Cost 146 in Europe requires 5 coins
# Cost 147  in U.S. requires 5 coins
# Cost 147 in Europe requires 5 coins
# Cost 148  in U.S. requires 6 coins
# Cost 148 in Europe requires 6 coins
# Cost 149  in U.S. requires 7 coins
# Cost 149 in Europe requires 6 coins
# Cost 150  in U.S. requires 2 coins
# Cost 150 in Europe requires 2 coins
# Cost 151  in U.S. requires 3 coins
# Cost 151 in Europe requires 3 coins
# Cost 152  in U.S. requires 4 coins
# Cost 152 in Europe requires 3 coins
# Cost 153  in U.S. requires 5 coins
# Cost 153 in Europe requires 4 coins
# Cost 154  in U.S. requires 6 coins
# Cost 154 in Europe requires 4 coins
# Cost 155  in U.S. requires 3 coins
# Cost 155 in Europe requires 3 coins
# Cost 156  in U.S. requires 4 coins
# Cost 156 in Europe requires 4 coins
# Cost 157  in U.S. requires 5 coins
# Cost 157 in Europe requires 4 coins
# Cost 158  in U.S. requires 6 coins
# Cost 158 in Europe requires 5 coins
# Cost 159  in U.S. requires 7 coins
# Cost 159 in Europe requires 5 coins
# Cost 160  in U.S. requires 3 coins
# Cost 160 in Europe requires 3 coins
# Cost 161  in U.S. requires 4 coins
# Cost 161 in Europe requires 4 coins
# Cost 162  in U.S. requires 5 coins
# Cost 162 in Europe requires 4 coins
# Cost 163  in U.S. requires 6 coins
# Cost 163 in Europe requires 5 coins
# Cost 164  in U.S. requires 7 coins
# Cost 164 in Europe requires 5 coins
# Cost 165  in U.S. requires 4 coins
# Cost 165 in Europe requires 4 coins
# Cost 166  in U.S. requires 5 coins
# Cost 166 in Europe requires 5 coins
# Cost 167  in U.S. requires 6 coins
# Cost 167 in Europe requires 5 coins
# Cost 168  in U.S. requires 7 coins
# Cost 168 in Europe requires 6 coins
# Cost 169  in U.S. requires 8 coins
# Cost 169 in Europe requires 6 coins
# Cost 170  in U.S. requires 4 coins
# Cost 170 in Europe requires 3 coins
# Cost 171  in U.S. requires 5 coins
# Cost 171 in Europe requires 4 coins
# Cost 172  in U.S. requires 6 coins
# Cost 172 in Europe requires 4 coins
# Cost 173  in U.S. requires 7 coins
# Cost 173 in Europe requires 5 coins
# Cost 174  in U.S. requires 8 coins
# Cost 174 in Europe requires 5 coins
# Cost 175  in U.S. requires 3 coins
# Cost 175 in Europe requires 4 coins
# Cost 176  in U.S. requires 4 coins
# Cost 176 in Europe requires 5 coins
# Cost 177  in U.S. requires 5 coins
# Cost 177 in Europe requires 5 coins
# Cost 178  in U.S. requires 6 coins
# Cost 178 in Europe requires 6 coins
# Cost 179  in U.S. requires 7 coins
# Cost 179 in Europe requires 6 coins
# Cost 180  in U.S. requires 4 coins
# Cost 180 in Europe requires 4 coins
# Cost 181  in U.S. requires 5 coins
# Cost 181 in Europe requires 5 coins
# Cost 182  in U.S. requires 6 coins
# Cost 182 in Europe requires 5 coins
# Cost 183  in U.S. requires 7 coins
# Cost 183 in Europe requires 6 coins
# Cost 184  in U.S. requires 8 coins
# Cost 184 in Europe requires 6 coins
# Cost 185  in U.S. requires 4 coins
# Cost 185 in Europe requires 5 coins
# Cost 186  in U.S. requires 5 coins
# Cost 186 in Europe requires 6 coins
# Cost 187  in U.S. requires 6 coins
# Cost 187 in Europe requires 6 coins
# Cost 188  in U.S. requires 7 coins
# Cost 188 in Europe requires 7 coins
# Cost 189  in U.S. requires 8 coins
# Cost 189 in Europe requires 7 coins
# Cost 190  in U.S. requires 5 coins
# Cost 190 in Europe requires 4 coins
# Cost 191  in U.S. requires 6 coins
# Cost 191 in Europe requires 5 coins
# Cost 192  in U.S. requires 7 coins
# Cost 192 in Europe requires 5 coins
# Cost 193  in U.S. requires 8 coins
# Cost 193 in Europe requires 6 coins
# Cost 194  in U.S. requires 9 coins
# Cost 194 in Europe requires 6 coins
# Cost 195  in U.S. requires 5 coins
# Cost 195 in Europe requires 5 coins
# Cost 196  in U.S. requires 6 coins
# Cost 196 in Europe requires 6 coins
# Cost 197  in U.S. requires 7 coins
# Cost 197 in Europe requires 6 coins
# Cost 198  in U.S. requires 8 coins
# Cost 198 in Europe requires 7 coins
# Cost 199  in U.S. requires 9 coins
# Cost 199 in Europe requires 7 coins
# Cost 200  in U.S. requires 0 coins
# Cost 200 in Europe requires 1 coins
# Cost 201  in U.S. requires 1 coins
# Cost 201 in Europe requires 2 coins
# Cost 202  in U.S. requires 2 coins
# Cost 202 in Europe requires 2 coins
# Cost 203  in U.S. requires 3 coins
# Cost 203 in Europe requires 3 coins
# Cost 204  in U.S. requires 4 coins
# Cost 204 in Europe requires 3 coins
# Cost 205  in U.S. requires 1 coins
# Cost 205 in Europe requires 2 coins
# Cost 206  in U.S. requires 2 coins
# Cost 206 in Europe requires 3 coins
# Cost 207  in U.S. requires 3 coins
# Cost 207 in Europe requires 3 coins
# Cost 208  in U.S. requires 4 coins
# Cost 208 in Europe requires 4 coins
# Cost 209  in U.S. requires 5 coins
# Cost 209 in Europe requires 4 coins
# Cost 210  in U.S. requires 1 coins
# Cost 210 in Europe requires 2 coins
# Cost 211  in U.S. requires 2 coins
# Cost 211 in Europe requires 3 coins
# Cost 212  in U.S. requires 3 coins
# Cost 212 in Europe requires 3 coins
# Cost 213  in U.S. requires 4 coins
# Cost 213 in Europe requires 4 coins
# Cost 214  in U.S. requires 5 coins
# Cost 214 in Europe requires 4 coins
# Cost 215  in U.S. requires 2 coins
# Cost 215 in Europe requires 3 coins
# Cost 216  in U.S. requires 3 coins
# Cost 216 in Europe requires 4 coins
# Cost 217  in U.S. requires 4 coins
# Cost 217 in Europe requires 4 coins
# Cost 218  in U.S. requires 5 coins
# Cost 218 in Europe requires 5 coins
# Cost 219  in U.S. requires 6 coins
# Cost 219 in Europe requires 5 coins
# Cost 220  in U.S. requires 2 coins
# Cost 220 in Europe requires 2 coins
# Cost 221  in U.S. requires 3 coins
# Cost 221 in Europe requires 3 coins
# Cost 222  in U.S. requires 4 coins
# Cost 222 in Europe requires 3 coins
# Cost 223  in U.S. requires 5 coins
# Cost 223 in Europe requires 4 coins
# Cost 224  in U.S. requires 6 coins
# Cost 224 in Europe requires 4 coins
# Cost 225  in U.S. requires 1 coins
# Cost 225 in Europe requires 3 coins
# Cost 226  in U.S. requires 2 coins
# Cost 226 in Europe requires 4 coins
# Cost 227  in U.S. requires 3 coins
# Cost 227 in Europe requires 4 coins
# Cost 228  in U.S. requires 4 coins
# Cost 228 in Europe requires 5 coins
# Cost 229  in U.S. requires 5 coins
# Cost 229 in Europe requires 5 coins
# Cost 230  in U.S. requires 2 coins
# Cost 230 in Europe requires 3 coins
# Cost 231  in U.S. requires 3 coins
# Cost 231 in Europe requires 4 coins
# Cost 232  in U.S. requires 4 coins
# Cost 232 in Europe requires 4 coins
# Cost 233  in U.S. requires 5 coins
# Cost 233 in Europe requires 5 coins
# Cost 234  in U.S. requires 6 coins
# Cost 234 in Europe requires 5 coins
# Cost 235  in U.S. requires 2 coins
# Cost 235 in Europe requires 4 coins
# Cost 236  in U.S. requires 3 coins
# Cost 236 in Europe requires 5 coins
# Cost 237  in U.S. requires 4 coins
# Cost 237 in Europe requires 5 coins
# Cost 238  in U.S. requires 5 coins
# Cost 238 in Europe requires 6 coins
# Cost 239  in U.S. requires 6 coins
# Cost 239 in Europe requires 6 coins
# Cost 240  in U.S. requires 3 coins
# Cost 240 in Europe requires 3 coins
# Cost 241  in U.S. requires 4 coins
# Cost 241 in Europe requires 4 coins
# Cost 242  in U.S. requires 5 coins
# Cost 242 in Europe requires 4 coins
# Cost 243  in U.S. requires 6 coins
# Cost 243 in Europe requires 5 coins
# Cost 244  in U.S. requires 7 coins
# Cost 244 in Europe requires 5 coins
# Cost 245  in U.S. requires 3 coins
# Cost 245 in Europe requires 4 coins
# Cost 246  in U.S. requires 4 coins
# Cost 246 in Europe requires 5 coins
# Cost 247  in U.S. requires 5 coins
# Cost 247 in Europe requires 5 coins
# Cost 248  in U.S. requires 6 coins
# Cost 248 in Europe requires 6 coins
# Cost 249  in U.S. requires 7 coins
# Cost 249 in Europe requires 6 coins
# Cost 250  in U.S. requires 2 coins
# Cost 250 in Europe requires 2 coins
# Cost 251  in U.S. requires 3 coins
# Cost 251 in Europe requires 3 coins
# Cost 252  in U.S. requires 4 coins
# Cost 252 in Europe requires 3 coins
# Cost 253  in U.S. requires 5 coins
# Cost 253 in Europe requires 4 coins
# Cost 254  in U.S. requires 6 coins
# Cost 254 in Europe requires 4 coins
# Cost 255  in U.S. requires 3 coins
# Cost 255 in Europe requires 3 coins
# Cost 256  in U.S. requires 4 coins
# Cost 256 in Europe requires 4 coins
# Cost 257  in U.S. requires 5 coins
# Cost 257 in Europe requires 4 coins
# Cost 258  in U.S. requires 6 coins
# Cost 258 in Europe requires 5 coins
# Cost 259  in U.S. requires 7 coins
# Cost 259 in Europe requires 5 coins
# Cost 260  in U.S. requires 3 coins
# Cost 260 in Europe requires 3 coins
# Cost 261  in U.S. requires 4 coins
# Cost 261 in Europe requires 4 coins
# Cost 262  in U.S. requires 5 coins
# Cost 262 in Europe requires 4 coins
# Cost 263  in U.S. requires 6 coins
# Cost 263 in Europe requires 5 coins
# Cost 264  in U.S. requires 7 coins
# Cost 264 in Europe requires 5 coins
# Cost 265  in U.S. requires 4 coins
# Cost 265 in Europe requires 4 coins
# Cost 266  in U.S. requires 5 coins
# Cost 266 in Europe requires 5 coins
# Cost 267  in U.S. requires 6 coins
# Cost 267 in Europe requires 5 coins
# Cost 268  in U.S. requires 7 coins
# Cost 268 in Europe requires 6 coins
# Cost 269  in U.S. requires 8 coins
# Cost 269 in Europe requires 6 coins
# Cost 270  in U.S. requires 4 coins
# Cost 270 in Europe requires 3 coins
# Cost 271  in U.S. requires 5 coins
# Cost 271 in Europe requires 4 coins
# Cost 272  in U.S. requires 6 coins
# Cost 272 in Europe requires 4 coins
# Cost 273  in U.S. requires 7 coins
# Cost 273 in Europe requires 5 coins
# Cost 274  in U.S. requires 8 coins
# Cost 274 in Europe requires 5 coins
# Cost 275  in U.S. requires 3 coins
# Cost 275 in Europe requires 4 coins
# Cost 276  in U.S. requires 4 coins
# Cost 276 in Europe requires 5 coins
# Cost 277  in U.S. requires 5 coins
# Cost 277 in Europe requires 5 coins
# Cost 278  in U.S. requires 6 coins
# Cost 278 in Europe requires 6 coins
# Cost 279  in U.S. requires 7 coins
# Cost 279 in Europe requires 6 coins
# Cost 280  in U.S. requires 4 coins
# Cost 280 in Europe requires 4 coins
# Cost 281  in U.S. requires 5 coins
# Cost 281 in Europe requires 5 coins
# Cost 282  in U.S. requires 6 coins
# Cost 282 in Europe requires 5 coins
# Cost 283  in U.S. requires 7 coins
# Cost 283 in Europe requires 6 coins
# Cost 284  in U.S. requires 8 coins
# Cost 284 in Europe requires 6 coins
# Cost 285  in U.S. requires 4 coins
# Cost 285 in Europe requires 5 coins
# Cost 286  in U.S. requires 5 coins
# Cost 286 in Europe requires 6 coins
# Cost 287  in U.S. requires 6 coins
# Cost 287 in Europe requires 6 coins
# Cost 288  in U.S. requires 7 coins
# Cost 288 in Europe requires 7 coins
# Cost 289  in U.S. requires 8 coins
# Cost 289 in Europe requires 7 coins
# Cost 290  in U.S. requires 5 coins
# Cost 290 in Europe requires 4 coins
# Cost 291  in U.S. requires 6 coins
# Cost 291 in Europe requires 5 coins
# Cost 292  in U.S. requires 7 coins
# Cost 292 in Europe requires 5 coins
# Cost 293  in U.S. requires 8 coins
# Cost 293 in Europe requires 6 coins
# Cost 294  in U.S. requires 9 coins
# Cost 294 in Europe requires 6 coins
# Cost 295  in U.S. requires 5 coins
# Cost 295 in Europe requires 5 coins
# Cost 296  in U.S. requires 6 coins
# Cost 296 in Europe requires 6 coins
# Cost 297  in U.S. requires 7 coins
# Cost 297 in Europe requires 6 coins
# Cost 298  in U.S. requires 8 coins
# Cost 298 in Europe requires 7 coins
# Cost 299  in U.S. requires 9 coins
# Cost 299 in Europe requires 7 coins
# Cost 300  in U.S. requires 0 coins
# Cost 300 in Europe requires 2 coins
# Cost 301  in U.S. requires 1 coins
# Cost 301 in Europe requires 3 coins
# Cost 302  in U.S. requires 2 coins
# Cost 302 in Europe requires 3 coins
# Cost 303  in U.S. requires 3 coins
# Cost 303 in Europe requires 4 coins
# Cost 304  in U.S. requires 4 coins
# Cost 304 in Europe requires 4 coins
# Cost 305  in U.S. requires 1 coins
# Cost 305 in Europe requires 3 coins
# Cost 306  in U.S. requires 2 coins
# Cost 306 in Europe requires 4 coins
# Cost 307  in U.S. requires 3 coins
# Cost 307 in Europe requires 4 coins
# Cost 308  in U.S. requires 4 coins
# Cost 308 in Europe requires 5 coins
# Cost 309  in U.S. requires 5 coins
# Cost 309 in Europe requires 5 coins
# Cost 310  in U.S. requires 1 coins
# Cost 310 in Europe requires 3 coins
# Cost 311  in U.S. requires 2 coins
# Cost 311 in Europe requires 4 coins
# Cost 312  in U.S. requires 3 coins
# Cost 312 in Europe requires 4 coins
# Cost 313  in U.S. requires 4 coins
# Cost 313 in Europe requires 5 coins
# Cost 314  in U.S. requires 5 coins
# Cost 314 in Europe requires 5 coins
# Cost 315  in U.S. requires 2 coins
# Cost 315 in Europe requires 4 coins
# Cost 316  in U.S. requires 3 coins
# Cost 316 in Europe requires 5 coins
# Cost 317  in U.S. requires 4 coins
# Cost 317 in Europe requires 5 coins
# Cost 318  in U.S. requires 5 coins
# Cost 318 in Europe requires 6 coins
# Cost 319  in U.S. requires 6 coins
# Cost 319 in Europe requires 6 coins
# Cost 320  in U.S. requires 2 coins
# Cost 320 in Europe requires 3 coins
# Cost 321  in U.S. requires 3 coins
# Cost 321 in Europe requires 4 coins
# Cost 322  in U.S. requires 4 coins
# Cost 322 in Europe requires 4 coins
# Cost 323  in U.S. requires 5 coins
# Cost 323 in Europe requires 5 coins
# Cost 324  in U.S. requires 6 coins
# Cost 324 in Europe requires 5 coins
# Cost 325  in U.S. requires 1 coins
# Cost 325 in Europe requires 4 coins
# Cost 326  in U.S. requires 2 coins
# Cost 326 in Europe requires 5 coins
# Cost 327  in U.S. requires 3 coins
# Cost 327 in Europe requires 5 coins
# Cost 328  in U.S. requires 4 coins
# Cost 328 in Europe requires 6 coins
# Cost 329  in U.S. requires 5 coins
# Cost 329 in Europe requires 6 coins
# Cost 330  in U.S. requires 2 coins
# Cost 330 in Europe requires 4 coins
# Cost 331  in U.S. requires 3 coins
# Cost 331 in Europe requires 5 coins
# Cost 332  in U.S. requires 4 coins
# Cost 332 in Europe requires 5 coins
# Cost 333  in U.S. requires 5 coins
# Cost 333 in Europe requires 6 coins
# Cost 334  in U.S. requires 6 coins
# Cost 334 in Europe requires 6 coins
# Cost 335  in U.S. requires 2 coins
# Cost 335 in Europe requires 5 coins
# Cost 336  in U.S. requires 3 coins
# Cost 336 in Europe requires 6 coins
# Cost 337  in U.S. requires 4 coins
# Cost 337 in Europe requires 6 coins
# Cost 338  in U.S. requires 5 coins
# Cost 338 in Europe requires 7 coins
# Cost 339  in U.S. requires 6 coins
# Cost 339 in Europe requires 7 coins
# Cost 340  in U.S. requires 3 coins
# Cost 340 in Europe requires 4 coins
# Cost 341  in U.S. requires 4 coins
# Cost 341 in Europe requires 5 coins
# Cost 342  in U.S. requires 5 coins
# Cost 342 in Europe requires 5 coins
# Cost 343  in U.S. requires 6 coins
# Cost 343 in Europe requires 6 coins
# Cost 344  in U.S. requires 7 coins
# Cost 344 in Europe requires 6 coins
# Cost 345  in U.S. requires 3 coins
# Cost 345 in Europe requires 5 coins
# Cost 346  in U.S. requires 4 coins
# Cost 346 in Europe requires 6 coins
# Cost 347  in U.S. requires 5 coins
# Cost 347 in Europe requires 6 coins
# Cost 348  in U.S. requires 6 coins
# Cost 348 in Europe requires 7 coins
# Cost 349  in U.S. requires 7 coins
# Cost 349 in Europe requires 7 coins
# Cost 350  in U.S. requires 2 coins
# Cost 350 in Europe requires 3 coins
# Cost 351  in U.S. requires 3 coins
# Cost 351 in Europe requires 4 coins
# Cost 352  in U.S. requires 4 coins
# Cost 352 in Europe requires 4 coins
# Cost 353  in U.S. requires 5 coins
# Cost 353 in Europe requires 5 coins
# Cost 354  in U.S. requires 6 coins
# Cost 354 in Europe requires 5 coins
# Cost 355  in U.S. requires 3 coins
# Cost 355 in Europe requires 4 coins
# Cost 356  in U.S. requires 4 coins
# Cost 356 in Europe requires 5 coins
# Cost 357  in U.S. requires 5 coins
# Cost 357 in Europe requires 5 coins
# Cost 358  in U.S. requires 6 coins
# Cost 358 in Europe requires 6 coins
# Cost 359  in U.S. requires 7 coins
# Cost 359 in Europe requires 6 coins
# Cost 360  in U.S. requires 3 coins
# Cost 360 in Europe requires 4 coins
# Cost 361  in U.S. requires 4 coins
# Cost 361 in Europe requires 5 coins
# Cost 362  in U.S. requires 5 coins
# Cost 362 in Europe requires 5 coins
# Cost 363  in U.S. requires 6 coins
# Cost 363 in Europe requires 6 coins
# Cost 364  in U.S. requires 7 coins
# Cost 364 in Europe requires 6 coins
# Cost 365  in U.S. requires 4 coins
# Cost 365 in Europe requires 5 coins
# Cost 366  in U.S. requires 5 coins
# Cost 366 in Europe requires 6 coins
# Cost 367  in U.S. requires 6 coins
# Cost 367 in Europe requires 6 coins
# Cost 368  in U.S. requires 7 coins
# Cost 368 in Europe requires 7 coins
# Cost 369  in U.S. requires 8 coins
# Cost 369 in Europe requires 7 coins
# Cost 370  in U.S. requires 4 coins
# Cost 370 in Europe requires 4 coins
# Cost 371  in U.S. requires 5 coins
# Cost 371 in Europe requires 5 coins
# Cost 372  in U.S. requires 6 coins
# Cost 372 in Europe requires 5 coins
# Cost 373  in U.S. requires 7 coins
# Cost 373 in Europe requires 6 coins
# Cost 374  in U.S. requires 8 coins
# Cost 374 in Europe requires 6 coins
# Cost 375  in U.S. requires 3 coins
# Cost 375 in Europe requires 5 coins
# Cost 376  in U.S. requires 4 coins
# Cost 376 in Europe requires 6 coins
# Cost 377  in U.S. requires 5 coins
# Cost 377 in Europe requires 6 coins
# Cost 378  in U.S. requires 6 coins
# Cost 378 in Europe requires 7 coins
# Cost 379  in U.S. requires 7 coins
# Cost 379 in Europe requires 7 coins
# Cost 380  in U.S. requires 4 coins
# Cost 380 in Europe requires 5 coins
# Cost 381  in U.S. requires 5 coins
# Cost 381 in Europe requires 6 coins
# Cost 382  in U.S. requires 6 coins
# Cost 382 in Europe requires 6 coins
# Cost 383  in U.S. requires 7 coins
# Cost 383 in Europe requires 7 coins
# Cost 384  in U.S. requires 8 coins
# Cost 384 in Europe requires 7 coins
# Cost 385  in U.S. requires 4 coins
# Cost 385 in Europe requires 6 coins
# Cost 386  in U.S. requires 5 coins
# Cost 386 in Europe requires 7 coins
# Cost 387  in U.S. requires 6 coins
# Cost 387 in Europe requires 7 coins
# Cost 388  in U.S. requires 7 coins
# Cost 388 in Europe requires 8 coins
# Cost 389  in U.S. requires 8 coins
# Cost 389 in Europe requires 8 coins
# Cost 390  in U.S. requires 5 coins
# Cost 390 in Europe requires 5 coins
# Cost 391  in U.S. requires 6 coins
# Cost 391 in Europe requires 6 coins
# Cost 392  in U.S. requires 7 coins
# Cost 392 in Europe requires 6 coins
# Cost 393  in U.S. requires 8 coins
# Cost 393 in Europe requires 7 coins
# Cost 394  in U.S. requires 9 coins
# Cost 394 in Europe requires 7 coins
# Cost 395  in U.S. requires 5 coins
# Cost 395 in Europe requires 6 coins
# Cost 396  in U.S. requires 6 coins
# Cost 396 in Europe requires 7 coins
# Cost 397  in U.S. requires 7 coins
# Cost 397 in Europe requires 7 coins
# Cost 398  in U.S. requires 8 coins
# Cost 398 in Europe requires 8 coins
# Cost 399  in U.S. requires 9 coins
# Cost 399 in Europe requires 8 coins
# Cost 400  in U.S. requires 0 coins
# Cost 400 in Europe requires 2 coins
# Cost 401  in U.S. requires 1 coins
# Cost 401 in Europe requires 3 coins
# Cost 402  in U.S. requires 2 coins
# Cost 402 in Europe requires 3 coins
# Cost 403  in U.S. requires 3 coins
# Cost 403 in Europe requires 4 coins
# Cost 404  in U.S. requires 4 coins
# Cost 404 in Europe requires 4 coins
# Cost 405  in U.S. requires 1 coins
# Cost 405 in Europe requires 3 coins
# Cost 406  in U.S. requires 2 coins
# Cost 406 in Europe requires 4 coins
# Cost 407  in U.S. requires 3 coins
# Cost 407 in Europe requires 4 coins
# Cost 408  in U.S. requires 4 coins
# Cost 408 in Europe requires 5 coins
# Cost 409  in U.S. requires 5 coins
# Cost 409 in Europe requires 5 coins
# Cost 410  in U.S. requires 1 coins
# Cost 410 in Europe requires 3 coins
# Cost 411  in U.S. requires 2 coins
# Cost 411 in Europe requires 4 coins
# Cost 412  in U.S. requires 3 coins
# Cost 412 in Europe requires 4 coins
# Cost 413  in U.S. requires 4 coins
# Cost 413 in Europe requires 5 coins
# Cost 414  in U.S. requires 5 coins
# Cost 414 in Europe requires 5 coins
# Cost 415  in U.S. requires 2 coins
# Cost 415 in Europe requires 4 coins
# Cost 416  in U.S. requires 3 coins
# Cost 416 in Europe requires 5 coins
# Cost 417  in U.S. requires 4 coins
# Cost 417 in Europe requires 5 coins
# Cost 418  in U.S. requires 5 coins
# Cost 418 in Europe requires 6 coins
# Cost 419  in U.S. requires 6 coins
# Cost 419 in Europe requires 6 coins
# Cost 420  in U.S. requires 2 coins
# Cost 420 in Europe requires 3 coins
# Cost 421  in U.S. requires 3 coins
# Cost 421 in Europe requires 4 coins
# Cost 422  in U.S. requires 4 coins
# Cost 422 in Europe requires 4 coins
# Cost 423  in U.S. requires 5 coins
# Cost 423 in Europe requires 5 coins
# Cost 424  in U.S. requires 6 coins
# Cost 424 in Europe requires 5 coins
# Cost 425  in U.S. requires 1 coins
# Cost 425 in Europe requires 4 coins
# Cost 426  in U.S. requires 2 coins
# Cost 426 in Europe requires 5 coins
# Cost 427  in U.S. requires 3 coins
# Cost 427 in Europe requires 5 coins
# Cost 428  in U.S. requires 4 coins
# Cost 428 in Europe requires 6 coins
# Cost 429  in U.S. requires 5 coins
# Cost 429 in Europe requires 6 coins
# Cost 430  in U.S. requires 2 coins
# Cost 430 in Europe requires 4 coins
# Cost 431  in U.S. requires 3 coins
# Cost 431 in Europe requires 5 coins
# Cost 432  in U.S. requires 4 coins
# Cost 432 in Europe requires 5 coins
# Cost 433  in U.S. requires 5 coins
# Cost 433 in Europe requires 6 coins
# Cost 434  in U.S. requires 6 coins
# Cost 434 in Europe requires 6 coins
# Cost 435  in U.S. requires 2 coins
# Cost 435 in Europe requires 5 coins
# Cost 436  in U.S. requires 3 coins
# Cost 436 in Europe requires 6 coins
# Cost 437  in U.S. requires 4 coins
# Cost 437 in Europe requires 6 coins
# Cost 438  in U.S. requires 5 coins
# Cost 438 in Europe requires 7 coins
# Cost 439  in U.S. requires 6 coins
# Cost 439 in Europe requires 7 coins
# Cost 440  in U.S. requires 3 coins
# Cost 440 in Europe requires 4 coins
# Cost 441  in U.S. requires 4 coins
# Cost 441 in Europe requires 5 coins
# Cost 442  in U.S. requires 5 coins
# Cost 442 in Europe requires 5 coins
# Cost 443  in U.S. requires 6 coins
# Cost 443 in Europe requires 6 coins
# Cost 444  in U.S. requires 7 coins
# Cost 444 in Europe requires 6 coins
# Cost 445  in U.S. requires 3 coins
# Cost 445 in Europe requires 5 coins
# Cost 446  in U.S. requires 4 coins
# Cost 446 in Europe requires 6 coins
# Cost 447  in U.S. requires 5 coins
# Cost 447 in Europe requires 6 coins
# Cost 448  in U.S. requires 6 coins
# Cost 448 in Europe requires 7 coins
# Cost 449  in U.S. requires 7 coins
# Cost 449 in Europe requires 7 coins
# Cost 450  in U.S. requires 2 coins
# Cost 450 in Europe requires 3 coins
# Cost 451  in U.S. requires 3 coins
# Cost 451 in Europe requires 4 coins
# Cost 452  in U.S. requires 4 coins
# Cost 452 in Europe requires 4 coins
# Cost 453  in U.S. requires 5 coins
# Cost 453 in Europe requires 5 coins
# Cost 454  in U.S. requires 6 coins
# Cost 454 in Europe requires 5 coins
# Cost 455  in U.S. requires 3 coins
# Cost 455 in Europe requires 4 coins
# Cost 456  in U.S. requires 4 coins
# Cost 456 in Europe requires 5 coins
# Cost 457  in U.S. requires 5 coins
# Cost 457 in Europe requires 5 coins
# Cost 458  in U.S. requires 6 coins
# Cost 458 in Europe requires 6 coins
# Cost 459  in U.S. requires 7 coins
# Cost 459 in Europe requires 6 coins
# Cost 460  in U.S. requires 3 coins
# Cost 460 in Europe requires 4 coins
# Cost 461  in U.S. requires 4 coins
# Cost 461 in Europe requires 5 coins
# Cost 462  in U.S. requires 5 coins
# Cost 462 in Europe requires 5 coins
# Cost 463  in U.S. requires 6 coins
# Cost 463 in Europe requires 6 coins
# Cost 464  in U.S. requires 7 coins
# Cost 464 in Europe requires 6 coins
# Cost 465  in U.S. requires 4 coins
# Cost 465 in Europe requires 5 coins
# Cost 466  in U.S. requires 5 coins
# Cost 466 in Europe requires 6 coins
# Cost 467  in U.S. requires 6 coins
# Cost 467 in Europe requires 6 coins
# Cost 468  in U.S. requires 7 coins
# Cost 468 in Europe requires 7 coins
# Cost 469  in U.S. requires 8 coins
# Cost 469 in Europe requires 7 coins
# Cost 470  in U.S. requires 4 coins
# Cost 470 in Europe requires 4 coins
# Cost 471  in U.S. requires 5 coins
# Cost 471 in Europe requires 5 coins
# Cost 472  in U.S. requires 6 coins
# Cost 472 in Europe requires 5 coins
# Cost 473  in U.S. requires 7 coins
# Cost 473 in Europe requires 6 coins
# Cost 474  in U.S. requires 8 coins
# Cost 474 in Europe requires 6 coins
# Cost 475  in U.S. requires 3 coins
# Cost 475 in Europe requires 5 coins
# Cost 476  in U.S. requires 4 coins
# Cost 476 in Europe requires 6 coins
# Cost 477  in U.S. requires 5 coins
# Cost 477 in Europe requires 6 coins
# Cost 478  in U.S. requires 6 coins
# Cost 478 in Europe requires 7 coins
# Cost 479  in U.S. requires 7 coins
# Cost 479 in Europe requires 7 coins
# Cost 480  in U.S. requires 4 coins
# Cost 480 in Europe requires 5 coins
# Cost 481  in U.S. requires 5 coins
# Cost 481 in Europe requires 6 coins
# Cost 482  in U.S. requires 6 coins
# Cost 482 in Europe requires 6 coins
# Cost 483  in U.S. requires 7 coins
# Cost 483 in Europe requires 7 coins
# Cost 484  in U.S. requires 8 coins
# Cost 484 in Europe requires 7 coins
# Cost 485  in U.S. requires 4 coins
# Cost 485 in Europe requires 6 coins
# Cost 486  in U.S. requires 5 coins
# Cost 486 in Europe requires 7 coins
# Cost 487  in U.S. requires 6 coins
# Cost 487 in Europe requires 7 coins
# Cost 488  in U.S. requires 7 coins
# Cost 488 in Europe requires 8 coins
# Cost 489  in U.S. requires 8 coins
# Cost 489 in Europe requires 8 coins
# Cost 490  in U.S. requires 5 coins
# Cost 490 in Europe requires 5 coins
# Cost 491  in U.S. requires 6 coins
# Cost 491 in Europe requires 6 coins
# Cost 492  in U.S. requires 7 coins
# Cost 492 in Europe requires 6 coins
# Cost 493  in U.S. requires 8 coins
# Cost 493 in Europe requires 7 coins
# Cost 494  in U.S. requires 9 coins
# Cost 494 in Europe requires 7 coins
# Cost 495  in U.S. requires 5 coins
# Cost 495 in Europe requires 6 coins
# Cost 496  in U.S. requires 6 coins
# Cost 496 in Europe requires 7 coins
# Cost 497  in U.S. requires 7 coins
# Cost 497 in Europe requires 7 coins
# Cost 498  in U.S. requires 8 coins
# Cost 498 in Europe requires 8 coins
# Cost 499  in U.S. requires 9 coins
# Cost 499 in Europe requires 8 coins

# %%
import matplotlib.pyplot as plt
plt.plot(cost_array, n_coins_us, 'o', label="U.S.")
plt.plot(cost_array, n_coins_euro, 'o', label="Euro")
plt.xlabel("Cost")
plt.ylabel("Number of Coins")
plt.legend()
plt.show()

# %%
import numpy as np
print("The U.S. coin system requires %.2f coins, on average." % np.mean(n_coins_us))
print("The Euro coin system requires %.2f coins, on average." % np.mean(n_coins_euro))
# Out:
# The U.S. coin system requires 4.71 coins, on average.
# The Euro coin system requires 4.61 coins, on average.

# %% [markdown]
# # It's not so much the number of coins, it's the mass of the coins

# %%
mass_us = [3.11, 5, 2.268, 5.670]
mass_euro = [2.30, 3.06, 3.92, 4.10, 5.74, 7.8, 7.5, 8.5]

mass_us.reverse()
mass_euro.reverse()

print(mass_us)

n_coins_us = []
n_coins_euro = []
cost_array = []

for cost in range(1,500):
    cost_array.append(cost)
    
    n_coins = 0
    remaining = cost%100
    #print ("Starting cost", cost)
    for i in range(len(us_coins)):
        while remaining >= us_coins[i]:
            n_coins += mass_us[i]
            remaining -= us_coins[i]
            #print("Coin", coin, "remaining", remaining)
    print("Cost", cost, " in U.S. requires", n_coins, "grams")
    n_coins_us.append(n_coins)
    
    n_coins = 0
    remaining = cost
    #print ("Starting cost", cost)
    for i in range(len(euro_coins)):
        while remaining >= euro_coins[i]:
            n_coins += mass_euro[i]
            remaining -= euro_coins[i]
            #print("Coin", coin, "remaining", remaining)
    print("Cost", cost, "in Europe requires", n_coins, "grams")
    n_coins_euro.append(n_coins)
# Out:
# [5.67, 2.268, 5, 3.11]
# Cost 1  in U.S. requires 3.11 grams
# Cost 1 in Europe requires 2.3 grams
# Cost 2  in U.S. requires 6.22 grams
# Cost 2 in Europe requires 3.06 grams
# Cost 3  in U.S. requires 9.33 grams
# Cost 3 in Europe requires 5.359999999999999 grams
# Cost 4  in U.S. requires 12.44 grams
# Cost 4 in Europe requires 6.12 grams
# Cost 5  in U.S. requires 5 grams
# Cost 5 in Europe requires 3.92 grams
# Cost 6  in U.S. requires 8.11 grams
# Cost 6 in Europe requires 6.22 grams
# Cost 7  in U.S. requires 11.219999999999999 grams
# Cost 7 in Europe requires 6.98 grams
# Cost 8  in U.S. requires 14.329999999999998 grams
# Cost 8 in Europe requires 9.280000000000001 grams
# Cost 9  in U.S. requires 17.439999999999998 grams
# Cost 9 in Europe requires 10.040000000000001 grams
# Cost 10  in U.S. requires 2.268 grams
# Cost 10 in Europe requires 4.1 grams
# Cost 11  in U.S. requires 5.378 grams
# Cost 11 in Europe requires 6.3999999999999995 grams
# Cost 12  in U.S. requires 8.488 grams
# Cost 12 in Europe requires 7.16 grams
# Cost 13  in U.S. requires 11.597999999999999 grams
# Cost 13 in Europe requires 9.46 grams
# Cost 14  in U.S. requires 14.707999999999998 grams
# Cost 14 in Europe requires 10.22 grams
# Cost 15  in U.S. requires 7.268 grams
# Cost 15 in Europe requires 8.02 grams
# Cost 16  in U.S. requires 10.378 grams
# Cost 16 in Europe requires 10.32 grams
# Cost 17  in U.S. requires 13.488 grams
# Cost 17 in Europe requires 11.08 grams
# Cost 18  in U.S. requires 16.598 grams
# Cost 18 in Europe requires 13.379999999999999 grams
# Cost 19  in U.S. requires 19.708 grams
# Cost 19 in Europe requires 14.14 grams
# Cost 20  in U.S. requires 4.536 grams
# Cost 20 in Europe requires 5.74 grams
# Cost 21  in U.S. requires 7.645999999999999 grams
# Cost 21 in Europe requires 8.04 grams
# Cost 22  in U.S. requires 10.755999999999998 grams
# Cost 22 in Europe requires 8.8 grams
# Cost 23  in U.S. requires 13.865999999999998 grams
# Cost 23 in Europe requires 11.100000000000001 grams
# Cost 24  in U.S. requires 16.976 grams
# Cost 24 in Europe requires 11.860000000000001 grams
# Cost 25  in U.S. requires 5.67 grams
# Cost 25 in Europe requires 9.66 grams
# Cost 26  in U.S. requires 8.78 grams
# Cost 26 in Europe requires 11.96 grams
# Cost 27  in U.S. requires 11.889999999999999 grams
# Cost 27 in Europe requires 12.72 grams
# Cost 28  in U.S. requires 14.999999999999998 grams
# Cost 28 in Europe requires 15.02 grams
# Cost 29  in U.S. requires 18.11 grams
# Cost 29 in Europe requires 15.780000000000001 grams
# Cost 30  in U.S. requires 10.67 grams
# Cost 30 in Europe requires 9.84 grams
# Cost 31  in U.S. requires 13.78 grams
# Cost 31 in Europe requires 12.14 grams
# Cost 32  in U.S. requires 16.89 grams
# Cost 32 in Europe requires 12.9 grams
# Cost 33  in U.S. requires 20.0 grams
# Cost 33 in Europe requires 15.2 grams
# Cost 34  in U.S. requires 23.11 grams
# Cost 34 in Europe requires 15.96 grams
# Cost 35  in U.S. requires 7.938 grams
# Cost 35 in Europe requires 13.76 grams
# Cost 36  in U.S. requires 11.048 grams
# Cost 36 in Europe requires 16.06 grams
# Cost 37  in U.S. requires 14.158 grams
# Cost 37 in Europe requires 16.82 grams
# Cost 38  in U.S. requires 17.268 grams
# Cost 38 in Europe requires 19.12 grams
# Cost 39  in U.S. requires 20.378 grams
# Cost 39 in Europe requires 19.88 grams
# Cost 40  in U.S. requires 12.937999999999999 grams
# Cost 40 in Europe requires 11.48 grams
# Cost 41  in U.S. requires 16.048 grams
# Cost 41 in Europe requires 13.780000000000001 grams
# Cost 42  in U.S. requires 19.157999999999998 grams
# Cost 42 in Europe requires 14.540000000000001 grams
# Cost 43  in U.S. requires 22.267999999999997 grams
# Cost 43 in Europe requires 16.84 grams
# Cost 44  in U.S. requires 25.377999999999997 grams
# Cost 44 in Europe requires 17.6 grams
# Cost 45  in U.S. requires 10.206 grams
# Cost 45 in Europe requires 15.4 grams
# Cost 46  in U.S. requires 13.315999999999999 grams
# Cost 46 in Europe requires 17.7 grams
# Cost 47  in U.S. requires 16.426 grams
# Cost 47 in Europe requires 18.46 grams
# Cost 48  in U.S. requires 19.535999999999998 grams
# Cost 48 in Europe requires 20.76 grams
# Cost 49  in U.S. requires 22.645999999999997 grams
# Cost 49 in Europe requires 21.52 grams
# Cost 50  in U.S. requires 11.34 grams
# Cost 50 in Europe requires 7.8 grams
# Cost 51  in U.S. requires 14.45 grams
# Cost 51 in Europe requires 10.1 grams
# Cost 52  in U.S. requires 17.56 grams
# Cost 52 in Europe requires 10.86 grams
# Cost 53  in U.S. requires 20.669999999999998 grams
# Cost 53 in Europe requires 13.16 grams
# Cost 54  in U.S. requires 23.779999999999998 grams
# Cost 54 in Europe requires 13.92 grams
# Cost 55  in U.S. requires 16.34 grams
# Cost 55 in Europe requires 11.719999999999999 grams
# Cost 56  in U.S. requires 19.45 grams
# Cost 56 in Europe requires 14.02 grams
# Cost 57  in U.S. requires 22.56 grams
# Cost 57 in Europe requires 14.78 grams
# Cost 58  in U.S. requires 25.669999999999998 grams
# Cost 58 in Europe requires 17.08 grams
# Cost 59  in U.S. requires 28.779999999999998 grams
# Cost 59 in Europe requires 17.84 grams
# Cost 60  in U.S. requires 13.608 grams
# Cost 60 in Europe requires 11.899999999999999 grams
# Cost 61  in U.S. requires 16.718 grams
# Cost 61 in Europe requires 14.2 grams
# Cost 62  in U.S. requires 19.828 grams
# Cost 62 in Europe requires 14.959999999999999 grams
# Cost 63  in U.S. requires 22.938 grams
# Cost 63 in Europe requires 17.259999999999998 grams
# Cost 64  in U.S. requires 26.048 grams
# Cost 64 in Europe requires 18.02 grams
# Cost 65  in U.S. requires 18.608 grams
# Cost 65 in Europe requires 15.819999999999999 grams
# Cost 66  in U.S. requires 21.718 grams
# Cost 66 in Europe requires 18.119999999999997 grams
# Cost 67  in U.S. requires 24.828 grams
# Cost 67 in Europe requires 18.88 grams
# Cost 68  in U.S. requires 27.938 grams
# Cost 68 in Europe requires 21.18 grams
# Cost 69  in U.S. requires 31.048 grams
# Cost 69 in Europe requires 21.939999999999998 grams
# Cost 70  in U.S. requires 15.876000000000001 grams
# Cost 70 in Europe requires 13.54 grams
# Cost 71  in U.S. requires 18.986 grams
# Cost 71 in Europe requires 15.84 grams
# Cost 72  in U.S. requires 22.096 grams
# Cost 72 in Europe requires 16.599999999999998 grams
# Cost 73  in U.S. requires 25.206 grams
# Cost 73 in Europe requires 18.9 grams
# Cost 74  in U.S. requires 28.316 grams
# Cost 74 in Europe requires 19.659999999999997 grams
# Cost 75  in U.S. requires 17.009999999999998 grams
# Cost 75 in Europe requires 17.46 grams
# Cost 76  in U.S. requires 20.119999999999997 grams
# Cost 76 in Europe requires 19.76 grams
# Cost 77  in U.S. requires 23.229999999999997 grams
# Cost 77 in Europe requires 20.52 grams
# Cost 78  in U.S. requires 26.339999999999996 grams
# Cost 78 in Europe requires 22.82 grams
# Cost 79  in U.S. requires 29.449999999999996 grams
# Cost 79 in Europe requires 23.58 grams
# Cost 80  in U.S. requires 22.009999999999998 grams
# Cost 80 in Europe requires 17.64 grams
# Cost 81  in U.S. requires 25.119999999999997 grams
# Cost 81 in Europe requires 19.94 grams
# Cost 82  in U.S. requires 28.229999999999997 grams
# Cost 82 in Europe requires 20.7 grams
# Cost 83  in U.S. requires 31.339999999999996 grams
# Cost 83 in Europe requires 23.0 grams
# Cost 84  in U.S. requires 34.449999999999996 grams
# Cost 84 in Europe requires 23.759999999999998 grams
# Cost 85  in U.S. requires 19.278 grams
# Cost 85 in Europe requires 21.560000000000002 grams
# Cost 86  in U.S. requires 22.387999999999998 grams
# Cost 86 in Europe requires 23.860000000000003 grams
# Cost 87  in U.S. requires 25.497999999999998 grams
# Cost 87 in Europe requires 24.62 grams
# Cost 88  in U.S. requires 28.607999999999997 grams
# Cost 88 in Europe requires 26.92 grams
# Cost 89  in U.S. requires 31.717999999999996 grams
# Cost 89 in Europe requires 27.68 grams
# Cost 90  in U.S. requires 24.278 grams
# Cost 90 in Europe requires 19.28 grams
# Cost 91  in U.S. requires 27.387999999999998 grams
# Cost 91 in Europe requires 21.580000000000002 grams
# Cost 92  in U.S. requires 30.497999999999998 grams
# Cost 92 in Europe requires 22.34 grams
# Cost 93  in U.S. requires 33.608 grams
# Cost 93 in Europe requires 24.64 grams
# Cost 94  in U.S. requires 36.717999999999996 grams
# Cost 94 in Europe requires 25.4 grams
# Cost 95  in U.S. requires 21.546 grams
# Cost 95 in Europe requires 23.200000000000003 grams
# Cost 96  in U.S. requires 24.656 grams
# Cost 96 in Europe requires 25.500000000000004 grams
# Cost 97  in U.S. requires 27.766 grams
# Cost 97 in Europe requires 26.26 grams
# Cost 98  in U.S. requires 30.875999999999998 grams
# Cost 98 in Europe requires 28.560000000000002 grams
# Cost 99  in U.S. requires 33.986 grams
# Cost 99 in Europe requires 29.32 grams
# Cost 100  in U.S. requires 0 grams
# Cost 100 in Europe requires 7.5 grams
# Cost 101  in U.S. requires 3.11 grams
# Cost 101 in Europe requires 9.8 grams
# Cost 102  in U.S. requires 6.22 grams
# Cost 102 in Europe requires 10.56 grams
# Cost 103  in U.S. requires 9.33 grams
# Cost 103 in Europe requires 12.86 grams
# Cost 104  in U.S. requires 12.44 grams
# Cost 104 in Europe requires 13.620000000000001 grams
# Cost 105  in U.S. requires 5 grams
# Cost 105 in Europe requires 11.42 grams
# Cost 106  in U.S. requires 8.11 grams
# Cost 106 in Europe requires 13.719999999999999 grams
# Cost 107  in U.S. requires 11.219999999999999 grams
# Cost 107 in Europe requires 14.48 grams
# Cost 108  in U.S. requires 14.329999999999998 grams
# Cost 108 in Europe requires 16.78 grams
# Cost 109  in U.S. requires 17.439999999999998 grams
# Cost 109 in Europe requires 17.54 grams
# Cost 110  in U.S. requires 2.268 grams
# Cost 110 in Europe requires 11.6 grams
# Cost 111  in U.S. requires 5.378 grams
# Cost 111 in Europe requires 13.899999999999999 grams
# Cost 112  in U.S. requires 8.488 grams
# Cost 112 in Europe requires 14.66 grams
# Cost 113  in U.S. requires 11.597999999999999 grams
# Cost 113 in Europe requires 16.96 grams
# Cost 114  in U.S. requires 14.707999999999998 grams
# Cost 114 in Europe requires 17.72 grams
# Cost 115  in U.S. requires 7.268 grams
# Cost 115 in Europe requires 15.52 grams
# Cost 116  in U.S. requires 10.378 grams
# Cost 116 in Europe requires 17.82 grams
# Cost 117  in U.S. requires 13.488 grams
# Cost 117 in Europe requires 18.58 grams
# Cost 118  in U.S. requires 16.598 grams
# Cost 118 in Europe requires 20.88 grams
# Cost 119  in U.S. requires 19.708 grams
# Cost 119 in Europe requires 21.639999999999997 grams
# Cost 120  in U.S. requires 4.536 grams
# Cost 120 in Europe requires 13.24 grams
# Cost 121  in U.S. requires 7.645999999999999 grams
# Cost 121 in Europe requires 15.54 grams
# Cost 122  in U.S. requires 10.755999999999998 grams
# Cost 122 in Europe requires 16.3 grams
# Cost 123  in U.S. requires 13.865999999999998 grams
# Cost 123 in Europe requires 18.6 grams
# Cost 124  in U.S. requires 16.976 grams
# Cost 124 in Europe requires 19.36 grams
# Cost 125  in U.S. requires 5.67 grams
# Cost 125 in Europe requires 17.16 grams
# Cost 126  in U.S. requires 8.78 grams
# Cost 126 in Europe requires 19.46 grams
# Cost 127  in U.S. requires 11.889999999999999 grams
# Cost 127 in Europe requires 20.22 grams
# Cost 128  in U.S. requires 14.999999999999998 grams
# Cost 128 in Europe requires 22.52 grams
# Cost 129  in U.S. requires 18.11 grams
# Cost 129 in Europe requires 23.279999999999998 grams
# Cost 130  in U.S. requires 10.67 grams
# Cost 130 in Europe requires 17.34 grams
# Cost 131  in U.S. requires 13.78 grams
# Cost 131 in Europe requires 19.64 grams
# Cost 132  in U.S. requires 16.89 grams
# Cost 132 in Europe requires 20.4 grams
# Cost 133  in U.S. requires 20.0 grams
# Cost 133 in Europe requires 22.7 grams
# Cost 134  in U.S. requires 23.11 grams
# Cost 134 in Europe requires 23.459999999999997 grams
# Cost 135  in U.S. requires 7.938 grams
# Cost 135 in Europe requires 21.259999999999998 grams
# Cost 136  in U.S. requires 11.048 grams
# Cost 136 in Europe requires 23.56 grams
# Cost 137  in U.S. requires 14.158 grams
# Cost 137 in Europe requires 24.319999999999997 grams
# Cost 138  in U.S. requires 17.268 grams
# Cost 138 in Europe requires 26.619999999999997 grams
# Cost 139  in U.S. requires 20.378 grams
# Cost 139 in Europe requires 27.379999999999995 grams
# Cost 140  in U.S. requires 12.937999999999999 grams
# Cost 140 in Europe requires 18.98 grams
# Cost 141  in U.S. requires 16.048 grams
# Cost 141 in Europe requires 21.28 grams
# Cost 142  in U.S. requires 19.157999999999998 grams
# Cost 142 in Europe requires 22.04 grams
# Cost 143  in U.S. requires 22.267999999999997 grams
# Cost 143 in Europe requires 24.34 grams
# Cost 144  in U.S. requires 25.377999999999997 grams
# Cost 144 in Europe requires 25.099999999999998 grams
# Cost 145  in U.S. requires 10.206 grams
# Cost 145 in Europe requires 22.9 grams
# Cost 146  in U.S. requires 13.315999999999999 grams
# Cost 146 in Europe requires 25.2 grams
# Cost 147  in U.S. requires 16.426 grams
# Cost 147 in Europe requires 25.959999999999997 grams
# Cost 148  in U.S. requires 19.535999999999998 grams
# Cost 148 in Europe requires 28.259999999999998 grams
# Cost 149  in U.S. requires 22.645999999999997 grams
# Cost 149 in Europe requires 29.019999999999996 grams
# Cost 150  in U.S. requires 11.34 grams
# Cost 150 in Europe requires 15.3 grams
# Cost 151  in U.S. requires 14.45 grams
# Cost 151 in Europe requires 17.6 grams
# Cost 152  in U.S. requires 17.56 grams
# Cost 152 in Europe requires 18.36 grams
# Cost 153  in U.S. requires 20.669999999999998 grams
# Cost 153 in Europe requires 20.66 grams
# Cost 154  in U.S. requires 23.779999999999998 grams
# Cost 154 in Europe requires 21.419999999999998 grams
# Cost 155  in U.S. requires 16.34 grams
# Cost 155 in Europe requires 19.22 grams
# Cost 156  in U.S. requires 19.45 grams
# Cost 156 in Europe requires 21.52 grams
# Cost 157  in U.S. requires 22.56 grams
# Cost 157 in Europe requires 22.279999999999998 grams
# Cost 158  in U.S. requires 25.669999999999998 grams
# Cost 158 in Europe requires 24.58 grams
# Cost 159  in U.S. requires 28.779999999999998 grams
# Cost 159 in Europe requires 25.339999999999996 grams
# Cost 160  in U.S. requires 13.608 grams
# Cost 160 in Europe requires 19.4 grams
# Cost 161  in U.S. requires 16.718 grams
# Cost 161 in Europe requires 21.7 grams
# Cost 162  in U.S. requires 19.828 grams
# Cost 162 in Europe requires 22.459999999999997 grams
# Cost 163  in U.S. requires 22.938 grams
# Cost 163 in Europe requires 24.759999999999998 grams
# Cost 164  in U.S. requires 26.048 grams
# Cost 164 in Europe requires 25.519999999999996 grams
# Cost 165  in U.S. requires 18.608 grams
# Cost 165 in Europe requires 23.32 grams
# Cost 166  in U.S. requires 21.718 grams
# Cost 166 in Europe requires 25.62 grams
# Cost 167  in U.S. requires 24.828 grams
# Cost 167 in Europe requires 26.38 grams
# Cost 168  in U.S. requires 27.938 grams
# Cost 168 in Europe requires 28.68 grams
# Cost 169  in U.S. requires 31.048 grams
# Cost 169 in Europe requires 29.439999999999998 grams
# Cost 170  in U.S. requires 15.876000000000001 grams
# Cost 170 in Europe requires 21.04 grams
# Cost 171  in U.S. requires 18.986 grams
# Cost 171 in Europe requires 23.34 grams
# Cost 172  in U.S. requires 22.096 grams
# Cost 172 in Europe requires 24.099999999999998 grams
# Cost 173  in U.S. requires 25.206 grams
# Cost 173 in Europe requires 26.4 grams
# Cost 174  in U.S. requires 28.316 grams
# Cost 174 in Europe requires 27.159999999999997 grams
# Cost 175  in U.S. requires 17.009999999999998 grams
# Cost 175 in Europe requires 24.96 grams
# Cost 176  in U.S. requires 20.119999999999997 grams
# Cost 176 in Europe requires 27.26 grams
# Cost 177  in U.S. requires 23.229999999999997 grams
# Cost 177 in Europe requires 28.02 grams
# Cost 178  in U.S. requires 26.339999999999996 grams
# Cost 178 in Europe requires 30.32 grams
# Cost 179  in U.S. requires 29.449999999999996 grams
# Cost 179 in Europe requires 31.08 grams
# Cost 180  in U.S. requires 22.009999999999998 grams
# Cost 180 in Europe requires 25.14 grams
# Cost 181  in U.S. requires 25.119999999999997 grams
# Cost 181 in Europe requires 27.44 grams
# Cost 182  in U.S. requires 28.229999999999997 grams
# Cost 182 in Europe requires 28.2 grams
# Cost 183  in U.S. requires 31.339999999999996 grams
# Cost 183 in Europe requires 30.5 grams
# Cost 184  in U.S. requires 34.449999999999996 grams
# Cost 184 in Europe requires 31.259999999999998 grams
# Cost 185  in U.S. requires 19.278 grams
# Cost 185 in Europe requires 29.060000000000002 grams
# Cost 186  in U.S. requires 22.387999999999998 grams
# Cost 186 in Europe requires 31.360000000000003 grams
# Cost 187  in U.S. requires 25.497999999999998 grams
# Cost 187 in Europe requires 32.120000000000005 grams
# Cost 188  in U.S. requires 28.607999999999997 grams
# Cost 188 in Europe requires 34.42 grams
# Cost 189  in U.S. requires 31.717999999999996 grams
# Cost 189 in Europe requires 35.18000000000001 grams
# Cost 190  in U.S. requires 24.278 grams
# Cost 190 in Europe requires 26.78 grams
# Cost 191  in U.S. requires 27.387999999999998 grams
# Cost 191 in Europe requires 29.080000000000002 grams
# Cost 192  in U.S. requires 30.497999999999998 grams
# Cost 192 in Europe requires 29.84 grams
# Cost 193  in U.S. requires 33.608 grams
# Cost 193 in Europe requires 32.14 grams
# Cost 194  in U.S. requires 36.717999999999996 grams
# Cost 194 in Europe requires 32.9 grams
# Cost 195  in U.S. requires 21.546 grams
# Cost 195 in Europe requires 30.700000000000003 grams
# Cost 196  in U.S. requires 24.656 grams
# Cost 196 in Europe requires 33.0 grams
# Cost 197  in U.S. requires 27.766 grams
# Cost 197 in Europe requires 33.760000000000005 grams
# Cost 198  in U.S. requires 30.875999999999998 grams
# Cost 198 in Europe requires 36.06 grams
# Cost 199  in U.S. requires 33.986 grams
# Cost 199 in Europe requires 36.82000000000001 grams
# Cost 200  in U.S. requires 0 grams
# Cost 200 in Europe requires 8.5 grams
# Cost 201  in U.S. requires 3.11 grams
# Cost 201 in Europe requires 10.8 grams
# Cost 202  in U.S. requires 6.22 grams
# Cost 202 in Europe requires 11.56 grams
# Cost 203  in U.S. requires 9.33 grams
# Cost 203 in Europe requires 13.86 grams
# Cost 204  in U.S. requires 12.44 grams
# Cost 204 in Europe requires 14.620000000000001 grams
# Cost 205  in U.S. requires 5 grams
# Cost 205 in Europe requires 12.42 grams
# Cost 206  in U.S. requires 8.11 grams
# Cost 206 in Europe requires 14.719999999999999 grams
# Cost 207  in U.S. requires 11.219999999999999 grams
# Cost 207 in Europe requires 15.48 grams
# Cost 208  in U.S. requires 14.329999999999998 grams
# Cost 208 in Europe requires 17.78 grams
# Cost 209  in U.S. requires 17.439999999999998 grams
# Cost 209 in Europe requires 18.54 grams
# Cost 210  in U.S. requires 2.268 grams
# Cost 210 in Europe requires 12.6 grams
# Cost 211  in U.S. requires 5.378 grams
# Cost 211 in Europe requires 14.899999999999999 grams
# Cost 212  in U.S. requires 8.488 grams
# Cost 212 in Europe requires 15.66 grams
# Cost 213  in U.S. requires 11.597999999999999 grams
# Cost 213 in Europe requires 17.96 grams
# Cost 214  in U.S. requires 14.707999999999998 grams
# Cost 214 in Europe requires 18.72 grams
# Cost 215  in U.S. requires 7.268 grams
# Cost 215 in Europe requires 16.52 grams
# Cost 216  in U.S. requires 10.378 grams
# Cost 216 in Europe requires 18.82 grams
# Cost 217  in U.S. requires 13.488 grams
# Cost 217 in Europe requires 19.58 grams
# Cost 218  in U.S. requires 16.598 grams
# Cost 218 in Europe requires 21.88 grams
# Cost 219  in U.S. requires 19.708 grams
# Cost 219 in Europe requires 22.639999999999997 grams
# Cost 220  in U.S. requires 4.536 grams
# Cost 220 in Europe requires 14.24 grams
# Cost 221  in U.S. requires 7.645999999999999 grams
# Cost 221 in Europe requires 16.54 grams
# Cost 222  in U.S. requires 10.755999999999998 grams
# Cost 222 in Europe requires 17.3 grams
# Cost 223  in U.S. requires 13.865999999999998 grams
# Cost 223 in Europe requires 19.6 grams
# Cost 224  in U.S. requires 16.976 grams
# Cost 224 in Europe requires 20.36 grams
# Cost 225  in U.S. requires 5.67 grams
# Cost 225 in Europe requires 18.16 grams
# Cost 226  in U.S. requires 8.78 grams
# Cost 226 in Europe requires 20.46 grams
# Cost 227  in U.S. requires 11.889999999999999 grams
# Cost 227 in Europe requires 21.22 grams
# Cost 228  in U.S. requires 14.999999999999998 grams
# Cost 228 in Europe requires 23.52 grams
# Cost 229  in U.S. requires 18.11 grams
# Cost 229 in Europe requires 24.279999999999998 grams
# Cost 230  in U.S. requires 10.67 grams
# Cost 230 in Europe requires 18.34 grams
# Cost 231  in U.S. requires 13.78 grams
# Cost 231 in Europe requires 20.64 grams
# Cost 232  in U.S. requires 16.89 grams
# Cost 232 in Europe requires 21.4 grams
# Cost 233  in U.S. requires 20.0 grams
# Cost 233 in Europe requires 23.7 grams
# Cost 234  in U.S. requires 23.11 grams
# Cost 234 in Europe requires 24.459999999999997 grams
# Cost 235  in U.S. requires 7.938 grams
# Cost 235 in Europe requires 22.259999999999998 grams
# Cost 236  in U.S. requires 11.048 grams
# Cost 236 in Europe requires 24.56 grams
# Cost 237  in U.S. requires 14.158 grams
# Cost 237 in Europe requires 25.319999999999997 grams
# Cost 238  in U.S. requires 17.268 grams
# Cost 238 in Europe requires 27.619999999999997 grams
# Cost 239  in U.S. requires 20.378 grams
# Cost 239 in Europe requires 28.379999999999995 grams
# Cost 240  in U.S. requires 12.937999999999999 grams
# Cost 240 in Europe requires 19.98 grams
# Cost 241  in U.S. requires 16.048 grams
# Cost 241 in Europe requires 22.28 grams
# Cost 242  in U.S. requires 19.157999999999998 grams
# Cost 242 in Europe requires 23.04 grams
# Cost 243  in U.S. requires 22.267999999999997 grams
# Cost 243 in Europe requires 25.34 grams
# Cost 244  in U.S. requires 25.377999999999997 grams
# Cost 244 in Europe requires 26.099999999999998 grams
# Cost 245  in U.S. requires 10.206 grams
# Cost 245 in Europe requires 23.9 grams
# Cost 246  in U.S. requires 13.315999999999999 grams
# Cost 246 in Europe requires 26.2 grams
# Cost 247  in U.S. requires 16.426 grams
# Cost 247 in Europe requires 26.959999999999997 grams
# Cost 248  in U.S. requires 19.535999999999998 grams
# Cost 248 in Europe requires 29.259999999999998 grams
# Cost 249  in U.S. requires 22.645999999999997 grams
# Cost 249 in Europe requires 30.019999999999996 grams
# Cost 250  in U.S. requires 11.34 grams
# Cost 250 in Europe requires 16.3 grams
# Cost 251  in U.S. requires 14.45 grams
# Cost 251 in Europe requires 18.6 grams
# Cost 252  in U.S. requires 17.56 grams
# Cost 252 in Europe requires 19.36 grams
# Cost 253  in U.S. requires 20.669999999999998 grams
# Cost 253 in Europe requires 21.66 grams
# Cost 254  in U.S. requires 23.779999999999998 grams
# Cost 254 in Europe requires 22.419999999999998 grams
# Cost 255  in U.S. requires 16.34 grams
# Cost 255 in Europe requires 20.22 grams
# Cost 256  in U.S. requires 19.45 grams
# Cost 256 in Europe requires 22.52 grams
# Cost 257  in U.S. requires 22.56 grams
# Cost 257 in Europe requires 23.279999999999998 grams
# Cost 258  in U.S. requires 25.669999999999998 grams
# Cost 258 in Europe requires 25.58 grams
# Cost 259  in U.S. requires 28.779999999999998 grams
# Cost 259 in Europe requires 26.339999999999996 grams
# Cost 260  in U.S. requires 13.608 grams
# Cost 260 in Europe requires 20.4 grams
# Cost 261  in U.S. requires 16.718 grams
# Cost 261 in Europe requires 22.7 grams
# Cost 262  in U.S. requires 19.828 grams
# Cost 262 in Europe requires 23.459999999999997 grams
# Cost 263  in U.S. requires 22.938 grams
# Cost 263 in Europe requires 25.759999999999998 grams
# Cost 264  in U.S. requires 26.048 grams
# Cost 264 in Europe requires 26.519999999999996 grams
# Cost 265  in U.S. requires 18.608 grams
# Cost 265 in Europe requires 24.32 grams
# Cost 266  in U.S. requires 21.718 grams
# Cost 266 in Europe requires 26.62 grams
# Cost 267  in U.S. requires 24.828 grams
# Cost 267 in Europe requires 27.38 grams
# Cost 268  in U.S. requires 27.938 grams
# Cost 268 in Europe requires 29.68 grams
# Cost 269  in U.S. requires 31.048 grams
# Cost 269 in Europe requires 30.439999999999998 grams
# Cost 270  in U.S. requires 15.876000000000001 grams
# Cost 270 in Europe requires 22.04 grams
# Cost 271  in U.S. requires 18.986 grams
# Cost 271 in Europe requires 24.34 grams
# Cost 272  in U.S. requires 22.096 grams
# Cost 272 in Europe requires 25.099999999999998 grams
# Cost 273  in U.S. requires 25.206 grams
# Cost 273 in Europe requires 27.4 grams
# Cost 274  in U.S. requires 28.316 grams
# Cost 274 in Europe requires 28.159999999999997 grams
# Cost 275  in U.S. requires 17.009999999999998 grams
# Cost 275 in Europe requires 25.96 grams
# Cost 276  in U.S. requires 20.119999999999997 grams
# Cost 276 in Europe requires 28.26 grams
# Cost 277  in U.S. requires 23.229999999999997 grams
# Cost 277 in Europe requires 29.02 grams
# Cost 278  in U.S. requires 26.339999999999996 grams
# Cost 278 in Europe requires 31.32 grams
# Cost 279  in U.S. requires 29.449999999999996 grams
# Cost 279 in Europe requires 32.08 grams
# Cost 280  in U.S. requires 22.009999999999998 grams
# Cost 280 in Europe requires 26.14 grams
# Cost 281  in U.S. requires 25.119999999999997 grams
# Cost 281 in Europe requires 28.44 grams
# Cost 282  in U.S. requires 28.229999999999997 grams
# Cost 282 in Europe requires 29.2 grams
# Cost 283  in U.S. requires 31.339999999999996 grams
# Cost 283 in Europe requires 31.5 grams
# Cost 284  in U.S. requires 34.449999999999996 grams
# Cost 284 in Europe requires 32.26 grams
# Cost 285  in U.S. requires 19.278 grams
# Cost 285 in Europe requires 30.060000000000002 grams
# Cost 286  in U.S. requires 22.387999999999998 grams
# Cost 286 in Europe requires 32.36 grams
# Cost 287  in U.S. requires 25.497999999999998 grams
# Cost 287 in Europe requires 33.120000000000005 grams
# Cost 288  in U.S. requires 28.607999999999997 grams
# Cost 288 in Europe requires 35.42 grams
# Cost 289  in U.S. requires 31.717999999999996 grams
# Cost 289 in Europe requires 36.18000000000001 grams
# Cost 290  in U.S. requires 24.278 grams
# Cost 290 in Europe requires 27.78 grams
# Cost 291  in U.S. requires 27.387999999999998 grams
# Cost 291 in Europe requires 30.080000000000002 grams
# Cost 292  in U.S. requires 30.497999999999998 grams
# Cost 292 in Europe requires 30.84 grams
# Cost 293  in U.S. requires 33.608 grams
# Cost 293 in Europe requires 33.14 grams
# Cost 294  in U.S. requires 36.717999999999996 grams
# Cost 294 in Europe requires 33.9 grams
# Cost 295  in U.S. requires 21.546 grams
# Cost 295 in Europe requires 31.700000000000003 grams
# Cost 296  in U.S. requires 24.656 grams
# Cost 296 in Europe requires 34.0 grams
# Cost 297  in U.S. requires 27.766 grams
# Cost 297 in Europe requires 34.760000000000005 grams
# Cost 298  in U.S. requires 30.875999999999998 grams
# Cost 298 in Europe requires 37.06 grams
# Cost 299  in U.S. requires 33.986 grams
# Cost 299 in Europe requires 37.82000000000001 grams
# Cost 300  in U.S. requires 0 grams
# Cost 300 in Europe requires 16.0 grams
# Cost 301  in U.S. requires 3.11 grams
# Cost 301 in Europe requires 18.3 grams
# Cost 302  in U.S. requires 6.22 grams
# Cost 302 in Europe requires 19.06 grams
# Cost 303  in U.S. requires 9.33 grams
# Cost 303 in Europe requires 21.36 grams
# Cost 304  in U.S. requires 12.44 grams
# Cost 304 in Europe requires 22.119999999999997 grams
# Cost 305  in U.S. requires 5 grams
# Cost 305 in Europe requires 19.92 grams
# Cost 306  in U.S. requires 8.11 grams
# Cost 306 in Europe requires 22.220000000000002 grams
# Cost 307  in U.S. requires 11.219999999999999 grams
# Cost 307 in Europe requires 22.98 grams
# Cost 308  in U.S. requires 14.329999999999998 grams
# Cost 308 in Europe requires 25.28 grams
# Cost 309  in U.S. requires 17.439999999999998 grams
# Cost 309 in Europe requires 26.04 grams
# Cost 310  in U.S. requires 2.268 grams
# Cost 310 in Europe requires 20.1 grams
# Cost 311  in U.S. requires 5.378 grams
# Cost 311 in Europe requires 22.400000000000002 grams
# Cost 312  in U.S. requires 8.488 grams
# Cost 312 in Europe requires 23.16 grams
# Cost 313  in U.S. requires 11.597999999999999 grams
# Cost 313 in Europe requires 25.46 grams
# Cost 314  in U.S. requires 14.707999999999998 grams
# Cost 314 in Europe requires 26.22 grams
# Cost 315  in U.S. requires 7.268 grams
# Cost 315 in Europe requires 24.020000000000003 grams
# Cost 316  in U.S. requires 10.378 grams
# Cost 316 in Europe requires 26.320000000000004 grams
# Cost 317  in U.S. requires 13.488 grams
# Cost 317 in Europe requires 27.080000000000002 grams
# Cost 318  in U.S. requires 16.598 grams
# Cost 318 in Europe requires 29.380000000000003 grams
# Cost 319  in U.S. requires 19.708 grams
# Cost 319 in Europe requires 30.14 grams
# Cost 320  in U.S. requires 4.536 grams
# Cost 320 in Europe requires 21.740000000000002 grams
# Cost 321  in U.S. requires 7.645999999999999 grams
# Cost 321 in Europe requires 24.040000000000003 grams
# Cost 322  in U.S. requires 10.755999999999998 grams
# Cost 322 in Europe requires 24.8 grams
# Cost 323  in U.S. requires 13.865999999999998 grams
# Cost 323 in Europe requires 27.1 grams
# Cost 324  in U.S. requires 16.976 grams
# Cost 324 in Europe requires 27.86 grams
# Cost 325  in U.S. requires 5.67 grams
# Cost 325 in Europe requires 25.660000000000004 grams
# Cost 326  in U.S. requires 8.78 grams
# Cost 326 in Europe requires 27.960000000000004 grams
# Cost 327  in U.S. requires 11.889999999999999 grams
# Cost 327 in Europe requires 28.720000000000002 grams
# Cost 328  in U.S. requires 14.999999999999998 grams
# Cost 328 in Europe requires 31.020000000000003 grams
# Cost 329  in U.S. requires 18.11 grams
# Cost 329 in Europe requires 31.78 grams
# Cost 330  in U.S. requires 10.67 grams
# Cost 330 in Europe requires 25.840000000000003 grams
# Cost 331  in U.S. requires 13.78 grams
# Cost 331 in Europe requires 28.140000000000004 grams
# Cost 332  in U.S. requires 16.89 grams
# Cost 332 in Europe requires 28.900000000000002 grams
# Cost 333  in U.S. requires 20.0 grams
# Cost 333 in Europe requires 31.200000000000003 grams
# Cost 334  in U.S. requires 23.11 grams
# Cost 334 in Europe requires 31.96 grams
# Cost 335  in U.S. requires 7.938 grams
# Cost 335 in Europe requires 29.760000000000005 grams
# Cost 336  in U.S. requires 11.048 grams
# Cost 336 in Europe requires 32.06 grams
# Cost 337  in U.S. requires 14.158 grams
# Cost 337 in Europe requires 32.82000000000001 grams
# Cost 338  in U.S. requires 17.268 grams
# Cost 338 in Europe requires 35.120000000000005 grams
# Cost 339  in U.S. requires 20.378 grams
# Cost 339 in Europe requires 35.88000000000001 grams
# Cost 340  in U.S. requires 12.937999999999999 grams
# Cost 340 in Europe requires 27.480000000000004 grams
# Cost 341  in U.S. requires 16.048 grams
# Cost 341 in Europe requires 29.780000000000005 grams
# Cost 342  in U.S. requires 19.157999999999998 grams
# Cost 342 in Europe requires 30.540000000000003 grams
# Cost 343  in U.S. requires 22.267999999999997 grams
# Cost 343 in Europe requires 32.84 grams
# Cost 344  in U.S. requires 25.377999999999997 grams
# Cost 344 in Europe requires 33.6 grams
# Cost 345  in U.S. requires 10.206 grams
# Cost 345 in Europe requires 31.400000000000006 grams
# Cost 346  in U.S. requires 13.315999999999999 grams
# Cost 346 in Europe requires 33.7 grams
# Cost 347  in U.S. requires 16.426 grams
# Cost 347 in Europe requires 34.46000000000001 grams
# Cost 348  in U.S. requires 19.535999999999998 grams
# Cost 348 in Europe requires 36.760000000000005 grams
# Cost 349  in U.S. requires 22.645999999999997 grams
# Cost 349 in Europe requires 37.52000000000001 grams
# Cost 350  in U.S. requires 11.34 grams
# Cost 350 in Europe requires 23.8 grams
# Cost 351  in U.S. requires 14.45 grams
# Cost 351 in Europe requires 26.1 grams
# Cost 352  in U.S. requires 17.56 grams
# Cost 352 in Europe requires 26.86 grams
# Cost 353  in U.S. requires 20.669999999999998 grams
# Cost 353 in Europe requires 29.16 grams
# Cost 354  in U.S. requires 23.779999999999998 grams
# Cost 354 in Europe requires 29.919999999999998 grams
# Cost 355  in U.S. requires 16.34 grams
# Cost 355 in Europe requires 27.72 grams
# Cost 356  in U.S. requires 19.45 grams
# Cost 356 in Europe requires 30.02 grams
# Cost 357  in U.S. requires 22.56 grams
# Cost 357 in Europe requires 30.779999999999998 grams
# Cost 358  in U.S. requires 25.669999999999998 grams
# Cost 358 in Europe requires 33.08 grams
# Cost 359  in U.S. requires 28.779999999999998 grams
# Cost 359 in Europe requires 33.839999999999996 grams
# Cost 360  in U.S. requires 13.608 grams
# Cost 360 in Europe requires 27.9 grams
# Cost 361  in U.S. requires 16.718 grams
# Cost 361 in Europe requires 30.2 grams
# Cost 362  in U.S. requires 19.828 grams
# Cost 362 in Europe requires 30.959999999999997 grams
# Cost 363  in U.S. requires 22.938 grams
# Cost 363 in Europe requires 33.26 grams
# Cost 364  in U.S. requires 26.048 grams
# Cost 364 in Europe requires 34.019999999999996 grams
# Cost 365  in U.S. requires 18.608 grams
# Cost 365 in Europe requires 31.82 grams
# Cost 366  in U.S. requires 21.718 grams
# Cost 366 in Europe requires 34.12 grams
# Cost 367  in U.S. requires 24.828 grams
# Cost 367 in Europe requires 34.88 grams
# Cost 368  in U.S. requires 27.938 grams
# Cost 368 in Europe requires 37.18 grams
# Cost 369  in U.S. requires 31.048 grams
# Cost 369 in Europe requires 37.940000000000005 grams
# Cost 370  in U.S. requires 15.876000000000001 grams
# Cost 370 in Europe requires 29.54 grams
# Cost 371  in U.S. requires 18.986 grams
# Cost 371 in Europe requires 31.84 grams
# Cost 372  in U.S. requires 22.096 grams
# Cost 372 in Europe requires 32.6 grams
# Cost 373  in U.S. requires 25.206 grams
# Cost 373 in Europe requires 34.9 grams
# Cost 374  in U.S. requires 28.316 grams
# Cost 374 in Europe requires 35.660000000000004 grams
# Cost 375  in U.S. requires 17.009999999999998 grams
# Cost 375 in Europe requires 33.46 grams
# Cost 376  in U.S. requires 20.119999999999997 grams
# Cost 376 in Europe requires 35.76 grams
# Cost 377  in U.S. requires 23.229999999999997 grams
# Cost 377 in Europe requires 36.52 grams
# Cost 378  in U.S. requires 26.339999999999996 grams
# Cost 378 in Europe requires 38.82 grams
# Cost 379  in U.S. requires 29.449999999999996 grams
# Cost 379 in Europe requires 39.580000000000005 grams
# Cost 380  in U.S. requires 22.009999999999998 grams
# Cost 380 in Europe requires 33.64 grams
# Cost 381  in U.S. requires 25.119999999999997 grams
# Cost 381 in Europe requires 35.94 grams
# Cost 382  in U.S. requires 28.229999999999997 grams
# Cost 382 in Europe requires 36.7 grams
# Cost 383  in U.S. requires 31.339999999999996 grams
# Cost 383 in Europe requires 39.0 grams
# Cost 384  in U.S. requires 34.449999999999996 grams
# Cost 384 in Europe requires 39.760000000000005 grams
# Cost 385  in U.S. requires 19.278 grams
# Cost 385 in Europe requires 37.56 grams
# Cost 386  in U.S. requires 22.387999999999998 grams
# Cost 386 in Europe requires 39.86 grams
# Cost 387  in U.S. requires 25.497999999999998 grams
# Cost 387 in Europe requires 40.620000000000005 grams
# Cost 388  in U.S. requires 28.607999999999997 grams
# Cost 388 in Europe requires 42.92 grams
# Cost 389  in U.S. requires 31.717999999999996 grams
# Cost 389 in Europe requires 43.68000000000001 grams
# Cost 390  in U.S. requires 24.278 grams
# Cost 390 in Europe requires 35.28 grams
# Cost 391  in U.S. requires 27.387999999999998 grams
# Cost 391 in Europe requires 37.58 grams
# Cost 392  in U.S. requires 30.497999999999998 grams
# Cost 392 in Europe requires 38.34 grams
# Cost 393  in U.S. requires 33.608 grams
# Cost 393 in Europe requires 40.64 grams
# Cost 394  in U.S. requires 36.717999999999996 grams
# Cost 394 in Europe requires 41.400000000000006 grams
# Cost 395  in U.S. requires 21.546 grams
# Cost 395 in Europe requires 39.2 grams
# Cost 396  in U.S. requires 24.656 grams
# Cost 396 in Europe requires 41.5 grams
# Cost 397  in U.S. requires 27.766 grams
# Cost 397 in Europe requires 42.260000000000005 grams
# Cost 398  in U.S. requires 30.875999999999998 grams
# Cost 398 in Europe requires 44.56 grams
# Cost 399  in U.S. requires 33.986 grams
# Cost 399 in Europe requires 45.32000000000001 grams
# Cost 400  in U.S. requires 0 grams
# Cost 400 in Europe requires 17.0 grams
# Cost 401  in U.S. requires 3.11 grams
# Cost 401 in Europe requires 19.3 grams
# Cost 402  in U.S. requires 6.22 grams
# Cost 402 in Europe requires 20.06 grams
# Cost 403  in U.S. requires 9.33 grams
# Cost 403 in Europe requires 22.36 grams
# Cost 404  in U.S. requires 12.44 grams
# Cost 404 in Europe requires 23.119999999999997 grams
# Cost 405  in U.S. requires 5 grams
# Cost 405 in Europe requires 20.92 grams
# Cost 406  in U.S. requires 8.11 grams
# Cost 406 in Europe requires 23.220000000000002 grams
# Cost 407  in U.S. requires 11.219999999999999 grams
# Cost 407 in Europe requires 23.98 grams
# Cost 408  in U.S. requires 14.329999999999998 grams
# Cost 408 in Europe requires 26.28 grams
# Cost 409  in U.S. requires 17.439999999999998 grams
# Cost 409 in Europe requires 27.04 grams
# Cost 410  in U.S. requires 2.268 grams
# Cost 410 in Europe requires 21.1 grams
# Cost 411  in U.S. requires 5.378 grams
# Cost 411 in Europe requires 23.400000000000002 grams
# Cost 412  in U.S. requires 8.488 grams
# Cost 412 in Europe requires 24.16 grams
# Cost 413  in U.S. requires 11.597999999999999 grams
# Cost 413 in Europe requires 26.46 grams
# Cost 414  in U.S. requires 14.707999999999998 grams
# Cost 414 in Europe requires 27.22 grams
# Cost 415  in U.S. requires 7.268 grams
# Cost 415 in Europe requires 25.020000000000003 grams
# Cost 416  in U.S. requires 10.378 grams
# Cost 416 in Europe requires 27.320000000000004 grams
# Cost 417  in U.S. requires 13.488 grams
# Cost 417 in Europe requires 28.080000000000002 grams
# Cost 418  in U.S. requires 16.598 grams
# Cost 418 in Europe requires 30.380000000000003 grams
# Cost 419  in U.S. requires 19.708 grams
# Cost 419 in Europe requires 31.14 grams
# Cost 420  in U.S. requires 4.536 grams
# Cost 420 in Europe requires 22.740000000000002 grams
# Cost 421  in U.S. requires 7.645999999999999 grams
# Cost 421 in Europe requires 25.040000000000003 grams
# Cost 422  in U.S. requires 10.755999999999998 grams
# Cost 422 in Europe requires 25.8 grams
# Cost 423  in U.S. requires 13.865999999999998 grams
# Cost 423 in Europe requires 28.1 grams
# Cost 424  in U.S. requires 16.976 grams
# Cost 424 in Europe requires 28.86 grams
# Cost 425  in U.S. requires 5.67 grams
# Cost 425 in Europe requires 26.660000000000004 grams
# Cost 426  in U.S. requires 8.78 grams
# Cost 426 in Europe requires 28.960000000000004 grams
# Cost 427  in U.S. requires 11.889999999999999 grams
# Cost 427 in Europe requires 29.720000000000002 grams
# Cost 428  in U.S. requires 14.999999999999998 grams
# Cost 428 in Europe requires 32.02 grams
# Cost 429  in U.S. requires 18.11 grams
# Cost 429 in Europe requires 32.78 grams
# Cost 430  in U.S. requires 10.67 grams
# Cost 430 in Europe requires 26.840000000000003 grams
# Cost 431  in U.S. requires 13.78 grams
# Cost 431 in Europe requires 29.140000000000004 grams
# Cost 432  in U.S. requires 16.89 grams
# Cost 432 in Europe requires 29.900000000000002 grams
# Cost 433  in U.S. requires 20.0 grams
# Cost 433 in Europe requires 32.2 grams
# Cost 434  in U.S. requires 23.11 grams
# Cost 434 in Europe requires 32.96 grams
# Cost 435  in U.S. requires 7.938 grams
# Cost 435 in Europe requires 30.760000000000005 grams
# Cost 436  in U.S. requires 11.048 grams
# Cost 436 in Europe requires 33.06 grams
# Cost 437  in U.S. requires 14.158 grams
# Cost 437 in Europe requires 33.82000000000001 grams
# Cost 438  in U.S. requires 17.268 grams
# Cost 438 in Europe requires 36.120000000000005 grams
# Cost 439  in U.S. requires 20.378 grams
# Cost 439 in Europe requires 36.88000000000001 grams
# Cost 440  in U.S. requires 12.937999999999999 grams
# Cost 440 in Europe requires 28.480000000000004 grams
# Cost 441  in U.S. requires 16.048 grams
# Cost 441 in Europe requires 30.780000000000005 grams
# Cost 442  in U.S. requires 19.157999999999998 grams
# Cost 442 in Europe requires 31.540000000000003 grams
# Cost 443  in U.S. requires 22.267999999999997 grams
# Cost 443 in Europe requires 33.84 grams
# Cost 444  in U.S. requires 25.377999999999997 grams
# Cost 444 in Europe requires 34.6 grams
# Cost 445  in U.S. requires 10.206 grams
# Cost 445 in Europe requires 32.400000000000006 grams
# Cost 446  in U.S. requires 13.315999999999999 grams
# Cost 446 in Europe requires 34.7 grams
# Cost 447  in U.S. requires 16.426 grams
# Cost 447 in Europe requires 35.46000000000001 grams
# Cost 448  in U.S. requires 19.535999999999998 grams
# Cost 448 in Europe requires 37.760000000000005 grams
# Cost 449  in U.S. requires 22.645999999999997 grams
# Cost 449 in Europe requires 38.52000000000001 grams
# Cost 450  in U.S. requires 11.34 grams
# Cost 450 in Europe requires 24.8 grams
# Cost 451  in U.S. requires 14.45 grams
# Cost 451 in Europe requires 27.1 grams
# Cost 452  in U.S. requires 17.56 grams
# Cost 452 in Europe requires 27.86 grams
# Cost 453  in U.S. requires 20.669999999999998 grams
# Cost 453 in Europe requires 30.16 grams
# Cost 454  in U.S. requires 23.779999999999998 grams
# Cost 454 in Europe requires 30.919999999999998 grams
# Cost 455  in U.S. requires 16.34 grams
# Cost 455 in Europe requires 28.72 grams
# Cost 456  in U.S. requires 19.45 grams
# Cost 456 in Europe requires 31.02 grams
# Cost 457  in U.S. requires 22.56 grams
# Cost 457 in Europe requires 31.779999999999998 grams
# Cost 458  in U.S. requires 25.669999999999998 grams
# Cost 458 in Europe requires 34.08 grams
# Cost 459  in U.S. requires 28.779999999999998 grams
# Cost 459 in Europe requires 34.839999999999996 grams
# Cost 460  in U.S. requires 13.608 grams
# Cost 460 in Europe requires 28.9 grams
# Cost 461  in U.S. requires 16.718 grams
# Cost 461 in Europe requires 31.2 grams
# Cost 462  in U.S. requires 19.828 grams
# Cost 462 in Europe requires 31.959999999999997 grams
# Cost 463  in U.S. requires 22.938 grams
# Cost 463 in Europe requires 34.26 grams
# Cost 464  in U.S. requires 26.048 grams
# Cost 464 in Europe requires 35.019999999999996 grams
# Cost 465  in U.S. requires 18.608 grams
# Cost 465 in Europe requires 32.82 grams
# Cost 466  in U.S. requires 21.718 grams
# Cost 466 in Europe requires 35.12 grams
# Cost 467  in U.S. requires 24.828 grams
# Cost 467 in Europe requires 35.88 grams
# Cost 468  in U.S. requires 27.938 grams
# Cost 468 in Europe requires 38.18 grams
# Cost 469  in U.S. requires 31.048 grams
# Cost 469 in Europe requires 38.940000000000005 grams
# Cost 470  in U.S. requires 15.876000000000001 grams
# Cost 470 in Europe requires 30.54 grams
# Cost 471  in U.S. requires 18.986 grams
# Cost 471 in Europe requires 32.839999999999996 grams
# Cost 472  in U.S. requires 22.096 grams
# Cost 472 in Europe requires 33.6 grams
# Cost 473  in U.S. requires 25.206 grams
# Cost 473 in Europe requires 35.9 grams
# Cost 474  in U.S. requires 28.316 grams
# Cost 474 in Europe requires 36.660000000000004 grams
# Cost 475  in U.S. requires 17.009999999999998 grams
# Cost 475 in Europe requires 34.46 grams
# Cost 476  in U.S. requires 20.119999999999997 grams
# Cost 476 in Europe requires 36.76 grams
# Cost 477  in U.S. requires 23.229999999999997 grams
# Cost 477 in Europe requires 37.52 grams
# Cost 478  in U.S. requires 26.339999999999996 grams
# Cost 478 in Europe requires 39.82 grams
# Cost 479  in U.S. requires 29.449999999999996 grams
# Cost 479 in Europe requires 40.580000000000005 grams
# Cost 480  in U.S. requires 22.009999999999998 grams
# Cost 480 in Europe requires 34.64 grams
# Cost 481  in U.S. requires 25.119999999999997 grams
# Cost 481 in Europe requires 36.94 grams
# Cost 482  in U.S. requires 28.229999999999997 grams
# Cost 482 in Europe requires 37.7 grams
# Cost 483  in U.S. requires 31.339999999999996 grams
# Cost 483 in Europe requires 40.0 grams
# Cost 484  in U.S. requires 34.449999999999996 grams
# Cost 484 in Europe requires 40.760000000000005 grams
# Cost 485  in U.S. requires 19.278 grams
# Cost 485 in Europe requires 38.56 grams
# Cost 486  in U.S. requires 22.387999999999998 grams
# Cost 486 in Europe requires 40.86 grams
# Cost 487  in U.S. requires 25.497999999999998 grams
# Cost 487 in Europe requires 41.620000000000005 grams
# Cost 488  in U.S. requires 28.607999999999997 grams
# Cost 488 in Europe requires 43.92 grams
# Cost 489  in U.S. requires 31.717999999999996 grams
# Cost 489 in Europe requires 44.68000000000001 grams
# Cost 490  in U.S. requires 24.278 grams
# Cost 490 in Europe requires 36.28 grams
# Cost 491  in U.S. requires 27.387999999999998 grams
# Cost 491 in Europe requires 38.58 grams
# Cost 492  in U.S. requires 30.497999999999998 grams
# Cost 492 in Europe requires 39.34 grams
# Cost 493  in U.S. requires 33.608 grams
# Cost 493 in Europe requires 41.64 grams
# Cost 494  in U.S. requires 36.717999999999996 grams
# Cost 494 in Europe requires 42.400000000000006 grams
# Cost 495  in U.S. requires 21.546 grams
# Cost 495 in Europe requires 40.2 grams
# Cost 496  in U.S. requires 24.656 grams
# Cost 496 in Europe requires 42.5 grams
# Cost 497  in U.S. requires 27.766 grams
# Cost 497 in Europe requires 43.260000000000005 grams
# Cost 498  in U.S. requires 30.875999999999998 grams
# Cost 498 in Europe requires 45.56 grams
# Cost 499  in U.S. requires 33.986 grams
# Cost 499 in Europe requires 46.32000000000001 grams

# %%
import matplotlib.pyplot as plt
plt.plot(cost_array, n_coins_us, 'o', label="U.S.")
plt.plot(cost_array, n_coins_euro, 'o', label="Euro")
plt.xlabel("Cost")
plt.ylabel("Number of Coins")
plt.legend()
plt.show()

# %%
import numpy as np
print("The U.S. coin system requires %.2f grams, on average." % np.mean(n_coins_us))
print("The Euro coin system requires %.2f grams, on average." % np.mean(n_coins_euro))
# Out:
# The U.S. coin system requires 18.58 grams, on average.
# The Euro coin system requires 25.31 grams, on average.

# %% [markdown]
# # Is there a better choice?
#
# In principle, we might be able to come up with an even better choice for the U.S. System. We have to have a 1 cent coin, clearly.  However, perhaps we could replace the other three coins (5, 10, 25) with a different set of three coins.  We could try to minimize the number of coins needed to make change for any amount.

# %%
mean_coins = []

min_mean_coins = 999999999999

for coin2 in range(2,8):
    for coin3 in range(8,18):
        for coin4 in range(18,100):
            
            us_coins = [coin4, coin3, coin2, 1]
            
            n_coins_us = []
            cost_array = []

            for cost in range(1,500):
                cost_array.append(cost)
    
                n_coins = 0
                remaining = cost%100
                #print ("Starting cost", cost)
                for coin in us_coins:
                    while remaining >= coin:
                        n_coins += 1
                        remaining -= coin
                        #print("Coin", coin, "remaining", remaining)
                #print("Cost", cost, " in U.S. requires", n_coins, "coins")
                n_coins_us.append(n_coins) 
            
            if np.mean(n_coins_us) < min_mean_coins:
                min_mean_coins = np.mean(n_coins_us)
                print("New minimum mean coins", min_mean_coins)
                print("New coin system", us_coins)
            mean_coins.append(np.mean(n_coins_us))
# Out:
# New minimum mean coins 4.749498997995992
# New coin system [18, 8, 2, 1]
# New minimum mean coins 4.619238476953908
# New coin system [19, 8, 2, 1]
# New minimum mean coins 4.609218436873747
# New coin system [20, 8, 2, 1]
# New minimum mean coins 4.5490981963927855
# New coin system [21, 8, 2, 1]
# New minimum mean coins 4.488977955911824
# New coin system [22, 8, 2, 1]
# New minimum mean coins 4.428857715430862
# New coin system [26, 8, 2, 1]
# New minimum mean coins 4.35871743486974
# New coin system [27, 8, 2, 1]
# New minimum mean coins 4.328657314629258
# New coin system [29, 8, 2, 1]
# New minimum mean coins 4.3086172344689375
# New coin system [22, 8, 3, 1]
# New minimum mean coins 4.2885771543086175
# New coin system [23, 8, 3, 1]
# New minimum mean coins 4.268537074148297
# New coin system [25, 8, 3, 1]
# New minimum mean coins 4.208416833667335
# New coin system [26, 8, 3, 1]
# New minimum mean coins 4.1783567134268536
# New coin system [27, 8, 3, 1]
# New minimum mean coins 4.148296593186373
# New coin system [28, 8, 3, 1]
# New minimum mean coins 4.128256513026052
# New coin system [29, 8, 3, 1]
# New minimum mean coins 4.108216432865731
# New coin system [37, 11, 3, 1]

# %%
import matplotlib.pyplot as plt
plt.plot(cost_array, n_coins_us, 'o', label="U.S.")
plt.xlabel("Cost")
plt.ylabel("Number of Coins")
plt.legend()
plt.show()

# %%
iteration = [i+1 for i in range(len(mean_coins))]

# %%
import matplotlib.pyplot as plt
plt.plot(iteration, mean_coins, '.', label="U.S.")
plt.xlabel("Iteration")
plt.ylabel("Mean Number of Coins")
plt.legend()

# %%
# The coin system for the United States

us_coins = [37, 11, 3, 1]

n_coins_us = []
cost_array = []

for cost in range(1,500):
    cost_array.append(cost)
    
    n_coins = 0
    remaining = cost%100
    #print ("Starting cost", cost)
    for coin in us_coins:
        while remaining >= coin:
            n_coins += 1
            remaining -= coin
            #print("Coin", coin, "remaining", remaining)
    print("Cost", cost, " in U.S. requires", n_coins, "coins")
    n_coins_us.append(n_coins)
# Out:
# Cost 1  in U.S. requires 1 coins
# Cost 2  in U.S. requires 2 coins
# Cost 3  in U.S. requires 1 coins
# Cost 4  in U.S. requires 2 coins
# Cost 5  in U.S. requires 3 coins
# Cost 6  in U.S. requires 2 coins
# Cost 7  in U.S. requires 3 coins
# Cost 8  in U.S. requires 4 coins
# Cost 9  in U.S. requires 3 coins
# Cost 10  in U.S. requires 4 coins
# Cost 11  in U.S. requires 1 coins
# Cost 12  in U.S. requires 2 coins
# Cost 13  in U.S. requires 3 coins
# Cost 14  in U.S. requires 2 coins
# Cost 15  in U.S. requires 3 coins
# Cost 16  in U.S. requires 4 coins
# Cost 17  in U.S. requires 3 coins
# Cost 18  in U.S. requires 4 coins
# Cost 19  in U.S. requires 5 coins
# Cost 20  in U.S. requires 4 coins
# Cost 21  in U.S. requires 5 coins
# Cost 22  in U.S. requires 2 coins
# Cost 23  in U.S. requires 3 coins
# Cost 24  in U.S. requires 4 coins
# Cost 25  in U.S. requires 3 coins
# Cost 26  in U.S. requires 4 coins
# Cost 27  in U.S. requires 5 coins
# Cost 28  in U.S. requires 4 coins
# Cost 29  in U.S. requires 5 coins
# Cost 30  in U.S. requires 6 coins
# Cost 31  in U.S. requires 5 coins
# Cost 32  in U.S. requires 6 coins
# Cost 33  in U.S. requires 3 coins
# Cost 34  in U.S. requires 4 coins
# Cost 35  in U.S. requires 5 coins
# Cost 36  in U.S. requires 4 coins
# Cost 37  in U.S. requires 1 coins
# Cost 38  in U.S. requires 2 coins
# Cost 39  in U.S. requires 3 coins
# Cost 40  in U.S. requires 2 coins
# Cost 41  in U.S. requires 3 coins
# Cost 42  in U.S. requires 4 coins
# Cost 43  in U.S. requires 3 coins
# Cost 44  in U.S. requires 4 coins
# Cost 45  in U.S. requires 5 coins
# Cost 46  in U.S. requires 4 coins
# Cost 47  in U.S. requires 5 coins
# Cost 48  in U.S. requires 2 coins
# Cost 49  in U.S. requires 3 coins
# Cost 50  in U.S. requires 4 coins
# Cost 51  in U.S. requires 3 coins
# Cost 52  in U.S. requires 4 coins
# Cost 53  in U.S. requires 5 coins
# Cost 54  in U.S. requires 4 coins
# Cost 55  in U.S. requires 5 coins
# Cost 56  in U.S. requires 6 coins
# Cost 57  in U.S. requires 5 coins
# Cost 58  in U.S. requires 6 coins
# Cost 59  in U.S. requires 3 coins
# Cost 60  in U.S. requires 4 coins
# Cost 61  in U.S. requires 5 coins
# Cost 62  in U.S. requires 4 coins
# Cost 63  in U.S. requires 5 coins
# Cost 64  in U.S. requires 6 coins
# Cost 65  in U.S. requires 5 coins
# Cost 66  in U.S. requires 6 coins
# Cost 67  in U.S. requires 7 coins
# Cost 68  in U.S. requires 6 coins
# Cost 69  in U.S. requires 7 coins
# Cost 70  in U.S. requires 4 coins
# Cost 71  in U.S. requires 5 coins
# Cost 72  in U.S. requires 6 coins
# Cost 73  in U.S. requires 5 coins
# Cost 74  in U.S. requires 2 coins
# Cost 75  in U.S. requires 3 coins
# Cost 76  in U.S. requires 4 coins
# Cost 77  in U.S. requires 3 coins
# Cost 78  in U.S. requires 4 coins
# Cost 79  in U.S. requires 5 coins
# Cost 80  in U.S. requires 4 coins
# Cost 81  in U.S. requires 5 coins
# Cost 82  in U.S. requires 6 coins
# Cost 83  in U.S. requires 5 coins
# Cost 84  in U.S. requires 6 coins
# Cost 85  in U.S. requires 3 coins
# Cost 86  in U.S. requires 4 coins
# Cost 87  in U.S. requires 5 coins
# Cost 88  in U.S. requires 4 coins
# Cost 89  in U.S. requires 5 coins
# Cost 90  in U.S. requires 6 coins
# Cost 91  in U.S. requires 5 coins
# Cost 92  in U.S. requires 6 coins
# Cost 93  in U.S. requires 7 coins
# Cost 94  in U.S. requires 6 coins
# Cost 95  in U.S. requires 7 coins
# Cost 96  in U.S. requires 4 coins
# Cost 97  in U.S. requires 5 coins
# Cost 98  in U.S. requires 6 coins
# Cost 99  in U.S. requires 5 coins
# Cost 100  in U.S. requires 0 coins
# Cost 101  in U.S. requires 1 coins
# Cost 102  in U.S. requires 2 coins
# Cost 103  in U.S. requires 1 coins
# Cost 104  in U.S. requires 2 coins
# Cost 105  in U.S. requires 3 coins
# Cost 106  in U.S. requires 2 coins
# Cost 107  in U.S. requires 3 coins
# Cost 108  in U.S. requires 4 coins
# Cost 109  in U.S. requires 3 coins
# Cost 110  in U.S. requires 4 coins
# Cost 111  in U.S. requires 1 coins
# Cost 112  in U.S. requires 2 coins
# Cost 113  in U.S. requires 3 coins
# Cost 114  in U.S. requires 2 coins
# Cost 115  in U.S. requires 3 coins
# Cost 116  in U.S. requires 4 coins
# Cost 117  in U.S. requires 3 coins
# Cost 118  in U.S. requires 4 coins
# Cost 119  in U.S. requires 5 coins
# Cost 120  in U.S. requires 4 coins
# Cost 121  in U.S. requires 5 coins
# Cost 122  in U.S. requires 2 coins
# Cost 123  in U.S. requires 3 coins
# Cost 124  in U.S. requires 4 coins
# Cost 125  in U.S. requires 3 coins
# Cost 126  in U.S. requires 4 coins
# Cost 127  in U.S. requires 5 coins
# Cost 128  in U.S. requires 4 coins
# Cost 129  in U.S. requires 5 coins
# Cost 130  in U.S. requires 6 coins
# Cost 131  in U.S. requires 5 coins
# Cost 132  in U.S. requires 6 coins
# Cost 133  in U.S. requires 3 coins
# Cost 134  in U.S. requires 4 coins
# Cost 135  in U.S. requires 5 coins
# Cost 136  in U.S. requires 4 coins
# Cost 137  in U.S. requires 1 coins
# Cost 138  in U.S. requires 2 coins
# Cost 139  in U.S. requires 3 coins
# Cost 140  in U.S. requires 2 coins
# Cost 141  in U.S. requires 3 coins
# Cost 142  in U.S. requires 4 coins
# Cost 143  in U.S. requires 3 coins
# Cost 144  in U.S. requires 4 coins
# Cost 145  in U.S. requires 5 coins
# Cost 146  in U.S. requires 4 coins
# Cost 147  in U.S. requires 5 coins
# Cost 148  in U.S. requires 2 coins
# Cost 149  in U.S. requires 3 coins
# Cost 150  in U.S. requires 4 coins
# Cost 151  in U.S. requires 3 coins
# Cost 152  in U.S. requires 4 coins
# Cost 153  in U.S. requires 5 coins
# Cost 154  in U.S. requires 4 coins
# Cost 155  in U.S. requires 5 coins
# Cost 156  in U.S. requires 6 coins
# Cost 157  in U.S. requires 5 coins
# Cost 158  in U.S. requires 6 coins
# Cost 159  in U.S. requires 3 coins
# Cost 160  in U.S. requires 4 coins
# Cost 161  in U.S. requires 5 coins
# Cost 162  in U.S. requires 4 coins
# Cost 163  in U.S. requires 5 coins
# Cost 164  in U.S. requires 6 coins
# Cost 165  in U.S. requires 5 coins
# Cost 166  in U.S. requires 6 coins
# Cost 167  in U.S. requires 7 coins
# Cost 168  in U.S. requires 6 coins
# Cost 169  in U.S. requires 7 coins
# Cost 170  in U.S. requires 4 coins
# Cost 171  in U.S. requires 5 coins
# Cost 172  in U.S. requires 6 coins
# Cost 173  in U.S. requires 5 coins
# Cost 174  in U.S. requires 2 coins
# Cost 175  in U.S. requires 3 coins
# Cost 176  in U.S. requires 4 coins
# Cost 177  in U.S. requires 3 coins
# Cost 178  in U.S. requires 4 coins
# Cost 179  in U.S. requires 5 coins
# Cost 180  in U.S. requires 4 coins
# Cost 181  in U.S. requires 5 coins
# Cost 182  in U.S. requires 6 coins
# Cost 183  in U.S. requires 5 coins
# Cost 184  in U.S. requires 6 coins
# Cost 185  in U.S. requires 3 coins
# Cost 186  in U.S. requires 4 coins
# Cost 187  in U.S. requires 5 coins
# Cost 188  in U.S. requires 4 coins
# Cost 189  in U.S. requires 5 coins
# Cost 190  in U.S. requires 6 coins
# Cost 191  in U.S. requires 5 coins
# Cost 192  in U.S. requires 6 coins
# Cost 193  in U.S. requires 7 coins
# Cost 194  in U.S. requires 6 coins
# Cost 195  in U.S. requires 7 coins
# Cost 196  in U.S. requires 4 coins
# Cost 197  in U.S. requires 5 coins
# Cost 198  in U.S. requires 6 coins
# Cost 199  in U.S. requires 5 coins
# Cost 200  in U.S. requires 0 coins
# Cost 201  in U.S. requires 1 coins
# Cost 202  in U.S. requires 2 coins
# Cost 203  in U.S. requires 1 coins
# Cost 204  in U.S. requires 2 coins
# Cost 205  in U.S. requires 3 coins
# Cost 206  in U.S. requires 2 coins
# Cost 207  in U.S. requires 3 coins
# Cost 208  in U.S. requires 4 coins
# Cost 209  in U.S. requires 3 coins
# Cost 210  in U.S. requires 4 coins
# Cost 211  in U.S. requires 1 coins
# Cost 212  in U.S. requires 2 coins
# Cost 213  in U.S. requires 3 coins
# Cost 214  in U.S. requires 2 coins
# Cost 215  in U.S. requires 3 coins
# Cost 216  in U.S. requires 4 coins
# Cost 217  in U.S. requires 3 coins
# Cost 218  in U.S. requires 4 coins
# Cost 219  in U.S. requires 5 coins
# Cost 220  in U.S. requires 4 coins
# Cost 221  in U.S. requires 5 coins
# Cost 222  in U.S. requires 2 coins
# Cost 223  in U.S. requires 3 coins
# Cost 224  in U.S. requires 4 coins
# Cost 225  in U.S. requires 3 coins
# Cost 226  in U.S. requires 4 coins
# Cost 227  in U.S. requires 5 coins
# Cost 228  in U.S. requires 4 coins
# Cost 229  in U.S. requires 5 coins
# Cost 230  in U.S. requires 6 coins
# Cost 231  in U.S. requires 5 coins
# Cost 232  in U.S. requires 6 coins
# Cost 233  in U.S. requires 3 coins
# Cost 234  in U.S. requires 4 coins
# Cost 235  in U.S. requires 5 coins
# Cost 236  in U.S. requires 4 coins
# Cost 237  in U.S. requires 1 coins
# Cost 238  in U.S. requires 2 coins
# Cost 239  in U.S. requires 3 coins
# Cost 240  in U.S. requires 2 coins
# Cost 241  in U.S. requires 3 coins
# Cost 242  in U.S. requires 4 coins
# Cost 243  in U.S. requires 3 coins
# Cost 244  in U.S. requires 4 coins
# Cost 245  in U.S. requires 5 coins
# Cost 246  in U.S. requires 4 coins
# Cost 247  in U.S. requires 5 coins
# Cost 248  in U.S. requires 2 coins
# Cost 249  in U.S. requires 3 coins
# Cost 250  in U.S. requires 4 coins
# Cost 251  in U.S. requires 3 coins
# Cost 252  in U.S. requires 4 coins
# Cost 253  in U.S. requires 5 coins
# Cost 254  in U.S. requires 4 coins
# Cost 255  in U.S. requires 5 coins
# Cost 256  in U.S. requires 6 coins
# Cost 257  in U.S. requires 5 coins
# Cost 258  in U.S. requires 6 coins
# Cost 259  in U.S. requires 3 coins
# Cost 260  in U.S. requires 4 coins
# Cost 261  in U.S. requires 5 coins
# Cost 262  in U.S. requires 4 coins
# Cost 263  in U.S. requires 5 coins
# Cost 264  in U.S. requires 6 coins
# Cost 265  in U.S. requires 5 coins
# Cost 266  in U.S. requires 6 coins
# Cost 267  in U.S. requires 7 coins
# Cost 268  in U.S. requires 6 coins
# Cost 269  in U.S. requires 7 coins
# Cost 270  in U.S. requires 4 coins
# Cost 271  in U.S. requires 5 coins
# Cost 272  in U.S. requires 6 coins
# Cost 273  in U.S. requires 5 coins
# Cost 274  in U.S. requires 2 coins
# Cost 275  in U.S. requires 3 coins
# Cost 276  in U.S. requires 4 coins
# Cost 277  in U.S. requires 3 coins
# Cost 278  in U.S. requires 4 coins
# Cost 279  in U.S. requires 5 coins
# Cost 280  in U.S. requires 4 coins
# Cost 281  in U.S. requires 5 coins
# Cost 282  in U.S. requires 6 coins
# Cost 283  in U.S. requires 5 coins
# Cost 284  in U.S. requires 6 coins
# Cost 285  in U.S. requires 3 coins
# Cost 286  in U.S. requires 4 coins
# Cost 287  in U.S. requires 5 coins
# Cost 288  in U.S. requires 4 coins
# Cost 289  in U.S. requires 5 coins
# Cost 290  in U.S. requires 6 coins
# Cost 291  in U.S. requires 5 coins
# Cost 292  in U.S. requires 6 coins
# Cost 293  in U.S. requires 7 coins
# Cost 294  in U.S. requires 6 coins
# Cost 295  in U.S. requires 7 coins
# Cost 296  in U.S. requires 4 coins
# Cost 297  in U.S. requires 5 coins
# Cost 298  in U.S. requires 6 coins
# Cost 299  in U.S. requires 5 coins
# Cost 300  in U.S. requires 0 coins
# Cost 301  in U.S. requires 1 coins
# Cost 302  in U.S. requires 2 coins
# Cost 303  in U.S. requires 1 coins
# Cost 304  in U.S. requires 2 coins
# Cost 305  in U.S. requires 3 coins
# Cost 306  in U.S. requires 2 coins
# Cost 307  in U.S. requires 3 coins
# Cost 308  in U.S. requires 4 coins
# Cost 309  in U.S. requires 3 coins
# Cost 310  in U.S. requires 4 coins
# Cost 311  in U.S. requires 1 coins
# Cost 312  in U.S. requires 2 coins
# Cost 313  in U.S. requires 3 coins
# Cost 314  in U.S. requires 2 coins
# Cost 315  in U.S. requires 3 coins
# Cost 316  in U.S. requires 4 coins
# Cost 317  in U.S. requires 3 coins
# Cost 318  in U.S. requires 4 coins
# Cost 319  in U.S. requires 5 coins
# Cost 320  in U.S. requires 4 coins
# Cost 321  in U.S. requires 5 coins
# Cost 322  in U.S. requires 2 coins
# Cost 323  in U.S. requires 3 coins
# Cost 324  in U.S. requires 4 coins
# Cost 325  in U.S. requires 3 coins
# Cost 326  in U.S. requires 4 coins
# Cost 327  in U.S. requires 5 coins
# Cost 328  in U.S. requires 4 coins
# Cost 329  in U.S. requires 5 coins
# Cost 330  in U.S. requires 6 coins
# Cost 331  in U.S. requires 5 coins
# Cost 332  in U.S. requires 6 coins
# Cost 333  in U.S. requires 3 coins
# Cost 334  in U.S. requires 4 coins
# Cost 335  in U.S. requires 5 coins
# Cost 336  in U.S. requires 4 coins
# Cost 337  in U.S. requires 1 coins
# Cost 338  in U.S. requires 2 coins
# Cost 339  in U.S. requires 3 coins
# Cost 340  in U.S. requires 2 coins
# Cost 341  in U.S. requires 3 coins
# Cost 342  in U.S. requires 4 coins
# Cost 343  in U.S. requires 3 coins
# Cost 344  in U.S. requires 4 coins
# Cost 345  in U.S. requires 5 coins
# Cost 346  in U.S. requires 4 coins
# Cost 347  in U.S. requires 5 coins
# Cost 348  in U.S. requires 2 coins
# Cost 349  in U.S. requires 3 coins
# Cost 350  in U.S. requires 4 coins
# Cost 351  in U.S. requires 3 coins
# Cost 352  in U.S. requires 4 coins
# Cost 353  in U.S. requires 5 coins
# Cost 354  in U.S. requires 4 coins
# Cost 355  in U.S. requires 5 coins
# Cost 356  in U.S. requires 6 coins
# Cost 357  in U.S. requires 5 coins
# Cost 358  in U.S. requires 6 coins
# Cost 359  in U.S. requires 3 coins
# Cost 360  in U.S. requires 4 coins
# Cost 361  in U.S. requires 5 coins
# Cost 362  in U.S. requires 4 coins
# Cost 363  in U.S. requires 5 coins
# Cost 364  in U.S. requires 6 coins
# Cost 365  in U.S. requires 5 coins
# Cost 366  in U.S. requires 6 coins
# Cost 367  in U.S. requires 7 coins
# Cost 368  in U.S. requires 6 coins
# Cost 369  in U.S. requires 7 coins
# Cost 370  in U.S. requires 4 coins
# Cost 371  in U.S. requires 5 coins
# Cost 372  in U.S. requires 6 coins
# Cost 373  in U.S. requires 5 coins
# Cost 374  in U.S. requires 2 coins
# Cost 375  in U.S. requires 3 coins
# Cost 376  in U.S. requires 4 coins
# Cost 377  in U.S. requires 3 coins
# Cost 378  in U.S. requires 4 coins
# Cost 379  in U.S. requires 5 coins
# Cost 380  in U.S. requires 4 coins
# Cost 381  in U.S. requires 5 coins
# Cost 382  in U.S. requires 6 coins
# Cost 383  in U.S. requires 5 coins
# Cost 384  in U.S. requires 6 coins
# Cost 385  in U.S. requires 3 coins
# Cost 386  in U.S. requires 4 coins
# Cost 387  in U.S. requires 5 coins
# Cost 388  in U.S. requires 4 coins
# Cost 389  in U.S. requires 5 coins
# Cost 390  in U.S. requires 6 coins
# Cost 391  in U.S. requires 5 coins
# Cost 392  in U.S. requires 6 coins
# Cost 393  in U.S. requires 7 coins
# Cost 394  in U.S. requires 6 coins
# Cost 395  in U.S. requires 7 coins
# Cost 396  in U.S. requires 4 coins
# Cost 397  in U.S. requires 5 coins
# Cost 398  in U.S. requires 6 coins
# Cost 399  in U.S. requires 5 coins
# Cost 400  in U.S. requires 0 coins
# Cost 401  in U.S. requires 1 coins
# Cost 402  in U.S. requires 2 coins
# Cost 403  in U.S. requires 1 coins
# Cost 404  in U.S. requires 2 coins
# Cost 405  in U.S. requires 3 coins
# Cost 406  in U.S. requires 2 coins
# Cost 407  in U.S. requires 3 coins
# Cost 408  in U.S. requires 4 coins
# Cost 409  in U.S. requires 3 coins
# Cost 410  in U.S. requires 4 coins
# Cost 411  in U.S. requires 1 coins
# Cost 412  in U.S. requires 2 coins
# Cost 413  in U.S. requires 3 coins
# Cost 414  in U.S. requires 2 coins
# Cost 415  in U.S. requires 3 coins
# Cost 416  in U.S. requires 4 coins
# Cost 417  in U.S. requires 3 coins
# Cost 418  in U.S. requires 4 coins
# Cost 419  in U.S. requires 5 coins
# Cost 420  in U.S. requires 4 coins
# Cost 421  in U.S. requires 5 coins
# Cost 422  in U.S. requires 2 coins
# Cost 423  in U.S. requires 3 coins
# Cost 424  in U.S. requires 4 coins
# Cost 425  in U.S. requires 3 coins
# Cost 426  in U.S. requires 4 coins
# Cost 427  in U.S. requires 5 coins
# Cost 428  in U.S. requires 4 coins
# Cost 429  in U.S. requires 5 coins
# Cost 430  in U.S. requires 6 coins
# Cost 431  in U.S. requires 5 coins
# Cost 432  in U.S. requires 6 coins
# Cost 433  in U.S. requires 3 coins
# Cost 434  in U.S. requires 4 coins
# Cost 435  in U.S. requires 5 coins
# Cost 436  in U.S. requires 4 coins
# Cost 437  in U.S. requires 1 coins
# Cost 438  in U.S. requires 2 coins
# Cost 439  in U.S. requires 3 coins
# Cost 440  in U.S. requires 2 coins
# Cost 441  in U.S. requires 3 coins
# Cost 442  in U.S. requires 4 coins
# Cost 443  in U.S. requires 3 coins
# Cost 444  in U.S. requires 4 coins
# Cost 445  in U.S. requires 5 coins
# Cost 446  in U.S. requires 4 coins
# Cost 447  in U.S. requires 5 coins
# Cost 448  in U.S. requires 2 coins
# Cost 449  in U.S. requires 3 coins
# Cost 450  in U.S. requires 4 coins
# Cost 451  in U.S. requires 3 coins
# Cost 452  in U.S. requires 4 coins
# Cost 453  in U.S. requires 5 coins
# Cost 454  in U.S. requires 4 coins
# Cost 455  in U.S. requires 5 coins
# Cost 456  in U.S. requires 6 coins
# Cost 457  in U.S. requires 5 coins
# Cost 458  in U.S. requires 6 coins
# Cost 459  in U.S. requires 3 coins
# Cost 460  in U.S. requires 4 coins
# Cost 461  in U.S. requires 5 coins
# Cost 462  in U.S. requires 4 coins
# Cost 463  in U.S. requires 5 coins
# Cost 464  in U.S. requires 6 coins
# Cost 465  in U.S. requires 5 coins
# Cost 466  in U.S. requires 6 coins
# Cost 467  in U.S. requires 7 coins
# Cost 468  in U.S. requires 6 coins
# Cost 469  in U.S. requires 7 coins
# Cost 470  in U.S. requires 4 coins
# Cost 471  in U.S. requires 5 coins
# Cost 472  in U.S. requires 6 coins
# Cost 473  in U.S. requires 5 coins
# Cost 474  in U.S. requires 2 coins
# Cost 475  in U.S. requires 3 coins
# Cost 476  in U.S. requires 4 coins
# Cost 477  in U.S. requires 3 coins
# Cost 478  in U.S. requires 4 coins
# Cost 479  in U.S. requires 5 coins
# Cost 480  in U.S. requires 4 coins
# Cost 481  in U.S. requires 5 coins
# Cost 482  in U.S. requires 6 coins
# Cost 483  in U.S. requires 5 coins
# Cost 484  in U.S. requires 6 coins
# Cost 485  in U.S. requires 3 coins
# Cost 486  in U.S. requires 4 coins
# Cost 487  in U.S. requires 5 coins
# Cost 488  in U.S. requires 4 coins
# Cost 489  in U.S. requires 5 coins
# Cost 490  in U.S. requires 6 coins
# Cost 491  in U.S. requires 5 coins
# Cost 492  in U.S. requires 6 coins
# Cost 493  in U.S. requires 7 coins
# Cost 494  in U.S. requires 6 coins
# Cost 495  in U.S. requires 7 coins
# Cost 496  in U.S. requires 4 coins
# Cost 497  in U.S. requires 5 coins
# Cost 498  in U.S. requires 6 coins
# Cost 499  in U.S. requires 5 coins

# %%
import matplotlib.pyplot as plt
plt.plot(cost_array, n_coins_us, 'o', label="U.S.")
plt.xlabel("Cost")
plt.ylabel("Number of Coins")
plt.legend()
plt.show()

# %%
import numpy as np
print("The U.S. coin system requires %.2f coins, on average." % np.mean(n_coins_us))
# Out:
# The U.S. coin system requires 4.11 coins, on average.
