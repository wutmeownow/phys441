# %% [markdown]
# # NORB LIGHTING

# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
#Import file
df_norb = pd.read_excel('Growlight.xlsx')
df_norb.head()
df_norb
# Out:
#           ASIN                                              Title  \
# 0   B07SYQ8BML  LED Grow Light Bulb, 28 LEDs Full Spectrum Pla...
# 1   B08GYFDLQH  BR30 Grow Light Full Spectrum LED Bulb, KOENET...
# 2   B07BRKT56T  SANSI 24W LED Plant Light Bulb Full Spectrum L...
# 3   B07BVDRBMN  120W LED Grow Light Bulb, Derlights Full Spect...
# 4   B08DRKGX5Y  Briignite BR30 LED Grow Light Bulb, 12W Full S...
# 5   B07BRKG7X1  SANSI 36W Daylight LED Plant Light Bulb Full S...
# 6   B08KG956CN  KOENETK BR30 Grow Light Bulb, Full Spectrum LE...
# 7   B08L4KQ5J2  36W LED Plant Grow Light Bulb 72 LEDs Greenhou...
# 8   B08FFJYM4R  LED Grow Light Bulb, Alitade PAR38 E26 Waterpr...
# 9   B07S2P69VC  SANSI Daylight LED Grow Light Bulb, 10W Full S...
# 10  B073G2JQTZ  Miracle LED Absolute Daylight Spectrum Grow Li...
# 11  B0748ZPKT7  Miracle LED Commercial Hydroponic Ultra Grow L...
# 12  B01NCVWFUE  SANSI 15W LED Grow Light Bulb Full Spectrum Gr...
# 13  B07KXBY2YH  SANSI 15W LED Grow Light Bulb, Daylight White ...
# 14  B07Q2GXZP3  TCP RLR20HH 50 Watt Equivalent LED Plant Light...
# 15  B01MCZ63VC  iPower GLLEDXA24C Full-Spectrum 24W LED Grow L...
# 16  B072F1HZ3Z  24 watt LED Plant Grow Light Bulb for Standard...
# 17  B0824QP68H  SecurityIng 28W LED Grow Light Bulb, E27 28 LE...
# 18  B07WJBYHH7  LED Grow Light Bulb - for Indoor Plants Full S...
# 19  B07WNB1L73  LED Grow Light Bulb - for Indoor Plants Full S...
# 20  B087RBTYKN  SecurityIng 18W LED Grow Light Bulb, E27 18 LE...
# 21  B082KMY5GX  SGLEDS 15W LED Sunlike Plant Grow Light Bulb F...
# 22  B08K3LDK6L  BOSYTRO LED Plant Grow Light Bulb Full Spectru...
# 23  B08SMDKQJK  9W 75 Watt Equivalent Grow Light Bulb, Led Gro...
# 24  B071D5PXDH  Feit Electric A19/11K/GROW/LED Bulb, A19 4.5" ...
# 25  B088T5T9ZH  Feit Electric A19/GROW/LEDG2/BX 60W Equivalent...
# 26  B07NNT3G7J  GE Grow Light Bulb, PAR38 Grow Light Bulb for ...
# 27  B07NP1H25N  GE Grow Light Bulb, PAR38 Grow Light Bulb for ...
# 28  B07NN6SVG6  GE BR30 LED Grow Lights for Indoor Plants, Ful...
# 29  B07NNZXGMW  GE BR30 LED Grow Lights for Indoor Plants, Ful...
#
#                 Category               Brand  Number_images  Price  \
# 0   Patio, Lawn & Garden              Gutori              1   1.47
# 1   Patio, Lawn & Garden             KOENETK              7   9.99
# 2   Patio, Lawn & Garden               SANSI              7  29.99
# 3   Patio, Lawn & Garden           Derlights              7  23.99
# 4   Patio, Lawn & Garden           Briignite              8  15.99
# 5   Patio, Lawn & Garden               SANSI              7  39.95
# 6   Patio, Lawn & Garden             KOENETK              7  12.99
# 7   Patio, Lawn & Garden            Haokaini              6   8.99
# 8   Patio, Lawn & Garden             alitade              8  33.99
# 9   Patio, Lawn & Garden               SANSI              7  18.98
# 10  Patio, Lawn & Garden          MiracleLED              4  14.99
# 11  Patio, Lawn & Garden          MiracleLED              4  15.20
# 12  Patio, Lawn & Garden               SANSI              7  19.95
# 13  Patio, Lawn & Garden               SANSI              7  19.98
# 14  Patio, Lawn & Garden                 TCP              5  13.61
# 15  Patio, Lawn & Garden              iPower              7  19.98
# 16  Patio, Lawn & Garden  Electronix Express              7  18.98
# 17  Patio, Lawn & Garden         SecurityIng              9   7.96
# 18  Patio, Lawn & Garden         Haus Bright              7  29.95
# 19  Patio, Lawn & Garden         Haus Bright              7  29.95
# 20  Patio, Lawn & Garden         SecurityIng              9   7.96
# 21  Patio, Lawn & Garden              SGLEDs              8  19.98
# 22  Patio, Lawn & Garden             BOSYTRO              7  16.98
# 23  Patio, Lawn & Garden             Neporal              7   6.99
# 24  Patio, Lawn & Garden       Feit Electric              8  14.68
# 25  Patio, Lawn & Garden       Feit Electric              9   9.97
# 26  Patio, Lawn & Garden         GE Lighting             10  24.49
# 27  Patio, Lawn & Garden         GE Lighting             10  28.91
# 28  Patio, Lawn & Garden         GE Lighting             10  10.88
# 29  Patio, Lawn & Garden         GE Lighting             10   9.89
#
#     MonthlySales  NetPrice  Monthly_Revenue  Review_Count  Reviews_Rating  \
# 0              6      1.17             8.82             1             5.0
# 1            237      5.01          2367.63            67             4.6
# 2            594     20.99         17814.06           882             4.6
# 3              5     20.39           119.95            27             4.3
# 4            353      9.29          5644.47            67             4.8
# 5            432     29.06         17258.40           666             4.4
# 6            124      7.56          1610.76            91             4.6
# 7              7      4.33            62.93             1             5.0
# 8              3     23.99           101.97             2             5.0
# 9            363     12.98          6889.74           659             4.7
# 10           462      9.43          6925.38          1539             4.5
# 11           884      9.61         13489.84          1547             4.4
# 12           303     12.06          5750.94           567             4.7
# 13           440     13.98          8791.20           684             4.7
# 14            12      8.26           162.84             9             4.5
# 15             6     12.08           119.88            32             3.8
# 16             2     12.65            37.96             8             2.5
# 17             8      3.46            63.68            83             4.0
# 18           215     20.56          6439.25           286             4.7
# 19           184     20.56          5510.80           322             4.7
# 20             4      3.96            31.84             3             3.8
# 21            62     13.50          1238.76            35             4.6
# 22            33     10.95           560.34             2             4.5
# 23           130      1.64           908.70             1             5.0
# 24            37     12.48           554.26           493             4.6
# 25           408      5.97          4067.76            70             4.7
# 26          1577     15.92         38620.73          1122             4.7
# 27          1589     18.68         45937.99          1128             4.7
# 28         18250      5.94        198560.00         11044             4.7
# 29         18250      5.89        180492.50         11044             4.7
#
#     Sales_Reviews
# 0            6.00
# 1            3.89
# 2            0.67
# 3            0.19
# 4            5.27
# 5            0.65
# 6            1.36
# 7            7.00
# 8            1.50
# 9            0.55
# 10           0.30
# 11           0.57
# 12           0.53
# 13           0.65
# 14           1.33
# 15           0.19
# 16           0.25
# 17           0.10
# 18           0.75
# 19           0.57
# 20           1.33
# 21           1.88
# 22          16.50
# 23         130.00
# 24           0.08
# 25           6.09
# 26           1.45
# 27           1.45
# 28           1.65
# 29           1.65

# %%
print(f'Number of rows: {len(df_norb)}')
print()
print(f'Shape: {df_norb.shape}')
print()
print(f'Columns: {df_norb.columns}')
print()
print(f'Dtypes: {df_norb.dtypes}')
# Out:
# Number of rows: 30
#
# Shape: (30, 12)
#
# Columns: Index(['ASIN', 'Title', 'Category', 'Brand', 'Number_images', 'Price',
#        'MonthlySales', 'NetPrice', 'Monthly_Revenue', 'Review_Count',
#        'Reviews_Rating', 'Sales_Reviews'],
#       dtype='object')
#
# Dtypes: ASIN                object
# Title               object
# Category            object
# Brand               object
# Number_images        int64
# Price              float64
# MonthlySales         int64
# NetPrice           float64
# Monthly_Revenue    float64
# Review_Count         int64
# Reviews_Rating     float64
# Sales_Reviews      float64
# dtype: object

# %% [markdown]
# # Linear Regression
# using data to see if rating of review and number of images and price effect sales.

# %%
#Correlation of the variables

# %%
x = df_norb[['Number_images']]
y = df_norb[['MonthlySales']]

regressor = LinearRegression()
regressor.fit(x, y)
y_pred = regressor.predict(x)
y_pred
# Out:
# array([[-4524.60103627],
#        [ 1273.83846388],
#        [ 1273.83846388],
#        [ 1273.83846388],
#        [ 2240.24504724],
#        [ 1273.83846388],
#        [ 1273.83846388],
#        [  307.43188052],
#        [ 2240.24504724],
#        [ 1273.83846388],
#        [-1625.38128619],
#        [-1625.38128619],
#        [ 1273.83846388],
#        [ 1273.83846388],
#        [ -658.97470283],
#        [ 1273.83846388],
#        [ 1273.83846388],
#        [ 3206.6516306 ],
#        [ 1273.83846388],
#        [ 1273.83846388],
#        [ 3206.6516306 ],
#        [ 2240.24504724],
#        [ 1273.83846388],
#        [ 1273.83846388],
#        [ 2240.24504724],
#        [ 3206.6516306 ],
#        [ 4173.05821396],
#        [ 4173.05821396],
#        [ 4173.05821396],
#        [ 4173.05821396]])

# %%
plt.scatter(x, y, color = 'red')
plt.plot(x, regressor.predict(x), color = 'blue')
plt.title('Number of images vs Monthly Sales')
plt.xlabel('Number of Images')
plt.ylabel('Monthly Sales')
plt.show()

# %% [markdown]
# There are two problems with the plot above:
#
# 1.  The two data points (row indices 28 and 29) with the very large monthly sales appears to be outliers.  So, we want to remove them from the data set, and then refit the data.
#
# 2.  The linear fit that we have chosen is of the form: y = mx + b.  That is, it allows for a negative y-intercept.  However, in this case, we cannot have monthly sales less than zero!  So, what we need to do is choose a different type of linear fit - one which fixes the y-intercept to be zero, and does a linear fit of the form: y = mx.

# %%
# First, remove the outliers, in reverse order so that we don't have reindexing problems.

df_norb = df_norb.drop([29])
df_norb = df_norb.drop([28])
df_norb
# Out:
#           ASIN                                              Title  \
# 0   B07SYQ8BML  LED Grow Light Bulb, 28 LEDs Full Spectrum Pla...
# 1   B08GYFDLQH  BR30 Grow Light Full Spectrum LED Bulb, KOENET...
# 2   B07BRKT56T  SANSI 24W LED Plant Light Bulb Full Spectrum L...
# 3   B07BVDRBMN  120W LED Grow Light Bulb, Derlights Full Spect...
# 4   B08DRKGX5Y  Briignite BR30 LED Grow Light Bulb, 12W Full S...
# 5   B07BRKG7X1  SANSI 36W Daylight LED Plant Light Bulb Full S...
# 6   B08KG956CN  KOENETK BR30 Grow Light Bulb, Full Spectrum LE...
# 7   B08L4KQ5J2  36W LED Plant Grow Light Bulb 72 LEDs Greenhou...
# 8   B08FFJYM4R  LED Grow Light Bulb, Alitade PAR38 E26 Waterpr...
# 9   B07S2P69VC  SANSI Daylight LED Grow Light Bulb, 10W Full S...
# 10  B073G2JQTZ  Miracle LED Absolute Daylight Spectrum Grow Li...
# 11  B0748ZPKT7  Miracle LED Commercial Hydroponic Ultra Grow L...
# 12  B01NCVWFUE  SANSI 15W LED Grow Light Bulb Full Spectrum Gr...
# 13  B07KXBY2YH  SANSI 15W LED Grow Light Bulb, Daylight White ...
# 14  B07Q2GXZP3  TCP RLR20HH 50 Watt Equivalent LED Plant Light...
# 15  B01MCZ63VC  iPower GLLEDXA24C Full-Spectrum 24W LED Grow L...
# 16  B072F1HZ3Z  24 watt LED Plant Grow Light Bulb for Standard...
# 17  B0824QP68H  SecurityIng 28W LED Grow Light Bulb, E27 28 LE...
# 18  B07WJBYHH7  LED Grow Light Bulb - for Indoor Plants Full S...
# 19  B07WNB1L73  LED Grow Light Bulb - for Indoor Plants Full S...
# 20  B087RBTYKN  SecurityIng 18W LED Grow Light Bulb, E27 18 LE...
# 21  B082KMY5GX  SGLEDS 15W LED Sunlike Plant Grow Light Bulb F...
# 22  B08K3LDK6L  BOSYTRO LED Plant Grow Light Bulb Full Spectru...
# 23  B08SMDKQJK  9W 75 Watt Equivalent Grow Light Bulb, Led Gro...
# 24  B071D5PXDH  Feit Electric A19/11K/GROW/LED Bulb, A19 4.5" ...
# 25  B088T5T9ZH  Feit Electric A19/GROW/LEDG2/BX 60W Equivalent...
# 26  B07NNT3G7J  GE Grow Light Bulb, PAR38 Grow Light Bulb for ...
# 27  B07NP1H25N  GE Grow Light Bulb, PAR38 Grow Light Bulb for ...
#
#                 Category               Brand  Number_images  Price  \
# 0   Patio, Lawn & Garden              Gutori              1   1.47
# 1   Patio, Lawn & Garden             KOENETK              7   9.99
# 2   Patio, Lawn & Garden               SANSI              7  29.99
# 3   Patio, Lawn & Garden           Derlights              7  23.99
# 4   Patio, Lawn & Garden           Briignite              8  15.99
# 5   Patio, Lawn & Garden               SANSI              7  39.95
# 6   Patio, Lawn & Garden             KOENETK              7  12.99
# 7   Patio, Lawn & Garden            Haokaini              6   8.99
# 8   Patio, Lawn & Garden             alitade              8  33.99
# 9   Patio, Lawn & Garden               SANSI              7  18.98
# 10  Patio, Lawn & Garden          MiracleLED              4  14.99
# 11  Patio, Lawn & Garden          MiracleLED              4  15.20
# 12  Patio, Lawn & Garden               SANSI              7  19.95
# 13  Patio, Lawn & Garden               SANSI              7  19.98
# 14  Patio, Lawn & Garden                 TCP              5  13.61
# 15  Patio, Lawn & Garden              iPower              7  19.98
# 16  Patio, Lawn & Garden  Electronix Express              7  18.98
# 17  Patio, Lawn & Garden         SecurityIng              9   7.96
# 18  Patio, Lawn & Garden         Haus Bright              7  29.95
# 19  Patio, Lawn & Garden         Haus Bright              7  29.95
# 20  Patio, Lawn & Garden         SecurityIng              9   7.96
# 21  Patio, Lawn & Garden              SGLEDs              8  19.98
# 22  Patio, Lawn & Garden             BOSYTRO              7  16.98
# 23  Patio, Lawn & Garden             Neporal              7   6.99
# 24  Patio, Lawn & Garden       Feit Electric              8  14.68
# 25  Patio, Lawn & Garden       Feit Electric              9   9.97
# 26  Patio, Lawn & Garden         GE Lighting             10  24.49
# 27  Patio, Lawn & Garden         GE Lighting             10  28.91
#
#     MonthlySales  NetPrice  Monthly_Revenue  Review_Count  Reviews_Rating  \
# 0              6      1.17             8.82             1             5.0
# 1            237      5.01          2367.63            67             4.6
# 2            594     20.99         17814.06           882             4.6
# 3              5     20.39           119.95            27             4.3
# 4            353      9.29          5644.47            67             4.8
# 5            432     29.06         17258.40           666             4.4
# 6            124      7.56          1610.76            91             4.6
# 7              7      4.33            62.93             1             5.0
# 8              3     23.99           101.97             2             5.0
# 9            363     12.98          6889.74           659             4.7
# 10           462      9.43          6925.38          1539             4.5
# 11           884      9.61         13489.84          1547             4.4
# 12           303     12.06          5750.94           567             4.7
# 13           440     13.98          8791.20           684             4.7
# 14            12      8.26           162.84             9             4.5
# 15             6     12.08           119.88            32             3.8
# 16             2     12.65            37.96             8             2.5
# 17             8      3.46            63.68            83             4.0
# 18           215     20.56          6439.25           286             4.7
# 19           184     20.56          5510.80           322             4.7
# 20             4      3.96            31.84             3             3.8
# 21            62     13.50          1238.76            35             4.6
# 22            33     10.95           560.34             2             4.5
# 23           130      1.64           908.70             1             5.0
# 24            37     12.48           554.26           493             4.6
# 25           408      5.97          4067.76            70             4.7
# 26          1577     15.92         38620.73          1122             4.7
# 27          1589     18.68         45937.99          1128             4.7
#
#     Sales_Reviews
# 0            6.00
# 1            3.89
# 2            0.67
# 3            0.19
# 4            5.27
# 5            0.65
# 6            1.36
# 7            7.00
# 8            1.50
# 9            0.55
# 10           0.30
# 11           0.57
# 12           0.53
# 13           0.65
# 14           1.33
# 15           0.19
# 16           0.25
# 17           0.10
# 18           0.75
# 19           0.57
# 20           1.33
# 21           1.88
# 22          16.50
# 23         130.00
# 24           0.08
# 25           6.09
# 26           1.45
# 27           1.45

# %%
# Now, redo the fit.  We specify an additional directive:  fit_intercept=False to remove the fitting of the
# y-intercept
#
# We see that the linear regression fit looks more reasonable now! :)

x = df_norb[['Number_images']]
y = df_norb[['MonthlySales']]

regressor = LinearRegression(fit_intercept=False)
regressor.fit(x, y)
y_pred = regressor.predict(x)

plt.scatter(x, y, color = 'red')
plt.plot(x, regressor.predict(x), color = 'blue')
plt.title('Number of images vs Monthly Sales')
plt.xlabel('Number of Images')
plt.ylabel('Monthly Sales')
plt.show()

# %%
#Multiple Linear Regression 
x = df_norb[['Number_images','Reviews_Rating', 'Price']]
y = df_norb[['MonthlySales']]

reg = LinearRegression(fit_intercept=False)
reg.fit(x,y)
predictedsales = reg.predict(x)

# %%
X0 = np.array(x['Number_images'])
plt.scatter(X0, y, color = 'red')
plt.scatter(X0, reg.predict(x), color = 'blue')
plt.title('Number of images vs Monthly Sales')
plt.xlabel('Number of Images')
plt.ylabel('Monthly Sales')
plt.show()

# %%
X1 = np.array(x['Reviews_Rating'])
plt.scatter(X1, y, color = 'red')
plt.scatter(X1, reg.predict(x), color = 'blue')
plt.title('Reviews Rating vs Monthly Sales')
plt.xlabel('Reviews Rating')
plt.ylabel('Monthly Sales')
plt.show()

# %%
X2 = np.array(x['Price'])
plt.scatter(X2, y, color = 'red')
plt.scatter(X2, reg.predict(x), color = 'blue')
plt.title('Price vs Monthly Sales')
plt.xlabel('Price')
plt.ylabel('Monthly Sales')
plt.show()

# %%
plt.scatter(y, predictedsales, color = 'blue')
plt.title('Predicted vs Actual Monthly Sales')
plt.xlabel('Actual Monthly Sales')
plt.ylabel('Predicted Monthly Sales')
plt.xlim(0,2000)
plt.ylim(0,2000)
plt.show()

# %% [markdown]
# # Finding Keywords to use on Amazon
#
# need to count all the specific words then take out the common words

# %%
textstring = ""
for c in df_norb['Title']:
    for word in c.split(" "):
        if word.isalpha() and word != 'for' and word != 'and' and word != 'nm' and word != 'by' and word != 'the' and word != 'to' and word != 'up' and len(word)>1:
            textstring = textstring + word + ' '
            
print (textstring)
# Out:
# LED Grow Light LEDs Full Spectrum Plant Growing Light Lamp Grow Tent Greenhouse Vegetables Hydroponic Indoor Plants Grow Light Full Spectrum LED KOENETK Indoor Plant LED Light Bulb Seeds Daylight White Grow Growing Lamp Indoor Hydroponic SANSI LED Plant Light Bulb Full Spectrum LED Grow Light Plant Lights Indoor Grow Light Bulb Hydroponics Greenhouse Houseplants Vegetable Sunlight White UV IR LED Grow Light Derlights Full Spectrum Plant Lights Bulb Indoor Plants Garden Hydroponics Greenhouse Veg Socket Briignite LED Grow Light Full Spectrum Grow Light Base Grow Lamp Grow Lights Indoor Greens SANSI Daylight LED Plant Light Bulb Full Spectrum Ceramic LED Grow Light Plant Bulb Sunlight White Grow Light Indoor Garden Farming Greenhouse Grow UV IR KOENETK Grow Light Full Spectrum LED Indoor Plant Light Bulb Seeds Growing Lamp Bulb Daylight Grow Lightbulb Indoor Hydroponic LED Plant Grow Light Bulb LEDs Greenhouse Flowers Planting LED Growing Light Indoor Plants Hydroponics Flowers Vegetables LED Grow Light Alitade Waterproof WiFi Compatible with Alexa Plant Bulb Full Spectrum Grow Lights Indoor Plants Growing SANSI Daylight LED Grow Light Full Spectrum Sunlight LED Grow Lights Indoor Plants Vegetables LED Plant White Lights Indoor Garden Greenhouses UV Miracle LED Absolute Daylight Spectrum Grow Lite Replaces Full Spectrum Hydroponic LED Plant Growing Light Bulb Indoor Miracle LED Commercial Hydroponic Ultra Grow Lite Replaces Daylight White Full Spectrum LED Indoor Plant Growing Light Bulb For DIY Horticulture Indoor Gardening SANSI LED Grow Light Bulb Full Spectrum Grow Lights Indoor Plant Grow Light Hydroponic Indoor Garden Succulent Veg Plant Light Bulb Sunlight Full SANSI LED Grow Light Daylight White Full Spectrum Grow Lights Indoor LED Plant Light Bulbs Indoor Garden Commercial Hydroponic TCP Watt Equivalent LED Plant Light Bulb Shatter Resistant Energy Efficient Lamp Full Spectrum iPower LED Grow Light Bulb Indoor Hydroponics Plant Growing Garden Greenhouse Pack Red White Leds watt LED Plant Grow Light Bulb Standard Socket Bands Suitable All Stages of Growth Flowering Fruiting Electronix Express SecurityIng LED Grow Light LEDs Full Spectrum Plant Fill Growing Lamp Indoor Plants Garden Hydroponic Vegetable Greenhouse Organic AC LED Grow Light Bulb Indoor Plants Full Spectrum Lamp Seed Greenhouse Medicinal Growing Warm White Haus Bright LED Grow Light Bulb Indoor Plants Full Spectrum Lamp Seed Greenhouse Medicinal Growing Pure White Haus Bright SecurityIng LED Grow Light LEDs Full Spectrum Plant Fill Growing Lamp Indoor Plants Garden Hydroponic Vegetable Greenhouse Organic AC SGLEDS LED Sunlike Plant Grow Light Bulb Full Spectrum Daylight Indoor Garden Houseplants Vegetables Flowers Greenhouse Hydroponic Growing Seeds Greens Flowering Fruiting BOSYTRO LED Plant Grow Light Bulb Full Spectrum Indoor Plants Light Growing Standard Lamp Hydroponic Indoor Garden Greenhouse Succulent Veg Flower Watt Equivalent Grow Light Led Grow Light with High Transmittance Clear Cover Indoor Blue Red Feit Electric Blue Red Spectrums Feit Electric Equivalent Indoor Greenhouse Garden Outdoor Full Plant Grow Light Blue red spectrums GE Grow Light Grow Light Bulb Indoor Full Balanced Lighting Seeds Greens GE Grow Light Grow Light Bulb Indoor Full Red Reproductive Spectrum Flowering Fruiting

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

wordcloud = WordCloud(width = 1000, height = 500).generate(textstring)

plt.figure(figsize=(15,8))
plt.imshow(wordcloud)
