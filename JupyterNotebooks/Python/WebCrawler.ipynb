# %%
from bs4 import BeautifulSoup
import requests
import requests.exceptions
from urllib.parse import urlsplit
from urllib.parse import urlparse
from collections import deque
import codecs

# %%
def get_page_title(url):
    
    try:    
        response = requests.get(url)
        titlesoup = BeautifulSoup(response.text, 'lxml')
        return titlesoup.title.text.strip()
    except:
        return "None"
    
    return titlesoup.title.text.strip()

# %%
def well_formed_anchor(anchor,debug):
    
    no_hash = anchor.find('#') == -1
    non_zero_length = len(anchor)>1
    not_js = anchor.find('javascript')==-1
    no_q = anchor.find('?')==-1
    not_pdf = anchor.find('.pdf')==-1
    not_svg = anchor.find('.svg')==-1
    no_colons = anchor[6:].find(':')==-1
    not_go = anchor.find('.go')==-1
    no_rel = anchor.find('..')==-1
    
    if debug:
        print (no_hash,non_zero_length,not_js,no_q,not_svg,no_colons,not_go)
    
    if non_zero_length and no_rel and no_hash and not_js and no_q and not_pdf and not_svg and no_colons and not_go:
        well_formed = True
    else:
        well_formed = False
        
    return well_formed

# %%
url = 'http://www.cnu.edu/'

# a queue of urls to be crawled next
new_urls = deque([url])
new_url_title = get_page_title(new_urls[0])
f = codecs.open("crawl.csv", "w", "utf-8")
#print ('url_source,url_target,page_title_target')
print ("%s,%s,%s" % ('None',new_urls[0],new_url_title))
f.write(u'url_source,url_target,page_title_target\n')
f.write(u"%s,%s,%s\n" % ('None',new_urls[0],new_url_title))

# a set of urls that we have already processed 
processed_urls = set()

# a set of domains inside the target website
local_urls = set()

# a set of domains outside the target website
foreign_urls = set()

# a set of broken urls
broken_urls = set()
# Out:
# None,http://www.cnu.edu/,Home - Christopher Newport University - Christopher Newport University

# %%
# process urls one by one until we exhaust the queue
link_counter = 1
max_link = 100
debug = True

while len(new_urls)>0:

    # move url from the queue to processed url set    
    url = new_urls.popleft()    
    processed_urls.add(url)
    # print(new_urls)
    
    # Now, get the source code of the current url being processed.  Check to make
    # sure that there are no obvious problems with this source code.  If there is,
    # add this url to the broken_urls list.
    try:    
        response = requests.get(url)
    except(requests.exceptions.MissingSchema, requests.exceptions.ConnectionError, requests.exceptions.InvalidURL, requests.exceptions.InvalidSchema):    
        # add broken urls to it’s own set, then continue    
        broken_urls.add(url)    
        continue
        
    # Extract base url to resolve relative links
    # 
    # This is not strictly necessary for this exercise, as all of the links
    # on all of the pages are within this one website, but it is good practice
    # in general.  We can refer to these variables later in the code, too ...
    parts = urlsplit(url)
    base = '{0.netloc}'.format(parts)
    strip_base = base.replace('www.', '')
    processed_urls.add(strip_base)
    base_url = '{0.scheme}://{0.netloc}'.format(parts)
    path = url[:url.rfind('/')+1] if '/' in parts.path else url
    
    #print (parts)
    #print (base)
    if debug: print (strip_base)
    if debug: print (base_url)
    if debug: print (path)
    
    # Extract the source code for this url into a BeautifulSoup object for processing
    soup = BeautifulSoup(response.text, 'lxml')
    
    page_link_counter = 0
    # Loop through all of the links found on the page corresponding to this url
    for link in soup.find_all('a'): 
        
        if page_link_counter == 20:
            break
        
        # extract link url from the anchor    
        anchor = link.attrs['href'] if 'href' in link.attrs else ''
        
        if debug: print ('----------------')
        if debug: print (anchor)
        
        # Check to see what the anchor looks like ... based on this, add the link
        # to either the local_urls set or the foreign_urls set.
        
        well_formed = well_formed_anchor(anchor,debug)
            
        if anchor.endswith('/'):
            anchor = anchor[:-1]
            
        if debug: print ('-------stripped---------')
        if debug: print (anchor,well_formed)
            
        if anchor.startswith('/') and well_formed:
            if debug: print ('here 1')
            local_link = base_url + anchor        
            local_urls.add(local_link)    
        elif strip_base in anchor and well_formed:
            if debug: print ('here 2')
            local_urls.add(anchor)    
        elif not anchor.startswith('http') and well_formed:
            if debug: print ('here 3')
            if path.endswith('/'):
                local_link = path + anchor
            else:
                local_link = path + '/' + anchor
            local_urls.add(local_link)
        else:
            if debug: print ('here 4')
            foreign_urls.add(anchor)
        
        #print(local_urls)
        #print(foreign_urls)
        
        # Finally, for all of the links in the local urls list, if it is not already
        # in the new_urls set, and it is not already in the processed_urls set, add
        # the link to the new_urls set.
        #
        # N.B.  If we add the url using 'append', it adds it to the END of new_urls list
        # So, this is going to be a breadth-first crawling algorithm!
        for i in local_urls:    
            if not i in new_urls and not i in processed_urls and link_counter < max_link:
                new_urls.append(i)
                page_link_counter = page_link_counter + 1
                link_counter = link_counter + 1
                print ("link_counter, page_link_counter = ",link_counter,page_link_counter)   
                #print('Adding %s to queue ... from %s' % (i,url))
                new_url_title = get_page_title(i)
                #print ("Page title = ",new_url_title)
                if debug: print ("%s,%s,%s" % (url,i,new_url_title))
                f.write(u"%s,%s,%s\n" % (url,i,new_url_title))
        if link_counter >= max_link:
            break
            
        #print ('end of loop',new_urls)

    if link_counter >= max_link:
        print ('Done!!')
        break

        
f.close()
# Out:
# cnu.edu
# http://www.cnu.edu
# http://www.cnu.edu/
# ----------------
# http://cnu.edu/coronavirus
# True True True True True True True
# -------stripped---------
# http://cnu.edu/coronavirus True
# here 2
# link_counter, page_link_counter =  2 1
# http://www.cnu.edu/,http://cnu.edu/coronavirus,COVID-19 Information - COVID-19 Information - Christopher Newport University
# ----------------
# http://cnu.edu/visit/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/visit/index.html True
# here 2
# link_counter, page_link_counter =  3 2
# http://www.cnu.edu/,http://cnu.edu/visit/index.html,Visit - Visit - Christopher Newport University
# ----------------
# http://cnu.edu/admission/freshman/howtoapply/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/admission/freshman/howtoapply/index.html True
# here 2
# link_counter, page_link_counter =  4 3
# http://www.cnu.edu/,http://cnu.edu/admission/freshman/howtoapply/index.html,How to Apply - How to Apply - Christopher Newport University
# ----------------
# http://cnu.edu/tuition/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/tuition/index.html True
# here 2
# link_counter, page_link_counter =  5 4
# http://www.cnu.edu/,http://cnu.edu/tuition/index.html,Tuition - Tuition - Christopher Newport University
# ----------------
# http://cnu.edu/giving/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/giving/index.html True
# here 2
# link_counter, page_link_counter =  6 5
# http://www.cnu.edu/,http://cnu.edu/giving/index.html,Home - Defining Significance - Christopher Newport University
# ----------------
# https://my.cnu.edu
# True True True True True True True
# -------stripped---------
# https://my.cnu.edu True
# here 2
# link_counter, page_link_counter =  7 6
# http://www.cnu.edu/,https://my.cnu.edu,myCNU - myCNU - Christopher Newport University
# ----------------
# http://cnu.edu/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/index.html True
# here 2
# link_counter, page_link_counter =  8 7
# http://www.cnu.edu/,http://cnu.edu/index.html,Home - Christopher Newport University - Christopher Newport University
# ----------------
# #
# False False True True True True True
# -------stripped---------
# # False
# here 4
# ----------------
# http://cnu.edu/whoweare/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/whoweare/index.html True
# here 2
# link_counter, page_link_counter =  9 8
# http://www.cnu.edu/,http://cnu.edu/whoweare/index.html,Who We Are - Who We Are - Christopher Newport University
# ----------------
# http://cnu.edu/academics/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/academics/index.html True
# here 2
# link_counter, page_link_counter =  10 9
# http://www.cnu.edu/,http://cnu.edu/academics/index.html,Academics - Academics - Christopher Newport University
# ----------------
# http://cnu.edu/life/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/life/index.html True
# here 2
# link_counter, page_link_counter =  11 10
# http://www.cnu.edu/,http://cnu.edu/life/index.html,Life at CNU - Life at CNU - Christopher Newport University
# ----------------
# http://cnu.edu/admission/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/admission/index.html True
# here 2
# link_counter, page_link_counter =  12 11
# http://www.cnu.edu/,http://cnu.edu/admission/index.html,Admission - Admission - Christopher Newport University
# ----------------
# http://cnusports.com
# True True True True True True True
# -------stripped---------
# http://cnusports.com True
# here 4
# ----------------
# http://cnu.edu/academics/areasofstudy/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/academics/areasofstudy/index.html True
# here 2
# link_counter, page_link_counter =  13 12
# http://www.cnu.edu/,http://cnu.edu/academics/areasofstudy/index.html,Areas of Study - Areas of Study - Christopher Newport University
# ----------------
# http://cnu.edu/visit/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/visit/index.html True
# here 2
# ----------------
# http://cnu.edu/admission/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/admission/index.html True
# here 2
# ----------------
# http://cnu.edu/academics/plp/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/academics/plp/index.html True
# here 2
# link_counter, page_link_counter =  14 13
# http://www.cnu.edu/,http://cnu.edu/academics/plp/index.html,President's Leadership Program - President's Leadership Program - Christopher Newport University
# ----------------
# http://cnu.edu/news/2021/02/22-psyc-f_lee/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/news/2021/02/22-psyc-f_lee/index.html True
# here 2
# link_counter, page_link_counter =  15 14
# http://www.cnu.edu/,http://cnu.edu/news/2021/02/22-psyc-f_lee/index.html,Professor contributes to new Hospice book on pandemic - Newsroom - Christopher Newport University
# ----------------
# http://cnu.edu/news/2021/02/09-lams-major/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/news/2021/02/09-lams-major/index.html True
# here 2
# link_counter, page_link_counter =  16 15
# http://www.cnu.edu/,http://cnu.edu/news/2021/02/09-lams-major/index.html,Class of ’21 Prepares to Lead - Newsroom - Christopher Newport University
# ----------------
# http://cnu.edu/news/2021/02/08-cnu-idst/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/news/2021/02/08-cnu-idst/index.html True
# here 2
# link_counter, page_link_counter =  17 16
# http://www.cnu.edu/,http://cnu.edu/news/2021/02/08-cnu-idst/index.html,Customized College - Newsroom - Christopher Newport University
# ----------------
# http://cnu.edu/news/2021/02/03-cnu-strive/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/news/2021/02/03-cnu-strive/index.html True
# here 2
# link_counter, page_link_counter =  18 17
# http://www.cnu.edu/,http://cnu.edu/news/2021/02/03-cnu-strive/index.html,Christopher Newport Featured In 2021 I’m First! Guide To College - Newsroom - Christopher Newport University
# ----------------
# http://cnu.edu/news/2021/01/20-faah-a18_chung/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/news/2021/01/20-faah-a18_chung/index.html True
# here 2
# link_counter, page_link_counter =  19 18
# http://www.cnu.edu/,http://cnu.edu/news/2021/01/20-faah-a18_chung/index.html,Art Alum Sees With Eyes of Hope - Newsroom - Christopher Newport University
# ----------------
# http://cnu.edu/news/2021/01/12-busn-poets_quants/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/news/2021/01/12-busn-poets_quants/index.html True
# here 2
# link_counter, page_link_counter =  20 19
# http://www.cnu.edu/,http://cnu.edu/news/2021/01/12-busn-poets_quants/index.html,New Ranking Highlights the Value of a Luter School Business Degree - Newsroom - Christopher Newport University
# ----------------
# http://cnu.edu/news/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/news/index.html True
# here 2
# link_counter, page_link_counter =  21 20
# http://www.cnu.edu/,http://cnu.edu/news/index.html,News - Newsroom - Christopher Newport University
# cnu.edu
# http://cnu.edu
# http://cnu.edu/
# ----------------
# http://cnu.edu/coronavirus
# True True True True True True True
# -------stripped---------
# http://cnu.edu/coronavirus True
# here 2
# ----------------
# http://cnu.edu/visit/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/visit/index.html True
# here 2
# ----------------
# http://cnu.edu/admission/freshman/howtoapply/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/admission/freshman/howtoapply/index.html True
# here 2
# ----------------
# http://cnu.edu/tuition/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/tuition/index.html True
# here 2
# ----------------
# http://cnu.edu/giving/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/giving/index.html True
# here 2
# ----------------
# https://my.cnu.edu
# True True True True True True True
# -------stripped---------
# https://my.cnu.edu True
# here 2
# ----------------
# http://cnu.edu/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/index.html True
# here 2
# ----------------
# #
# False False True True True True True
# -------stripped---------
# # False
# here 4
# ----------------
# http://cnu.edu/whoweare/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/whoweare/index.html True
# here 2
# ----------------
# http://cnu.edu/academics/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/academics/index.html True
# here 2
# ----------------
# http://cnu.edu/life/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/life/index.html True
# here 2
# ----------------
# http://cnu.edu/admission/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/admission/index.html True
# here 2
# ----------------
# http://cnusports.com
# True True True True True True True
# -------stripped---------
# http://cnusports.com True
# here 4
# ----------------
# http://cnu.edu/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/index.html True
# here 2
# ----------------
# mailto:hr-tracker@cnu.edu
# True True True True True False True
# -------stripped---------
# mailto:hr-tracker@cnu.edu False
# here 4
# ----------------
# mailto:dosa@cnu.edu
# True True True True True False True
# -------stripped---------
# mailto:dosa@cnu.edu False
# here 4
# ----------------
# operations/students/index.html
# True True True True True True True
# -------stripped---------
# operations/students/index.html True
# here 3
# link_counter, page_link_counter =  22 1
# http://cnu.edu/coronavirus,http://cnu.edu/operations/students/index.html,Error - 404-Page Not Found - Christopher Newport University
# ----------------
# operations/employees/index.html
# True True True True True True True
# -------stripped---------
# operations/employees/index.html True
# here 3
# link_counter, page_link_counter =  23 2
# http://cnu.edu/coronavirus,http://cnu.edu/operations/employees/index.html,Error - 404-Page Not Found - Christopher Newport University
# ----------------
# operations/visitors/index.html
# True True True True True True True
# -------stripped---------
# operations/visitors/index.html True
# here 3
# link_counter, page_link_counter =  24 3
# http://cnu.edu/coronavirus,http://cnu.edu/operations/visitors/index.html,Error - 404-Page Not Found - Christopher Newport University
# ----------------
# index.html
# True True True True True True True
# -------stripped---------
# index.html True
# here 3
# ----------------
# dashboard/index.html
# True True True True True True True
# -------stripped---------
# dashboard/index.html True
# here 3
# link_counter, page_link_counter =  25 4
# http://cnu.edu/coronavirus,http://cnu.edu/dashboard/index.html,Error - 404-Page Not Found - Christopher Newport University
# ----------------
# testing/index.html
# True True True True True True True
# -------stripped---------
# testing/index.html True
# here 3
# link_counter, page_link_counter =  26 5
# http://cnu.edu/coronavirus,http://cnu.edu/testing/index.html,Error - 404-Page Not Found - Christopher Newport University
# ----------------
# operations/index.html
# True True True True True True True
# -------stripped---------
# operations/index.html True
# here 3
# link_counter, page_link_counter =  27 6
# http://cnu.edu/coronavirus,http://cnu.edu/operations/index.html,403 Forbidden
# ----------------
# communications/index.html
# True True True True True True True
# -------stripped---------
# communications/index.html True
# here 3
# link_counter, page_link_counter =  28 7
# http://cnu.edu/coronavirus,http://cnu.edu/communications/index.html,Communication - Redirecting - Christopher Newport University
# ----------------
# protocols/index.html
# True True True True True True True
# -------stripped---------
# protocols/index.html True
# here 3
# link_counter, page_link_counter =  29 8
# http://cnu.edu/coronavirus,http://cnu.edu/protocols/index.html,Error - 404-Page Not Found - Christopher Newport University
# ----------------
# contract/index.html
# True True True True True True True
# -------stripped---------
# contract/index.html True
# here 3
# link_counter, page_link_counter =  30 9
# http://cnu.edu/coronavirus,http://cnu.edu/contract/index.html,Error - 404-Page Not Found - Christopher Newport University
# ----------------
# plan/index.html
# True True True True True True True
# -------stripped---------
# plan/index.html True
# here 3
# link_counter, page_link_counter =  31 10
# http://cnu.edu/coronavirus,http://cnu.edu/plan/index.html,Error - 404-Page Not Found - Christopher Newport University
# ----------------
# caresact/index.html
# True True True True True True True
# -------stripped---------
# caresact/index.html True
# here 3
# link_counter, page_link_counter =  32 11
# http://cnu.edu/coronavirus,http://cnu.edu/caresact/index.html,Error - 404-Page Not Found - Christopher Newport University
# ----------------
# http://cnu.edu/relaunch/tracker/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/relaunch/tracker/index.html True
# here 2
# link_counter, page_link_counter =  33 12
# http://cnu.edu/coronavirus,http://cnu.edu/relaunch/tracker/index.html,Symptom Tracker - Captains Relaunch - Christopher Newport University
# ----------------
# https://cnu.rivhs.net/
# True True True True True True True
# -------stripped---------
# https://cnu.rivhs.net True
# here 4
# ----------------
# https://mychart.riversideonline.com/mychart/Authentication/Login?
# True True True False True True True
# -------stripped---------
# https://mychart.riversideonline.com/mychart/Authentication/Login? False
# here 4
# ----------------
# https://www.vdh.virginia.gov/covidwise/
# True True True True True True False
# -------stripped---------
# https://www.vdh.virginia.gov/covidwise False
# here 4
# ----------------
# https://www.vdh.virginia.gov/coronavirus/covid-19-testing/covid-19-testing-sites/
# True True True True True True False
# -------stripped---------
# https://www.vdh.virginia.gov/coronavirus/covid-19-testing/covid-19-testing-sites False
# here 4
# ----------------
# https://covid19.va.education/
# True True True True True True True
# -------stripped---------
# https://covid19.va.education True
# here 4
# ----------------
# //cnu.edu/news/widgets/covid-19/index.html
# True True True True True True True
# -------stripped---------
# //cnu.edu/news/widgets/covid-19/index.html True
# here 1
# link_counter, page_link_counter =  34 13
# http://cnu.edu/coronavirus,http://cnu.edu//cnu.edu/news/widgets/covid-19/index.html,Error - 404-Page Not Found - Christopher Newport University
# ----------------
# //cnu.edu/news/category/covid-19/index.html
# True True True True True True True
# -------stripped---------
# //cnu.edu/news/category/covid-19/index.html True
# here 1
# link_counter, page_link_counter =  35 14
# http://cnu.edu/coronavirus,http://cnu.edu//cnu.edu/news/category/covid-19/index.html,Error - 404-Page Not Found - Christopher Newport University
# ----------------
# javascript:emailCurrentPage()
# True True False True True False True
# -------stripped---------
# javascript:emailCurrentPage() False
# here 4
# ----------------
# javascript:window.print()
# True True False True True False True
# -------stripped---------
# javascript:window.print() False
# here 4
# ----------------
# https://get.adobe.com/reader/
# True True True True True True True
# -------stripped---------
# https://get.adobe.com/reader True
# here 4
# ----------------
# #
# False False True True True True True
# -------stripped---------
# # False
# here 4
# ----------------
# #
# False False True True True True True
# -------stripped---------
# # False
# here 4
# ----------------
# http://cnu.edu/hr/employment/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/hr/employment/index.html True
# here 2
# link_counter, page_link_counter =  36 15
# http://cnu.edu/coronavirus,http://cnu.edu/hr/employment/index.html,Employment - Human Resources - Christopher Newport University
# ----------------
# http://cnu.edu/public/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/public/index.html True
# here 2
# link_counter, page_link_counter =  37 16
# http://cnu.edu/coronavirus,http://cnu.edu/public/index.html,Public Information - Public Information - Christopher Newport University
# ----------------
# http://cnu.edu/public/calendar/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/public/calendar/index.html True
# here 2
# link_counter, page_link_counter =  38 17
# http://cnu.edu/coronavirus,http://cnu.edu/public/calendar/index.html,Academic Calendar - Public Information - Christopher Newport University
# ----------------
# http://cnu.edu/visit/campusmap/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/visit/campusmap/index.html True
# here 2
# link_counter, page_link_counter =  39 18
# http://cnu.edu/coronavirus,http://cnu.edu/visit/campusmap/index.html,Campus Map - Visit - Christopher Newport University
# ----------------
# http://cnu.edu/studentconsumerinfo/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/studentconsumerinfo/index.html True
# here 2
# link_counter, page_link_counter =  40 19
# http://cnu.edu/coronavirus,http://cnu.edu/studentconsumerinfo/index.html,Student Consumer Information - Student Consumer Information - Christopher Newport University
# ----------------
# http://www.youvisit.com
# True True True True True True True
# -------stripped---------
# http://www.youvisit.com True
# here 4
# ----------------
# https://www.facebook.com/christophernewportuniversity
# True True True True True True True
# -------stripped---------
# https://www.facebook.com/christophernewportuniversity True
# here 4
# ----------------
# https://twitter.com/cnucaptains
# True True True True True True True
# -------stripped---------
# https://twitter.com/cnucaptains True
# here 4
# ----------------
# http://instagram.com/christophernewportu
# True True True True True True True
# -------stripped---------
# http://instagram.com/christophernewportu True
# here 4
# ----------------
# http://www.youtube.com/christophernewportu
# True True True True True True True
# -------stripped---------
# http://www.youtube.com/christophernewportu True
# here 4
# ----------------
# https://www.linkedin.com/edu/christopher-newport-university-19570
# True True True True True True True
# -------stripped---------
# https://www.linkedin.com/edu/christopher-newport-university-19570 True
# here 4
# ----------------
# http://cnu.edu/library/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/library/index.html True
# here 2
# link_counter, page_link_counter =  41 20
# http://cnu.edu/coronavirus,http://cnu.edu/library/index.html,Trible Library - Trible Library - Christopher Newport University
# cnu.edu
# http://cnu.edu
# http://cnu.edu/visit/
# ----------------
# http://cnu.edu/coronavirus
# True True True True True True True
# -------stripped---------
# http://cnu.edu/coronavirus True
# here 2
# ----------------
# http://cnu.edu/visit/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/visit/index.html True
# here 2
# ----------------
# http://cnu.edu/admission/freshman/howtoapply/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/admission/freshman/howtoapply/index.html True
# here 2
# ----------------
# http://cnu.edu/tuition/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/tuition/index.html True
# here 2
# ----------------
# http://cnu.edu/giving/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/giving/index.html True
# here 2
# ----------------
# https://my.cnu.edu
# True True True True True True True
# -------stripped---------
# https://my.cnu.edu True
# here 2
# ----------------
# http://cnu.edu/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/index.html True
# here 2
# ----------------
# #
# False False True True True True True
# -------stripped---------
# # False
# here 4
# ----------------
# http://cnu.edu/whoweare/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/whoweare/index.html True
# here 2
# ----------------
# http://cnu.edu/academics/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/academics/index.html True
# here 2
# ----------------
# http://cnu.edu/life/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/life/index.html True
# here 2
# ----------------
# http://cnu.edu/admission/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/admission/index.html True
# here 2
# ----------------
# http://cnusports.com
# True True True True True True True
# -------stripped---------
# http://cnusports.com True
# here 4
# ----------------
# http://cnu.edu/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/index.html True
# here 2
# ----------------
# http://cnu.edu/admission/freshman/toursandevents/tour/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/admission/freshman/toursandevents/tour/index.html True
# here 2
# link_counter, page_link_counter =  42 1
# http://cnu.edu/visit/index.html,http://cnu.edu/admission/freshman/toursandevents/tour/index.html,Campus Tours - Freshman Admission - Christopher Newport University
# ----------------
# http://cnu.edu/admission/freshman/interviews/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/admission/freshman/interviews/index.html True
# here 2
# link_counter, page_link_counter =  43 2
# http://cnu.edu/visit/index.html,http://cnu.edu/admission/freshman/interviews/index.html,Interviews - Freshman Admission - Christopher Newport University
# ----------------
# http://cnu.edu/admission/freshman/toursandevents/tour/index.html#qanda
# False True True True True True True
# -------stripped---------
# http://cnu.edu/admission/freshman/toursandevents/tour/index.html#qanda False
# here 4
# ----------------
# http://cnu.edu/admission/freshman/interviews/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/admission/freshman/interviews/index.html True
# here 2
# ----------------
# https://youtu.be/rpelLcXv-5w
# True True True True True True True
# -------stripped---------
# https://youtu.be/rpelLcXv-5w True
# here 4
# ----------------
# http://www.youvisit.com
# True True True True True True True
# -------stripped---------
# http://www.youvisit.com True
# here 4
# ----------------
# index.html
# True True True True True True True
# -------stripped---------
# index.html True
# here 3
# ----------------
# campusmap/index.html
# True True True True True True True
# -------stripped---------
# campusmap/index.html True
# here 3
# ----------------
# todo/index.html
# True True True True True True True
# -------stripped---------
# todo/index.html True
# here 3
# link_counter, page_link_counter =  44 3
# http://cnu.edu/visit/index.html,http://cnu.edu/visit/todo/index.html,Things to Do - Visit - Christopher Newport University
# ----------------
# dining/index.html
# True True True True True True True
# -------stripped---------
# dining/index.html True
# here 3
# link_counter, page_link_counter =  45 4
# http://cnu.edu/visit/index.html,http://cnu.edu/visit/dining/index.html,Dining - Visit - Christopher Newport University
# ----------------
# accommodations/index.html
# True True True True True True True
# -------stripped---------
# accommodations/index.html True
# here 3
# link_counter, page_link_counter =  46 5
# http://cnu.edu/visit/index.html,http://cnu.edu/visit/accommodations/index.html,Accommodations - Visit - Christopher Newport University
# ----------------
# directions/index.html
# True True True True True True True
# -------stripped---------
# directions/index.html True
# here 3
# link_counter, page_link_counter =  47 6
# http://cnu.edu/visit/index.html,http://cnu.edu/visit/directions/index.html,Directions - Visit - Christopher Newport University
# ----------------
# http://cnu.edu/families/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/families/index.html True
# here 2
# link_counter, page_link_counter =  48 7
# http://cnu.edu/visit/index.html,http://cnu.edu/families/index.html,For Families - For Families - Christopher Newport University
# ----------------
# javascript:emailCurrentPage()
# True True False True True False True
# -------stripped---------
# javascript:emailCurrentPage() False
# here 4
# ----------------
# javascript:window.print()
# True True False True True False True
# -------stripped---------
# javascript:window.print() False
# here 4
# ----------------
# https://get.adobe.com/reader/
# True True True True True True True
# -------stripped---------
# https://get.adobe.com/reader True
# here 4
# ----------------
# #
# False False True True True True True
# -------stripped---------
# # False
# here 4
# ----------------
# #
# False False True True True True True
# -------stripped---------
# # False
# here 4
# ----------------
# http://cnu.edu/admission/freshman/_pdf/cnu-visitor_guidelines.pdf
# True True True True True True True
# -------stripped---------
# http://cnu.edu/admission/freshman/_pdf/cnu-visitor_guidelines.pdf False
# here 4
# ----------------
# http://cnu.edu/hr/employment/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/hr/employment/index.html True
# here 2
# ----------------
# http://cnu.edu/public/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/public/index.html True
# here 2
# ----------------
# http://cnu.edu/public/calendar/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/public/calendar/index.html True
# here 2
# ----------------
# http://cnu.edu/visit/campusmap/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/visit/campusmap/index.html True
# here 2
# ----------------
# http://cnu.edu/studentconsumerinfo/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/studentconsumerinfo/index.html True
# here 2
# ----------------
# http://www.youvisit.com
# True True True True True True True
# -------stripped---------
# http://www.youvisit.com True
# here 4
# ----------------
# https://www.facebook.com/christophernewportuniversity
# True True True True True True True
# -------stripped---------
# https://www.facebook.com/christophernewportuniversity True
# here 4
# ----------------
# https://twitter.com/cnucaptains
# True True True True True True True
# -------stripped---------
# https://twitter.com/cnucaptains True
# here 4
# ----------------
# http://instagram.com/christophernewportu
# True True True True True True True
# -------stripped---------
# http://instagram.com/christophernewportu True
# here 4
# ----------------
# http://www.youtube.com/christophernewportu
# True True True True True True True
# -------stripped---------
# http://www.youtube.com/christophernewportu True
# here 4
# ----------------
# https://www.linkedin.com/edu/christopher-newport-university-19570
# True True True True True True True
# -------stripped---------
# https://www.linkedin.com/edu/christopher-newport-university-19570 True
# here 4
# ----------------
# http://cnu.edu/library/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/library/index.html True
# here 2
# ----------------
# https://admit.cnu.edu/register/?id=bb901bd9-ff61-4ff8-8d3e-d36a181f8548
# True True True False True True True
# -------stripped---------
# https://admit.cnu.edu/register/?id=bb901bd9-ff61-4ff8-8d3e-d36a181f8548 False
# here 4
# ----------------
# http://cnu.edu/public/safety/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/public/safety/index.html True
# here 2
# link_counter, page_link_counter =  49 8
# http://cnu.edu/visit/index.html,http://cnu.edu/public/safety/index.html,Campus Safety - Campus Safety - Christopher Newport University
# ----------------
# http://cnu.edu/titleixeo/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/titleixeo/index.html True
# here 2
# link_counter, page_link_counter =  50 9
# http://cnu.edu/visit/index.html,http://cnu.edu/titleixeo/index.html,Title IX and Equal Opportunity - Title IX and Equal Opportunity - Christopher Newport University
# ----------------
# http://cnualert.info/
# True True True True True True True
# -------stripped---------
# http://cnualert.info True
# here 4
# ----------------
# https://cascade.cnu.edu/entity/open.act?id=6f714c890a02005e338d85352b4babe6&type=page
# True True True False True True True
# -------stripped---------
# https://cascade.cnu.edu/entity/open.act?id=6f714c890a02005e338d85352b4babe6&type=page False
# here 4
# ----------------
# https://christophernewport.wufoo.com/forms/k1t49gti0wt9a8g/
# True True True True True True True
# -------stripped---------
# https://christophernewport.wufoo.com/forms/k1t49gti0wt9a8g True
# here 4
# cnu.edu
# http://cnu.edu
# http://cnu.edu/admission/freshman/howtoapply/
# ----------------
# http://cnu.edu/coronavirus
# True True True True True True True
# -------stripped---------
# http://cnu.edu/coronavirus True
# here 2
# ----------------
# http://cnu.edu/visit/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/visit/index.html True
# here 2
# ----------------
# http://cnu.edu/admission/freshman/howtoapply/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/admission/freshman/howtoapply/index.html True
# here 2
# ----------------
# http://cnu.edu/tuition/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/tuition/index.html True
# here 2
# ----------------
# http://cnu.edu/giving/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/giving/index.html True
# here 2
# ----------------
# https://my.cnu.edu
# True True True True True True True
# -------stripped---------
# https://my.cnu.edu True
# here 2
# ----------------
# http://cnu.edu/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/index.html True
# here 2
# ----------------
# #
# False False True True True True True
# -------stripped---------
# # False
# here 4
# ----------------
# http://cnu.edu/whoweare/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/whoweare/index.html True
# here 2
# ----------------
# http://cnu.edu/academics/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/academics/index.html True
# here 2
# ----------------
# http://cnu.edu/life/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/life/index.html True
# here 2
# ----------------
# http://cnu.edu/admission/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/admission/index.html True
# here 2
# ----------------
# http://cnusports.com
# True True True True True True True
# -------stripped---------
# http://cnusports.com True
# here 4
# ----------------
# http://cnu.edu/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/index.html True
# here 2
# ----------------
# ../../index.html
# True True True True True True True
# -------stripped---------
# ../../index.html False
# here 4
# ----------------
# ../index.html
# True True True True True True True
# -------stripped---------
# ../index.html False
# here 4
# ----------------
# https://www.commonapp.org/explore/christopher-newport-university
# True True True True True True True
# -------stripped---------
# https://www.commonapp.org/explore/christopher-newport-university True
# here 4
# ----------------
# https://www.mycoalition.org/public/info/cnu
# True True True True True True True
# -------stripped---------
# https://www.mycoalition.org/public/info/cnu True
# here 4
# ----------------
# http://cnu.edu/titleixeo/_pdf/cnu-notice_of_nondiscrimination_and_titleix_policy_statement.pdf
# True True True True True True True
# -------stripped---------
# http://cnu.edu/titleixeo/_pdf/cnu-notice_of_nondiscrimination_and_titleix_policy_statement.pdf False
# here 4
# ----------------
# http://cnu.edu/police/_pdf/annualreport.pdf
# True True True True True True True
# -------stripped---------
# http://cnu.edu/police/_pdf/annualreport.pdf False
# here 4
# ----------------
# ../../index.html
# True True True True True True True
# -------stripped---------
# ../../index.html False
# here 4
# ----------------
# ../index.html
# True True True True True True True
# -------stripped---------
# ../index.html False
# here 4
# ----------------
# index.html
# True True True True True True True
# -------stripped---------
# index.html True
# here 3
# ----------------
# requirements/index.html
# True True True True True True True
# -------stripped---------
# requirements/index.html True
# here 3
# link_counter, page_link_counter =  51 1
# http://cnu.edu/admission/freshman/howtoapply/index.html,http://cnu.edu/admission/freshman/howtoapply/requirements/index.html,Admission Requirements - How to Apply - Christopher Newport University
# ----------------
# https://admit.cnu.edu/portal/status
# True True True True True True True
# -------stripped---------
# https://admit.cnu.edu/portal/status True
# here 2
# link_counter, page_link_counter =  52 2
# http://cnu.edu/admission/freshman/howtoapply/index.html,https://admit.cnu.edu/portal/status,Login
# ----------------
# ../review/index.html
# True True True True True True True
# -------stripped---------
# ../review/index.html False
# here 4
# ----------------
# ../toursandevents/index.html
# True True True True True True True
# -------stripped---------
# ../toursandevents/index.html False
# here 4
# ----------------
# ../interviews/index.html
# True True True True True True True
# -------stripped---------
# ../interviews/index.html False
# here 4
# ----------------
# ../scholarships/index.html
# True True True True True True True
# -------stripped---------
# ../scholarships/index.html False
# here 4
# ----------------
# ../faq/index.html
# True True True True True True True
# -------stripped---------
# ../faq/index.html False
# here 4
# ----------------
# https://admit.cnu.edu/register/?id=bb901bd9-ff61-4ff8-8d3e-d36a181f8548
# True True True False True True True
# -------stripped---------
# https://admit.cnu.edu/register/?id=bb901bd9-ff61-4ff8-8d3e-d36a181f8548 False
# here 4
# ----------------
# ../people/index.html
# True True True True True True True
# -------stripped---------
# ../people/index.html False
# here 4
# ----------------
# ../tourguides/index.html
# True True True True True True True
# -------stripped---------
# ../tourguides/index.html False
# here 4
# ----------------
# ../hscounselor/index.html
# True True True True True True True
# -------stripped---------
# ../hscounselor/index.html False
# here 4
# ----------------
# ../communitycaptains/index.html
# True True True True True True True
# -------stripped---------
# ../communitycaptains/index.html False
# here 4
# ----------------
# testoptional/index.html
# True True True True True True True
# -------stripped---------
# testoptional/index.html True
# here 3
# link_counter, page_link_counter =  53 3
# http://cnu.edu/admission/freshman/howtoapply/index.html,http://cnu.edu/admission/freshman/howtoapply/testoptional/index.html,Test Optional - How to Apply - Christopher Newport University
# ----------------
# artmajor/index.html
# True True True True True True True
# -------stripped---------
# artmajor/index.html True
# here 3
# link_counter, page_link_counter =  54 4
# http://cnu.edu/admission/freshman/howtoapply/index.html,http://cnu.edu/admission/freshman/howtoapply/artmajor/index.html,Art Major Applicants - How to Apply - Christopher Newport University
# ----------------
# musicmajor/index.html
# True True True True True True True
# -------stripped---------
# musicmajor/index.html True
# here 3
# link_counter, page_link_counter =  55 5
# http://cnu.edu/admission/freshman/howtoapply/index.html,http://cnu.edu/admission/freshman/howtoapply/musicmajor/index.html,Music Major Applicants - How to Apply - Christopher Newport University
# ----------------
# theatermajor/index.html
# True True True True True True True
# -------stripped---------
# theatermajor/index.html True
# here 3
# link_counter, page_link_counter =  56 6
# http://cnu.edu/admission/freshman/howtoapply/index.html,http://cnu.edu/admission/freshman/howtoapply/theatermajor/index.html,Theater Major Applicants - How to Apply - Christopher Newport University
# ----------------
# homeschooled/index.html
# True True True True True True True
# -------stripped---------
# homeschooled/index.html True
# here 3
# link_counter, page_link_counter =  57 7
# http://cnu.edu/admission/freshman/howtoapply/index.html,http://cnu.edu/admission/freshman/howtoapply/homeschooled/index.html,Home-Schooled Applicants - How to Apply - Christopher Newport University
# ----------------
# http://cnu.edu/registrar/placement/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/registrar/placement/index.html True
# here 2
# link_counter, page_link_counter =  58 8
# http://cnu.edu/admission/freshman/howtoapply/index.html,http://cnu.edu/registrar/placement/index.html,Placement Credit - Office of the Registrar - Christopher Newport University
# ----------------
# javascript:emailCurrentPage()
# True True False True True False True
# -------stripped---------
# javascript:emailCurrentPage() False
# here 4
# ----------------
# javascript:window.print()
# True True False True True False True
# -------stripped---------
# javascript:window.print() False
# here 4
# ----------------
# https://get.adobe.com/reader/
# True True True True True True True
# -------stripped---------
# https://get.adobe.com/reader True
# here 4
# ----------------
# #
# False False True True True True True
# -------stripped---------
# # False
# here 4
# ----------------
# #
# False False True True True True True
# -------stripped---------
# # False
# here 4
# ----------------
# mailto:admit@cnu.edu
# True True True True True False True
# -------stripped---------
# mailto:admit@cnu.edu False
# here 4
# ----------------
# http://twitter.com/CNU_Admission
# True True True True True True True
# -------stripped---------
# http://twitter.com/CNU_Admission True
# here 4
# ----------------
# https://www.instagram.com/cnu_admission/
# True True True True True True True
# -------stripped---------
# https://www.instagram.com/cnu_admission True
# here 4
# ----------------
# ../_pdf/cnu-visitor_guidelines.pdf
# True True True True True True True
# -------stripped---------
# ../_pdf/cnu-visitor_guidelines.pdf False
# here 4
# ----------------
# http://cnu.edu/visit/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/visit/index.html True
# here 2
# ----------------
# http://cnu.edu/hr/employment/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/hr/employment/index.html True
# here 2
# ----------------
# http://cnu.edu/public/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/public/index.html True
# here 2
# ----------------
# http://cnu.edu/public/calendar/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/public/calendar/index.html True
# here 2
# ----------------
# http://cnu.edu/visit/campusmap/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/visit/campusmap/index.html True
# here 2
# ----------------
# http://cnu.edu/studentconsumerinfo/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/studentconsumerinfo/index.html True
# here 2
# ----------------
# http://www.youvisit.com
# True True True True True True True
# -------stripped---------
# http://www.youvisit.com True
# here 4
# ----------------
# https://www.facebook.com/christophernewportuniversity
# True True True True True True True
# -------stripped---------
# https://www.facebook.com/christophernewportuniversity True
# here 4
# ----------------
# https://twitter.com/cnucaptains
# True True True True True True True
# -------stripped---------
# https://twitter.com/cnucaptains True
# here 4
# ----------------
# http://instagram.com/christophernewportu
# True True True True True True True
# -------stripped---------
# http://instagram.com/christophernewportu True
# here 4
# ----------------
# http://www.youtube.com/christophernewportu
# True True True True True True True
# -------stripped---------
# http://www.youtube.com/christophernewportu True
# here 4
# ----------------
# https://www.linkedin.com/edu/christopher-newport-university-19570
# True True True True True True True
# -------stripped---------
# https://www.linkedin.com/edu/christopher-newport-university-19570 True
# here 4
# ----------------
# http://cnu.edu/library/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/library/index.html True
# here 2
# ----------------
# https://admit.cnu.edu/register/?id=bb901bd9-ff61-4ff8-8d3e-d36a181f8548
# True True True False True True True
# -------stripped---------
# https://admit.cnu.edu/register/?id=bb901bd9-ff61-4ff8-8d3e-d36a181f8548 False
# here 4
# ----------------
# http://cnu.edu/public/safety/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/public/safety/index.html True
# here 2
# ----------------
# http://cnu.edu/titleixeo/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/titleixeo/index.html True
# here 2
# ----------------
# http://cnualert.info/
# True True True True True True True
# -------stripped---------
# http://cnualert.info True
# here 4
# ----------------
# https://cascade.cnu.edu/entity/open.act?id=314d065a0a02005e338d85354d25adc4&type=page
# True True True False True True True
# -------stripped---------
# https://cascade.cnu.edu/entity/open.act?id=314d065a0a02005e338d85354d25adc4&type=page False
# here 4
# ----------------
# https://christophernewport.wufoo.com/forms/k1t49gti0wt9a8g/
# True True True True True True True
# -------stripped---------
# https://christophernewport.wufoo.com/forms/k1t49gti0wt9a8g True
# here 4
# cnu.edu
# http://cnu.edu
# http://cnu.edu/tuition/
# ----------------
# http://cnu.edu/coronavirus
# True True True True True True True
# -------stripped---------
# http://cnu.edu/coronavirus True
# here 2
# ----------------
# http://cnu.edu/visit/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/visit/index.html True
# here 2
# ----------------
# http://cnu.edu/admission/freshman/howtoapply/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/admission/freshman/howtoapply/index.html True
# here 2
# ----------------
# http://cnu.edu/tuition/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/tuition/index.html True
# here 2
# ----------------
# http://cnu.edu/giving/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/giving/index.html True
# here 2
# ----------------
# https://my.cnu.edu
# True True True True True True True
# -------stripped---------
# https://my.cnu.edu True
# here 2
# ----------------
# http://cnu.edu/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/index.html True
# here 2
# ----------------
# #
# False False True True True True True
# -------stripped---------
# # False
# here 4
# ----------------
# http://cnu.edu/whoweare/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/whoweare/index.html True
# here 2
# ----------------
# http://cnu.edu/academics/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/academics/index.html True
# here 2
# ----------------
# http://cnu.edu/life/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/life/index.html True
# here 2
# ----------------
# http://cnu.edu/admission/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/admission/index.html True
# here 2
# ----------------
# http://cnusports.com
# True True True True True True True
# -------stripped---------
# http://cnusports.com True
# here 4
# ----------------
# http://cnu.edu/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/index.html True
# here 2
# ----------------
# https://commerce.cashnet.com/cashneti/SelfServe/eBillLogin.aspx?client=CNU_PROD
# True True True False True True True
# -------stripped---------
# https://commerce.cashnet.com/cashneti/SelfServe/eBillLogin.aspx?client=CNU_PROD False
# here 4
# ----------------
# index.html
# True True True True True True True
# -------stripped---------
# index.html True
# here 3
# ----------------
# instate/index.html
# True True True True True True True
# -------stripped---------
# instate/index.html True
# here 3
# link_counter, page_link_counter =  59 1
# http://cnu.edu/tuition/index.html,http://cnu.edu/tuition/instate/index.html,Eligibility for In-State Tuition - Tuition - Christopher Newport University
# ----------------
# http://cnu.edu/businessoffice/payment/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/businessoffice/payment/index.html True
# here 2
# link_counter, page_link_counter =  60 2
# http://cnu.edu/tuition/index.html,http://cnu.edu/businessoffice/payment/index.html,Payment Information - Business Office - Christopher Newport University
# ----------------
# refund/index.html
# True True True True True True True
# -------stripped---------
# refund/index.html True
# here 3
# link_counter, page_link_counter =  61 3
# http://cnu.edu/tuition/index.html,http://cnu.edu/tuition/refund/index.html,Refund Policies - Tuition - Christopher Newport University
# ----------------
# http://cnu.edu/financialaid/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/financialaid/index.html True
# here 2
# link_counter, page_link_counter =  62 4
# http://cnu.edu/tuition/index.html,http://cnu.edu/financialaid/index.html,Financial Aid - Financial Aid - Christopher Newport University
# ----------------
# captainscommitment/index.html
# True True True True True True True
# -------stripped---------
# captainscommitment/index.html True
# here 3
# link_counter, page_link_counter =  63 5
# http://cnu.edu/tuition/index.html,http://cnu.edu/tuition/captainscommitment/index.html,Captains Commitment - Tuition - Christopher Newport University
# ----------------
# http://cnu.edu/admission/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/admission/index.html True
# here 2
# ----------------
# http://cnu.edu/businessoffice/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/businessoffice/index.html True
# here 2
# link_counter, page_link_counter =  64 6
# http://cnu.edu/tuition/index.html,http://cnu.edu/businessoffice/index.html,Business Office - Business Office - Christopher Newport University
# ----------------
# http://cnu.edu/financialaid/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/financialaid/index.html True
# here 2
# ----------------
# http://cnu.edu/financialaid/calculator/npcalc.htm
# True True True True True True True
# -------stripped---------
# http://cnu.edu/financialaid/calculator/npcalc.htm True
# here 2
# link_counter, page_link_counter =  65 7
# http://cnu.edu/tuition/index.html,http://cnu.edu/financialaid/calculator/npcalc.htm,Net Price Calculator
# ----------------
# http://authorizedpayer.cnu.edu/
# True True True True True True True
# -------stripped---------
# http://authorizedpayer.cnu.edu True
# here 2
# link_counter, page_link_counter =  66 8
# http://cnu.edu/tuition/index.html,http://authorizedpayer.cnu.edu,Authorized Payer - Redirecting - Christopher Newport University
# ----------------
# http://cnu.edu/financialaid/_pdf/cnu-form-appeal_of_tuition_refund_policy.pdf
# True True True True True True True
# -------stripped---------
# http://cnu.edu/financialaid/_pdf/cnu-form-appeal_of_tuition_refund_policy.pdf False
# here 4
# ----------------
# javascript:emailCurrentPage()
# True True False True True False True
# -------stripped---------
# javascript:emailCurrentPage() False
# here 4
# ----------------
# javascript:window.print()
# True True False True True False True
# -------stripped---------
# javascript:window.print() False
# here 4
# ----------------
# https://get.adobe.com/reader/
# True True True True True True True
# -------stripped---------
# https://get.adobe.com/reader True
# here 4
# ----------------
# #
# False False True True True True True
# -------stripped---------
# # False
# here 4
# ----------------
# #
# False False True True True True True
# -------stripped---------
# # False
# here 4
# ----------------
# mailto:studentaccts@cnu.edu
# True True True True True False True
# -------stripped---------
# mailto:studentaccts@cnu.edu False
# here 4
# ----------------
# ...
# True True True True True True True
# -------stripped---------
# http://cnualert.info True
# here 4
# ----------------
# #
# False False True True True True True
# -------stripped---------
# # False
# here 4
# ----------------
# https://cascade.cnu.edu/entity/open.act?id=5fe845850a02005e338d85357bf270ef&type=page
# True True True False True True True
# -------stripped---------
# https://cascade.cnu.edu/entity/open.act?id=5fe845850a02005e338d85357bf270ef&type=page False
# here 4
# ----------------
# https://christophernewport.wufoo.com/forms/k1t49gti0wt9a8g/
# True True True True True True True
# -------stripped---------
# https://christophernewport.wufoo.com/forms/k1t49gti0wt9a8g True
# here 4
# cnu.edu
# http://cnu.edu
# http://cnu.edu/whoweare/
# ----------------
# http://cnu.edu/coronavirus
# True True True True True True True
# -------stripped---------
# http://cnu.edu/coronavirus True
# here 2
# ----------------
# http://cnu.edu/visit/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/visit/index.html True
# here 2
# ----------------
# http://cnu.edu/admission/freshman/howtoapply/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/admission/freshman/howtoapply/index.html True
# here 2
# ----------------
# http://cnu.edu/tuition/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/tuition/index.html True
# here 2
# ----------------
# http://cnu.edu/giving/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/giving/index.html True
# here 2
# ----------------
# https://my.cnu.edu
# True True True True True True True
# -------stripped---------
# https://my.cnu.edu True
# here 2
# ----------------
# http://cnu.edu/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/index.html True
# here 2
# ----------------
# #
# False False True True True True True
# -------stripped---------
# # False
# here 4
# ----------------
# http://cnu.edu/whoweare/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/whoweare/index.html True
# here 2
# ----------------
# http://cnu.edu/academics/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/academics/index.html True
# here 2
# ----------------
# http://cnu.edu/life/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/life/index.html True
# here 2
# ----------------
# http://cnu.edu/admission/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/admission/index.html True
# here 2
# ----------------
# http://cnusports.com
# True True True True True True True
# -------stripped---------
# http://cnusports.com True
# here 4
# ----------------
# http://cnu.edu/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/index.html True
# here 2
# ----------------
# index.html
# True True True True True True True
# -------stripped---------
# index.html True
# here 3
# ----------------
# mission/index.html
# True True True True True True True
# -------stripped---------
# mission/index.html True
# here 3
# link_counter, page_link_counter =  81 1
# http://cnu.edu/whoweare/index.html,http://cnu.edu/whoweare/mission/index.html,Mission - Who We Are - Christopher Newport University
# ----------------
# vision/index.html
# True True True True True True True
# -------stripped---------
# vision/index.html True
# here 3
# link_counter, page_link_counter =  82 2
# http://cnu.edu/whoweare/index.html,http://cnu.edu/whoweare/vision/index.html,Vision - Who We Are - Christopher Newport University
# ----------------
# values/index.html
# True True True True True True True
# -------stripped---------
# values/index.html True
# here 3
# link_counter, page_link_counter =  83 3
# http://cnu.edu/whoweare/index.html,http://cnu.edu/whoweare/values/index.html,Core Values - Who We Are - Christopher Newport University
# ----------------
# http://cnu.edu/diversityinclusion/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/diversityinclusion/index.html True
# here 2
# link_counter, page_link_counter =  84 4
# http://cnu.edu/whoweare/index.html,http://cnu.edu/diversityinclusion/index.html,Office of Diversity, Equity and Inclusion - Office of Diversity, Equity and Inclusion - Christopher Newport University
# ----------------
# freespeech/index.html
# True True True True True True True
# -------stripped---------
# freespeech/index.html True
# here 3
# link_counter, page_link_counter =  85 5
# http://cnu.edu/whoweare/index.html,http://cnu.edu/whoweare/freespeech/index.html,University Statement on Free Speech and Expression - Who We Are - Christopher Newport University
# ----------------
# honorcode/index.html
# True True True True True True True
# -------stripped---------
# honorcode/index.html True
# here 3
# link_counter, page_link_counter =  86 6
# http://cnu.edu/whoweare/index.html,http://cnu.edu/whoweare/honorcode/index.html,Honor Code - Who We Are - Christopher Newport University
# ----------------
# liberallearning/index.html
# True True True True True True True
# -------stripped---------
# liberallearning/index.html True
# here 3
# link_counter, page_link_counter =  87 7
# http://cnu.edu/whoweare/index.html,http://cnu.edu/whoweare/liberallearning/index.html,Liberal Learning - Who We Are - Christopher Newport University
# ----------------
# rankings/index.html
# True True True True True True True
# -------stripped---------
# rankings/index.html True
# here 3
# link_counter, page_link_counter =  88 8
# http://cnu.edu/whoweare/index.html,http://cnu.edu/whoweare/rankings/index.html,Rankings and Recognition - Who We Are - Christopher Newport University
# ----------------
# history/index.html
# True True True True True True True
# -------stripped---------
# history/index.html True
# here 3
# link_counter, page_link_counter =  89 9
# http://cnu.edu/whoweare/index.html,http://cnu.edu/whoweare/history/index.html,History - Who We Are - Christopher Newport University
# ----------------
# administration/index.html
# True True True True True True True
# -------stripped---------
# administration/index.html True
# here 3
# link_counter, page_link_counter =  90 10
# http://cnu.edu/whoweare/index.html,http://cnu.edu/whoweare/administration/index.html,Administration - Who We Are - Christopher Newport University
# ----------------
# traditions/index.html
# True True True True True True True
# -------stripped---------
# traditions/index.html True
# here 3
# link_counter, page_link_counter =  91 11
# http://cnu.edu/whoweare/index.html,http://cnu.edu/whoweare/traditions/index.html,Traditions - Who We Are - Christopher Newport University
# ----------------
# http://cnu.edu/visit/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/visit/index.html True
# here 2
# ----------------
# bov/index.html
# True True True True True True True
# -------stripped---------
# bov/index.html True
# here 3
# link_counter, page_link_counter =  92 12
# http://cnu.edu/whoweare/index.html,http://cnu.edu/whoweare/bov/index.html,Board of Visitors - Board of Visitors - Christopher Newport University
# ----------------
# http://cnu.edu/accreditation/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/accreditation/index.html True
# here 2
# link_counter, page_link_counter =  93 13
# http://cnu.edu/whoweare/index.html,http://cnu.edu/accreditation/index.html,Accreditation - Accreditation - Christopher Newport University
# ----------------
# javascript:emailCurrentPage()
# True True False True True False True
# -------stripped---------
# javascript:emailCurrentPage() False
# here 4
# ----------------
# javascript:window.print()
# True True False True True False True
# -------stripped---------
# javascript:window.print() False
# here 4
# ----------------
# https://get.adobe.com/reader/
# True True True True True True True
# -------stripped---------
# https://get.adobe.com/reader True
# here 4
# ----------------
# #
# False False True True True True True
# -------stripped---------
# # False
# here 4
# ----------------
# #
# False False True True True True True
# -------stripped---------
# # False
# here 4
# ----------------
# http://cnu.edu/hr/employment/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/hr/employment/index.html True
# here 2
# ----------------
# http://cnu.edu/public/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/public/index.html True
# here 2
# ----------------
# http://cnu.edu/public/calendar/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/public/calendar/index.html True
# here 2
# ----------------
# http://cnu.edu/visit/campusmap/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/visit/campusmap/index.html True
# here 2
# ----------------
# http://cnu.edu/studentconsumerinfo/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/studentconsumerinfo/index.html True
# here 2
# ----------------
# http://www.youvisit.com
# True True True True True True True
# -------stripped---------
# http://www.youvisit.com True
# here 4
# ----------------
# https://www.facebook.com/christophernewportuniversity
# True True True True True True True
# -------stripped---------
# https://www.facebook.com/christophernewportuniversity True
# here 4
# ----------------
# https://twitter.com/cnucaptains
# True True True True True True True
# -------stripped---------
# https://twitter.com/cnucaptains True
# here 4
# ----------------
# http://instagram.com/christophernewportu
# True True True True True True True
# -------stripped---------
# http://instagram.com/christophernewportu True
# here 4
# ----------------
# http://www.youtube.com/christophernewportu
# True True True True True True True
# -------stripped---------
# http://www.youtube.com/christophernewportu True
# here 4
# ----------------
# https://www.linkedin.com/edu/christopher-newport-university-19570
# True True True True True True True
# -------stripped---------
# https://www.linkedin.com/edu/christopher-newport-university-19570 True
# here 4
# ----------------
# http://cnu.edu/library/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/library/index.html True
# here 2
# ----------------
# https://admit.cnu.edu/register/?id=bb901bd9-ff61-4ff8-8d3e-d36a181f8548
# True True True False True True True
# -------stripped---------
# https://admit.cnu.edu/register/?id=bb901bd9-ff61-4ff8-8d3e-d36a181f8548 False
# here 4
# ----------------
# http://cnu.edu/public/safety/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/public/safety/index.html True
# here 2
# ----------------
# http://cnu.edu/titleixeo/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/titleixeo/index.html True
# here 2
# ----------------
# http://cnualert.info/
# True True True True True True True
# -------stripped---------
# http://cnualert.info True
# here 4
# ----------------
# https://cascade.cnu.edu/entity/open.act?id=2ce226a60a02005e338d85351338d1fc&type=page
# True True True False True True True
# -------stripped---------
# https://cascade.cnu.edu/entity/open.act?id=2ce226a60a02005e338d85351338d1fc&type=page False
# here 4
# ----------------
# https://christophernewport.wufoo.com/forms/k1t49gti0wt9a8g/
# True True True True True True True
# -------stripped---------
# https://christophernewport.wufoo.com/forms/k1t49gti0wt9a8g True
# here 4
# cnu.edu
# http://cnu.edu
# http://cnu.edu/academics/
# ----------------
# http://cnu.edu/coronavirus
# True True True True True True True
# -------stripped---------
# http://cnu.edu/coronavirus True
# here 2
# ----------------
# http://cnu.edu/visit/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/visit/index.html True
# here 2
# ----------------
# http://cnu.edu/admission/freshman/howtoapply/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/admission/freshman/howtoapply/index.html True
# here 2
# ----------------
# http://cnu.edu/tuition/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/tuition/index.html True
# here 2
# ----------------
# http://cnu.edu/giving/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/giving/index.html True
# here 2
# ----------------
# https://my.cnu.edu
# True True True True True True True
# -------stripped---------
# https://my.cnu.edu True
# here 2
# ----------------
# http://cnu.edu/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/index.html True
# here 2
# ----------------
# #
# False False True True True True True
# -------stripped---------
# # False
# here 4
# ----------------
# http://cnu.edu/whoweare/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/whoweare/index.html True
# here 2
# ----------------
# http://cnu.edu/academics/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/academics/index.html True
# here 2
# ----------------
# http://cnu.edu/life/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/life/index.html True
# here 2
# ----------------
# http://cnu.edu/admission/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/admission/index.html True
# here 2
# ----------------
# http://cnusports.com
# True True True True True True True
# -------stripped---------
# http://cnusports.com True
# here 4
# ----------------
# http://cnu.edu/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/index.html True
# here 2
# ----------------
# areasofstudy/index.html
# True True True True True True True
# -------stripped---------
# areasofstudy/index.html True
# here 3
# ----------------
# liberallearning/index.html
# True True True True True True True
# -------stripped---------
# liberallearning/index.html True
# here 3
# link_counter, page_link_counter =  94 1
# http://cnu.edu/academics/index.html,http://cnu.edu/academics/liberallearning/index.html,Liberal Learning - Liberal Learning - Christopher Newport University
# ----------------
# plp/index.html
# True True True True True True True
# -------stripped---------
# plp/index.html True
# here 3
# ----------------
# studyabroad/index.html
# True True True True True True True
# -------stripped---------
# studyabroad/index.html True
# here 3
# link_counter, page_link_counter =  95 2
# http://cnu.edu/academics/index.html,http://cnu.edu/academics/studyabroad/index.html,Study Abroad - Study Abroad - Christopher Newport University
# ----------------
# areasofstudy/index.html
# True True True True True True True
# -------stripped---------
# areasofstudy/index.html True
# here 3
# ----------------
# departments/index.html
# True True True True True True True
# -------stripped---------
# departments/index.html True
# here 3
# link_counter, page_link_counter =  96 3
# http://cnu.edu/academics/index.html,http://cnu.edu/academics/departments/index.html,Departments - Departments - Christopher Newport University
# ----------------
# graduatestudies/index.html
# True True True True True True True
# -------stripped---------
# graduatestudies/index.html True
# here 3
# link_counter, page_link_counter =  97 4
# http://cnu.edu/academics/index.html,http://cnu.edu/academics/graduatestudies/index.html,Graduate Studies - Academics - Christopher Newport University
# ----------------
# http://cnu.edu/public/undergradcatalog/index.html
# True True True True True True True
# -------stripped---------
# http://cnu.edu/public/undergradcatalog/index.html True
# here 2
# link_counter, page_link_counter =  98 5
# http://cnu.edu/academics/index.html,http://cnu.edu/public/undergradcatalog/index.html,Undergraduate Catalog - Undergraduate Catalog - Christopher Newport University
# ----------------
# resources/index.html
# True True True True True True True
# -------stripped---------
# resources/index.html True
# here 3
# link_counter, page_link_counter =  99 6
# http://cnu.edu/academics/index.html,http://cnu.edu/academics/resources/index.html,Academic Resources - Academic Resources - Christopher Newport University
# ----------------
# honors/index.html
# True True True True True True True
# -------stripped---------
# honors/index.html True
# here 3
# link_counter, page_link_counter =  100 7
# http://cnu.edu/academics/index.html,http://cnu.edu/academics/honors/index.html,Honors Program - Honors Program - Christopher Newport University
# Done!!
