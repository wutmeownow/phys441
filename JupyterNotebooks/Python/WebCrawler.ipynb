# %%
from bs4 import BeautifulSoup
import requests
import requests.exceptions
from urllib.parse import urlsplit
from urllib.parse import urlparse
from collections import deque
import codecs

# %%
def get_page_title(url):
    try:    
        response = requests.get(url)
        titlesoup = BeautifulSoup(response.text, 'lxml')
        return titlesoup.title.text.strip()
    except:
        return "None"
    

    return titlesoup.title.text.strip()

# %%
url = 'http://www.bankofamerica.com'

# a queue of urls to be crawled next
new_urls = deque([url])
new_url_title = get_page_title(new_urls[0])
f = codecs.open("crawl.csv", "w", "utf-8")
#print ('url_source,url_target,page_title_target')
#print ("%s,%s,%s" % ('None',new_urls[0],new_url_title))
f.write(u'url_source,url_target,page_title_target\n')
f.write(u"%s,%s,%s\n" % ('None',new_urls[0],new_url_title))

# a set of urls that we have already processed 
processed_urls = set()

# a set of domains inside the target website
local_urls = set()

# a set of domains outside the target website
foreign_urls = set()

# a set of broken urls
broken_urls = set()

# %%
# process urls one by one until we exhaust the queue
link_counter = 1
max_link = 100
debug = 0

while len(new_urls)>0:
    # move url from the queue to processed url set    
    url = new_urls.popleft()    
    processed_urls.add(url)
    # print(new_urls)
    
    # Now, get the source code of the current url being processed.  Check to make
    # sure that there are no obvious problems with this source code.  If there is,
    # add this url to the broken_urls list.
    try:    
        response = requests.get(url)
    except(requests.exceptions.MissingSchema, requests.exceptions.ConnectionError, requests.exceptions.InvalidURL, requests.exceptions.InvalidSchema):    
        # add broken urls to it’s own set, then continue    
        broken_urls.add(url)    
        continue
        
    # Extract base url to resolve relative links
    # 
    # This is not strictly necessary for this exercise, as all of the links
    # on all of the pages are within this one website, but it is good practice
    # in general.  We can refer to these variables later in the code, too ...
    parts = urlsplit(url)
    base = '{0.netloc}'.format(parts)
    strip_base = base.replace('www.', '')
    base_url = '{0.scheme}://{0.netloc}'.format(parts)
    path = url[:url.rfind('/')+1] if '/' in parts.path else url
    
    #print (parts)
    #print (base)
    #print (strip_base)
    if debug: print (base_url)
    #print (path)
    
    # Extract the source code for this url into a BeautifulSoup object for processing
    soup = BeautifulSoup(response.text, 'lxml')
    
    page_link_counter = 0
    # Loop through all of the links found on the page corresponding to this url
    for link in soup.find_all('a'): 
        
        if page_link_counter == 20:
            break
        
        # extract link url from the anchor    
        anchor = link.attrs['href'] if 'href' in link.attrs else ''
        
        if debug: print ('----------------')
        if debug: print (anchor)
        
        # Check to see what the anchor looks like ... based on this, add the link
        # to either the local_urls set or the foreign_urls set.
        
        if len(anchor)>1 and anchor.find('#')==-1 and anchor.find('?')==-1 and anchor.find('javascript')==-1 and anchor.find('.pdf')==-1 and anchor.find('.svg')==-1 and anchor.find(':')==-1 and anchor.find('.go')==-1:
            well_formed = True
        else:
            well_formed = False
            
        if anchor.endswith('/'):
            anchor = anchor[:-1]
            
        if anchor.startswith('/') and well_formed:
            if debug: print ('here 1')
            local_link = base_url + anchor        
            local_urls.add(local_link)    
        elif strip_base in anchor and well_formed:
            if debug: print ('here 2')
            local_urls.add(anchor)    
        elif not anchor.startswith('http') and well_formed:
            if debug: print ('here 3')
            local_link = path + anchor        
            local_urls.add(local_link)    
        else:
            if debug: print ('here 4')
            foreign_urls.add(anchor)
        
        #print(local_urls)
        #print(foreign_urls)
        
        # Finally, for all of the links in the local urls list, if it is not already
        # in the new_urls set, and it is not already in the processed_urls set, add
        # the link to the new_urls set.
        #
        # N.B.  If we add the url using 'append', it adds it to the END of new_urls list
        # So, this is going to be a breadth-first crawling algorithm!
        for i in local_urls:    
            if not i in new_urls and not i in processed_urls and link_counter < max_link:
                new_urls.append(i)
                page_link_counter = page_link_counter + 1
                link_counter = link_counter + 1
                print ("link_counter, page_link_counter = ",link_counter,page_link_counter)   
                #print('Adding %s to queue ... from %s' % (i,url))
                new_url_title = get_page_title(i)
                #print ("Page title = ",new_url_title)
                if debug: print ("%s,%s,%s" % (url,i,new_url_title))
                f.write(u"%s,%s,%s\n" % (url,i,new_url_title))
        if link_counter >= max_link:
            break
            
        #print ('end of loop',new_urls)

    if link_counter >= max_link:
        print ('Done!!')
        break

        
f.close()
# Out:
# http://www.bankofamerica.com
# ----------------
# #skip-to-h1
# here 4
# ----------------
# javascript:void(0);
# here 4
# ----------------
# /smallbusiness
# here 1
# link_counter, page_link_counter =  2 1
# http://www.bankofamerica.com,http://www.bankofamerica.com/smallbusiness,Small Business Banking, Credit Cards & Loans â Bank of America
# ----------------
# https://www.ml.com/wealthmanagement.html
# here 4
# ----------------
# https://www.bofaml.com/content/boaml/en_us/home.html
# here 4
# ----------------
# https://www.bankofamerica.com/security-center/overview/
# here 4
# ----------------
# https://about.bankofamerica.com/
# here 4
# ----------------
# es/
# here 3
# link_counter, page_link_counter =  3 2
# http://www.bankofamerica.com,http://www.bankofamerica.comes,None
# ----------------
# /customer-service/contact-us/?request_locale=en_US
# here 4
# ----------------
# /help/overview.go?request_locale=en_US
# here 4
# ----------------
# https://www.bankofamerica.com
# here 4
# ----------------
# https://staticweb.bankofamerica.com/cavmwebbactouch/common/index.html#home?app=signonv2
# here 4
# ----------------
# https://www.bankofamerica.com/sitemap/hub/signin.go?request_locale=en_US
# here 4
# ----------------
# javascript:void(0);
# here 4
# ----------------
# https://secure.bankofamerica.com/login/enroll/entry/olbEnroll.go?reason=model_enroll&request_locale=en-us
# here 4
# ----------------
# https://secure.bankofamerica.com/auth/enroll/enroll-entry/
# here 4
# ----------------
# https://secure.bankofamerica.com/mycommunications/public/appointments/getTopics.go?marketingCode=NEWHP_ECHMPG
# here 4
# ----------------
# https://secure.bankofamerica.com/mycommunications/public/appointments/getTopics.go?marketingCode=NEWHP_ECHMPG
# here 4
# ----------------
# /online-banking/mobile-and-online-banking-features/#defaultManageAccounts
# here 4
# ----------------
# /help/overview.go?request_locale=en_US
# here 4
# ----------------
# /mobile/mobile-banking-help.go?request_locale=en_US
# here 4
# ----------------
# https://locators.bankofamerica.com/
# here 4
# ----------------
# /customer-service/contact-us/?request_locale=en_US
# here 4
# ----------------
# /customer-service/contact-us/?request_locale=en_US
# here 4
# ----------------
# /privacy/overview.go?request_locale=en_US
# here 4
# ----------------
# /smallbusiness
# here 1
# ----------------
# https://www.ml.com/wealthmanagement.html
# here 4
# ----------------
# https://www.bofaml.com/content/boaml/en_us/home.html
# here 4
# ----------------
# https://homeloanhelp.bankofamerica.com/en/index.html
# here 4
# ----------------
# https://about.bankofamerica.com/
# here 4
# ----------------
# es/
# here 3
# ----------------
# javascript:void(0);
# here 4
# ----------------
# https://staticweb.bankofamerica.com/cavmwebbactouch/common/index.html#home?app=signonv2
# here 4
# ----------------
# https://promo.bankofamerica.com/mobile-banking/
# here 4
# ----------------
# https://itunes.apple.com/us/app/bank-america-mobile-banking/id284847138?mt=8'
# here 4
# ----------------
# https://itunes.apple.com/us/app/bank-of-america-mobile-banking/id284847138?mt=8
# here 4
# ----------------
# https://play.google.com/store/apps/details?id=com.infonow.bofa
# here 4
# ----------------
# /online-banking/iphone-banking-app.go
# here 4
# ----------------
#
# here 4
# ----------------
# /deposits/checking/checking-accounts/
# here 1
# link_counter, page_link_counter =  4 3
# http://www.bankofamerica.com,http://www.bankofamerica.com/deposits/checking/checking-accounts,Bank of America Advantage Banking - A Flexible Checking Account
# ----------------
# /deposits/savings/savings-accounts/
# here 1
# link_counter, page_link_counter =  5 4
# http://www.bankofamerica.com,http://www.bankofamerica.com/deposits/savings/savings-accounts,Savings Account - Open a Bank of America Advantage Savings Account Online
# ----------------
# /credit-cards/
# here 1
# link_counter, page_link_counter =  6 5
# http://www.bankofamerica.com,http://www.bankofamerica.com/credit-cards,Credit Cards: Find & Apply for a Credit Card Online at Bank of America
# ----------------
# /mortgage/home-mortgage/
# here 1
# link_counter, page_link_counter =  7 6
# http://www.bankofamerica.com,http://www.bankofamerica.com/mortgage/home-mortgage,Mortgages - Home Mortgage Loans from Bank of America
# ----------------
# /auto-loans/
# here 1
# link_counter, page_link_counter =  8 7
# http://www.bankofamerica.com,http://www.bankofamerica.com/auto-loans,Auto Loans & Car Financing from Bank of America
# ----------------
# /smallbusiness/
# here 1
# ----------------
# https://www.merrilledge.com/?src_cd=bac_hp_l1_desktop
# here 4
# ----------------
# https://bettermoneyhabits.bankofamerica.com/en
# here 4
# ----------------
# /student-banking/
# here 1
# link_counter, page_link_counter =  9 8
# http://www.bankofamerica.com,http://www.bankofamerica.com/student-banking,Banking Accounts for Students & Resources from Bank of America
# ----------------
# javascript:void(0);
# here 4
# ----------------
# /deposits/checking/advantage-banking/
# here 1
# link_counter, page_link_counter =  10 9
# http://www.bankofamerica.com,http://www.bankofamerica.com/deposits/checking/advantage-banking,Bank of America Advantage Banking - A Flexible Checking Account
# ----------------
# /deposits/checking/advantage-banking/
# here 1
# ----------------
# /student-banking/
# here 1
# ----------------
# /smallbusiness/deposits/checking-accounts/
# here 1
# link_counter, page_link_counter =  11 10
# http://www.bankofamerica.com,http://www.bankofamerica.com/smallbusiness/deposits/checking-accounts,Business Checking Accounts | Open a Business Bank Account Online
# ----------------
# /onlinebanking/online-banking.go?request_locale=en_US
# here 4
# ----------------
# /online-banking/mobile-and-online-banking-features/
# here 1
# link_counter, page_link_counter =  12 11
# http://www.bankofamerica.com,http://www.bankofamerica.com/online-banking/mobile-and-online-banking-features,Mobile Banking & Online Banking Features from Bank of America
# ----------------
# https://secure.bankofamerica.com/secure-mycommunications/public/appointments/?marketingCode=HPCS_ECBBA_A1000
# here 4
# ----------------
# /signature-services/
# here 1
# link_counter, page_link_counter =  13 12
# http://www.bankofamerica.com,http://www.bankofamerica.com/signature-services,Support Before, During and After Financial Life Events
# ----------------
# /preferred-rewards/my-rewards/
# here 1
# link_counter, page_link_counter =  14 13
# http://www.bankofamerica.com,http://www.bankofamerica.com/preferred-rewards/my-rewards,My Rewards - All Your Bank of America Rewards in One Place
# ----------------
# javascript:void(0);
# here 4
# ----------------
# /deposits/savings/savings-accounts/
# here 1
# ----------------
# /deposits/savings/child-savings-accounts/
# here 1
# link_counter, page_link_counter =  15 14
# http://www.bankofamerica.com,http://www.bankofamerica.com/deposits/savings/child-savings-accounts,Child Savings Accounts - A Savings Account for Kids
# ----------------
# /deposits/bank-cds/cd-accounts/
# here 1
# link_counter, page_link_counter =  16 15
# http://www.bankofamerica.com,http://www.bankofamerica.com/deposits/bank-cds/cd-accounts,CD Accounts - Certificate of Deposit (CD) Interest Rates
# ----------------
# /deposits/iras/retirement-accounts/
# here 1
# link_counter, page_link_counter =  17 16
# http://www.bankofamerica.com,http://www.bankofamerica.com/deposits/iras/retirement-accounts,Individual Retirement Accounts - Open an IRA Online
# ----------------
# /onlinebanking/online-banking.go?request_locale=en_US
# here 4
# ----------------
# /online-banking/mobile-and-online-banking-features/
# here 1
# ----------------
# https://secure.bankofamerica.com/secure-mycommunications/public/appointments/?marketingCode=HPCS_ECBBA_A1000
# here 4
# ----------------
# /signature-services/
# here 1
# ----------------
# /preferred-rewards/my-rewards/
# here 1
# ----------------
# javascript:void(0);
# here 4
# ----------------
# /credit-cards/
# here 1
# ----------------
# /credit-cards/cash-back-credit-cards/
# here 1
# link_counter, page_link_counter =  18 17
# http://www.bankofamerica.com,http://www.bankofamerica.com/credit-cards/cash-back-credit-cards,Cash Back Credit Cards & Cash Rewards Credit Cards
# ----------------
# /credit-cards/travel-credit-cards/
# here 1
# link_counter, page_link_counter =  19 18
# http://www.bankofamerica.com,http://www.bankofamerica.com/credit-cards/travel-credit-cards,Travel Rewards Credit Cards: Cruise Line & Air Miles Credit Cards
# ----------------
# /credit-cards/low-interest-credit-cards/
# here 1
# link_counter, page_link_counter =  20 19
# http://www.bankofamerica.com,http://www.bankofamerica.com/credit-cards/low-interest-credit-cards,Lower Interest Rate Credit Cards from Bank of America
# ----------------
# /credit-cards/point-rewards-credit-cards/
# here 1
# link_counter, page_link_counter =  21 20
# http://www.bankofamerica.com,http://www.bankofamerica.com/credit-cards/point-rewards-credit-cards,Rewards Credit Cards from Bank of America
# http://www.bankofamerica.com
# ----------------
# #skip-to-h1
# here 4
# ----------------
# /
# here 4
# ----------------
# /smallbusiness
# here 1
# ----------------
# https://www.ml.com/wealthmanagement.html
# here 4
# ----------------
# https://www.bofaml.com/content/boaml/en_us/home.html
# here 4
# ----------------
# https://www.bankofamerica.com/security-center/overview/
# here 4
# ----------------
# https://about.bankofamerica.com/
# here 4
# ----------------
# /contactus/contactus.go?request_locale=en_US
# here 4
# ----------------
# /help/overview.go?request_locale=en_US
# here 4
# ----------------
# https://www.bankofamerica.com
# here 4
# ----------------
# https://staticweb.bankofamerica.com/cavmwebbactouch/common/index.html#home?app=signonv2
# here 4
# ----------------
# https://www.bankofamerica.com/sitemap/hub/signin.go?request_locale=en_US
# here 4
# ----------------
# javascript:void(0);
# here 4
# ----------------
# https://secure.bankofamerica.com/login/enroll/entry/olbEnroll.go?reason=model_enroll&request_locale=en-us
# here 4
# ----------------
# https://secure.bankofamerica.com/auth/enroll/enroll-entry/
# here 4
# ----------------
# https://secure.bankofamerica.com/mycommunications/public/appointments/getTopics.go?request_locale=en_US&marketingCode=HPPOPULARLINKS_ECHMPG
# here 4
# ----------------
# https://staticweb.bankofamerica.com/cavmwebbactouch/common/index.html#home?app=bba
# here 4
# ----------------
# /online-banking/mobile-and-online-banking-features/#defaultManageAccounts
# here 4
# ----------------
# /help/overview.go?request_locale=en_US
# here 4
# ----------------
# /mobile/mobile-banking-help.go?request_locale=en_US
# here 4
# ----------------
# https://locators.bankofamerica.com/
# here 4
# ----------------
# /contactus/contactus.go?request_locale=en_US
# here 4
# ----------------
# /mobile/mobile-banking-help.go?request_locale=en_US
# here 4
# ----------------
# /privacy/overview.go?request_locale=en_US
# here 4
# ----------------
# /
# here 4
# ----------------
# https://www.ml.com/wealthmanagement.html
# here 4
# ----------------
# https://www.bofaml.com/content/boaml/en_us/home.html
# here 4
# ----------------
# https://about.bankofamerica.com/
# here 4
# ----------------
# javascript:void(0);
# here 4
# ----------------
# https://staticweb.bankofamerica.com/cavmwebbactouch/common/index.html#home?app=signonv2
# here 4
# ----------------
# https://promo.bankofamerica.com/mobile-banking/
# here 4
# ----------------
# https://itunes.apple.com/us/app/bank-america-mobile-banking/id284847138?mt=8'
# here 4
# ----------------
# https://itunes.apple.com/us/app/bank-of-america-mobile-banking/id284847138?mt=8
# here 4
# ----------------
# https://play.google.com/store/apps/details?id=com.infonow.bofa
# here 4
# ----------------
# /online-banking/iphone-banking-app.go
# here 4
# ----------------
#
# here 4
# ----------------
# /smallbusiness/deposits/checking-accounts/
# here 1
# ----------------
# /smallbusiness/cd-savings-accounts.go
# here 4
# ----------------
# https://promo.bankofamerica.com/olbs/index.html
# here 4
# ----------------
# /smallbusiness/credit-cards/#popular
# here 4
# ----------------
# /smallbusiness/business-financing/
# here 1
# link_counter, page_link_counter =  22 1
# http://www.bankofamerica.com/smallbusiness,http://www.bankofamerica.com/smallbusiness/business-financing,Small Business Loans - Compare Loan Types and Start Your Application
# ----------------
# /smallbusiness/merchant-services/
# here 1
# link_counter, page_link_counter =  23 2
# http://www.bankofamerica.com/smallbusiness,http://www.bankofamerica.com/smallbusiness/merchant-services,Merchant Services: Credit Card & Payment Processing Solutions
# ----------------
# https://www.merrilledge.com/small-business?src_cd=bac_sb_hp_nav
# here 4
# ----------------
# /smallbusiness/resources/
# here 1
# link_counter, page_link_counter =  24 3
# http://www.bankofamerica.com/smallbusiness,http://www.bankofamerica.com/smallbusiness/resources,
# ----------------
# javascript:void(0);
# here 4
# ----------------
# /smallbusiness/deposits/checking-accounts/
# here 1
# ----------------
# /smallbusiness/deposits/checking-accounts/business-fundamentals/
# here 1
# link_counter, page_link_counter =  25 4
# http://www.bankofamerica.com/smallbusiness,http://www.bankofamerica.com/smallbusiness/deposits/checking-accounts/business-fundamentals,Business Fundamentals® Checking Solution from Bank of America
# ----------------
# /smallbusiness/deposits/checking-accounts/business-advantage/
# here 1
# link_counter, page_link_counter =  26 5
# http://www.bankofamerica.com/smallbusiness,http://www.bankofamerica.com/smallbusiness/deposits/checking-accounts/business-advantage,Business Advantage Checking Account from Bank of America
# ----------------
# /smallbusiness/business-debit-card.go
# here 4
# ----------------
# /smallbusiness/online-banking.go
# here 4
# ----------------
# /smallbusiness/online-banking/mobile/features.go
# here 4
# ----------------
# https://secure.bankofamerica.com/secure-mycommunications/public/appointments/?marketingCode=SBHPCHKL1_ECBBA_A2000
# here 4
# ----------------
# https://promo.bankofamerica.com/RelationshipRewards/
# here 4
# ----------------
# javascript:void(0);
# here 4
# ----------------
# /smallbusiness/cd-savings-accounts.go
# here 4
# ----------------
# /smallbusiness/savings-accounts/business-investment-account.go
# here 4
# ----------------
# /smallbusiness/savings-accounts/business-advantage-savings.go
# here 4
# ----------------
# /smallbusiness/deposits/savings-accounts/cd-accounts/
# here 1
# link_counter, page_link_counter =  27 6
# http://www.bankofamerica.com/smallbusiness,http://www.bankofamerica.com/smallbusiness/deposits/savings-accounts/cd-accounts,Business Certificate of Deposit (CD) Accounts from Bank of America
# ----------------
# /smallbusiness/online-banking.go
# here 4
# ----------------
# /smallbusiness/online-banking/mobile/features.go
# here 4
# ----------------
# https://secure.bankofamerica.com/secure-mycommunications/public/appointments/?marketingCode=SBHPSAVL1_ECBBA_A2000
# here 4
# ----------------
# https://promo.bankofamerica.com/RelationshipRewards/
# here 4
# ----------------
# javascript:void(0);
# here 4
# ----------------
# /smallbusiness/merchant-services/
# here 1
# ----------------
# /smallbusiness/online-banking/cash-management.go
# here 4
# ----------------
# https://www.bankofamerica.com/businessadvantage360/
# here 4
# ----------------
# /smallbusiness/online-banking/payroll.go
# here 4
# ----------------
# /smallbusiness/online-banking/cash-management/remote-deposit.go
# here 4
# ----------------
# /smallbusiness/online-banking/account-management.go
# here 4
# ----------------
# https://healthaccounts.bankofamerica.com/explore-sm-business.shtml
# here 4
# ----------------
# /smallbusiness/online-banking.go
# here 4
# ----------------
# https://secure.bankofamerica.com/secure-mycommunications/public/appointments/?marketingCode=SBHPBUSL1_ECBBA_A2000
# here 4
# ----------------
# https://promo.bankofamerica.com/RelationshipRewards/
# here 4
# ----------------
# javascript:void(0);
# here 4
# ----------------
# /smallbusiness/credit-cards/view-all-small-business-credit-cards/
# here 1
# link_counter, page_link_counter =  28 7
# http://www.bankofamerica.com/smallbusiness,http://www.bankofamerica.com/smallbusiness/credit-cards/view-all-small-business-credit-cards,Small Business Credit Cards from Bank of America
# ----------------
# /smallbusiness/credit-cards/business-popular-credit-cards/
# here 1
# link_counter, page_link_counter =  29 8
# http://www.bankofamerica.com/smallbusiness,http://www.bankofamerica.com/smallbusiness/credit-cards/business-popular-credit-cards,Popular Business Credit Cards â Must Haves for Your Small Business
# ----------------
# /smallbusiness/credit-cards/business-cash-back-credit-cards/
# here 1
# link_counter, page_link_counter =  30 9
# http://www.bankofamerica.com/smallbusiness,http://www.bankofamerica.com/smallbusiness/credit-cards/business-cash-back-credit-cards,Cash Back Business Credit Cards â Earn Cash Rewards
# ----------------
# /smallbusiness/credit-cards/business-travel-credit-cards/
# here 1
# link_counter, page_link_counter =  31 10
# http://www.bankofamerica.com/smallbusiness,http://www.bankofamerica.com/smallbusiness/credit-cards/business-travel-credit-cards,Travel Rewards Small Business Credit Cards from Bank of America
# ----------------
# /smallbusiness/credit-cards/business-low-interest-credit-cards/
# here 1
# link_counter, page_link_counter =  32 11
# http://www.bankofamerica.com/smallbusiness,http://www.bankofamerica.com/smallbusiness/credit-cards/business-low-interest-credit-cards,Low Interest Small Business Credit Cards from Bank of America
# ----------------
# /smallbusiness/credit-cards/compare-small-business-credit-cards/
# here 1
# link_counter, page_link_counter =  33 12
# http://www.bankofamerica.com/smallbusiness,http://www.bankofamerica.com/smallbusiness/credit-cards/compare-small-business-credit-cards,Compare Small Business Credit Cards from Bank of America
# ----------------
# /smallbusiness/merchant-services/
# here 1
# ----------------
# /credit-cards
# here 1
# ----------------
# https://secure.bankofamerica.com/secure-mycommunications/public/appointments/?marketingCode=SBHPCCL1_ECBBA_A2000
# here 4
# ----------------
# https://promo.bankofamerica.com/RelationshipRewards/
# here 4
# ----------------
# javascript:void(0);
# here 4
# ----------------
# /smallbusiness/business-financing/
# here 1
# ----------------
# /smallbusiness/business-financing/unsecured-business-line-of-credit/
# here 1
# link_counter, page_link_counter =  34 13
# http://www.bankofamerica.com/smallbusiness,http://www.bankofamerica.com/smallbusiness/business-financing/unsecured-business-line-of-credit,Unsecured Business Lines of Credit at Bank of America
# ----------------
# /smallbusiness/business-financing/unsecured-business-loans/
# here 1
# link_counter, page_link_counter =  35 14
# http://www.bankofamerica.com/smallbusiness,http://www.bankofamerica.com/smallbusiness/business-financing/unsecured-business-loans,Unsecured Business Loans & Financing from Bank of America
# ----------------
# /smallbusiness/business-financing/auto-loans/
# here 1
# link_counter, page_link_counter =  36 15
# http://www.bankofamerica.com/smallbusiness,http://www.bankofamerica.com/smallbusiness/business-financing/auto-loans,Business Auto Loans & Financing for Commercial Vehicles
# ----------------
# /smallbusiness/business-financing/business-line-of-credit/
# here 1
# link_counter, page_link_counter =  37 16
# http://www.bankofamerica.com/smallbusiness,http://www.bankofamerica.com/smallbusiness/business-financing/business-line-of-credit,Secured Business Line of Credit at Bank of America
# ----------------
# /smallbusiness/business-financing/business-loans/
# here 1
# link_counter, page_link_counter =  38 17
# http://www.bankofamerica.com/smallbusiness,http://www.bankofamerica.com/smallbusiness/business-financing/business-loans,Secured Business Loans at Bank of America
# ----------------
# /smallbusiness/business-financing/commercial-real-estate-loans/
# here 1
# link_counter, page_link_counter =  39 18
# http://www.bankofamerica.com/smallbusiness,http://www.bankofamerica.com/smallbusiness/business-financing/commercial-real-estate-loans,Commercial Real Estate Loans & Property Financing
# ----------------
# /smallbusiness/business-financing/sba-financing/
# here 1
# link_counter, page_link_counter =  40 19
# http://www.bankofamerica.com/smallbusiness,http://www.bankofamerica.com/smallbusiness/business-financing/sba-financing,SBA Loans & Financing for Your Business - Bank of America
# ----------------
# /smallbusiness/business-financing/practice-solutions/
# here 1
# link_counter, page_link_counter =  41 20
# http://www.bankofamerica.com/smallbusiness,http://www.bankofamerica.com/smallbusiness/business-financing/practice-solutions,Medical Practice Loans & Financing from Bank of America
# http://www.bankofamerica.com
# ----------------
# #skip-to-h1
# here 4
# ----------------
# /
# here 4
# ----------------
# https://staticweb.bankofamerica.com/cavmwebbactouch/common/index.html#home?app=signon
# here 4
# ----------------
# /online-banking/sign-in/
# here 1
# link_counter, page_link_counter =  42 1
# http://www.bankofamerica.com/deposits/checking/checking-accounts,http://www.bankofamerica.com/online-banking/sign-in,Sign in to Bank of America Online & Mobile Banking to Manage Your Accounts
# ----------------
# https://locators.bankofamerica.com
# here 4
# ----------------
# es
# here 3
# link_counter, page_link_counter =  43 2
# http://www.bankofamerica.com/deposits/checking/checking-accounts,http://www.bankofamerica.com/deposits/checking/es,None
# ----------------
# javascript:void(0);
# here 4
# ----------------
# /
# here 4
# ----------------
# /contactus/contactus.go?topicId=checking_savings
# here 4
# ----------------
# https://locators.bankofamerica.com
# here 4
# ----------------
# /deposits/applying-for-accounts-faqs/
# here 1
# link_counter, page_link_counter =  44 3
# http://www.bankofamerica.com/deposits/checking/checking-accounts,http://www.bankofamerica.com/deposits/applying-for-accounts-faqs,Bank Account Application FAQs: What Do You Need to Apply?
# ----------------
# https://secure.bankofamerica.com/mycommunications/public/appointments/loc.go
# here 4
# ----------------
# es
# here 3
# ----------------
# es
# here 3
# ----------------
# javascript:void(0);
# here 4
# ----------------
# /deposits/bank-account-interest-rates/
# here 1
# link_counter, page_link_counter =  45 4
# http://www.bankofamerica.com/deposits/checking/checking-accounts,http://www.bankofamerica.com/deposits/bank-account-interest-rates,Account Interest Rates for Savings, Checking, CDs & IRAs
# ----------------
# /deposits/account-fees/
# here 1
# link_counter, page_link_counter =  46 5
# http://www.bankofamerica.com/deposits/checking/checking-accounts,http://www.bankofamerica.com/deposits/account-fees,Account Maintenance Fees for Savings, Checking, CDs & IRAs
# ----------------
# /deposits/checking/checking-clarity-statement/
# here 1
# link_counter, page_link_counter =  47 6
# http://www.bankofamerica.com/deposits/checking/checking-accounts,http://www.bankofamerica.com/deposits/checking/checking-clarity-statement,Bank of America Checking Clarity Statement
# ----------------
# /deposits/managing-your-money.go?request_locale=en_US
# here 4
# ----------------
# /deposits/access-your-accounts.go?request_locale=en_US
# here 4
# ----------------
# /deposits/bank-account-interest-rates/
# here 1
# ----------------
# /deposits/account-fees/
# here 1
# ----------------
# /deposits/checking/checking-clarity-statement/
# here 1
# ----------------
# /deposits/managing-your-money.go?request_locale=en_US
# here 4
# ----------------
# /deposits/access-your-accounts.go?request_locale=en_US
# here 4
# ----------------
# javascript:void(0);
# here 4
# ----------------
# /deposits/checking/advantage-banking/
# here 1
# ----------------
# /deposits/savings/savings-accounts/
# here 1
# ----------------
# /deposits/bank-cds/cd-accounts/
# here 1
# ----------------
# /deposits/iras/retirement-accounts/
# here 1
# ----------------
# /deposits/checking/debit-card/
# here 1
# link_counter, page_link_counter =  48 7
# http://www.bankofamerica.com/deposits/checking/checking-accounts,http://www.bankofamerica.com/deposits/checking/debit-card,Debit Cards - Apply for a Bank Debit Card from Bank of America
# ----------------
# /deposits/bank-accounts/
# here 1
# link_counter, page_link_counter =  49 8
# http://www.bankofamerica.com/deposits/checking/checking-accounts,http://www.bankofamerica.com/deposits/bank-accounts,Bank Accounts - Open a Bank Account Online Today
# ----------------
# /deposits/checking/advantage-banking/
# here 1
# ----------------
# /deposits/savings/savings-accounts/
# here 1
# ----------------
# /deposits/bank-cds/cd-accounts/
# here 1
# ----------------
# /deposits/iras/retirement-accounts/
# here 1
# ----------------
# /deposits/checking/debit-card/
# here 1
# ----------------
# /deposits/bank-accounts/
# here 1
# ----------------
# javascript:void(0);
# here 4
# ----------------
# javascript:void(0);
# here 4
# ----------------
# #
# here 4
# ----------------
# /deposits/checking/advantage-safebalance-banking-account/before-you-apply/
# here 1
# link_counter, page_link_counter =  50 9
# http://www.bankofamerica.com/deposits/checking/checking-accounts,http://www.bankofamerica.com/deposits/checking/advantage-safebalance-banking-account/before-you-apply,Advantage SafeBalance Banking Account - Before You Apply
# ----------------
# /deposits/checking/advantage-safebalance-banking-account/before-you-apply/
# here 1
# ----------------
# #
# here 4
# ----------------
# /deposits/checking/advantage-plus-banking-account/before-you-apply/
# here 1
# link_counter, page_link_counter =  51 10
# http://www.bankofamerica.com/deposits/checking/checking-accounts,http://www.bankofamerica.com/deposits/checking/advantage-plus-banking-account/before-you-apply,Advantage Plus Banking Account - Before You Apply
# ----------------
# /deposits/checking/advantage-plus-banking-account/before-you-apply/
# here 1
# ----------------
# #
# here 4
# ----------------
# /deposits/account-rates-fees-faqs/#combined-balances
# here 4
# ----------------
# /deposits/checking/advantage-relationship-banking-account/before-you-apply/
# here 1
# link_counter, page_link_counter =  52 11
# http://www.bankofamerica.com/deposits/checking/checking-accounts,http://www.bankofamerica.com/deposits/checking/advantage-relationship-banking-account/before-you-apply,Advantage Relationship Banking Account - Before You Apply
# ----------------
# /deposits/checking/advantage-relationship-banking-account/before-you-apply/
# here 1
# ----------------
# javascript:void(0);
# here 4
# ----------------
# javascript:void(0);
# here 4
# ----------------
# #ftn_advantageErica_content
# here 4
# ----------------
# #ftn_advantageErica_content
# here 4
# ----------------
# #ftn_advantageErica_content
# here 4
# ----------------
# #ftn_advantageZelle_content
# here 4
# ----------------
# #ftn_advantageFingerprint_content
# here 4
# ----------------
# #ftn_advantageLockUnlock_content
# here 4
# ----------------
# #ftn_advantageFingerprint_content
# here 4
# ----------------
# #ftn_advantageLockUnlock_content
# here 4
# ----------------
# #ftn_advantageFingerprint_content
# here 4
# ----------------
# #ftn_advantageLockUnlock_content
# here 4
# ----------------
# #ftn_advantageZelle_content
# here 4
# ----------------
# #ftn_advantageZelle_content
# here 4
# ----------------
# #ftn_advantageCustomAlerts_content
# here 4
# ----------------
# #ftn_advantageSpendingBudgeting_content
# here 4
# ----------------
# #ftn_advantageCustomAlerts_content
# here 4
# ----------------
# #ftn_advantageSpendingBudgeting_content
# here 4
# ----------------
# #ftn_advantageCustomAlerts_content
# here 4
# ----------------
# #ftn_advantageSpendingBudgeting_content
# here 4
# ----------------
# javascript:void(0);
# here 4
# ----------------
# javascript:void(0);
# here 4
# ----------------
# javascript:void(0);
# here 4
# ----------------
# javascript:void(0);
# here 4
# ----------------
# javascript:void(0);
# here 4
# ----------------
# javascript:void(0);
# here 4
# ----------------
# #ftn_advantageEligibleStudents_content
# here 4
# ----------------
# #ftn_overdraft-negative-balance_content
# here 4
# ----------------
# /deposits/checking/advantage-safebalance-banking-account/before-you-apply/
# here 1
# ----------------
# /deposits/checking/advantage-safebalance-banking-account/before-you-apply/
# here 1
# ----------------
# #ftn_advantagePreferredRewards_content
# here 4
# ----------------
# #ftn_advantageEligibleStudents_content
# here 4
# ----------------
# /deposits/checking/checking-clarity-statement/
# here 1
# ----------------
# javascript:void(0);
# here 4
# ----------------
# #ftn_advantageEligibleStudents_content
# here 4
# ----------------
# #ftn_overdraft-negative-balance_content
# here 4
# ----------------
# /deposits/checking/advantage-safebalance-banking-account/before-you-apply/
# here 1
# ----------------
# #ftn_advantagePreferredRewards_content
# here 4
# ----------------
# #ftn_advantageEligibleStudents_content
# here 4
# ----------------
# /deposits/checking/checking-clarity-statement/
# here 1
# ----------------
# #ftn_advantageOverdraftProtection_content
# here 4
# ----------------
# /deposits/checking/advantage-plus-banking-account/before-you-apply/
# here 1
# ----------------
# /deposits/checking/advantage-plus-banking-account/before-you-apply/
# here 1
# ----------------
# /deposits/account-rates-fees-faqs/#qualifying-direct-deposits
# here 4
# ----------------
# #ftn_advantagePreferredRewards_content
# here 4
# ----------------
# #ftn_advantageEligibleStudents_content
# here 4
# ----------------
# /deposits/checking/checking-clarity-statement/
# here 1
# ----------------
# javascript:void(0);
# here 4
# ----------------
# #ftn_advantageOverdraftProtection_content
# here 4
# ----------------
# /deposits/checking/advantage-plus-banking-account/before-you-apply/
# here 1
# ----------------
# /deposits/account-rates-fees-faqs/#qualifying-direct-deposits
# here 4
# ----------------
# #ftn_advantagePreferredRewards_content
# here 4
# ----------------
# #ftn_advantageEligibleStudents_content
# here 4
# ----------------
# /deposits/checking/checking-clarity-statement/
# here 1
# ----------------
# #ftn_advantageAdditionalAccounts_content
# here 4
# ----------------
# /deposits/bank-account-interest-rates/
# here 1
# ----------------
# #ftn_advantageOverdraftProtection_content
# here 4
# ----------------
# /deposits/checking/advantage-relationship-banking-account/before-you-apply/
# here 1
# ----------------
# /deposits/checking/advantage-relationship-banking-account/before-you-apply/
# here 1
# ----------------
# /deposits/account-rates-fees-faqs/#combined-balances
# here 4
# ----------------
# #ftn_advantagePreferredRewards_content
# here 4
# ----------------
# /deposits/checking/checking-clarity-statement/
# here 1
# ----------------
# javascript:void(0);
# here 4
# ----------------
# #ftn_advantageAdditionalAccounts_content
# here 4
# ----------------
# /deposits/bank-account-interest-rates/
# here 1
# ----------------
# #ftn_advantageOverdraftProtection_content
# here 4
# ----------------
# /deposits/checking/advantage-relationship-banking-account/before-you-apply/
# here 1
# ----------------
# /deposits/account-rates-fees-faqs/#combined-balances
# here 4
# ----------------
# #ftn_advantagePreferredRewards_content
# here 4
# ----------------
# /deposits/checking/checking-clarity-statement/
# here 1
# ----------------
# javascript:void(0);
# here 4
# ----------------
# /deposits/checking/advantage-safebalance-banking-account/before-you-apply/
# here 1
# ----------------
# /deposits/checking/advantage-plus-banking-account/before-you-apply/
# here 1
# ----------------
# /deposits/checking/advantage-relationship-banking-account/before-you-apply/
# here 1
# ----------------
# #ftn_advantagePreferredRewards_content
# here 4
# ----------------
# #ftn_advantageEligibleStudents_content
# here 4
# ----------------
# /deposits/account-rates-fees-faqs/#qualifying-direct-deposits
# here 4
# ----------------
# #ftn_advantagePreferredRewards_content
# here 4
# ----------------
# #ftn_advantageEligibleStudents_content
# here 4
# ----------------
# /deposits/account-rates-fees-faqs/#combined-balances
# here 4
# ----------------
# #ftn_advantagePreferredRewards_content
# here 4
# ----------------
# #ftn_advantageAPY_content
# here 4
# ----------------
# #ftn_advantageOverdraftSetting_content
# here 4
# ----------------
# #ftn_advantageOverdraftSetting_content
# here 4
# ----------------
# #ftn_advantageOverdraftProtection_content
# here 4
# ----------------
# /deposits/resources/personal-schedule-fees.go?request_locale=en_US
# here 4
# ----------------
# /deposits/resources/personal-schedule-fees.go?request_locale=en_US
# here 4
# ----------------
# #ftn_advantageOverdraftFee_content
# here 4
# ----------------
# #ftn_advantageReturnedItemFee_content
# here 4
# ----------------
# /deposits/checking/checking-clarity-statement/
# here 1
# ----------------
# /deposits/checking/advantage-safebalance-banking-account/before-you-apply/
# here 1
# ----------------
# /deposits/checking/advantage-plus-banking-account/before-you-apply/
# here 1
# ----------------
# /deposits/checking/advantage-relationship-banking-account/before-you-apply/
# here 1
# ----------------
# javascript:void(0)
# here 4
# ----------------
# javascript:void(0)
# here 4
# ----------------
# #ftn_advantageZeroLiabilityGuarantee_content
# here 4
# ----------------
# #ftn_advantageMobileCheckDeposits_content
# here 4
# ----------------
# #ftn_advantageSpendingBudgeting_content
# here 4
# ----------------
# #ftn_advantageLockUnlock_content
# here 4
# ----------------
# #ftn_advantageCustomAlerts_content
# here 4
# ----------------
# #ftn_advantageFingerprint_content
# here 4
# ----------------
# #ftn_advantageZeroLiabilityGuarantee_content
# here 4
# ----------------
# #ftn_advantageMobileCheckDeposits_content
# here 4
# ----------------
# #ftn_advantageSpendingBudgeting_content
# here 4
# ----------------
# #ftn_advantageLockUnlock_content
# here 4
# ----------------
# #ftn_advantageCustomAlerts_content
# here 4
# ----------------
# #ftn_advantageFingerprint_content
# here 4
# ----------------
# javascript:void(0);
# here 4
# ----------------
# javascript:void(0);
# here 4
# ----------------
# https://www.bankofamerica.com/student-banking/
# here 4
# ----------------
# https://www.bankofamerica.com/deposits/resources/personal-schedule-fees.go?request_locale=en_US
# here 4
# ----------------
# javascript:void(0);
# here 4
# ----------------
# javascript:void(0);
# here 4
# ----------------
# javascript:void(0);
# here 4
# ----------------
# javascript:void(0);
# here 4
# ----------------
# javascript:void(0);
# here 4
# ----------------
# javascript:void(0);
# here 4
# ----------------
# javascript:void(0);
# here 4
# ----------------
# javascript:void(0);
# here 4
# ----------------
# javascript:void(0);
# here 4
# ----------------
# javascript:void(0);
# here 4
# ----------------
# javascript:void(0);
# here 4
# ----------------
# javascript:void(0);
# here 4
# ----------------
# /login/enroll/entry/olbEnroll.go?reason=model_enroll
# here 4
# ----------------
# javascript:void(0);
# here 4
# ----------------
# /login/sign-in/signOnV2Screen.go
# here 4
# ----------------
# /help/overview.go?request_locale=en_US
# here 4
# ----------------
# javascript:void(0);
# here 4
# ----------------
# javascript:void(0);
# here 4
# ----------------
# https://bettermoneyhabits.bankofamerica.com/en/personal-banking/checking-account-information
# here 4
# ----------------
# https://bettermoneyhabits.bankofamerica.com/en/saving-budgeting/creating-a-budget
# here 4
# ----------------
# https://bettermoneyhabits.bankofamerica.com/en/personal-banking/avoid-bank-fees
# here 4
# ----------------
# https://bettermoneyhabits.bankofamerica.com/en/saving-budgeting
# here 4
# ----------------
# javascript:void(0);
# here 4
# ----------------
# javascript:void(0);
# here 4
# ----------------
# /deposits/savings/savings-accounts/
# here 1
# ----------------
# /deposits/bank-cds/cd-accounts/
# here 1
# ----------------
# /deposits/iras/retirement-accounts/
# here 1
# ----------------
# /deposits/checking/debit-card/
# here 1
# ----------------
# /deposits/checking/checking-clarity-statement/
# here 1
# ----------------
# javascript:void(0);
# here 4
# ----------------
# javascript:void(0);
# here 4
# ----------------
# /preferred-rewards/
# here 1
# link_counter, page_link_counter =  53 12
# http://www.bankofamerica.com/deposits/checking/checking-accounts,http://www.bankofamerica.com/preferred-rewards,Bank of America Preferred Rewards Program
# ----------------
# https://promo.bankofamerica.com/deals/
# here 4
# ----------------
# /deposits/keep-the-change/
# here 1
# link_counter, page_link_counter =  54 13
# http://www.bankofamerica.com/deposits/checking/checking-accounts,http://www.bankofamerica.com/deposits/keep-the-change,Keep the Change® Savings Program from Bank of America
# ----------------
# javascript:void(0);
# here 4
# ----------------
# /deposits/checking/advantage-safebalance-banking-account/before-you-apply/
# here 1
# ----------------
# /deposits/checking/advantage-plus-banking-account/before-you-apply/
# here 1
# ----------------
# /deposits/checking/advantage-relationship-banking-account/before-you-apply/
# here 1
# ----------------
# #ftn_advantagePreferredRewards_content
# here 4
# ----------------
# #ftn_advantageEligibleStudents_content
# here 4
# ----------------
# /deposits/account-rates-fees-faqs/#qualifying-direct-deposits
# here 4
# ----------------
# #ftn_advantagePreferredRewards_content
# here 4
# ----------------
# #ftn_advantageEligibleStudents_content
# here 4
# ----------------
# /deposits/account-rates-fees-faqs/#combined-balances
# here 4
# ----------------
# #ftn_advantagePreferredRewards_content
# here 4
# ----------------
# #ftn_advantageAPY_content
# here 4
# ----------------
# #ftn_advantageOverdraftSetting_content
# here 4
# ----------------
# #ftn_advantageOverdraftSetting_content
# here 4
# ----------------
# #ftn_advantageOverdraftProtection_content
# here 4
# ----------------
# /deposits/resources/personal-schedule-fees.go?request_locale=en_US
# here 4
# ----------------
# /deposits/resources/personal-schedule-fees.go?request_locale=en_US
# here 4
# ----------------
# #ftn_advantageOverdraftFee_content
# here 4
# ----------------
# #ftn_advantageReturnedItemFee_content
# here 4
# ----------------
# /deposits/checking/checking-clarity-statement/
# here 1
# ----------------
# /deposits/checking/advantage-safebalance-banking-account/before-you-apply/
# here 1
# ----------------
# /deposits/checking/advantage-plus-banking-account/before-you-apply/
# here 1
# ----------------
# /deposits/checking/advantage-relationship-banking-account/before-you-apply/
# here 1
# ----------------
# javascript:void(0)
# here 4
# ----------------
# javascript:void(0)
# here 4
# ----------------
# javascript:void(0)
# here 4
# ----------------
# https://secure.bankofamerica.com/mycommunications/public/appointments/getTopics.go?marketingCode=BBAPRSNL15_ECDEP_A1000&orig=discussiontopic&request_locale=en_US&comment=I%20have%20questions%20about%20a%20Bank%20of%20America%AE%20Core%20Checking%20account
# here 4
# ----------------
# https://secure.bankofamerica.com/mycommunications/public/appointments/getTopics.go?marketingCode=BBAPRSNL15_ECDEP_A1000&orig=discussiontopic&request_locale=en_US&comment=I%20have%20questions%20about%20a%20Bank%20of%20America%AE%20Core%20Checking%20account
# here 4
# ----------------
# tel:844.375.7028
# here 4
# ----------------
# #panel-legal
# here 4
# ----------------
# /?request_locale=en_US
# here 4
# ----------------
# /deposits/checking/checking-accounts/
# here 1
# ----------------
# #footer-links-0
# here 4
# ----------------
# /deposits/checking/advantage-banking/
# here 1
# ----------------
# /student-banking/
# here 1
# ----------------
# /deposits/checking/debit-card/
# here 1
# ----------------
# /deposits/checking/checking-clarity-statement/
# here 1
# ----------------
# #footer-links-1
# here 4
# ----------------
# /deposits/savings/savings-accounts/
# here 1
# ----------------
# /deposits/savings/child-savings-accounts/
# here 1
# ----------------
# /deposits/savings/utma-savings-account-for-children/
# here 1
# link_counter, page_link_counter =  55 14
# http://www.bankofamerica.com/deposits/checking/checking-accounts,http://www.bankofamerica.com/deposits/savings/utma-savings-account-for-children,UTMA Account - Custodial Savings Account for Children
# ----------------
# #footer-links-2
# here 4
# ----------------
# /deposits/bank-cds/cd-accounts/
# here 1
# ----------------
# /deposits/bank-cds/featured-cd/
# here 1
# link_counter, page_link_counter =  56 15
# http://www.bankofamerica.com/deposits/checking/checking-accounts,http://www.bankofamerica.com/deposits/bank-cds/featured-cd,Featured CD from Bank of America
# ----------------
# /deposits/bank-cds/standard-term-cd/
# here 1
# link_counter, page_link_counter =  57 16
# http://www.bankofamerica.com/deposits/checking/checking-accounts,http://www.bankofamerica.com/deposits/bank-cds/standard-term-cd,Standard Term CD from Bank of America
# ----------------
# #footer-links-3
# here 4
# ----------------
# /deposits/iras/retirement-accounts/
# here 1
# ----------------
# /deposits/iras/retirement-accounts/savings-iras/
# here 1
# link_counter, page_link_counter =  58 17
# http://www.bankofamerica.com/deposits/checking/checking-accounts,http://www.bankofamerica.com/deposits/iras/retirement-accounts/savings-iras,Savings IRAs from Bank of America
# ----------------
# https://www.merrilledge.com/retirement-planning
# here 4
# ----------------
# https://www.merrilledge.com/m/pages/mobile/retirement-planning-mobile.aspx?src_cd=bac_ira
# here 4
# ----------------
# #footer-links-4
# here 4
# ----------------
# https://bettermoneyhabits.bankofamerica.com/en/saving-budgeting
# here 4
# ----------------
# https://bettermoneyhabits.bankofamerica.com/en/personal-banking
# here 4
# ----------------
# /deposits/routing-number-faqs/?request_locale=en_US
# here 4
# ----------------
# /deposits/manage/glossary
# here 1
# link_counter, page_link_counter =  59 18
# http://www.bankofamerica.com/deposits/checking/checking-accounts,http://www.bankofamerica.com/deposits/manage/glossary,Glossary of Financial Banking Terms from Bank of America
# ----------------
# /deposits/savings/savings-goal-calculator/
# here 1
# link_counter, page_link_counter =  60 19
# http://www.bankofamerica.com/deposits/checking/checking-accounts,http://www.bankofamerica.com/deposits/savings/savings-goal-calculator,Savings Goal Calculator for Short Term Financial Goals
# ----------------
# https://promo.bankofamerica.com/deals/
# here 4
# ----------------
# /deposits/keep-the-change/?request_locale=en_US
# here 4
# ----------------
# /deposits/switch-banks
# here 1
# link_counter, page_link_counter =  61 20
# http://www.bankofamerica.com/deposits/checking/checking-accounts,http://www.bankofamerica.com/deposits/switch-banks,How to Switch Banks Online with Bank of America
# http://www.bankofamerica.com
# ----------------
# #skip-to-h1
# here 4
# ----------------
# /
# here 4
# ----------------
# https://staticweb.bankofamerica.com/cavmwebbactouch/common/index.html#home?app=signon
# here 4
# ----------------
# /online-banking/sign-in/
# here 1
# ----------------
# https://locators.bankofamerica.com
# here 4
# ----------------
# es
# here 3
# link_counter, page_link_counter =  62 1
# http://www.bankofamerica.com/deposits/savings/savings-accounts,http://www.bankofamerica.com/deposits/savings/es,None
# ----------------
# javascript:void(0);
# here 4
# ----------------
# /
# here 4
# ----------------
# /contactus/contactus.go?topicId=checking_savings
# here 4
# ----------------
# https://locators.bankofamerica.com
# here 4
# ----------------
# /deposits/applying-for-accounts-faqs/
# here 1
# ----------------
# https://secure.bankofamerica.com/mycommunications/public/appointments/loc.go
# here 4
# ----------------
# es
# here 3
# ----------------
# es
# here 3
# ----------------
# javascript:void(0);
# here 4
# ----------------
# /deposits/bank-account-interest-rates/
# here 1
# ----------------
# /deposits/account-fees/
# here 1
# ----------------
# /deposits/checking/checking-clarity-statement/
# here 1
# ----------------
# /deposits/managing-your-money.go?request_locale=en_US
# here 4
# ----------------
# /deposits/access-your-accounts.go?request_locale=en_US
# here 4
# ----------------
# /deposits/bank-account-interest-rates/
# here 1
# ----------------
# /deposits/account-fees/
# here 1
# ----------------
# /deposits/checking/checking-clarity-statement/
# here 1
# ----------------
# /deposits/managing-your-money.go?request_locale=en_US
# here 4
# ----------------
# /deposits/access-your-accounts.go?request_locale=en_US
# here 4
# ----------------
# javascript:void(0);
# here 4
# ----------------
# /deposits/checking/advantage-banking/
# here 1
# ----------------
# /deposits/savings/savings-accounts/
# here 1
# ----------------
# /deposits/bank-cds/cd-accounts/
# here 1
# ----------------
# /deposits/iras/retirement-accounts/
# here 1
# ----------------
# /deposits/checking/debit-card/
# here 1
# ----------------
# /deposits/bank-accounts/
# here 1
# ----------------
# /deposits/checking/advantage-banking/
# here 1
# ----------------
# /deposits/savings/savings-accounts/
# here 1
# ----------------
# /deposits/bank-cds/cd-accounts/
# here 1
# ----------------
# /deposits/iras/retirement-accounts/
# here 1
# ----------------
# /deposits/checking/debit-card/
# here 1
# ----------------
# /deposits/bank-accounts/
# here 1
# ----------------
# /deposits/savings/rewards-savings-account/before-you-apply/
# here 1
# link_counter, page_link_counter =  63 2
# http://www.bankofamerica.com/deposits/savings/savings-accounts,http://www.bankofamerica.com/deposits/savings/rewards-savings-account/before-you-apply,Advantage Savings Account - Before You Apply
# ----------------
# /deposits/savings/rewards-savings-account/before-you-apply/
# here 1
# ----------------
# https://secure.bankofamerica.com/applynow/initialize-workflow.go?requesttype=SNR
# here 4
# ----------------
# https://secure.bankofamerica.com/applynow/initialize-workflow.go?requesttype=SNR
# here 4
# ----------------
# #waysToSaveDepositsModule
# here 4
# ----------------
# #feesCollapsibleSection
# here 4
# ----------------
# #ratesCollapsibleSection
# here 4
# ----------------
# #benefitsCollapsibleSection
# here 4
# ----------------
# #resourcesCollapsibleSection
# here 4
# ----------------
# /deposits/savings/rewards-savings-account/before-you-apply/
# here 1
# ----------------
# javascript:void(0);
# here 4
# ----------------
# https://secure.bankofamerica.com/mycommunications/public/appointments/getTopics.go?marketingCode=BBACHKING15_ECDEP_A1000&cm_mmc=olb-general-_-vanity-_-appointments-_-na&orig=landing&request_locale=en_US
# here 4
# ----------------
# https://secure.bankofamerica.com/mycommunications/public/appointments/getTopics.go?marketingCode=BBACHKING15_ECDEP_A1000&cm_mmc=olb-general-_-vanity-_-appointments-_-na&orig=landing&request_locale=en_US
# here 4
# ----------------
# tel:844.375.7027
# here 4
# ----------------
# javascript:void(0);
# here 4
# ----------------
# javascript:void(0);
# here 4
# ----------------
# https://www.bankofamerica.com/preferred-rewards/
# here 4
# ----------------
# #ftn_bankAmeriDeals_content
# here 4
# ----------------
# https://promo.bankofamerica.com/deals/
# here 4
# ----------------
# #ftn_keepTheChange_content
# here 4
# ----------------
# /deposits/manage/keep-the-change.go?request_locale=en_US
# here 4
# ----------------
# javascript:void(0);
# here 4
# ----------------
# javascript:void(0);
# here 4
# ----------------
# #ftn_rewardsSavingsWaiver_content
# here 4
# ----------------
# #ftn_advantageEligibleStudents_content
# here 4
# ----------------
# #ftn_withdrawalDisclosure_content
# here 4
# ----------------
# #ftn_federalRegulationsOnTransfers_content
# here 4
# ----------------
# /deposits/account-fees/#Rewards%20Savings
# here 4
# ----------------
# /deposits/resources/personal-schedule-fees.go?request_locale=en_US
# here 4
# ----------------
# /content/documents/deposits/service/pdf/docrepo/Rewards_MMS_en_ADA_aug2016.pdf
# here 4
# ----------------
# #ftn_rewardsSavingsWaiver_content
# here 4
# ----------------
# #ftn_advantageEligibleStudents_content
# here 4
# ----------------
# #ftn_withdrawalDisclosure_content
# here 4
# ----------------
# #ftn_federalRegulationsOnTransfers_content
# here 4
# ----------------
# /deposits/account-fees/#Rewards%20Savings
# here 4
# ----------------
# /deposits/resources/personal-schedule-fees.go?request_locale=en_US
# here 4
# ----------------
# /content/documents/deposits/service/pdf/docrepo/Rewards_MMS_en_ADA_aug2016.pdf
# here 4
# ----------------
# javascript:void(0);
# here 4
# ----------------
# javascript:void(0);
# here 4
# ----------------
# #ftn_apyBalanceTiers_content
# here 4
# ----------------
# #ftn_annualPercentageYield_content
# here 4
# ----------------
# #ftn_apyBalanceTiers_content
# here 4
# ----------------
# #ftn_annualPercentageYield_content
# here 4
# ----------------
# javascript:void(0);
# here 4
# ----------------
# #ftn_annualPercentageYield_content
# here 4
# ----------------
# #ftn_annualPercentageYield_content
# here 4
# ----------------
# #ftn_annualPercentageYield_content
# here 4
# ----------------
# https://www.bankofamerica.com/preferred-rewards/
# here 4
# ----------------
# /deposits/bank-cds/cd-accounts/
# here 1
# ----------------
# /deposits/iras/retirement-accounts/
# here 1
# ----------------
# /deposits/savings/child-savings-accounts/
# here 1
# ----------------
# https://www.merrilledge.com/college-savings/529?src_cd=bac_hp_nav_529
# here 4
# ----------------
# javascript:void(0);
# here 4
# ----------------
# javascript:void(0);
# here 4
# ----------------
# javascript:void(0)
# here 4
# ----------------
# javascript:void(0)
# here 4
# ----------------
# javascript:void(0)
# here 4
# ----------------
# javascript:void(0)
# here 4
# ----------------
# javascript:void(0)
# here 4
# ----------------
# javascript:void(0)
# here 4
# ----------------
# https://locators.bankofamerica.com/
# here 4
# ----------------
# #ftn_mobileCheckDeposits_content
# here 4
# ----------------
# #ftn_withdrawalDisclosure_content
# here 4
# ----------------
# #ftn_advantageCustomAlerts_content
# here 4
# ----------------
# #ftn_overdraftProtectionFees_content
# here 4
# ...
# http://www.bankofamerica.com/credit-cards,http://www.bankofamerica.com/credit-cards/credit-card-with-no-annual-fee,Credit Cards with No Annual Fee from Bank of America
# ----------------
# /credit-cards/promo-rate-balance-transfers-credit-cards/
# here 1
# link_counter, page_link_counter =  77 9
# http://www.bankofamerica.com/credit-cards,http://www.bankofamerica.com/credit-cards/promo-rate-balance-transfers-credit-cards,Balance Transfer Credit Cards with Low Intro APR
# ----------------
# /credit-cards/promo-rate-purchases-credit-cards/
# here 1
# link_counter, page_link_counter =  78 10
# http://www.bankofamerica.com/credit-cards,http://www.bankofamerica.com/credit-cards/promo-rate-purchases-credit-cards,Credit Cards with Low Intro APR on Purchases
# ----------------
# /credit-cards/no-foreign-transaction-fee-credit-cards/
# here 1
# link_counter, page_link_counter =  79 11
# http://www.bankofamerica.com/credit-cards,http://www.bankofamerica.com/credit-cards/no-foreign-transaction-fee-credit-cards,Credit Cards with No Foreign Transaction Fees
# ----------------
# /credit-cards/preferred-rewards-credit-cards/
# here 1
# link_counter, page_link_counter =  80 12
# http://www.bankofamerica.com/credit-cards,http://www.bankofamerica.com/credit-cards/preferred-rewards-credit-cards,Preferred Rewards Eligible Credit Cards
# ----------------
# /credit-cards/credit-card-with-no-annual-fee/
# here 1
# ----------------
# /credit-cards/promo-rate-balance-transfers-credit-cards/
# here 1
# ----------------
# /credit-cards/promo-rate-purchases-credit-cards/
# here 1
# ----------------
# /credit-cards/no-foreign-transaction-fee-credit-cards/
# here 1
# ----------------
# /credit-cards/preferred-rewards-credit-cards/
# here 1
# ----------------
# javascript:void(0);
# here 4
# ----------------
# /credit-cards/compare-credit-cards/
# here 1
# link_counter, page_link_counter =  81 13
# http://www.bankofamerica.com/credit-cards,http://www.bankofamerica.com/credit-cards/compare-credit-cards,Compare Credit Cards with the Credit Card Comparison Tool
# ----------------
# https://secure.bankofamerica.com/applynow/initialize-workflow.go?requesttype=snr&flow=cards
# here 4
# ----------------
# /credit-cards/free-fico-credit-score/
# here 1
# link_counter, page_link_counter =  82 14
# http://www.bankofamerica.com/credit-cards,http://www.bankofamerica.com/credit-cards/free-fico-credit-score,Get your FICO® Score for Free in Online and Mobile Banking
# ----------------
# https://bettermoneyhabits.bankofamerica.com/en/credit
# here 4
# ----------------
# https://mynewcard2.bankofamerica.com/USCCapp/Ctl/entry?pid=padm_prefill&tk=21&to=16&cc=DM
# here 4
# ----------------
# /credit-cards/credit-card-agreements/
# here 1
# link_counter, page_link_counter =  83 15
# http://www.bankofamerica.com/credit-cards,http://www.bankofamerica.com/credit-cards/credit-card-agreements,Sample Credit Card Agreements from Bank of America
# ----------------
# /smallbusiness/credit-cards/
# here 1
# link_counter, page_link_counter =  84 16
# http://www.bankofamerica.com/credit-cards,http://www.bankofamerica.com/smallbusiness/credit-cards,Small Business Credit Cards from Bank of America
# ----------------
# /credit-cards/compare-credit-cards/
# here 1
# ----------------
# https://secure.bankofamerica.com/applynow/initialize-workflow.go?requesttype=snr&flow=cards
# here 4
# ----------------
# /credit-cards/free-fico-credit-score/
# here 1
# ----------------
# https://bettermoneyhabits.bankofamerica.com/en/credit
# here 4
# ----------------
# https://mynewcard2.bankofamerica.com/USCCapp/Ctl/entry?pid=padm_prefill&tk=21&to=16&cc=DM
# here 4
# ----------------
# /credit-cards/credit-card-agreements/
# here 1
# ----------------
# /smallbusiness/credit-cards/
# here 1
# ----------------
# /privacy/overview.go
# here 4
# ----------------
# javascript:void(0);
# here 4
# ----------------
# javascript:void(0);
# here 4
# ----------------
# https://secure.bankofamerica.com/applynow/initialize-workflow.go?requesttype=C&campaignid=4047601&productoffercode=8U
# here 4
# ----------------
# #categories
# here 4
# ----------------
# #filter
# here 4
# ----------------
# #featured
# here 4
# ----------------
# #cash
# here 4
# ----------------
# #travel
# here 4
# ----------------
# #airline
# here 4
# ----------------
# #lowInterest
# here 4
# ----------------
# #buildCredit
# here 4
# ----------------
# #points
# here 4
# ----------------
# #students
# here 4
# ----------------
# #more
# here 4
# ----------------
# #featured
# here 4
# ----------------
# #cash
# here 4
# ----------------
# #travel
# here 4
# ----------------
# #airline
# here 4
# ----------------
# #lowInterest
# here 4
# ----------------
# #buildCredit
# here 4
# ----------------
# #points
# here 4
# ----------------
# #students
# here 4
# ----------------
# javascript:void(0);
# here 4
# ----------------
# /credit-cards/credit-card-with-no-annual-fee/
# here 1
# ----------------
# /credit-cards/no-foreign-transaction-fee-credit-cards/
# here 1
# ----------------
# /credit-cards/promo-rate-balance-transfers-credit-cards/
# here 1
# ----------------
# /credit-cards/promo-rate-purchases-credit-cards/
# here 1
# ----------------
# /credit-cards/preferred-rewards-credit-cards/
# here 1
# ----------------
# /credit-cards/visa-credit-cards/
# here 1
# link_counter, page_link_counter =  85 17
# http://www.bankofamerica.com/credit-cards,http://www.bankofamerica.com/credit-cards/visa-credit-cards,Visa® Credit Cards & Applications from Bank of America
# ----------------
# /credit-cards/mastercard-credit-cards/
# here 1
# link_counter, page_link_counter =  86 18
# http://www.bankofamerica.com/credit-cards,http://www.bankofamerica.com/credit-cards/mastercard-credit-cards,Mastercard® Credit Cards from Bank of America
# ----------------
# javascript:void(0);
# here 4
# ----------------
# javascript:void(0);
# here 4
# ----------------
# /
# here 4
# ----------------
# /credit-cards/
# here 1
# ----------------
# javascript:void(0);
# here 4
# ----------------
# javascript:void(0);
# here 4
# ----------------
# javascript:history.back();
# here 4
# ----------------
# /credit-cards/compare-credit-cards/
# here 1
# ----------------
# https://secure.bankofamerica.com/secure-offers/public/customizedOffers?subchannel=ECCSHL&request_locale=en-us
# here 4
# ----------------
# https://secure.bankofamerica.com/secure-offers/public/customizedOffers?subchannel=ECCSHL&request_locale=en-us
# here 4
# ----------------
# https://www.bankofamerica.com/preferred-rewards/#benefits
# here 4
# ----------------
# /credit-cards/manage-your-credit-card-account/
# here 1
# ----------------
# https://secure.bankofamerica.com/applynow/initialize-workflow.go?requesttype=snr&flow=cards
# here 4
# ----------------
# https://secure.bankofamerica.com/apply-credit-cards/public/application-status/
# here 4
# ----------------
# https://mynewcard2.bankofamerica.com/USCCapp/Ctl/entry?pid=padm_prefill&tk=21&to=16&cc=DM
# here 4
# ----------------
# /credit-cards/credit-card-agreements/
# here 1
# ----------------
# https://bettermoneyhabits.bankofamerica.com/en/credit?subTopicId=choosing-a-credit-card
# here 4
# ----------------
# https://bettermoneyhabits.bankofamerica.com/en/credit?subTopicId=managing-credit-cards
# here 4
# ----------------
# https://bettermoneyhabits.bankofamerica.com/en/debt
# here 4
# ----------------
# https://bettermoneyhabits.bankofamerica.com/en/credit?subTopicId=credit-score
# here 4
# ----------------
# https://secure.bankofamerica.com/mycommunications/public/appointments/getTopics.go?marketingCode=CARDOVER_ECBBA_A1000&comment=I%20am%20interested%20in%20a%20Bank%20of%20America%AE%20credit%20card
# here 4
# ----------------
# https://www.bankofamerica.com
# here 4
# ----------------
# https://www.bankofamerica.com/credit-cards/
# here 4
# ----------------
# #footer-links-0
# here 4
# ----------------
# /credit-cards
# here 1
# ----------------
# https://secure.bankofamerica.com/secure-offers/public/customizedOffers?subchannel=ECCSPF&request_locale=en-us
# here 4
# ----------------
# https://secure.bankofamerica.com/secure-offers/public/customizedOffers?subchannel=ECCSPF&request_locale=en-us
# here 4
# ----------------
# https://secure.bankofamerica.com/apply-credit-cards/public/application-status/
# here 4
# ----------------
# https://secure.bankofamerica.com/applynow/initialize-workflow.go?requesttype=snr&flow=cards
# here 4
# ----------------
# https://mynewcard2.bankofamerica.com/USCCapp/Ctl/entry?pid=padm_prefill&tk=21&to=16&cc=DM
# here 4
# ----------------
# /credit-cards/compare-credit-cards/
# here 1
# ----------------
# /credit-cards/free-fico-credit-score/
# here 1
# ----------------
# /smallbusiness/credit-cards/
# here 1
# ----------------
# #footer-links-1
# here 4
# ----------------
# /credit-cards/cash-back-credit-cards/
# here 1
# ----------------
# /credit-cards/travel-credit-cards/
# here 1
# ----------------
# /credit-cards/airline-credit-cards/
# here 1
# ----------------
# /credit-cards/low-interest-credit-cards/
# here 1
# ----------------
# /credit-cards/credit-cards-to-build-credit/
# here 1
# ----------------
# /credit-cards/student-credit-cards/
# here 1
# ----------------
# /credit-cards/point-rewards-credit-cards/
# here 1
# ----------------
# /credit-cards/credit-card-with-no-annual-fee/
# here 1
# ----------------
# /credit-cards/no-foreign-transaction-fee-credit-cards/
# here 1
# ----------------
# #footer-links-2
# here 4
# ----------------
# https://bettermoneyhabits.bankofamerica.com/en/credit?subTopicId=choosing-a-credit-card
# here 4
# ----------------
# https://bettermoneyhabits.bankofamerica.com/en/credit?subTopicId=managing-credit-cards
# here 4
# ----------------
# https://bettermoneyhabits.bankofamerica.com/en/debt
# here 4
# ----------------
# https://bettermoneyhabits.bankofamerica.com/en/credit?subTopicId=credit-score
# here 4
# ----------------
# /credit-cards/credit-card-account-information-faq/
# here 1
# ----------------
# /credit-cards/glossary/
# here 1
# link_counter, page_link_counter =  87 19
# http://www.bankofamerica.com/credit-cards,http://www.bankofamerica.com/credit-cards/glossary,Credit Card Terminology: Glossary of Terms & Definitions
# ----------------
# #footer-links-3
# here 4
# ----------------
# /credit-cards/manage-your-credit-card-account/
# here 1
# ----------------
# /online-banking/mobile-and-online-banking-features/overview/?request_locale=en_US
# here 4
# ----------------
# /online-banking/sign-in/?request_locale=en_US
# here 4
# ----------------
# /privacy/accounts-cards/credit-debit-card-security.go?request_locale=en_US
# here 4
# ----------------
# /banking-information/assistance/credit-cards/credit-cards-assistance-overview.go?request_locale=en_US
# here 4
# ----------------
# /
# here 4
# ----------------
# https://www.bankofamerica.com/security-center/privacy-overview/
# here 4
# ----------------
# https://www.bankofamerica.com/security-center/overview/
# here 4
# ----------------
# https://careers.bankofamerica.com/
# here 4
# ----------------
# javascript:void(0);
# here 4
# ----------------
# /information/personal/
# here 1
# ----------------
# javascript:void(0);
# here 4
# ----------------
# /security-center/online-privacy-notice/#advertising-on-our-sites
# here 4
# ----------------
# /security-center/online-privacy-notice/
# here 1
# ----------------
# /security-center/faq/online-privacy/
# here 1
# ----------------
# es/
# here 3
# ----------------
# /help/equalhousing-popup/
# here 1
# http://www.bankofamerica.com
# ----------------
# #skip-to-h1
# here 4
# ----------------
# /
# here 4
# ----------------
# https://staticweb.bankofamerica.com/cavmwebbactouch/common/index.html#home?app=signon
# here 4
# ----------------
# /online-banking/sign-in/
# here 1
# ----------------
# https://locators.bankofamerica.com
# here 4
# ----------------
# es/
# here 3
# link_counter, page_link_counter =  88 1
# http://www.bankofamerica.com/mortgage/home-mortgage,http://www.bankofamerica.com/mortgage/es,Préstamos para vivienda y las tasas actuales de Bank of America
# ----------------
# javascript:void(0);
# here 4
# ----------------
# /
# here 4
# ----------------
# /customer-service/contact-us/?request_locale=en_US
# here 4
# ----------------
# https://locators.bankofamerica.com
# here 4
# ----------------
# /mortgage/faqs/#mortgage-refinance/
# here 4
# ----------------
# https://secure.bankofamerica.com/secure-mycommunications/public/appointments/
# here 4
# ----------------
# es/
# here 3
# ----------------
# es/
# here 3
# ----------------
# javascript:void(0);
# here 4
# ----------------
# /mortgage/home-mortgage/
# here 1
# ----------------
# /mortgage/mortgage-rates/
# here 1
# link_counter, page_link_counter =  89 2
# http://www.bankofamerica.com/mortgage/home-mortgage,http://www.bankofamerica.com/mortgage/mortgage-rates,Mortgage Rates - Today's Rates from Bank of America
# ----------------
# /mortgage/mortgage-calculator/
# here 1
# link_counter, page_link_counter =  90 3
# http://www.bankofamerica.com/mortgage/home-mortgage,http://www.bankofamerica.com/mortgage/mortgage-calculator,Mortgage Calculator from Bank of America
# ----------------
# /mortgage/closing-costs-calculator/
# here 1
# link_counter, page_link_counter =  91 4
# http://www.bankofamerica.com/mortgage/home-mortgage,http://www.bankofamerica.com/mortgage/closing-costs-calculator,Closing Costs Calculator - Estimate Closing Costs at Bank of America
# ----------------
# /mortgage/learn/
# here 1
# link_counter, page_link_counter =  92 5
# http://www.bankofamerica.com/mortgage/home-mortgage,http://www.bankofamerica.com/mortgage/learn,Learn about Mortgages, Refinancing and Home Equity from Bank of America
# ----------------
# /mortgage/first-time-home-buyer/
# here 1
# link_counter, page_link_counter =  93 6
# http://www.bankofamerica.com/mortgage/home-mortgage,http://www.bankofamerica.com/mortgage/first-time-home-buyer,First-time Home Buyer Information, Tools and Resources
# ----------------
# /mortgage/home-mortgage/
# here 1
# ----------------
# /mortgage/mortgage-rates/
# here 1
# ----------------
# /mortgage/mortgage-calculator/
# here 1
# ----------------
# /mortgage/closing-costs-calculator/
# here 1
# ----------------
# /mortgage/learn/
# here 1
# ----------------
# /mortgage/first-time-home-buyer/
# here 1
# ----------------
# javascript:void(0);
# here 4
# ----------------
# /mortgage/refinance/
# here 1
# link_counter, page_link_counter =  94 7
# http://www.bankofamerica.com/mortgage/home-mortgage,http://www.bankofamerica.com/mortgage/refinance,Mortgage Refinance and Home Refinancing from Bank of America
# ----------------
# /mortgage/refinance-rates/
# here 1
# link_counter, page_link_counter =  95 8
# http://www.bankofamerica.com/mortgage/home-mortgage,http://www.bankofamerica.com/mortgage/refinance-rates,Refinance Rates - Today's Rates from Bank of America
# ----------------
# /mortgage/refinance-calculator/
# here 1
# link_counter, page_link_counter =  96 9
# http://www.bankofamerica.com/mortgage/home-mortgage,http://www.bankofamerica.com/mortgage/refinance-calculator,Mortgage Refinance Calculator from Bank of America
# ----------------
# https://homevaluerealestatecenter.bankofamerica.com/
# here 4
# ----------------
# /mortgage/learn/#/refinance
# here 4
# ----------------
# /mortgage/refinance/
# here 1
# ----------------
# /mortgage/refinance-rates/
# here 1
# ----------------
# /mortgage/refinance-calculator/
# here 1
# ----------------
# https://homevaluerealestatecenter.bankofamerica.com/
# here 4
# ----------------
# /mortgage/learn/#/refinance
# here 4
# ----------------
# javascript:void(0);
# here 4
# ----------------
# /home-equity/
# here 1
# link_counter, page_link_counter =  97 10
# http://www.bankofamerica.com/mortgage/home-mortgage,http://www.bankofamerica.com/home-equity,Home Equity Line of Credit (HELOC) from Bank of America
# ----------------
# /home-equity/home-equity-rates/
# here 1
# link_counter, page_link_counter =  98 11
# http://www.bankofamerica.com/mortgage/home-mortgage,http://www.bankofamerica.com/home-equity/home-equity-rates,Home Equity Rates - Low HELOC Rates
# ----------------
# /home-equity/home-equity-calculator/
# here 1
# link_counter, page_link_counter =  99 12
# http://www.bankofamerica.com/mortgage/home-mortgage,http://www.bankofamerica.com/home-equity/home-equity-calculator,Home Equity Line of Credit (HELOC) Payment Calculator
# ----------------
# /mortgage/learn/#/home-equity
# here 4
# ----------------
# /home-equity/
# here 1
# ----------------
# /home-equity/home-equity-rates/
# here 1
# ----------------
# /home-equity/home-equity-calculator/
# here 1
# ----------------
# /mortgage/learn/#/home-equity
# here 4
# ----------------
# javascript:void(0);
# here 4
# ----------------
# /mortgage/
# here 1
# link_counter, page_link_counter =  100 13
# http://www.bankofamerica.com/mortgage/home-mortgage,http://www.bankofamerica.com/mortgage,Home Loans and Current Rates from Bank of America
# Done!!
