# %% [markdown]
# ### Game of Pig
#
# Rules:
#
# 1. Two players take turns rolling a single die as many times as they wish. Each roll adds a score equal to the number rolled to the player's total.
# 2. If a player rolls a 1, their score for that turn is zero, and their turn ends.
# 3. At any point during a player's turn, they can choose to stop rolling and keep their score. The first player to reach 100 wins.
#
# That's it! Let's play.
#
# There are two basic strategies for this game.  The first is known as roll-based strategy, where you roll a set number of times on each turn (unless you lose).  The second is known as score-based strategy, where you roll until you reach a certain score, and then stop.
#
# Here, we investigate the score-based strategy.

# %%
# The usual libraries
import random
import matplotlib.pyplot as plt
import numpy as np


# A couple of debug flags to control print statements
debug1 = False
debug2 = False

# Number of games to simulate for each configuration
nsims = 1000

# %%
# function to play an entire game of pig
# N_stop is the score at which the player will stop rolling
# end_score is the score at which the game ends
# returns the average roll per turn

def game_play(N_stop,end_score):

    # Initialize the score (for each of two players) and turn number within the game
    score = [0,0]
    turn = 0

    # Play the game - keep going until one player reaches the end score
    while score[0] < end_score and score[1] < end_score:

        # Initialize the score for this player during this turn and increment turn number
        turn_score = 0
        turn += 1

        if debug2:
            print("Turn", turn)
            for i in range(2):
                print("Player", i+1, "score:", score[i])
            print("Player", turn%2+1, "turn")

        roll = 0
        # Keep rolling until you roll a 1 or reach N_stop
        while roll != 1 and turn_score < N_stop and score[turn%2] < end_score:

            roll = random.randint(1,6)
            if debug2:
                print("Roll:", roll)

            if roll == 1:
                if debug2:
                    print("Player", turn%2+1, "loses turn")
                # If you roll a 1, you lose all points for this turn and your turn is over
                score[turn%2] = score[turn%2] - turn_score
                break
            else:
                score[turn%2] += roll
                if debug2:
                    print("Player", turn%2+1, "score:", score[turn%2])
                #
                turn_score += roll

        if debug2:
            print("Player", turn%2+1, "turn over")
            print()

    if debug1:
        print(f"Final score: Player 1: {score[0]}, Player 2: {score[1]}")
        print(f"Player {np.argmax(score)+1} wins!")
        print(f"Game took {turn} turns")

    return 2.0*np.mean(score)/turn

# %%
# consider four different end scores .. 50, 100, 200, 500.  For each, plot the average roll vs. N_stop
end_score = [50,100, 200, 500]

# initialize an array to hold the four different arrays of average roll vs. N_stop for the four different end scores.  Each array will have 49 elements, one for each N_stop from 1 to 49
avg_array_sum = []

for j in range(4):
    avg_array = []
    for nstop in range(1,50):
        sum_avg = 0
        for i in range(nsims):
            avg = game_play(nstop,end_score[j])
            sum_avg += avg
            #print(f"Average roll over all turns = {avg}")

        print(f"Average roll over all turns and sims for N_stop = {nstop} is {sum_avg/nsims}")
        avg_array.append(sum_avg/nsims)

    avg_array_sum.append(avg_array)
# Out:
# Average roll over all turns and sims for N_stop = 1 is 3.348387077916663
# Average roll over all turns and sims for N_stop = 2 is 3.374439824727923
# Average roll over all turns and sims for N_stop = 3 is 3.8693918274282972
# Average roll over all turns and sims for N_stop = 4 is 4.354859252722693
# Average roll over all turns and sims for N_stop = 5 is 4.875768653500006
# Average roll over all turns and sims for N_stop = 6 is 5.454183108533616
# Average roll over all turns and sims for N_stop = 7 is 6.007775098366809
# Average roll over all turns and sims for N_stop = 8 is 6.363614834993795
# Average roll over all turns and sims for N_stop = 9 is 6.673975864420652
# Average roll over all turns and sims for N_stop = 10 is 7.033252136520555
# Average roll over all turns and sims for N_stop = 11 is 7.477609362606673
# Average roll over all turns and sims for N_stop = 12 is 7.63259295661563
# Average roll over all turns and sims for N_stop = 13 is 7.800487503352148
# Average roll over all turns and sims for N_stop = 14 is 7.9134012902366315
# Average roll over all turns and sims for N_stop = 15 is 8.370746393880165
# Average roll over all turns and sims for N_stop = 16 is 8.728744327035384
# Average roll over all turns and sims for N_stop = 17 is 8.771184356220148
# Average roll over all turns and sims for N_stop = 18 is 8.657178137498681
# Average roll over all turns and sims for N_stop = 19 is 8.74730817901547
# Average roll over all turns and sims for N_stop = 20 is 8.799046465446777
# Average roll over all turns and sims for N_stop = 21 is 8.64558854732641
# Average roll over all turns and sims for N_stop = 22 is 8.87209667565708
# Average roll over all turns and sims for N_stop = 23 is 9.385140540372415
# Average roll over all turns and sims for N_stop = 24 is 9.925670855838522
# Average roll over all turns and sims for N_stop = 25 is 10.089743210009592
# Average roll over all turns and sims for N_stop = 26 is 10.25401545926602
# Average roll over all turns and sims for N_stop = 27 is 10.037052884858644
# Average roll over all turns and sims for N_stop = 28 is 9.912457082713688
# Average roll over all turns and sims for N_stop = 29 is 9.720503247282172
# Average roll over all turns and sims for N_stop = 30 is 9.553044768973896
# Average roll over all turns and sims for N_stop = 31 is 10.039429838248259
# Average roll over all turns and sims for N_stop = 32 is 9.63291432146749
# Average roll over all turns and sims for N_stop = 33 is 9.680713777762218
# Average roll over all turns and sims for N_stop = 34 is 9.317204219619603
# Average roll over all turns and sims for N_stop = 35 is 9.282555984302805
# Average roll over all turns and sims for N_stop = 36 is 9.558743676575224
# Average roll over all turns and sims for N_stop = 37 is 9.376499000288682
# Average roll over all turns and sims for N_stop = 38 is 9.338274695277729
# Average roll over all turns and sims for N_stop = 39 is 8.998095128940687
# Average roll over all turns and sims for N_stop = 40 is 8.902960589064666
# Average roll over all turns and sims for N_stop = 41 is 8.709481781698837
# Average roll over all turns and sims for N_stop = 42 is 8.683213994912887
# Average roll over all turns and sims for N_stop = 43 is 8.250230933826884
# Average roll over all turns and sims for N_stop = 44 is 8.257924195397178
# Average roll over all turns and sims for N_stop = 45 is 9.08511422238727
# Average roll over all turns and sims for N_stop = 46 is 9.06497447956556
# Average roll over all turns and sims for N_stop = 47 is 9.87497994912846
# Average roll over all turns and sims for N_stop = 48 is 9.989725657916592
# Average roll over all turns and sims for N_stop = 49 is 11.13652258067241
# Average roll over all turns and sims for N_stop = 1 is 3.3522137678270423
# Average roll over all turns and sims for N_stop = 2 is 3.3521675208928947
# Average roll over all turns and sims for N_stop = 3 is 3.844125306488996
# Average roll over all turns and sims for N_stop = 4 is 4.305033021085455
# Average roll over all turns and sims for N_stop = 5 is 4.85111244051547
# Average roll over all turns and sims for N_stop = 6 is 5.414011738739203
# Average roll over all turns and sims for N_stop = 7 is 6.01407085050312
# Average roll over all turns and sims for N_stop = 8 is 6.291051887056197
# Average roll over all turns and sims for N_stop = 9 is 6.6561345834704735
# Average roll over all turns and sims for N_stop = 10 is 6.990569397999392
# Average roll over all turns and sims for N_stop = 11 is 7.314076053194802
# Average roll over all turns and sims for N_stop = 12 is 7.5377183943267765
# Average roll over all turns and sims for N_stop = 13 is 7.824523862877358
# Average roll over all turns and sims for N_stop = 14 is 7.854531826565663
# Average roll over all turns and sims for N_stop = 15 is 8.210241174216044
# Average roll over all turns and sims for N_stop = 16 is 8.284459228200841
# Average roll over all turns and sims for N_stop = 17 is 8.178810137399566
# Average roll over all turns and sims for N_stop = 18 is 8.419047955978332
# Average roll over all turns and sims for N_stop = 19 is 8.734513883204297
# Average roll over all turns and sims for N_stop = 20 is 8.644863869687756
# Average roll over all turns and sims for N_stop = 21 is 8.695064906891709
# Average roll over all turns and sims for N_stop = 22 is 8.603092041934389
# Average roll over all turns and sims for N_stop = 23 is 8.675763116671147
# Average roll over all turns and sims for N_stop = 24 is 8.845737113010983
# Average roll over all turns and sims for N_stop = 25 is 8.93335569634838
# Average roll over all turns and sims for N_stop = 26 is 8.897708707322753
# Average roll over all turns and sims for N_stop = 27 is 8.62845021452508
# Average roll over all turns and sims for N_stop = 28 is 8.534420332675221
# Average roll over all turns and sims for N_stop = 29 is 8.638330116485246
# Average roll over all turns and sims for N_stop = 30 is 8.598639399728432
# Average roll over all turns and sims for N_stop = 31 is 8.5473497718694
# Average roll over all turns and sims for N_stop = 32 is 8.672593156249572
# Average roll over all turns and sims for N_stop = 33 is 8.733174994547765
# Average roll over all turns and sims for N_stop = 34 is 8.68985975891013
# Average roll over all turns and sims for N_stop = 35 is 8.568056992920432
# Average roll over all turns and sims for N_stop = 36 is 8.213377139152511
# Average roll over all turns and sims for N_stop = 37 is 8.616421830367376
# Average roll over all turns and sims for N_stop = 38 is 8.445723082574043
# Average roll over all turns and sims for N_stop = 39 is 8.413226433807116
# Average roll over all turns and sims for N_stop = 40 is 8.270024560945897
# Average roll over all turns and sims for N_stop = 41 is 8.06209568344811
# Average roll over all turns and sims for N_stop = 42 is 7.9662876677813275
# Average roll over all turns and sims for N_stop = 43 is 7.737268578557041
# Average roll over all turns and sims for N_stop = 44 is 7.635401964303701
# Average roll over all turns and sims for N_stop = 45 is 7.179186690806662
# Average roll over all turns and sims for N_stop = 46 is 7.223229722373742
# Average roll over all turns and sims for N_stop = 47 is 7.159306140495754
# Average roll over all turns and sims for N_stop = 48 is 7.27541023270813
# Average roll over all turns and sims for N_stop = 49 is 7.413310659818097
# Average roll over all turns and sims for N_stop = 1 is 3.342784319963129
# Average roll over all turns and sims for N_stop = 2 is 3.331758295917953
# Average roll over all turns and sims for N_stop = 3 is 3.848046386589182
# Average roll over all turns and sims for N_stop = 4 is 4.327554314882393
# Average roll over all turns and sims for N_stop = 5 is 4.8455068942174035
# Average roll over all turns and sims for N_stop = 6 is 5.405040542140214
# Average roll over all turns and sims for N_stop = 7 is 5.998845495897197
# Average roll over all turns and sims for N_stop = 8 is 6.2416756430076346
# Average roll over all turns and sims for N_stop = 9 is 6.583973751961205
# Average roll over all turns and sims for N_stop = 10 is 6.934667129395662
# Average roll over all turns and sims for N_stop = 11 is 7.218610881297105
# Average roll over all turns and sims for N_stop = 12 is 7.455901621440917
# Average roll over all turns and sims for N_stop = 13 is 7.67327809494064
# Average roll over all turns and sims for N_stop = 14 is 7.835449798807763
# Average roll over all turns and sims for N_stop = 15 is 7.949684063517113
# Average roll over all turns and sims for N_stop = 16 is 8.182928943978315
# Average roll over all turns and sims for N_stop = 17 is 8.240950922805057
# Average roll over all turns and sims for N_stop = 18 is 8.226678139496329
# Average roll over all turns and sims for N_stop = 19 is 8.396148904388088
# Average roll over all turns and sims for N_stop = 20 is 8.361744049282269
# Average roll over all turns and sims for N_stop = 21 is 8.468003974451445
# Average roll over all turns and sims for N_stop = 22 is 8.443593203066296
# Average roll over all turns and sims for N_stop = 23 is 8.51936263350725
# Average roll over all turns and sims for N_stop = 24 is 8.661421985716013
# Average roll over all turns and sims for N_stop = 25 is 8.324697626804575
# Average roll over all turns and sims for N_stop = 26 is 8.171361597893258
# Average roll over all turns and sims for N_stop = 27 is 8.290584048398209
# Average roll over all turns and sims for N_stop = 28 is 8.217679703047077
# Average roll over all turns and sims for N_stop = 29 is 8.112943007303828
# Average roll over all turns and sims for N_stop = 30 is 8.109023513491996
# Average roll over all turns and sims for N_stop = 31 is 7.952318632760608
# Average roll over all turns and sims for N_stop = 32 is 7.864627076845391
# Average roll over all turns and sims for N_stop = 33 is 7.923170601021808
# Average roll over all turns and sims for N_stop = 34 is 7.7824053953896
# Average roll over all turns and sims for N_stop = 35 is 7.5906619055529205
# Average roll over all turns and sims for N_stop = 36 is 7.536434904096003
# Average roll over all turns and sims for N_stop = 37 is 7.260276297379951
# Average roll over all turns and sims for N_stop = 38 is 7.153415350151446
# Average roll over all turns and sims for N_stop = 39 is 7.334192549079953
# Average roll over all turns and sims for N_stop = 40 is 7.484981812451055
# Average roll over all turns and sims for N_stop = 41 is 7.086893877820342
# Average roll over all turns and sims for N_stop = 42 is 7.04791330914624
# Average roll over all turns and sims for N_stop = 43 is 6.786351475938921
# Average roll over all turns and sims for N_stop = 44 is 6.849023067554852
# Average roll over all turns and sims for N_stop = 45 is 6.6719280393320375
# Average roll over all turns and sims for N_stop = 46 is 6.355528229772062
# Average roll over all turns and sims for N_stop = 47 is 6.313922835446851
# Average roll over all turns and sims for N_stop = 48 is 6.069726662785263
# Average roll over all turns and sims for N_stop = 49 is 6.178580960673283
# Average roll over all turns and sims for N_stop = 1 is 3.336132581602093
# Average roll over all turns and sims for N_stop = 2 is 3.335336864125049
# Average roll over all turns and sims for N_stop = 3 is 3.8367130069490103
# Average roll over all turns and sims for N_stop = 4 is 4.3095678452589965
# Average roll over all turns and sims for N_stop = 5 is 4.830941242797972
# Average roll over all turns and sims for N_stop = 6 is 5.3883860564885
# Average roll over all turns and sims for N_stop = 7 is 5.979982483212013
# Average roll over all turns and sims for N_stop = 8 is 6.268355504985239
# Average roll over all turns and sims for N_stop = 9 is 6.607922883280533
# Average roll over all turns and sims for N_stop = 10 is 6.906106142139334
# Average roll over all turns and sims for N_stop = 11 is 7.129685885222667
# Average roll over all turns and sims for N_stop = 12 is 7.421248962148709
# Average roll over all turns and sims for N_stop = 13 is 7.587539668017001
# Average roll over all turns and sims for N_stop = 14 is 7.768045892437652
# Average roll over all turns and sims for N_stop = 15 is 7.93197846664848
# Average roll over all turns and sims for N_stop = 16 is 8.034911159081823
# Average roll over all turns and sims for N_stop = 17 is 8.12298830230627
# Average roll over all turns and sims for N_stop = 18 is 8.13701368790785
# Average roll over all turns and sims for N_stop = 19 is 8.196263228570315
# Average roll over all turns and sims for N_stop = 20 is 8.248391799512587
# Average roll over all turns and sims for N_stop = 21 is 8.265143891831315
# Average roll over all turns and sims for N_stop = 22 is 8.277868693990785
# Average roll over all turns and sims for N_stop = 23 is 8.236515185727844
# Average roll over all turns and sims for N_stop = 24 is 8.175128270119185
# Average roll over all turns and sims for N_stop = 25 is 8.121813874780283
# Average roll over all turns and sims for N_stop = 26 is 8.068304649830663
# Average roll over all turns and sims for N_stop = 27 is 8.012416268389893
# Average roll over all turns and sims for N_stop = 28 is 7.98589808299128
# Average roll over all turns and sims for N_stop = 29 is 7.880056541666444
# Average roll over all turns and sims for N_stop = 30 is 7.844381318190536
# Average roll over all turns and sims for N_stop = 31 is 7.629137337538097
# Average roll over all turns and sims for N_stop = 32 is 7.605461592074356
# Average roll over all turns and sims for N_stop = 33 is 7.488628514595432
# Average roll over all turns and sims for N_stop = 34 is 7.366368864214461
# Average roll over all turns and sims for N_stop = 35 is 7.256158561583136
# Average roll over all turns and sims for N_stop = 36 is 7.054088201442305
# Average roll over all turns and sims for N_stop = 37 is 7.002183795527053
# Average roll over all turns and sims for N_stop = 38 is 6.890676290868093
# Average roll over all turns and sims for N_stop = 39 is 6.685586342063113
# Average roll over all turns and sims for N_stop = 40 is 6.614790516789319
# Average roll over all turns and sims for N_stop = 41 is 6.502106859777489
# Average roll over all turns and sims for N_stop = 42 is 6.364161438790521
# Average roll over all turns and sims for N_stop = 43 is 6.1777832565342115
# Average roll over all turns and sims for N_stop = 44 is 6.043259642185515
# Average roll over all turns and sims for N_stop = 45 is 6.000467740801544
# Average roll over all turns and sims for N_stop = 46 is 5.896710646263905
# Average roll over all turns and sims for N_stop = 47 is 5.685757338358843
# Average roll over all turns and sims for N_stop = 48 is 5.620802330813854
# Average roll over all turns and sims for N_stop = 49 is 5.434579804207109

# %%
# plot the average roll vs. N_stop for each of the four end scores
fig, ax = plt.subplots(1,1, figsize=(12,12))
for j in range(4):
    ax.plot(range(1,50), avg_array_sum[j], label=f"End score = {end_score[j]}")
    ax.set_xlabel("N_stop")
    ax.set_ylabel("Average roll")
    ax.legend()
    ax.set_title("Average roll vs. N_stop")

# plot some interesting vertical lines ... the idea is that for a certain target end score, one should think about finishing the game in an integral number of turns

score = 50

for i in range(1,4):
    interesting_roll = score/i
    ax.axvline(interesting_roll, color='k', linestyle='--', alpha=0.2)

ax.set_xlim(0,50)

# calculate the theoretical average roll per turn for each N_stop and add to the plot
nstopp = np.arange(1, 50)
prob = (5/6)**(nstopp/4.0) * nstopp

ax.plot(nstopp, prob, '.--', label='Theoretical')
ax.legend()

# %%
# Testing the game_play function
debug1 = True
debug2 = True
avg = game_play(10,100)
print(avg)
# Out:
# Turn 1
# Player 1 score: 0
# Player 2 score: 0
# Player 2 turn
# Roll: 5
# Player 2 score: 5
# Roll: 2
# Player 2 score: 7
# Roll: 3
# Player 2 score: 10
# Player 2 turn over
#
# Turn 2
# Player 1 score: 0
# Player 2 score: 10
# Player 1 turn
# Roll: 2
# Player 1 score: 2
# Roll: 2
# Player 1 score: 4
# Roll: 2
# Player 1 score: 6
# Roll: 6
# Player 1 score: 12
# Player 1 turn over
#
# Turn 3
# Player 1 score: 12
# Player 2 score: 10
# Player 2 turn
# Roll: 2
# Player 2 score: 12
# Roll: 1
# Player 2 loses turn
# Player 2 turn over
#
# Turn 4
# Player 1 score: 12
# Player 2 score: 10
# Player 1 turn
# Roll: 5
# Player 1 score: 17
# Roll: 6
# Player 1 score: 23
# Player 1 turn over
#
# Turn 5
# Player 1 score: 23
# Player 2 score: 10
# Player 2 turn
# Roll: 5
# Player 2 score: 15
# Roll: 6
# Player 2 score: 21
# Player 2 turn over
#
# Turn 6
# Player 1 score: 23
# Player 2 score: 21
# Player 1 turn
# Roll: 4
# Player 1 score: 27
# Roll: 3
# Player 1 score: 30
# Roll: 1
# Player 1 loses turn
# Player 1 turn over
#
# Turn 7
# Player 1 score: 23
# Player 2 score: 21
# Player 2 turn
# Roll: 3
# Player 2 score: 24
# Roll: 4
# Player 2 score: 28
# Roll: 6
# Player 2 score: 34
# Player 2 turn over
#
# Turn 8
# Player 1 score: 23
# Player 2 score: 34
# Player 1 turn
# Roll: 5
# Player 1 score: 28
# Roll: 2
# Player 1 score: 30
# Roll: 1
# Player 1 loses turn
# Player 1 turn over
#
# Turn 9
# Player 1 score: 23
# Player 2 score: 34
# Player 2 turn
# Roll: 2
# Player 2 score: 36
# Roll: 2
# Player 2 score: 38
# Roll: 2
# Player 2 score: 40
# Roll: 5
# Player 2 score: 45
# Player 2 turn over
#
# Turn 10
# Player 1 score: 23
# Player 2 score: 45
# Player 1 turn
# Roll: 4
# Player 1 score: 27
# Roll: 2
# Player 1 score: 29
# Roll: 4
# Player 1 score: 33
# Player 1 turn over
#
# Turn 11
# Player 1 score: 33
# Player 2 score: 45
# Player 2 turn
# Roll: 4
# Player 2 score: 49
# Roll: 5
# Player 2 score: 54
# Roll: 1
# Player 2 loses turn
# Player 2 turn over
#
# Turn 12
# Player 1 score: 33
# Player 2 score: 45
# Player 1 turn
# Roll: 4
# Player 1 score: 37
# Roll: 5
# Player 1 score: 42
# Roll: 4
# Player 1 score: 46
# Player 1 turn over
#
# Turn 13
# Player 1 score: 46
# Player 2 score: 45
# Player 2 turn
# Roll: 6
# Player 2 score: 51
# Roll: 2
# Player 2 score: 53
# Roll: 6
# Player 2 score: 59
# Player 2 turn over
#
# Turn 14
# Player 1 score: 46
# Player 2 score: 59
# Player 1 turn
# Roll: 2
# Player 1 score: 48
# Roll: 5
# Player 1 score: 53
# Roll: 2
# Player 1 score: 55
# Roll: 1
# Player 1 loses turn
# Player 1 turn over
#
# Turn 15
# Player 1 score: 46
# Player 2 score: 59
# Player 2 turn
# Roll: 1
# Player 2 loses turn
# Player 2 turn over
#
# Turn 16
# Player 1 score: 46
# Player 2 score: 59
# Player 1 turn
# Roll: 1
# Player 1 loses turn
# Player 1 turn over
#
# Turn 17
# Player 1 score: 46
# Player 2 score: 59
# Player 2 turn
# Roll: 4
# Player 2 score: 63
# Roll: 6
# Player 2 score: 69
# Player 2 turn over
#
# Turn 18
# Player 1 score: 46
# Player 2 score: 69
# Player 1 turn
# Roll: 1
# Player 1 loses turn
# Player 1 turn over
#
# Turn 19
# Player 1 score: 46
# Player 2 score: 69
# Player 2 turn
# Roll: 3
# Player 2 score: 72
# Roll: 1
# Player 2 loses turn
# Player 2 turn over
#
# Turn 20
# Player 1 score: 46
# Player 2 score: 69
# Player 1 turn
# Roll: 5
# Player 1 score: 51
# Roll: 2
# Player 1 score: 53
# Roll: 6
# Player 1 score: 59
# Player 1 turn over
#
# Turn 21
# Player 1 score: 59
# Player 2 score: 69
# Player 2 turn
# Roll: 2
# Player 2 score: 71
# Roll: 5
# Player 2 score: 76
# Roll: 2
# Player 2 score: 78
# Roll: 6
# Player 2 score: 84
# Player 2 turn over
#
# Turn 22
# Player 1 score: 59
# Player 2 score: 84
# Player 1 turn
# Roll: 6
# Player 1 score: 65
# Roll: 5
# Player 1 score: 70
# Player 1 turn over
#
# Turn 23
# Player 1 score: 70
# Player 2 score: 84
# Player 2 turn
# Roll: 2
# Player 2 score: 86
# Roll: 6
# Player 2 score: 92
# Roll: 1
# Player 2 loses turn
# Player 2 turn over
#
# Turn 24
# Player 1 score: 70
# Player 2 score: 84
# Player 1 turn
# Roll: 2
# Player 1 score: 72
# Roll: 3
# Player 1 score: 75
# Roll: 2
# Player 1 score: 77
# Roll: 3
# Player 1 score: 80
# Player 1 turn over
#
# Turn 25
# Player 1 score: 80
# Player 2 score: 84
# Player 2 turn
# Roll: 4
# Player 2 score: 88
# Roll: 1
# Player 2 loses turn
# Player 2 turn over
#
# Turn 26
# Player 1 score: 80
# Player 2 score: 84
# Player 1 turn
# Roll: 3
# Player 1 score: 83
# Roll: 1
# Player 1 loses turn
# Player 1 turn over
#
# Turn 27
# Player 1 score: 80
# Player 2 score: 84
# Player 2 turn
# Roll: 6
# Player 2 score: 90
# Roll: 1
# Player 2 loses turn
# Player 2 turn over
#
# Turn 28
# Player 1 score: 80
# Player 2 score: 84
# Player 1 turn
# Roll: 2
# Player 1 score: 82
# Roll: 4
# Player 1 score: 86
# Roll: 1
# Player 1 loses turn
# Player 1 turn over
#
# Turn 29
# Player 1 score: 80
# Player 2 score: 84
# Player 2 turn
# Roll: 2
# Player 2 score: 86
# Roll: 1
# Player 2 loses turn
# Player 2 turn over
#
# Turn 30
# Player 1 score: 80
# Player 2 score: 84
# Player 1 turn
# Roll: 6
# Player 1 score: 86
# Roll: 3
# Player 1 score: 89
# Roll: 1
# Player 1 loses turn
# Player 1 turn over
#
# Turn 31
# Player 1 score: 80
# Player 2 score: 84
# Player 2 turn
# Roll: 6
# Player 2 score: 90
# Roll: 4
# Player 2 score: 94
# Player 2 turn over
#
# Turn 32
# Player 1 score: 80
# Player 2 score: 94
# Player 1 turn
# Roll: 5
# Player 1 score: 85
# Roll: 4
# Player 1 score: 89
# Roll: 3
# Player 1 score: 92
# Player 1 turn over
#
# Turn 33
# Player 1 score: 92
# Player 2 score: 94
# Player 2 turn
# Roll: 5
# Player 2 score: 99
# Roll: 3
# Player 2 score: 102
# Player 2 turn over
#
# Final score: Player 1: 92, Player 2: 102
# Player 2 wins!
# Game took 33 turns
# 5.878787878787879
