# %%
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt

# %%
def fx(x):
    return x*np.sin(x)

# %%
n = 60
x = np.linspace(0,4.0*np.pi,n+1)

y = np.zeros(n+1)

for i in range(n+1):
    y[i] = fx(x[i])
    
print(x,y)
# Out:
# [ 0.          0.20943951  0.41887902  0.62831853  0.83775804  1.04719755
#   1.25663706  1.46607657  1.67551608  1.88495559  2.0943951   2.30383461
#   2.51327412  2.72271363  2.93215314  3.14159265  3.35103216  3.56047167
#   3.76991118  3.97935069  4.1887902   4.39822972  4.60766923  4.81710874
#   5.02654825  5.23598776  5.44542727  5.65486678  5.86430629  6.0737458
#   6.28318531  6.49262482  6.70206433  6.91150384  7.12094335  7.33038286
#   7.53982237  7.74926188  7.95870139  8.1681409   8.37758041  8.58701992
#   8.79645943  9.00589894  9.21533845  9.42477796  9.63421747  9.84365698
#  10.05309649 10.262536   10.47197551 10.68141502 10.89085453 11.10029404
#  11.30973355 11.51917306 11.72861257 11.93805208 12.14749159 12.3569311
#  12.56637061] [ 0.00000000e+00  4.35449227e-02  1.70373447e-01  3.69316366e-01
#   6.22575553e-01  9.06899682e-01  1.19513287e+00  1.45804525e+00
#   1.66633743e+00  1.79269930e+00  1.81379936e+00  1.71208277e+00
#   1.47726546e+00  1.10742740e+00  6.09628918e-01  3.84734139e-16
#  -6.96718763e-01 -1.44817430e+00 -2.21589820e+00 -2.95723388e+00
#  -3.62759873e+00 -4.18296503e+00 -4.58242793e+00 -4.79072011e+00
#  -4.78053146e+00 -4.53449841e+00 -4.04674110e+00 -3.32384729e+00
#  -2.38522825e+00 -1.26280276e+00 -1.53893655e-15  1.34989260e+00
#   2.72597515e+00  4.06248003e+00  5.29189220e+00  6.34829777e+00
#   7.17079720e+00  7.70681061e+00  7.91510279e+00  7.76836363e+00
#   7.25519746e+00  6.38139942e+00  5.17042913e+00  3.66302910e+00
#   1.91597660e+00  3.46260725e-15 -2.00306644e+00 -4.00377600e+00
#  -5.90906186e+00 -7.62655053e+00 -9.06899682e+00 -1.01586294e+01
#  -1.08311933e+01 -1.10394855e+01 -1.07561958e+01 -9.97589650e+00
#  -8.71605774e+00 -7.01701096e+00 -4.94082995e+00 -2.56915044e+00
#  -6.15574622e-15]

# %%
def P(x,y,n,xval):

    sum = 0.0
    for j in range(n+1):
        numerator_product = 1.0
        denominator_product = 1.0
        for k in range(n+1):
            if not k==j:
                numerator_product=numerator_product*(xval-x[k])
                denominator_product=denominator_product*(x[j]-x[k])
        sum = sum + numerator_product*y[j]/denominator_product
    
    if abs(sum)>100:
        print ('Weird Point',xval,sum)
        sum = 0.0
    return sum

# %%
xfit = np.linspace(0,4.0*np.pi,n)
yfitP = np.zeros(n)
yfitE = np.zeros(n)
for i in range(n):
    yfitP[i]=P(x,y,n,xfit[i])
    yfitE[i]=fx(xfit[i])
    
#print (yfitP)
#print (yfitE)

# %%
fig = plt.figure(figsize=(7, 7))
plt.scatter(xfit,yfitE)
plt.plot(xfit,yfitP,'r-')

# %%
pfit = np.polyfit(x,y,60)

print (pfit)
# Out:
# [-1.24152136e-62  3.30482875e-61  6.31770193e-61 -3.25935184e-59
#  -4.51503319e-58 -1.84610034e-57  3.50996786e-56  8.54534771e-55
#   9.75921215e-54  4.81465737e-53 -5.98999726e-52 -1.89101740e-50
#  -2.73158902e-49 -2.37552568e-48 -3.60310957e-48  3.09882845e-46
#   6.83454807e-45  8.79194680e-44  6.65903033e-43 -9.48048492e-43
#  -1.29899650e-40 -2.49044036e-39 -2.89099265e-38 -1.67185670e-37
#   1.52800850e-36  5.94590222e-35  9.32192609e-34  8.30761508e-33
#   1.79455829e-33 -1.42866621e-30 -2.81682121e-29 -2.86354645e-28
#  -3.34944612e-28  4.63077831e-26  9.16740905e-25  7.85093487e-24
#  -3.71282892e-23 -2.18030735e-21 -2.92770517e-20 -3.04047318e-20
#   5.68980561e-18  9.26096903e-17  6.38872371e-17 -2.03890377e-14
#  -2.72570049e-13  1.76008797e-12  8.35723895e-11  2.64561159e-10
#  -1.79575079e-08 -1.10337571e-07  3.58618696e-06 -4.01219150e-06
#  -1.85007688e-04 -3.16659804e-05  8.38606912e-03 -6.05754050e-05
#  -1.66620699e-01 -2.13787064e-05  1.00000531e+00 -5.10548151e-07
#   3.12432302e-10]
# /usr/local/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3508: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
