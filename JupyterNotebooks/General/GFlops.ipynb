# %%
import numpy as np
import matplotlib.pyplot as plt
# !pip install pandas
try:
    import pandas as pd
except ImportError:
    # !pip install pandas
    import pandas as pd

df_jlabdaq = pd.read_csv("lin_xeon64_jlabdaq.txt", delimiter=r"\s+")
df_jlabvis1 = pd.read_csv("lin_xeon64_jlabvis1.txt", delimiter=r"\s+")
# Out:
# WARNING: Skipping /usr/local/lib/python3.11/site-packages/docutils-0.20.1-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /usr/local/lib/python3.11/site-packages/numpy-1.25.1-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /usr/local/lib/python3.11/site-packages/docutils-0.20.1-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /usr/local/lib/python3.11/site-packages/numpy-1.25.1-py3.11.egg-info due to invalid metadata entry 'name'
# ...
# WARNING: Skipping /usr/local/lib/python3.11/site-packages/docutils-0.20.1-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /usr/local/lib/python3.11/site-packages/numpy-1.25.1-py3.11.egg-info due to invalid metadata entry 'name'
# WARNING: Skipping /usr/local/lib/python3.11/site-packages/docutils-0.20.1-py3.11.egg-info due to invalid metadata entry 'name'
# ...

# %%
plt.plot(df_jlabdaq["Size"],df_jlabdaq["GFlops"])
plt.plot(df_jlabvis1["Size"],df_jlabvis1["GFlops"])
