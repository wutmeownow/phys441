# %% [markdown]
# ### Game of Pig
#
# Rules:
#
# 1. Two players take turns rolling a single die as many times as they wish. Each roll adds a score equal to the number rolled to the player's total.
# 2. If a player rolls a 1, their score for that turn is zero, and their turn ends.
# 3. At any point during a player's turn, they can choose to stop rolling and keep their score. The first player to reach 100 wins.
#
# That's it! Let's play.
#
# There are two basic strategies for this game.  The first is known as roll-based strategy, where you roll a set number of times on each turn (unless you lose).  The second is known as score-based strategy, where you roll until you reach a certain score, and then stop.
#
# Let's investigate the roll-based strategy.

# %%
# The usual libraries
import random
import matplotlib.pyplot as plt
import numpy as np


# A couple of debug flags to control print statements
debug1 = False
debug2 = False

# Number of games to simulate for each configuration
nsims = 1000

# %% [markdown]
# Now, let's look at the roll-based strategy.  In this strategy, we will roll a fixed number of times on each turn.  We will consider the same four end scores as above, and will consider the average roll per turn as a function of the number of rolls per turn.

# %%
# function to play an entire game of pig
# N_roll is the number of rolls per turn
# end_score is the score at which the game ends
# returns the average roll per turn

debug1 = False
debug2 = False

def game_play2(N_roll,end_score):

    # Initialize the score (for each of two players) and turn number within the game
    score = [0,0]
    turn = 0

    # Play the game - keep going until one player reaches the end score
    while score[0] < end_score and score[1] < end_score:

        # Initialize the score for this player during this turn and increment turn number
        turn_score = 0
        turn += 1

        if debug2:
            print("Turn", turn)
            for i in range(2):
                print("Player", i+1, "score:", score[i])
            print("Player", turn%2+1, "turn")

        roll = 0
        n_rolls = 0
        # Keep rolling until you roll a 1 or reach N_stop
        while roll != 1 and n_rolls < N_roll:

            roll = random.randint(1,6)
            n_rolls += 1

            if debug2:
                print("Roll:", roll)
                print("Number of rolls:", n_rolls)

            if roll == 1:
                if debug2:
                    print("Player", turn%2+1, "loses turn")
                # If you roll a 1, you lose all points for this turn and your turn is over
                score[turn%2] = score[turn%2] - turn_score
                break
            else:
                score[turn%2] += roll
                if debug2:
                    print("Player", turn%2+1, "score:", score[turn%2])
                #
                turn_score += roll

        if debug2:
            print("Player", turn%2+1, "turn over")
            print()

    if debug1:
        print(f"Final score: Player 1: {score[0]}, Player 2: {score[1]}")
        print(f"Player {np.argmax(score)+1} wins!")
        print(f"Game took {turn} turns")

    return 2.0*np.mean(score)/turn

# %%
# consider four different end scores .. 50, 100, 200, 500.  For each, plot the average roll vs. N_stop
end_score2 = [50, 100, 200, 500]

# initialize an array to hold the four different arrays of average roll vs. N_stop for the four different end scores.  Each array will have 49 elements, one for each N_stop from 1 to 49
avg_array_sum2 = []

for j in range(4):
    avg_array2 = []
    for nroll in range(1,20):
        sum_avg = 0
        for i in range(nsims):
            avg = game_play2(nroll,end_score2[j])
            sum_avg += avg
            #print(f"Average roll over all turns = {avg}")

        print(f"Average roll over all turns and sims for N_roll = {nroll} is {sum_avg/nsims}")
        avg_array2.append(sum_avg/nsims)

    avg_array_sum2.append(avg_array2)
# Out:
# Average roll over all turns and sims for N_roll = 1 is 3.3805348169000555
# Average roll over all turns and sims for N_roll = 2 is 5.7107603649623435
# Average roll over all turns and sims for N_roll = 3 is 7.2664369670370395
# Average roll over all turns and sims for N_roll = 4 is 8.399683718416686
# Average roll over all turns and sims for N_roll = 5 is 8.986768738056199
# Average roll over all turns and sims for N_roll = 6 is 9.869149970009596
# Average roll over all turns and sims for N_roll = 7 is 9.659028317306007
# Average roll over all turns and sims for N_roll = 8 is 9.878926768393196
# Average roll over all turns and sims for N_roll = 9 is 9.41409305318352
# Average roll over all turns and sims for N_roll = 10 is 9.222790955489453
# Average roll over all turns and sims for N_roll = 11 is 9.557973541983987
# Average roll over all turns and sims for N_roll = 12 is 10.269380917461874
# Average roll over all turns and sims for N_roll = 13 is 11.544213631759117
# Average roll over all turns and sims for N_roll = 14 is 11.824521354984451
# Average roll over all turns and sims for N_roll = 15 is 12.326940454955542
# Average roll over all turns and sims for N_roll = 16 is 10.896386712328416
# Average roll over all turns and sims for N_roll = 17 is 9.288682496205519
# Average roll over all turns and sims for N_roll = 18 is 9.009339065989927
# Average roll over all turns and sims for N_roll = 19 is 8.54319169538773
# Average roll over all turns and sims for N_roll = 1 is 3.3432871184561765
# Average roll over all turns and sims for N_roll = 2 is 5.6235500006924495
# Average roll over all turns and sims for N_roll = 3 is 7.149924286140605
# Average roll over all turns and sims for N_roll = 4 is 8.052860425008095
# Average roll over all turns and sims for N_roll = 5 is 8.540355621064453
# Average roll over all turns and sims for N_roll = 6 is 8.631404345484524
# Average roll over all turns and sims for N_roll = 7 is 8.830538712274041
# Average roll over all turns and sims for N_roll = 8 is 8.756673523171742
# Average roll over all turns and sims for N_roll = 9 is 8.287185301198722
# Average roll over all turns and sims for N_roll = 10 is 7.891542205547696
# Average roll over all turns and sims for N_roll = 11 is 7.4115471548899485
# Average roll over all turns and sims for N_roll = 12 is 7.323016979250869
# Average roll over all turns and sims for N_roll = 13 is 7.270398227681042
# Average roll over all turns and sims for N_roll = 14 is 6.533836997108242
# Average roll over all turns and sims for N_roll = 15 is 5.661695227468635
# Average roll over all turns and sims for N_roll = 16 is 5.838407572561123
# Average roll over all turns and sims for N_roll = 17 is 4.926109157648859
# Average roll over all turns and sims for N_roll = 18 is 4.329274808781659
# Average roll over all turns and sims for N_roll = 19 is 3.717688618396674
# Average roll over all turns and sims for N_roll = 1 is 3.343002836230218
# Average roll over all turns and sims for N_roll = 2 is 5.588011491045813
# Average roll over all turns and sims for N_roll = 3 is 7.0496158229390895
# Average roll over all turns and sims for N_roll = 4 is 7.892190945642081
# Average roll over all turns and sims for N_roll = 5 is 8.317140321801055
# Average roll over all turns and sims for N_roll = 6 is 8.505673212267542
# Average roll over all turns and sims for N_roll = 7 is 8.247534162866968
# Average roll over all turns and sims for N_roll = 8 is 8.006081574398111
# Average roll over all turns and sims for N_roll = 9 is 7.506593470569838
# Average roll over all turns and sims for N_roll = 10 is 7.195842691193639
# Average roll over all turns and sims for N_roll = 11 is 6.68896971505717
# Average roll over all turns and sims for N_roll = 12 is 6.109130958027963
# Average roll over all turns and sims for N_roll = 13 is 5.695604545816716
# Average roll over all turns and sims for N_roll = 14 is 5.288179508558414
# Average roll over all turns and sims for N_roll = 15 is 4.549416214363288
# Average roll over all turns and sims for N_roll = 16 is 4.150539005778442
# Average roll over all turns and sims for N_roll = 17 is 3.9871659268128803
# Average roll over all turns and sims for N_roll = 18 is 3.517499957814756
# Average roll over all turns and sims for N_roll = 19 is 3.091735473981759
# Average roll over all turns and sims for N_roll = 1 is 3.338950591688904
# Average roll over all turns and sims for N_roll = 2 is 5.571797852367479
# Average roll over all turns and sims for N_roll = 3 is 7.009455883303883
# Average roll over all turns and sims for N_roll = 4 is 7.786256932688138
# Average roll over all turns and sims for N_roll = 5 is 8.150448333792363
# Average roll over all turns and sims for N_roll = 6 is 8.148315053982214
# Average roll over all turns and sims for N_roll = 7 is 7.9823650939042174
# Average roll over all turns and sims for N_roll = 8 is 7.6158810469067575
# Average roll over all turns and sims for N_roll = 9 is 7.296901008232588
# Average roll over all turns and sims for N_roll = 10 is 6.715497188255689
# Average roll over all turns and sims for N_roll = 11 is 6.225962170498853
# Average roll over all turns and sims for N_roll = 12 is 5.631617462339346
# Average roll over all turns and sims for N_roll = 13 is 5.165864683330417
# Average roll over all turns and sims for N_roll = 14 is 4.632415711772327
# Average roll over all turns and sims for N_roll = 15 is 4.233519451255087
# Average roll over all turns and sims for N_roll = 16 is 3.7718501699014073
# Average roll over all turns and sims for N_roll = 17 is 3.36268799848572
# Average roll over all turns and sims for N_roll = 18 is 2.9364623695166996
# Average roll over all turns and sims for N_roll = 19 is 2.583946801111475

# %%
# plot the average roll vs. N_stop for each of the four end scores
fig, ax = plt.subplots(1,1, figsize=(12,12))
for j in range(4):
    ax.plot(range(1,20), avg_array_sum2[j], label=f"End score = {end_score2[j]}")
    ax.set_xlabel("N_roll")
    ax.set_ylabel("Average roll")
    ax.set_title("Average roll vs. N_roll")

# calculate the theoretical average roll per turn for each N_roll and add to the plot
nroll = np.arange(1, 20)
prob = (5/6)**nroll * 4 * nroll

ax.plot(nroll, prob, '.--', label='Theoretical')
ax.legend()

# %%
# Testing the game_play2 function
debug1 = True
debug2 = True
avg = game_play2(3,100)
print(avg)
# Out:
# Turn 1
# Player 1 score: 0
# Player 2 score: 0
# Player 2 turn
# Roll: 4
# Number of rolls: 1
# Player 2 score: 4
# Roll: 6
# Number of rolls: 2
# Player 2 score: 10
# Roll: 5
# Number of rolls: 3
# Player 2 score: 15
# Player 2 turn over
#
# Turn 2
# Player 1 score: 0
# Player 2 score: 15
# Player 1 turn
# Roll: 3
# Number of rolls: 1
# Player 1 score: 3
# Roll: 2
# Number of rolls: 2
# Player 1 score: 5
# Roll: 6
# Number of rolls: 3
# Player 1 score: 11
# Player 1 turn over
#
# Turn 3
# Player 1 score: 11
# Player 2 score: 15
# Player 2 turn
# Roll: 5
# Number of rolls: 1
# Player 2 score: 20
# Roll: 4
# Number of rolls: 2
# Player 2 score: 24
# Roll: 2
# Number of rolls: 3
# Player 2 score: 26
# Player 2 turn over
#
# Turn 4
# Player 1 score: 11
# Player 2 score: 26
# Player 1 turn
# Roll: 2
# Number of rolls: 1
# Player 1 score: 13
# Roll: 6
# Number of rolls: 2
# Player 1 score: 19
# Roll: 6
# Number of rolls: 3
# Player 1 score: 25
# Player 1 turn over
#
# Turn 5
# Player 1 score: 25
# Player 2 score: 26
# Player 2 turn
# Roll: 3
# Number of rolls: 1
# Player 2 score: 29
# Roll: 4
# Number of rolls: 2
# Player 2 score: 33
# Roll: 4
# Number of rolls: 3
# Player 2 score: 37
# Player 2 turn over
#
# Turn 6
# Player 1 score: 25
# Player 2 score: 37
# Player 1 turn
# Roll: 6
# Number of rolls: 1
# Player 1 score: 31
# Roll: 1
# Number of rolls: 2
# Player 1 loses turn
# Player 1 turn over
#
# Turn 7
# Player 1 score: 25
# Player 2 score: 37
# Player 2 turn
# Roll: 1
# Number of rolls: 1
# Player 2 loses turn
# Player 2 turn over
#
# Turn 8
# Player 1 score: 25
# Player 2 score: 37
# Player 1 turn
# Roll: 2
# Number of rolls: 1
# Player 1 score: 27
# Roll: 6
# Number of rolls: 2
# Player 1 score: 33
# Roll: 1
# Number of rolls: 3
# Player 1 loses turn
# Player 1 turn over
#
# Turn 9
# Player 1 score: 25
# Player 2 score: 37
# Player 2 turn
# Roll: 5
# Number of rolls: 1
# Player 2 score: 42
# Roll: 3
# Number of rolls: 2
# Player 2 score: 45
# Roll: 4
# Number of rolls: 3
# Player 2 score: 49
# Player 2 turn over
#
# Turn 10
# Player 1 score: 25
# Player 2 score: 49
# Player 1 turn
# Roll: 3
# Number of rolls: 1
# Player 1 score: 28
# Roll: 4
# Number of rolls: 2
# Player 1 score: 32
# Roll: 1
# Number of rolls: 3
# Player 1 loses turn
# Player 1 turn over
#
# Turn 11
# Player 1 score: 25
# Player 2 score: 49
# Player 2 turn
# Roll: 6
# Number of rolls: 1
# Player 2 score: 55
# Roll: 5
# Number of rolls: 2
# Player 2 score: 60
# Roll: 5
# Number of rolls: 3
# Player 2 score: 65
# Player 2 turn over
#
# Turn 12
# Player 1 score: 25
# Player 2 score: 65
# Player 1 turn
# Roll: 6
# Number of rolls: 1
# Player 1 score: 31
# Roll: 1
# Number of rolls: 2
# Player 1 loses turn
# Player 1 turn over
#
# Turn 13
# Player 1 score: 25
# Player 2 score: 65
# Player 2 turn
# Roll: 5
# Number of rolls: 1
# Player 2 score: 70
# Roll: 3
# Number of rolls: 2
# Player 2 score: 73
# Roll: 1
# Number of rolls: 3
# Player 2 loses turn
# Player 2 turn over
#
# Turn 14
# Player 1 score: 25
# Player 2 score: 65
# Player 1 turn
# Roll: 3
# Number of rolls: 1
# Player 1 score: 28
# Roll: 2
# Number of rolls: 2
# Player 1 score: 30
# Roll: 6
# Number of rolls: 3
# Player 1 score: 36
# Player 1 turn over
#
# Turn 15
# Player 1 score: 36
# Player 2 score: 65
# Player 2 turn
# Roll: 1
# Number of rolls: 1
# Player 2 loses turn
# Player 2 turn over
#
# Turn 16
# Player 1 score: 36
# Player 2 score: 65
# Player 1 turn
# Roll: 1
# Number of rolls: 1
# Player 1 loses turn
# Player 1 turn over
#
# Turn 17
# Player 1 score: 36
# Player 2 score: 65
# Player 2 turn
# Roll: 1
# Number of rolls: 1
# Player 2 loses turn
# Player 2 turn over
#
# Turn 18
# Player 1 score: 36
# Player 2 score: 65
# Player 1 turn
# Roll: 1
# Number of rolls: 1
# Player 1 loses turn
# Player 1 turn over
#
# Turn 19
# Player 1 score: 36
# Player 2 score: 65
# Player 2 turn
# Roll: 3
# Number of rolls: 1
# Player 2 score: 68
# Roll: 2
# Number of rolls: 2
# Player 2 score: 70
# Roll: 6
# Number of rolls: 3
# Player 2 score: 76
# Player 2 turn over
#
# Turn 20
# Player 1 score: 36
# Player 2 score: 76
# Player 1 turn
# Roll: 5
# Number of rolls: 1
# Player 1 score: 41
# Roll: 5
# Number of rolls: 2
# Player 1 score: 46
# Roll: 5
# Number of rolls: 3
# Player 1 score: 51
# Player 1 turn over
#
# Turn 21
# Player 1 score: 51
# Player 2 score: 76
# Player 2 turn
# Roll: 2
# Number of rolls: 1
# Player 2 score: 78
# Roll: 2
# Number of rolls: 2
# Player 2 score: 80
# Roll: 3
# Number of rolls: 3
# Player 2 score: 83
# Player 2 turn over
#
# Turn 22
# Player 1 score: 51
# Player 2 score: 83
# Player 1 turn
# Roll: 6
# Number of rolls: 1
# Player 1 score: 57
# Roll: 6
# Number of rolls: 2
# Player 1 score: 63
# Roll: 5
# Number of rolls: 3
# Player 1 score: 68
# Player 1 turn over
#
# Turn 23
# Player 1 score: 68
# Player 2 score: 83
# Player 2 turn
# Roll: 1
# Number of rolls: 1
# Player 2 loses turn
# Player 2 turn over
#
# Turn 24
# Player 1 score: 68
# Player 2 score: 83
# Player 1 turn
# Roll: 4
# Number of rolls: 1
# Player 1 score: 72
# Roll: 5
# Number of rolls: 2
# Player 1 score: 77
# Roll: 5
# Number of rolls: 3
# Player 1 score: 82
# Player 1 turn over
#
# Turn 25
# Player 1 score: 82
# Player 2 score: 83
# Player 2 turn
# Roll: 6
# Number of rolls: 1
# Player 2 score: 89
# Roll: 6
# Number of rolls: 2
# Player 2 score: 95
# Roll: 1
# Number of rolls: 3
# Player 2 loses turn
# Player 2 turn over
#
# Turn 26
# Player 1 score: 82
# Player 2 score: 83
# Player 1 turn
# Roll: 2
# Number of rolls: 1
# Player 1 score: 84
# Roll: 1
# Number of rolls: 2
# Player 1 loses turn
# Player 1 turn over
#
# Turn 27
# Player 1 score: 82
# Player 2 score: 83
# Player 2 turn
# Roll: 3
# Number of rolls: 1
# Player 2 score: 86
# Roll: 2
# Number of rolls: 2
# Player 2 score: 88
# Roll: 6
# Number of rolls: 3
# Player 2 score: 94
# Player 2 turn over
#
# Turn 28
# Player 1 score: 82
# Player 2 score: 94
# Player 1 turn
# Roll: 4
# Number of rolls: 1
# Player 1 score: 86
# Roll: 5
# Number of rolls: 2
# Player 1 score: 91
# Roll: 3
# Number of rolls: 3
# Player 1 score: 94
# Player 1 turn over
#
# Turn 29
# Player 1 score: 94
# Player 2 score: 94
# Player 2 turn
# Roll: 6
# Number of rolls: 1
# Player 2 score: 100
# Roll: 4
# Number of rolls: 2
# Player 2 score: 104
# Roll: 2
# Number of rolls: 3
# Player 2 score: 106
# Player 2 turn over
#
# Final score: Player 1: 94, Player 2: 106
# Player 2 wins!
# Game took 29 turns
# 6.896551724137931
