# %% [markdown]
# ### Game of Pig
#
# Rules:
#
# 1. Two players take turns rolling a single die as many times as they wish. Each roll adds a score equal to the number rolled to the player's total.
# 2. If a player rolls a 1, their score for that turn is zero, and their turn ends.
# 3. At any point during a player's turn, they can choose to stop rolling and keep their score. The first player to reach 100 wins.
#
# That's it! Let's play.
#
# There are two basic strategies for this game.  The first is known as roll-based strategy, where you roll a set number of times on each turn (unless you lose).  The second is known as score-based strategy, where you roll until you reach a certain score, and then stop.
#
# Let's investigate the roll-based strategy.

# %%
# The usual libraries
import random
import matplotlib.pyplot as plt
import numpy as np


# A couple of debug flags to control print statements
debug1 = False
debug2 = False

# Number of games to simulate for each configuration
nsims = 10000

# %% [markdown]
# Now, let's look at the roll-based strategy.  In this strategy, we will roll a fixed number of times on each turn.  We will consider the same four end scores as above, and will consider the average roll per turn as a function of the number of rolls per turn.

# %%
# function to play an entire game of pig
# N_roll is the number of rolls per turn
# end_score is the score at which the game ends
# returns the average roll per turn

debug1 = False
debug2 = False

def game_play2(N_roll,end_score):

    # Initialize the score (for each of two players) and turn number within the game
    score = [0,0]
    turn = 0

    # Play the game - keep going until one player reaches the end score
    while score[0] < end_score and score[1] < end_score:

        # Initialize the score for this player during this turn and increment turn number
        turn_score = 0
        turn += 1

        if debug2:
            print("Turn", turn)
            for i in range(2):
                print("Player", i+1, "score:", score[i])
            print("Player", turn%2+1, "turn")

        roll = 0
        n_rolls = 0
        # Keep rolling until you roll a 1 or reach N_stop
        while roll != 1 and n_rolls < N_roll:

            roll = random.randint(1,6)
            n_rolls += 1

            if debug2:
                print("Roll:", roll)
                print("Number of rolls:", n_rolls)

            if roll == 1:
                if debug2:
                    print("Player", turn%2+1, "loses turn")
                # If you roll a 1, you lose all points for this turn and your turn is over
                score[turn%2] = score[turn%2] - turn_score
                break
            else:
                score[turn%2] += roll
                if debug2:
                    print("Player", turn%2+1, "score:", score[turn%2])
                #
                turn_score += roll

        if debug2:
            print("Player", turn%2+1, "turn over")
            print()

    if debug1:
        print(f"Final score: Player 1: {score[0]}, Player 2: {score[1]}")
        print(f"Player {np.argmax(score)+1} wins!")
        print(f"Game took {turn} turns")

    return 2.0*np.mean(score)/turn

# %%
# consider four different end scores .. 50, 100, 200, 500.  For each, plot the average roll vs. N_stop
end_score2 = [50, 100, 200, 500]

# initialize an array to hold the four different arrays of average roll vs. N_stop for the four different end scores.  Each array will have 49 elements, one for each N_stop from 1 to 49
avg_array_sum2 = []

for j in range(4):
    avg_array2 = []
    for nroll in range(1,20):
        sum_avg = 0
        for i in range(nsims):
            avg = game_play2(nroll,end_score2[j])
            sum_avg += avg
            #print(f"Average roll over all turns = {avg}")

        print(f"Average roll over all turns and sims for N_roll = {nroll} is {sum_avg/nsims}")
        avg_array2.append(sum_avg/nsims)

    avg_array_sum2.append(avg_array2)
# Out:
# Average roll over all turns and sims for N_roll = 1 is 3.3734743474981186
# Average roll over all turns and sims for N_roll = 2 is 5.701700421837936
# Average roll over all turns and sims for N_roll = 3 is 7.322051170525889
# Average roll over all turns and sims for N_roll = 4 is 8.461848780331419
# Average roll over all turns and sims for N_roll = 5 is 9.095432906167584
# Average roll over all turns and sims for N_roll = 6 is 9.681043312588189
# Average roll over all turns and sims for N_roll = 7 is 9.935924872152585
# Average roll over all turns and sims for N_roll = 8 is 9.866849596169375
# Average roll over all turns and sims for N_roll = 9 is 9.557200844150543
# Average roll over all turns and sims for N_roll = 10 is 9.139689154030632
# Average roll over all turns and sims for N_roll = 11 is 9.357707636027026
# Average roll over all turns and sims for N_roll = 12 is 10.37992726836786
# Average roll over all turns and sims for N_roll = 13 is 11.567945251286279
# Average roll over all turns and sims for N_roll = 14 is 11.754076685800406
# Average roll over all turns and sims for N_roll = 15 is 11.351536946127734
# Average roll over all turns and sims for N_roll = 16 is 10.508102237680239
# Average roll over all turns and sims for N_roll = 17 is 9.739125498069402
# Average roll over all turns and sims for N_roll = 18 is 9.115555186846823
# Average roll over all turns and sims for N_roll = 19 is 8.43079371985128
# Average roll over all turns and sims for N_roll = 1 is 3.3542623569011716
# Average roll over all turns and sims for N_roll = 2 is 5.651009264429125
# Average roll over all turns and sims for N_roll = 3 is 7.136416087747195
# Average roll over all turns and sims for N_roll = 4 is 8.081607032480234
# Average roll over all turns and sims for N_roll = 5 is 8.579696965363054
# Average roll over all turns and sims for N_roll = 6 is 8.796516628680335
# Average roll over all turns and sims for N_roll = 7 is 8.817515424470852
# Average roll over all turns and sims for N_roll = 8 is 8.584725844711054
# Average roll over all turns and sims for N_roll = 9 is 8.363021365104133
# Average roll over all turns and sims for N_roll = 10 is 7.938292961365646
# Average roll over all turns and sims for N_roll = 11 is 7.398976328373823
# Average roll over all turns and sims for N_roll = 12 is 7.183344446972091
# Average roll over all turns and sims for N_roll = 13 is 7.002180794800654
# Average roll over all turns and sims for N_roll = 14 is 6.611216990465671
# Average roll over all turns and sims for N_roll = 15 is 5.990245333162423
# Average roll over all turns and sims for N_roll = 16 is 5.372701642183214
# Average roll over all turns and sims for N_roll = 17 is 4.8661250858369405
# Average roll over all turns and sims for N_roll = 18 is 4.286531533751048
# Average roll over all turns and sims for N_roll = 19 is 3.811370710614755
# Average roll over all turns and sims for N_roll = 1 is 3.3414579993035995
# Average roll over all turns and sims for N_roll = 2 is 5.600172238266246
# Average roll over all turns and sims for N_roll = 3 is 7.046901770882032
# Average roll over all turns and sims for N_roll = 4 is 7.886077572168694
# Average roll over all turns and sims for N_roll = 5 is 8.308505289727549
# Average roll over all turns and sims for N_roll = 6 is 8.408205086270618
# Average roll over all turns and sims for N_roll = 7 is 8.318802569280225
# Average roll over all turns and sims for N_roll = 8 is 8.018868008233092
# Average roll over all turns and sims for N_roll = 9 is 7.620837099211081
# Average roll over all turns and sims for N_roll = 10 is 7.161838547091642
# Average roll over all turns and sims for N_roll = 11 is 6.693259196906847
# Average roll over all turns and sims for N_roll = 12 is 6.147800498717444
# Average roll over all turns and sims for N_roll = 13 is 5.729152720219264
# Average roll over all turns and sims for N_roll = 14 is 5.23848061671261
# Average roll over all turns and sims for N_roll = 15 is 4.639601036304111
# Average roll over all turns and sims for N_roll = 16 is 4.202003324073225
# Average roll over all turns and sims for N_roll = 17 is 3.9169170941934186
# Average roll over all turns and sims for N_roll = 18 is 3.53042708766961
# Average roll over all turns and sims for N_roll = 19 is 3.1380205891941317
# Average roll over all turns and sims for N_roll = 1 is 3.338167689890387
# Average roll over all turns and sims for N_roll = 2 is 5.570681062240572
# Average roll over all turns and sims for N_roll = 3 is 6.981574243688626
# Average roll over all turns and sims for N_roll = 4 is 7.790314966882663
# Average roll over all turns and sims for N_roll = 5 is 8.140921013887285
# Average roll over all turns and sims for N_roll = 6 is 8.157138708784199
# Average roll over all turns and sims for N_roll = 7 is 7.997420906340075
# Average roll over all turns and sims for N_roll = 8 is 7.654035027935691
# Average roll over all turns and sims for N_roll = 9 is 7.196355953696408
# Average roll over all turns and sims for N_roll = 10 is 6.742931342242351
# Average roll over all turns and sims for N_roll = 11 is 6.169801290078313
# Average roll over all turns and sims for N_roll = 12 is 5.683226668828018
# Average roll over all turns and sims for N_roll = 13 is 5.114179257087832
# Average roll over all turns and sims for N_roll = 14 is 4.620283767304771
# Average roll over all turns and sims for N_roll = 15 is 4.166414955815777
# Average roll over all turns and sims for N_roll = 16 is 3.7610318855721583
# Average roll over all turns and sims for N_roll = 17 is 3.3146492433480295
# Average roll over all turns and sims for N_roll = 18 is 2.9346486140473433
# Average roll over all turns and sims for N_roll = 19 is 2.606959568981821

# %%
# plot the average roll vs. N_stop for each of the four end scores
fig, ax = plt.subplots(1,1, figsize=(12,12))
for j in range(4):
    ax.plot(range(1,20), avg_array_sum2[j], label=f"End score = {end_score2[j]}")
    ax.set_xlabel("N_roll")
    ax.set_ylabel("Average roll")
    ax.set_title("Average roll vs. N_roll")

# calculate the theoretical average roll per turn for each N_roll and add to the plot
nroll = np.arange(1, 20)
prob = (5/6)**nroll * 4 * nroll

ax.plot(nroll, prob, '.--', label='Theoretical')
ax.legend()

# %%
# Testing the game_play2 function
debug1 = True
debug2 = True
avg = game_play2(3,100)
print(avg)
# Out:
# Turn 1
# Player 1 score: 0
# Player 2 score: 0
# Player 2 turn
# Roll: 1
# Number of rolls: 1
# Player 2 loses turn
# Player 2 turn over
#
# Turn 2
# Player 1 score: 0
# Player 2 score: 0
# Player 1 turn
# Roll: 6
# Number of rolls: 1
# Player 1 score: 6
# Roll: 5
# Number of rolls: 2
# Player 1 score: 11
# Roll: 3
# Number of rolls: 3
# Player 1 score: 14
# Player 1 turn over
#
# Turn 3
# Player 1 score: 14
# Player 2 score: 0
# Player 2 turn
# Roll: 3
# Number of rolls: 1
# Player 2 score: 3
# Roll: 3
# Number of rolls: 2
# Player 2 score: 6
# Roll: 6
# Number of rolls: 3
# Player 2 score: 12
# Player 2 turn over
#
# Turn 4
# Player 1 score: 14
# Player 2 score: 12
# Player 1 turn
# Roll: 3
# Number of rolls: 1
# Player 1 score: 17
# Roll: 2
# Number of rolls: 2
# Player 1 score: 19
# Roll: 1
# Number of rolls: 3
# Player 1 loses turn
# Player 1 turn over
#
# Turn 5
# Player 1 score: 14
# Player 2 score: 12
# Player 2 turn
# Roll: 2
# Number of rolls: 1
# Player 2 score: 14
# Roll: 2
# Number of rolls: 2
# Player 2 score: 16
# Roll: 5
# Number of rolls: 3
# Player 2 score: 21
# Player 2 turn over
#
# Turn 6
# Player 1 score: 14
# Player 2 score: 21
# Player 1 turn
# Roll: 3
# Number of rolls: 1
# Player 1 score: 17
# Roll: 3
# Number of rolls: 2
# Player 1 score: 20
# Roll: 3
# Number of rolls: 3
# Player 1 score: 23
# Player 1 turn over
#
# Turn 7
# Player 1 score: 23
# Player 2 score: 21
# Player 2 turn
# Roll: 3
# Number of rolls: 1
# Player 2 score: 24
# Roll: 3
# Number of rolls: 2
# Player 2 score: 27
# Roll: 6
# Number of rolls: 3
# Player 2 score: 33
# Player 2 turn over
#
# Turn 8
# Player 1 score: 23
# Player 2 score: 33
# Player 1 turn
# Roll: 1
# Number of rolls: 1
# Player 1 loses turn
# Player 1 turn over
#
# Turn 9
# Player 1 score: 23
# Player 2 score: 33
# Player 2 turn
# Roll: 6
# Number of rolls: 1
# Player 2 score: 39
# Roll: 3
# Number of rolls: 2
# Player 2 score: 42
# Roll: 1
# Number of rolls: 3
# Player 2 loses turn
# Player 2 turn over
#
# Turn 10
# Player 1 score: 23
# Player 2 score: 33
# Player 1 turn
# Roll: 3
# Number of rolls: 1
# Player 1 score: 26
# Roll: 1
# Number of rolls: 2
# Player 1 loses turn
# Player 1 turn over
#
# Turn 11
# Player 1 score: 23
# Player 2 score: 33
# Player 2 turn
# Roll: 4
# Number of rolls: 1
# Player 2 score: 37
# Roll: 4
# Number of rolls: 2
# Player 2 score: 41
# Roll: 2
# Number of rolls: 3
# Player 2 score: 43
# Player 2 turn over
#
# Turn 12
# Player 1 score: 23
# Player 2 score: 43
# Player 1 turn
# Roll: 2
# Number of rolls: 1
# Player 1 score: 25
# Roll: 3
# Number of rolls: 2
# Player 1 score: 28
# Roll: 5
# Number of rolls: 3
# Player 1 score: 33
# Player 1 turn over
#
# Turn 13
# Player 1 score: 33
# Player 2 score: 43
# Player 2 turn
# Roll: 5
# Number of rolls: 1
# Player 2 score: 48
# Roll: 4
# Number of rolls: 2
# Player 2 score: 52
# Roll: 6
# Number of rolls: 3
# Player 2 score: 58
# Player 2 turn over
#
# Turn 14
# Player 1 score: 33
# Player 2 score: 58
# Player 1 turn
# Roll: 1
# Number of rolls: 1
# Player 1 loses turn
# Player 1 turn over
#
# Turn 15
# Player 1 score: 33
# Player 2 score: 58
# Player 2 turn
# Roll: 1
# Number of rolls: 1
# Player 2 loses turn
# Player 2 turn over
#
# Turn 16
# Player 1 score: 33
# Player 2 score: 58
# Player 1 turn
# Roll: 3
# Number of rolls: 1
# Player 1 score: 36
# Roll: 3
# Number of rolls: 2
# Player 1 score: 39
# Roll: 2
# Number of rolls: 3
# Player 1 score: 41
# Player 1 turn over
#
# Turn 17
# Player 1 score: 41
# Player 2 score: 58
# Player 2 turn
# Roll: 6
# Number of rolls: 1
# Player 2 score: 64
# Roll: 1
# Number of rolls: 2
# Player 2 loses turn
# Player 2 turn over
#
# Turn 18
# Player 1 score: 41
# Player 2 score: 58
# Player 1 turn
# Roll: 1
# Number of rolls: 1
# Player 1 loses turn
# Player 1 turn over
#
# Turn 19
# Player 1 score: 41
# Player 2 score: 58
# Player 2 turn
# Roll: 5
# Number of rolls: 1
# Player 2 score: 63
# Roll: 5
# Number of rolls: 2
# Player 2 score: 68
# Roll: 1
# Number of rolls: 3
# Player 2 loses turn
# Player 2 turn over
#
# Turn 20
# Player 1 score: 41
# Player 2 score: 58
# Player 1 turn
# Roll: 6
# Number of rolls: 1
# Player 1 score: 47
# Roll: 6
# Number of rolls: 2
# Player 1 score: 53
# Roll: 1
# Number of rolls: 3
# Player 1 loses turn
# Player 1 turn over
#
# Turn 21
# Player 1 score: 41
# Player 2 score: 58
# Player 2 turn
# Roll: 1
# Number of rolls: 1
# Player 2 loses turn
# Player 2 turn over
#
# Turn 22
# Player 1 score: 41
# Player 2 score: 58
# Player 1 turn
# Roll: 2
# Number of rolls: 1
# Player 1 score: 43
# Roll: 3
# Number of rolls: 2
# Player 1 score: 46
# Roll: 1
# Number of rolls: 3
# Player 1 loses turn
# Player 1 turn over
#
# Turn 23
# Player 1 score: 41
# Player 2 score: 58
# Player 2 turn
# Roll: 5
# Number of rolls: 1
# Player 2 score: 63
# Roll: 5
# Number of rolls: 2
# Player 2 score: 68
# Roll: 4
# Number of rolls: 3
# Player 2 score: 72
# Player 2 turn over
#
# Turn 24
# Player 1 score: 41
# Player 2 score: 72
# Player 1 turn
# Roll: 6
# Number of rolls: 1
# Player 1 score: 47
# Roll: 1
# Number of rolls: 2
# Player 1 loses turn
# Player 1 turn over
#
# Turn 25
# Player 1 score: 41
# Player 2 score: 72
# Player 2 turn
# Roll: 6
# Number of rolls: 1
# Player 2 score: 78
# Roll: 1
# Number of rolls: 2
# Player 2 loses turn
# Player 2 turn over
#
# Turn 26
# Player 1 score: 41
# Player 2 score: 72
# Player 1 turn
# Roll: 3
# Number of rolls: 1
# Player 1 score: 44
# Roll: 5
# Number of rolls: 2
# Player 1 score: 49
# Roll: 2
# Number of rolls: 3
# Player 1 score: 51
# Player 1 turn over
#
# Turn 27
# Player 1 score: 51
# Player 2 score: 72
# Player 2 turn
# Roll: 5
# Number of rolls: 1
# Player 2 score: 77
# Roll: 5
# Number of rolls: 2
# Player 2 score: 82
# Roll: 1
# Number of rolls: 3
# Player 2 loses turn
# Player 2 turn over
#
# Turn 28
# Player 1 score: 51
# Player 2 score: 72
# Player 1 turn
# Roll: 5
# Number of rolls: 1
# Player 1 score: 56
# Roll: 1
# Number of rolls: 2
# Player 1 loses turn
# Player 1 turn over
#
# Turn 29
# Player 1 score: 51
# Player 2 score: 72
# Player 2 turn
# Roll: 5
# Number of rolls: 1
# Player 2 score: 77
# Roll: 1
# Number of rolls: 2
# Player 2 loses turn
# Player 2 turn over
#
# Turn 30
# Player 1 score: 51
# Player 2 score: 72
# Player 1 turn
# Roll: 5
# Number of rolls: 1
# Player 1 score: 56
# Roll: 2
# Number of rolls: 2
# Player 1 score: 58
# Roll: 6
# Number of rolls: 3
# Player 1 score: 64
# Player 1 turn over
#
# Turn 31
# Player 1 score: 64
# Player 2 score: 72
# Player 2 turn
# Roll: 4
# Number of rolls: 1
# Player 2 score: 76
# Roll: 4
# Number of rolls: 2
# Player 2 score: 80
# Roll: 1
# Number of rolls: 3
# Player 2 loses turn
# Player 2 turn over
#
# Turn 32
# Player 1 score: 64
# Player 2 score: 72
# Player 1 turn
# Roll: 4
# Number of rolls: 1
# Player 1 score: 68
# Roll: 2
# Number of rolls: 2
# Player 1 score: 70
# Roll: 3
# Number of rolls: 3
# Player 1 score: 73
# Player 1 turn over
#
# Turn 33
# Player 1 score: 73
# Player 2 score: 72
# Player 2 turn
# Roll: 3
# Number of rolls: 1
# Player 2 score: 75
# Roll: 2
# Number of rolls: 2
# Player 2 score: 77
# Roll: 6
# Number of rolls: 3
# Player 2 score: 83
# Player 2 turn over
#
# Turn 34
# Player 1 score: 73
# Player 2 score: 83
# Player 1 turn
# Roll: 1
# Number of rolls: 1
# Player 1 loses turn
# Player 1 turn over
#
# Turn 35
# Player 1 score: 73
# Player 2 score: 83
# Player 2 turn
# Roll: 2
# Number of rolls: 1
# Player 2 score: 85
# Roll: 1
# Number of rolls: 2
# Player 2 loses turn
# Player 2 turn over
#
# Turn 36
# Player 1 score: 73
# Player 2 score: 83
# Player 1 turn
# Roll: 1
# Number of rolls: 1
# Player 1 loses turn
# Player 1 turn over
#
# Turn 37
# Player 1 score: 73
# Player 2 score: 83
# Player 2 turn
# Roll: 5
# Number of rolls: 1
# Player 2 score: 88
# Roll: 5
# Number of rolls: 2
# Player 2 score: 93
# Roll: 3
# Number of rolls: 3
# Player 2 score: 96
# Player 2 turn over
#
# Turn 38
# Player 1 score: 73
# Player 2 score: 96
# Player 1 turn
# Roll: 4
# Number of rolls: 1
# Player 1 score: 77
# Roll: 3
# Number of rolls: 2
# Player 1 score: 80
# Roll: 3
# Number of rolls: 3
# Player 1 score: 83
# Player 1 turn over
#
# Turn 39
# Player 1 score: 83
# Player 2 score: 96
# Player 2 turn
# Roll: 2
# Number of rolls: 1
# Player 2 score: 98
# Roll: 3
# Number of rolls: 2
# Player 2 score: 101
# Roll: 4
# Number of rolls: 3
# Player 2 score: 105
# Player 2 turn over
#
# Final score: Player 1: 83, Player 2: 105
# Player 2 wins!
# Game took 39 turns
# 4.82051282051282
