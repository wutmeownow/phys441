# %% [markdown]
# ### Game of Pig
#
# Rules:
#
# 1. Two players take turns rolling a single die as many times as they wish. Each roll adds a score equal to the number rolled to the player's total.
# 2. If a player rolls a 1, their score for that turn is zero, and their turn ends.
# 3. At any point during a player's turn, they can choose to stop rolling and keep their score. The first player to reach 100 wins.
#
# That's it! Let's play.
#
# There are two basic strategies for this game.  The first is known as roll-based strategy, where you roll a set number of times on each turn (unless you lose).  The second is known as score-based strategy, where you roll until you reach a certain score, and then stop.  We will explore both of these strategies, but will start with the score-based strategy.

# %%
# The usual libraries
import random
import matplotlib.pyplot as plt
import numpy as np


# A couple of debug flags to control print statements
debug1 = False
debug2 = False

# Number of games to simulate for each configuration
nsims = 1000

# %%
# function to play an entire geame of pig
# N_stop is the score at which the player will stop rolling
# end_score is the score at which the game ends
# returns the average roll per turn

def game_play(N_stop,end_score):

    # Initialize the score (for each of two players) and turn number within the game
    score = [0,0]
    turn = 0

    # Play the game - keep going until one player reaches the end score
    while score[0] < end_score and score[1] < end_score:

        # Initialize the score for this player during this turn and increment turn number
        turn_score = 0
        turn += 1

        if debug2:
            print("Turn", turn)
            for i in range(2):
                print("Player", i+1, "score:", score[i])
            print("Player", turn%2+1, "turn")

        roll = 0
        # Keep rolling until you roll a 1 or reach N_stop
        while roll != 1 and turn_score < N_stop:

            roll = random.randint(1,6)
            if debug2:
                print("Roll:", roll)

            if roll == 1:
                if debug2:
                    print("Player", turn%2+1, "loses turn")
                # If you roll a 1, you lose all points for this turn and your turn is over
                score[turn%2] = score[turn%2] - turn_score
                break
            else:
                score[turn%2] += roll
                if debug2:
                    print("Player", turn%2+1, "score:", score[turn%2])
                #
                turn_score += roll

        if debug2:
            print("Player", turn%2+1, "turn over")
            print()

    if debug1:
        print(f"Final score: Player 1: {score[0]}, Player 2: {score[1]}")
        print(f"Player {np.argmax(score)+1} wins!")
        print(f"Game took {turn} turns")

    return 2.0*np.mean(score)/turn

# %%
# consider four different end scores .. 50, 100, 200, 500.  For each, plot the average roll vs. N_stop
end_score = [50,100, 200, 500]

# initialize an array to hold the four different arrays of average roll vs. N_stop for the four different end scores.  Each array will have 49 elements, one for each N_stop from 1 to 49
avg_array_sum = []

for j in range(4):
    avg_array = []
    for nstop in range(1,50):
        sum_avg = 0
        for i in range(nsims):
            avg = game_play(nstop,end_score[j])
            sum_avg += avg
            #print(f"Average roll over all turns = {avg}")

        print(f"Average roll over all turns and sims for N_stop = {nstop} is {sum_avg/nsims}")
        avg_array.append(sum_avg/nsims)

    avg_array_sum.append(avg_array)
# Out:
# Average roll over all turns and sims for N_stop = 1 is 3.3979941053196807
# Average roll over all turns and sims for N_stop = 2 is 3.383809073520843
# Average roll over all turns and sims for N_stop = 3 is 3.846406997764791
# Average roll over all turns and sims for N_stop = 4 is 4.358828455737623
# Average roll over all turns and sims for N_stop = 5 is 4.883301424814188
# Average roll over all turns and sims for N_stop = 6 is 5.508109582468101
# Average roll over all turns and sims for N_stop = 7 is 6.160665263812
# Average roll over all turns and sims for N_stop = 8 is 6.4885689776454445
# Average roll over all turns and sims for N_stop = 9 is 6.828413440748695
# Average roll over all turns and sims for N_stop = 10 is 7.28717514478288
# Average roll over all turns and sims for N_stop = 11 is 7.672902554176993
# Average roll over all turns and sims for N_stop = 12 is 7.863995789722258
# Average roll over all turns and sims for N_stop = 13 is 8.195326159626099
# Average roll over all turns and sims for N_stop = 14 is 8.433312436118902
# Average roll over all turns and sims for N_stop = 15 is 8.716309130429215
# Average roll over all turns and sims for N_stop = 16 is 8.939059722764398
# Average roll over all turns and sims for N_stop = 17 is 9.001848158727062
# Average roll over all turns and sims for N_stop = 18 is 9.096598971351593
# Average roll over all turns and sims for N_stop = 19 is 9.212081338501996
# Average roll over all turns and sims for N_stop = 20 is 9.16563992313172
# Average roll over all turns and sims for N_stop = 21 is 9.243482101731898
# Average roll over all turns and sims for N_stop = 22 is 9.465487492479024
# Average roll over all turns and sims for N_stop = 23 is 9.86612869772365
# Average roll over all turns and sims for N_stop = 24 is 10.164218783180559
# Average roll over all turns and sims for N_stop = 25 is 10.456388127966326
# Average roll over all turns and sims for N_stop = 26 is 10.42499767838358
# Average roll over all turns and sims for N_stop = 27 is 9.911220302794193
# Average roll over all turns and sims for N_stop = 28 is 10.170870034858362
# Average roll over all turns and sims for N_stop = 29 is 10.11483758440912
# Average roll over all turns and sims for N_stop = 30 is 10.086697245576648
# Average roll over all turns and sims for N_stop = 31 is 9.9189343493907
# Average roll over all turns and sims for N_stop = 32 is 10.2596971203045
# Average roll over all turns and sims for N_stop = 33 is 9.827658523641691
# Average roll over all turns and sims for N_stop = 34 is 9.67841256299787
# Average roll over all turns and sims for N_stop = 35 is 9.751419822153263
# Average roll over all turns and sims for N_stop = 36 is 9.411236343452991
# Average roll over all turns and sims for N_stop = 37 is 9.504240351333081
# Average roll over all turns and sims for N_stop = 38 is 8.920434460585177
# Average roll over all turns and sims for N_stop = 39 is 8.951465395132653
# Average roll over all turns and sims for N_stop = 40 is 8.873837737880162
# Average roll over all turns and sims for N_stop = 41 is 8.729489462611797
# Average roll over all turns and sims for N_stop = 42 is 8.684567870485795
# Average roll over all turns and sims for N_stop = 43 is 8.400624546500586
# Average roll over all turns and sims for N_stop = 44 is 8.489963096489944
# Average roll over all turns and sims for N_stop = 45 is 8.661286322148623
# Average roll over all turns and sims for N_stop = 46 is 8.681320502824052
# Average roll over all turns and sims for N_stop = 47 is 9.814438082142168
# Average roll over all turns and sims for N_stop = 48 is 10.611954381593643
# Average roll over all turns and sims for N_stop = 49 is 12.466379516745908
# Average roll over all turns and sims for N_stop = 1 is 3.3537749857566626
# Average roll over all turns and sims for N_stop = 2 is 3.3399783159538687
# Average roll over all turns and sims for N_stop = 3 is 3.858897873208931
# Average roll over all turns and sims for N_stop = 4 is 4.36379914672847
# Average roll over all turns and sims for N_stop = 5 is 4.860992444963774
# Average roll over all turns and sims for N_stop = 6 is 5.435733872862311
# Average roll over all turns and sims for N_stop = 7 is 6.008371733952803
# Average roll over all turns and sims for N_stop = 8 is 6.36687470323298
# Average roll over all turns and sims for N_stop = 9 is 6.649645458033573
# Average roll over all turns and sims for N_stop = 10 is 7.058770469246972
# Average roll over all turns and sims for N_stop = 11 is 7.327277288917779
# Average roll over all turns and sims for N_stop = 12 is 7.631760697512774
# Average roll over all turns and sims for N_stop = 13 is 7.810406650888169
# Average roll over all turns and sims for N_stop = 14 is 7.9602962414505765
# Average roll over all turns and sims for N_stop = 15 is 8.229614691311939
# Average roll over all turns and sims for N_stop = 16 is 8.369554217030359
# Average roll over all turns and sims for N_stop = 17 is 8.551215894565939
# Average roll over all turns and sims for N_stop = 18 is 8.696186534969469
# Average roll over all turns and sims for N_stop = 19 is 8.677974112839477
# Average roll over all turns and sims for N_stop = 20 is 8.719602564084846
# Average roll over all turns and sims for N_stop = 21 is 8.698412774995685
# Average roll over all turns and sims for N_stop = 22 is 8.795550949919466
# Average roll over all turns and sims for N_stop = 23 is 8.846484114705683
# Average roll over all turns and sims for N_stop = 24 is 8.993378790412493
# Average roll over all turns and sims for N_stop = 25 is 8.924086155191716
# Average roll over all turns and sims for N_stop = 26 is 8.77819897174408
# Average roll over all turns and sims for N_stop = 27 is 8.873852550336418
# Average roll over all turns and sims for N_stop = 28 is 8.89240119106504
# Average roll over all turns and sims for N_stop = 29 is 8.750438752280079
# Average roll over all turns and sims for N_stop = 30 is 8.673421697630772
# Average roll over all turns and sims for N_stop = 31 is 8.672187075149912
# Average roll over all turns and sims for N_stop = 32 is 8.527501132089261
# Average roll over all turns and sims for N_stop = 33 is 8.684247549476428
# Average roll over all turns and sims for N_stop = 34 is 8.472474957880838
# Average roll over all turns and sims for N_stop = 35 is 8.53922867516997
# Average roll over all turns and sims for N_stop = 36 is 8.397757409145095
# Average roll over all turns and sims for N_stop = 37 is 8.277653661979953
# Average roll over all turns and sims for N_stop = 38 is 8.337489451247587
# Average roll over all turns and sims for N_stop = 39 is 7.942408260675675
# Average roll over all turns and sims for N_stop = 40 is 7.99198606916333
# Average roll over all turns and sims for N_stop = 41 is 7.885104975027523
# Average roll over all turns and sims for N_stop = 42 is 7.596896569123202
# Average roll over all turns and sims for N_stop = 43 is 7.279560491668321
# Average roll over all turns and sims for N_stop = 44 is 7.250101075114126
# Average roll over all turns and sims for N_stop = 45 is 6.845285358588126
# Average roll over all turns and sims for N_stop = 46 is 7.0131886463683255
# Average roll over all turns and sims for N_stop = 47 is 6.732954518262273
# Average roll over all turns and sims for N_stop = 48 is 7.027738157295792
# Average roll over all turns and sims for N_stop = 49 is 7.360389275574541
# Average roll over all turns and sims for N_stop = 1 is 3.3407260153797442
# Average roll over all turns and sims for N_stop = 2 is 3.346442893941722
# Average roll over all turns and sims for N_stop = 3 is 3.840932258207957
# Average roll over all turns and sims for N_stop = 4 is 4.306277957616635
# Average roll over all turns and sims for N_stop = 5 is 4.8476835084258845
# Average roll over all turns and sims for N_stop = 6 is 5.4397561669861885
# Average roll over all turns and sims for N_stop = 7 is 6.016892949853638
# Average roll over all turns and sims for N_stop = 8 is 6.286996054219367
# Average roll over all turns and sims for N_stop = 9 is 6.678364388176591
# Average roll over all turns and sims for N_stop = 10 is 6.895435711348659
# Average roll over all turns and sims for N_stop = 11 is 7.269236291310069
# Average roll over all turns and sims for N_stop = 12 is 7.473377759420251
# Average roll over all turns and sims for N_stop = 13 is 7.705809763655753
# Average roll over all turns and sims for N_stop = 14 is 7.8570757931422035
# Average roll over all turns and sims for N_stop = 15 is 8.017150263911564
# Average roll over all turns and sims for N_stop = 16 is 8.137645441092056
# Average roll over all turns and sims for N_stop = 17 is 8.322309859234787
# Average roll over all turns and sims for N_stop = 18 is 8.279023901049655
# Average roll over all turns and sims for N_stop = 19 is 8.449994178520361
# Average roll over all turns and sims for N_stop = 20 is 8.490518239507887
# Average roll over all turns and sims for N_stop = 21 is 8.451730398377336
# Average roll over all turns and sims for N_stop = 22 is 8.457303126473755
# Average roll over all turns and sims for N_stop = 23 is 8.468771981030242
# Average roll over all turns and sims for N_stop = 24 is 8.545460395579509
# Average roll over all turns and sims for N_stop = 25 is 8.441976342639267
# Average roll over all turns and sims for N_stop = 26 is 8.425034966811094
# Average roll over all turns and sims for N_stop = 27 is 8.2844713519119
# Average roll over all turns and sims for N_stop = 28 is 8.346231425840353
# Average roll over all turns and sims for N_stop = 29 is 8.225603355674874
# Average roll over all turns and sims for N_stop = 30 is 8.148077738299488
# Average roll over all turns and sims for N_stop = 31 is 8.045330367471825
# Average roll over all turns and sims for N_stop = 32 is 7.8511618037796005
# Average roll over all turns and sims for N_stop = 33 is 7.906630293450901
# Average roll over all turns and sims for N_stop = 34 is 7.726485720343739
# Average roll over all turns and sims for N_stop = 35 is 7.548780130747976
# Average roll over all turns and sims for N_stop = 36 is 7.605623999638583
# Average roll over all turns and sims for N_stop = 37 is 7.360436581242157
# Average roll over all turns and sims for N_stop = 38 is 7.33422399988263
# Average roll over all turns and sims for N_stop = 39 is 7.243844232338743
# Average roll over all turns and sims for N_stop = 40 is 7.172003353853026
# Average roll over all turns and sims for N_stop = 41 is 6.918250262913582
# Average roll over all turns and sims for N_stop = 42 is 6.923413329899761
# Average roll over all turns and sims for N_stop = 43 is 6.666532073112128
# Average roll over all turns and sims for N_stop = 44 is 6.507496572480164
# Average roll over all turns and sims for N_stop = 45 is 6.409078099520829
# Average roll over all turns and sims for N_stop = 46 is 6.201327322550638
# Average roll over all turns and sims for N_stop = 47 is 6.090965356892559
# Average roll over all turns and sims for N_stop = 48 is 6.076864965989599
# Average roll over all turns and sims for N_stop = 49 is 6.017519507037011
# Average roll over all turns and sims for N_stop = 1 is 3.3325663554804663
# Average roll over all turns and sims for N_stop = 2 is 3.3428987979156166
# Average roll over all turns and sims for N_stop = 3 is 3.840608438866411
# Average roll over all turns and sims for N_stop = 4 is 4.3136567073595815
# Average roll over all turns and sims for N_stop = 5 is 4.830853639965071
# Average roll over all turns and sims for N_stop = 6 is 5.39517003050664
# Average roll over all turns and sims for N_stop = 7 is 6.005515658851583
# Average roll over all turns and sims for N_stop = 8 is 6.272202916003969
# Average roll over all turns and sims for N_stop = 9 is 6.599396192553762
# Average roll over all turns and sims for N_stop = 10 is 6.883805297150974
# Average roll over all turns and sims for N_stop = 11 is 7.182973405964028
# Average roll over all turns and sims for N_stop = 12 is 7.413209369067531
# Average roll over all turns and sims for N_stop = 13 is 7.63504583552652
# Average roll over all turns and sims for N_stop = 14 is 7.764578648813535
# Average roll over all turns and sims for N_stop = 15 is 7.917002395884671
# Average roll over all turns and sims for N_stop = 16 is 8.084755863253104
# Average roll over all turns and sims for N_stop = 17 is 8.131915700139743
# Average roll over all turns and sims for N_stop = 18 is 8.177886196206916
# Average roll over all turns and sims for N_stop = 19 is 8.265070649125846
# Average roll over all turns and sims for N_stop = 20 is 8.227457769382104
# Average roll over all turns and sims for N_stop = 21 is 8.298116104939421
# Average roll over all turns and sims for N_stop = 22 is 8.26521917129422
# Average roll over all turns and sims for N_stop = 23 is 8.23993354746604
# Average roll over all turns and sims for N_stop = 24 is 8.196183909570237
# Average roll over all turns and sims for N_stop = 25 is 8.154824881107187
# Average roll over all turns and sims for N_stop = 26 is 8.088430874284127
# Average roll over all turns and sims for N_stop = 27 is 8.049390600499446
# Average roll over all turns and sims for N_stop = 28 is 7.985797169802588
# Average roll over all turns and sims for N_stop = 29 is 7.876463444789753
# Average roll over all turns and sims for N_stop = 30 is 7.747316345297502
# Average roll over all turns and sims for N_stop = 31 is 7.67211656606734
# Average roll over all turns and sims for N_stop = 32 is 7.537723469504879
# Average roll over all turns and sims for N_stop = 33 is 7.504206435880609
# Average roll over all turns and sims for N_stop = 34 is 7.375439952389618
# Average roll over all turns and sims for N_stop = 35 is 7.192496906784726
# Average roll over all turns and sims for N_stop = 36 is 7.124252810180344
# Average roll over all turns and sims for N_stop = 37 is 6.973935112903724
# Average roll over all turns and sims for N_stop = 38 is 6.849085779898655
# Average roll over all turns and sims for N_stop = 39 is 6.706693758473642
# Average roll over all turns and sims for N_stop = 40 is 6.7005730330369895
# Average roll over all turns and sims for N_stop = 41 is 6.552979894275344
# Average roll over all turns and sims for N_stop = 42 is 6.348293147171813
# Average roll over all turns and sims for N_stop = 43 is 6.28572424738685
# Average roll over all turns and sims for N_stop = 44 is 6.094350766585358
# Average roll over all turns and sims for N_stop = 45 is 5.890526032767464
# Average roll over all turns and sims for N_stop = 46 is 5.810733457507426
# Average roll over all turns and sims for N_stop = 47 is 5.7260345950262215
# Average roll over all turns and sims for N_stop = 48 is 5.611525578909881
# Average roll over all turns and sims for N_stop = 49 is 5.494990419600701

# %%
# plot the average roll vs. N_stop for each of the four end scores
fig, ax = plt.subplots(1,1, figsize=(12,12))
for j in range(4):
    ax.plot(range(1,50), avg_array_sum[j], label=f"End score = {end_score[j]}")
    ax.set_xlabel("N_stop")
    ax.set_ylabel("Average roll")
    ax.legend()
    ax.set_title("Average roll vs. N_stop")

# plot some interesting vertical lines ... the idea is that for a certain target end score, one should think about finishing the game in an integral number of turns

score = 50

for i in range(1,4):
    interesting_roll = score/i
    ax.axvline(interesting_roll, color='k', linestyle='--', alpha=0.2)

ax.set_xlim(0,50)

# calculate the theoretical average roll per turn for each N_roll and add to the plot
nstopp = np.arange(1, 50)
prob = (5/6)**(nstopp/4.0) * nstopp

ax.plot(nstopp, prob, '.--', label='Theoretical')
ax.legend()

# %% [markdown]
# Now, let's look at the roll-based strategy.  In this strategy, we will roll a fixed number of times on each turn.  We will consider the same four end scores as above, and will consider the average roll per turn as a function of the number of rolls per turn.

# %%
# function to play an entire game of pig
# N_roll is the number of rolls per turn
# end_score is the score at which the game ends
# returns the average roll per turn

debug1 = False
debug2 = False

def game_play2(N_roll,end_score):

    # Initialize the score (for each of two players) and turn number within the game
    score = [0,0]
    turn = 0

    # Play the game - keep going until one player reaches the end score
    while score[0] < end_score and score[1] < end_score:

        # Initialize the score for this player during this turn and increment turn number
        turn_score = 0
        turn += 1

        if debug2:
            print("Turn", turn)
            for i in range(2):
                print("Player", i+1, "score:", score[i])
            print("Player", turn%2+1, "turn")

        roll = 0
        n_rolls = 0
        # Keep rolling until you roll a 1 or reach N_stop
        while roll != 1 and n_rolls < N_roll:

            roll = random.randint(1,6)
            n_rolls += 1

            if debug2:
                print("Roll:", roll)
                print("Number of rolls:", n_rolls)

            if roll == 1:
                if debug2:
                    print("Player", turn%2+1, "loses turn")
                # If you roll a 1, you lose all points for this turn and your turn is over
                score[turn%2] = score[turn%2] - turn_score
                break
            else:
                score[turn%2] += roll
                if debug2:
                    print("Player", turn%2+1, "score:", score[turn%2])
                #
                turn_score += roll

        if debug2:
            print("Player", turn%2+1, "turn over")
            print()

    if debug1:
        print(f"Final score: Player 1: {score[0]}, Player 2: {score[1]}")
        print(f"Player {np.argmax(score)+1} wins!")
        print(f"Game took {turn} turns")

    return 2.0*np.mean(score)/turn

# %%
# consider four different end scores .. 50, 100, 200, 500.  For each, plot the average roll vs. N_stop
end_score2 = [50, 100, 200, 500]

# initialize an array to hold the four different arrays of average roll vs. N_stop for the four different end scores.  Each array will have 49 elements, one for each N_stop from 1 to 49
avg_array_sum2 = []

for j in range(4):
    avg_array2 = []
    for nroll in range(1,20):
        sum_avg = 0
        for i in range(nsims):
            avg = game_play2(nroll,end_score2[j])
            sum_avg += avg
            #print(f"Average roll over all turns = {avg}")

        print(f"Average roll over all turns and sims for N_roll = {nroll} is {sum_avg/nsims}")
        avg_array2.append(sum_avg/nsims)

    avg_array_sum2.append(avg_array2)
# Out:
# Average roll over all turns and sims for N_roll = 1 is 3.361734057486495
# Average roll over all turns and sims for N_roll = 2 is 5.716012865272893
# Average roll over all turns and sims for N_roll = 3 is 7.4291797476958
# Average roll over all turns and sims for N_roll = 4 is 8.383977743069948
# Average roll over all turns and sims for N_roll = 5 is 9.006357192547116
# Average roll over all turns and sims for N_roll = 6 is 9.624973626314235
# Average roll over all turns and sims for N_roll = 7 is 10.235576451058684
# Average roll over all turns and sims for N_roll = 8 is 10.1142561816003
# Average roll over all turns and sims for N_roll = 9 is 9.423424674612843
# Average roll over all turns and sims for N_roll = 10 is 9.364361813269864
# Average roll over all turns and sims for N_roll = 11 is 9.573561481697467
# Average roll over all turns and sims for N_roll = 12 is 10.614886524280207
# Average roll over all turns and sims for N_roll = 13 is 11.577107028814712
# Average roll over all turns and sims for N_roll = 14 is 11.339386069496456
# Average roll over all turns and sims for N_roll = 15 is 11.80496185692565
# Average roll over all turns and sims for N_roll = 16 is 10.910046940361731
# Average roll over all turns and sims for N_roll = 17 is 10.82079190421007
# Average roll over all turns and sims for N_roll = 18 is 8.936335319779863
# Average roll over all turns and sims for N_roll = 19 is 8.391085446320544
# Average roll over all turns and sims for N_roll = 1 is 3.357811561855044
# Average roll over all turns and sims for N_roll = 2 is 5.59918678306162
# Average roll over all turns and sims for N_roll = 3 is 7.084060702767779
# Average roll over all turns and sims for N_roll = 4 is 8.045151705533314
# Average roll over all turns and sims for N_roll = 5 is 8.605385423966151
# Average roll over all turns and sims for N_roll = 6 is 8.84539999549688
# Average roll over all turns and sims for N_roll = 7 is 8.704575382377636
# Average roll over all turns and sims for N_roll = 8 is 8.700832263973718
# Average roll over all turns and sims for N_roll = 9 is 8.551395653792294
# Average roll over all turns and sims for N_roll = 10 is 7.857821086662769
# Average roll over all turns and sims for N_roll = 11 is 7.391272056082689
# Average roll over all turns and sims for N_roll = 12 is 7.16159623761025
# Average roll over all turns and sims for N_roll = 13 is 7.1341972851233315
# Average roll over all turns and sims for N_roll = 14 is 6.573793095783734
# Average roll over all turns and sims for N_roll = 15 is 6.016370507081152
# Average roll over all turns and sims for N_roll = 16 is 5.455393545509762
# Average roll over all turns and sims for N_roll = 17 is 4.87159374919173
# Average roll over all turns and sims for N_roll = 18 is 4.756498673822426
# Average roll over all turns and sims for N_roll = 19 is 3.9167244588634422
# Average roll over all turns and sims for N_roll = 1 is 3.342728131533805
# Average roll over all turns and sims for N_roll = 2 is 5.592411788763983
# Average roll over all turns and sims for N_roll = 3 is 7.052807074544255
# Average roll over all turns and sims for N_roll = 4 is 7.8573966350236235
# Average roll over all turns and sims for N_roll = 5 is 8.379544152733226
# Average roll over all turns and sims for N_roll = 6 is 8.409299731465818
# Average roll over all turns and sims for N_roll = 7 is 8.308350225534111
# Average roll over all turns and sims for N_roll = 8 is 8.051190959671965
# Average roll over all turns and sims for N_roll = 9 is 7.422923182323128
# Average roll over all turns and sims for N_roll = 10 is 7.103010576965979
# Average roll over all turns and sims for N_roll = 11 is 6.7704137438692324
# Average roll over all turns and sims for N_roll = 12 is 6.284299031734249
# Average roll over all turns and sims for N_roll = 13 is 5.840665262828945
# Average roll over all turns and sims for N_roll = 14 is 5.165119647082899
# Average roll over all turns and sims for N_roll = 15 is 4.558206346534608
# Average roll over all turns and sims for N_roll = 16 is 4.18677206615125
# Average roll over all turns and sims for N_roll = 17 is 4.0047044055175105
# Average roll over all turns and sims for N_roll = 18 is 3.6016383649343227
# Average roll over all turns and sims for N_roll = 19 is 3.1307446149358493
# Average roll over all turns and sims for N_roll = 1 is 3.332952271511846
# Average roll over all turns and sims for N_roll = 2 is 5.583440809116949
# Average roll over all turns and sims for N_roll = 3 is 6.980034213165982
# Average roll over all turns and sims for N_roll = 4 is 7.782738510179955
# Average roll over all turns and sims for N_roll = 5 is 8.1454083182624
# Average roll over all turns and sims for N_roll = 6 is 8.196257208491659
# Average roll over all turns and sims for N_roll = 7 is 8.013019865527754
# Average roll over all turns and sims for N_roll = 8 is 7.682725652281324
# Average roll over all turns and sims for N_roll = 9 is 7.224980920158093
# Average roll over all turns and sims for N_roll = 10 is 6.7406113034575466
# Average roll over all turns and sims for N_roll = 11 is 6.205243961392031
# Average roll over all turns and sims for N_roll = 12 is 5.5891607701894195
# Average roll over all turns and sims for N_roll = 13 is 5.168835265570496
# Average roll over all turns and sims for N_roll = 14 is 4.56301804308882
# Average roll over all turns and sims for N_roll = 15 is 4.18949726134331
# Average roll over all turns and sims for N_roll = 16 is 3.6939412586878593
# Average roll over all turns and sims for N_roll = 17 is 3.2593745746449376
# Average roll over all turns and sims for N_roll = 18 is 2.9644650665185575
# Average roll over all turns and sims for N_roll = 19 is 2.559294112556129

# %%
# plot the average roll vs. N_stop for each of the four end scores
fig, ax = plt.subplots(1,1, figsize=(12,12))
for j in range(4):
    ax.plot(range(1,20), avg_array_sum2[j], label=f"End score = {end_score2[j]}")
    ax.set_xlabel("N_roll")
    ax.set_ylabel("Average roll")
    ax.set_title("Average roll vs. N_roll")

# calculate the theoretical average roll per turn for each N_roll and add to the plot
nroll = np.arange(1, 20)
prob = (5/6)**nroll * 4 * nroll

ax.plot(nroll, prob, '.--', label='Theoretical')
ax.legend()

# %%
# Testing the game_play2 function
debug1 = True
debug2 = True
avg = game_play2(3,100)
print(avg)
# Out:
# Turn 1
# Player 1 score: 0
# Player 2 score: 0
# Player 2 turn
# Roll: 3
# Number of rolls: 1
# Player 2 score: 3
# Roll: 2
# Number of rolls: 2
# Player 2 score: 5
# Roll: 3
# Number of rolls: 3
# Player 2 score: 8
# Player 2 turn over
#
# Turn 2
# Player 1 score: 0
# Player 2 score: 8
# Player 1 turn
# Roll: 2
# Number of rolls: 1
# Player 1 score: 2
# Roll: 5
# Number of rolls: 2
# Player 1 score: 7
# Roll: 3
# Number of rolls: 3
# Player 1 score: 10
# Player 1 turn over
#
# Turn 3
# Player 1 score: 10
# Player 2 score: 8
# Player 2 turn
# Roll: 3
# Number of rolls: 1
# Player 2 score: 11
# Roll: 2
# Number of rolls: 2
# Player 2 score: 13
# Roll: 1
# Number of rolls: 3
# Player 2 loses turn
# Player 2 turn over
#
# Turn 4
# Player 1 score: 10
# Player 2 score: 8
# Player 1 turn
# Roll: 6
# Number of rolls: 1
# Player 1 score: 16
# Roll: 6
# Number of rolls: 2
# Player 1 score: 22
# Roll: 6
# Number of rolls: 3
# Player 1 score: 28
# Player 1 turn over
#
# Turn 5
# Player 1 score: 28
# Player 2 score: 8
# Player 2 turn
# Roll: 4
# Number of rolls: 1
# Player 2 score: 12
# Roll: 3
# Number of rolls: 2
# Player 2 score: 15
# Roll: 2
# Number of rolls: 3
# Player 2 score: 17
# Player 2 turn over
#
# Turn 6
# Player 1 score: 28
# Player 2 score: 17
# Player 1 turn
# Roll: 2
# Number of rolls: 1
# Player 1 score: 30
# Roll: 1
# Number of rolls: 2
# Player 1 loses turn
# Player 1 turn over
#
# Turn 7
# Player 1 score: 28
# Player 2 score: 17
# Player 2 turn
# Roll: 1
# Number of rolls: 1
# Player 2 loses turn
# Player 2 turn over
#
# Turn 8
# Player 1 score: 28
# Player 2 score: 17
# Player 1 turn
# Roll: 6
# Number of rolls: 1
# Player 1 score: 34
# Roll: 2
# Number of rolls: 2
# Player 1 score: 36
# Roll: 3
# Number of rolls: 3
# Player 1 score: 39
# Player 1 turn over
#
# Turn 9
# Player 1 score: 39
# Player 2 score: 17
# Player 2 turn
# Roll: 6
# Number of rolls: 1
# Player 2 score: 23
# Roll: 2
# Number of rolls: 2
# Player 2 score: 25
# Roll: 6
# Number of rolls: 3
# Player 2 score: 31
# Player 2 turn over
#
# Turn 10
# Player 1 score: 39
# Player 2 score: 31
# Player 1 turn
# Roll: 5
# Number of rolls: 1
# Player 1 score: 44
# Roll: 2
# Number of rolls: 2
# Player 1 score: 46
# Roll: 3
# Number of rolls: 3
# Player 1 score: 49
# Player 1 turn over
#
# Turn 11
# Player 1 score: 49
# Player 2 score: 31
# Player 2 turn
# Roll: 1
# Number of rolls: 1
# Player 2 loses turn
# Player 2 turn over
#
# Turn 12
# Player 1 score: 49
# Player 2 score: 31
# Player 1 turn
# Roll: 1
# Number of rolls: 1
# Player 1 loses turn
# Player 1 turn over
#
# Turn 13
# Player 1 score: 49
# Player 2 score: 31
# Player 2 turn
# Roll: 5
# Number of rolls: 1
# Player 2 score: 36
# Roll: 5
# Number of rolls: 2
# Player 2 score: 41
# Roll: 2
# Number of rolls: 3
# Player 2 score: 43
# Player 2 turn over
#
# Turn 14
# Player 1 score: 49
# Player 2 score: 43
# Player 1 turn
# Roll: 1
# Number of rolls: 1
# Player 1 loses turn
# Player 1 turn over
#
# Turn 15
# Player 1 score: 49
# Player 2 score: 43
# Player 2 turn
# Roll: 1
# Number of rolls: 1
# Player 2 loses turn
# Player 2 turn over
#
# Turn 16
# Player 1 score: 49
# Player 2 score: 43
# Player 1 turn
# Roll: 5
# Number of rolls: 1
# Player 1 score: 54
# Roll: 5
# Number of rolls: 2
# Player 1 score: 59
# Roll: 5
# Number of rolls: 3
# Player 1 score: 64
# Player 1 turn over
#
# Turn 17
# Player 1 score: 64
# Player 2 score: 43
# Player 2 turn
# Roll: 2
# Number of rolls: 1
# Player 2 score: 45
# Roll: 5
# Number of rolls: 2
# Player 2 score: 50
# Roll: 6
# Number of rolls: 3
# Player 2 score: 56
# Player 2 turn over
#
# Turn 18
# Player 1 score: 64
# Player 2 score: 56
# Player 1 turn
# Roll: 4
# Number of rolls: 1
# Player 1 score: 68
# Roll: 3
# Number of rolls: 2
# Player 1 score: 71
# Roll: 1
# Number of rolls: 3
# Player 1 loses turn
# Player 1 turn over
#
# Turn 19
# Player 1 score: 64
# Player 2 score: 56
# Player 2 turn
# Roll: 6
# Number of rolls: 1
# Player 2 score: 62
# Roll: 1
# Number of rolls: 2
# Player 2 loses turn
# Player 2 turn over
#
# Turn 20
# Player 1 score: 64
# Player 2 score: 56
# Player 1 turn
# Roll: 2
# Number of rolls: 1
# Player 1 score: 66
# Roll: 6
# Number of rolls: 2
# Player 1 score: 72
# Roll: 4
# Number of rolls: 3
# Player 1 score: 76
# Player 1 turn over
#
# Turn 21
# Player 1 score: 76
# Player 2 score: 56
# Player 2 turn
# Roll: 1
# Number of rolls: 1
# Player 2 loses turn
# Player 2 turn over
#
# Turn 22
# Player 1 score: 76
# Player 2 score: 56
# Player 1 turn
# Roll: 3
# Number of rolls: 1
# Player 1 score: 79
# Roll: 3
# Number of rolls: 2
# Player 1 score: 82
# Roll: 6
# Number of rolls: 3
# Player 1 score: 88
# Player 1 turn over
#
# Turn 23
# Player 1 score: 88
# Player 2 score: 56
# Player 2 turn
# Roll: 1
# Number of rolls: 1
# Player 2 loses turn
# Player 2 turn over
#
# Turn 24
# Player 1 score: 88
# Player 2 score: 56
# Player 1 turn
# Roll: 5
# Number of rolls: 1
# Player 1 score: 93
# Roll: 3
# Number of rolls: 2
# Player 1 score: 96
# Roll: 3
# Number of rolls: 3
# Player 1 score: 99
# Player 1 turn over
#
# Turn 25
# Player 1 score: 99
# Player 2 score: 56
# Player 2 turn
# Roll: 3
# Number of rolls: 1
# Player 2 score: 59
# Roll: 1
# Number of rolls: 2
# Player 2 loses turn
# Player 2 turn over
#
# Turn 26
# Player 1 score: 99
# Player 2 score: 56
# Player 1 turn
# Roll: 5
# Number of rolls: 1
# Player 1 score: 104
# Roll: 5
# Number of rolls: 2
# Player 1 score: 109
# Roll: 5
# Number of rolls: 3
# Player 1 score: 114
# Player 1 turn over
#
# Final score: Player 1: 114, Player 2: 56
# Player 1 wins!
# Game took 26 turns
# 6.538461538461538
