# %% [markdown]
# ### Game of Pig
#
# Rules:
#
# 1. Two players take turns rolling a single die as many times as they wish. Each roll adds a score equal to the number rolled to the player's total.
# 2. If a player rolls a 1, their score for that turn is zero, and their turn ends.
# 3. At any point during a player's turn, they can choose to stop rolling and keep their score. The first player to reach 100 wins.
#
# That's it! Let's play.
#
# There are two basic strategies for this game.  The first is known as roll-based strategy, where you roll a set number of times on each turn (unless you lose).  The second is known as score-based strategy, where you roll until you reach a certain score, and then stop.
#
# We seek to develop an algorithm that combines these two strategies.  One such algorithm is as follows:
#
# Roll until you reach N_stop points, unless you reach N_roll rolls first.

# %%
# The usual libraries
import random
import matplotlib.pyplot as plt
import numpy as np


# A couple of debug flags to control print statements
debug1 = False
debug2 = False

# Number of games to simulate for each configuration
nsims = 100

# %%
# function to play an entire game of pig
# N_roll is the number of rolls per turn
# N_stop is the score at which the player stops rolling
# end_score is the score at which the game ends
# returns the average roll per turn

debug1 = False
debug2 = False

def game_play3(N_roll, N_stop, end_score):

    # Initialize the score (for each of two players) and turn number within the game
    score = [0,0]
    turn = 0

    # Play the game - keep going until one player reaches the end score
    while score[0] < end_score and score[1] < end_score:

        # Initialize the score for this player during this turn and increment turn number
        turn_score = 0
        turn += 1

        if debug2:
            print("Turn", turn)
            for i in range(2):
                print("Player", i+1, "score:", score[i])
            print("Player", turn%2+1, "turn")

        roll = 0
        n_rolls = 0
        # Keep rolling until you (roll a 1) or (reach N_roll) or (reach N_stop) or (win the game)
        while roll != 1 and n_rolls < N_roll and turn_score < N_stop and score[turn%2] < end_score:

            roll = random.randint(1,6)
            n_rolls += 1

            if debug2:
                print("Roll:", roll)
                print("Number of rolls:", n_rolls)

            if roll == 1:
                if debug2:
                    print("Player", turn%2+1, "loses turn")
                # If you roll a 1, you lose all points for this turn and your turn is over
                score[turn%2] = score[turn%2] - turn_score
                break
            else:
                score[turn%2] += roll
                if debug2:
                    print("Player", turn%2+1, "score:", score[turn%2])
                #
                turn_score += roll

        if debug2:
            print("Player", turn%2+1, "turn over")
            print()

    if debug1:
        print(f"Final score: Player 1: {score[0]}, Player 2: {score[1]}")
        print(f"Player {np.argmax(score)+1} wins!")
        print(f"Game took {turn} turns")

    return 2.0*np.mean(score)/turn

# %%
import pandas as pd
# Choose end score
end_score3 = 500

# initialize an array to hold the four different arrays of average roll vs. N_stop for the four different end scores.  Each array will have 49 elements, one for each N_stop from 1 to 49
df = pd.DataFrame(columns=['N_stop', 'N_roll', 'Avg_roll'])

print(df)

for nstop in range(1,100):
    for nroll in range(1,50):
        sum_avg = 0
        for i in range(nsims):
            avg = game_play3(nroll, nstop, end_score3)
            sum_avg += avg
            #print(f"Average roll over all turns = {avg}")

        print(f"Average roll over all turns and sims for N_roll = {nroll} and N_stop = {nstop} is {sum_avg/nsims}")
        df.loc[len(df.index)] = [nstop, nroll, sum_avg/nsims]
# Out:
# Empty DataFrame
# Columns: [N_stop, N_roll, Avg_roll]
# Index: []
# Average roll over all turns and sims for N_roll = 1 and N_stop = 1 is 3.323798481873001
# Average roll over all turns and sims for N_roll = 2 and N_stop = 1 is 3.332553788606473
# Average roll over all turns and sims for N_roll = 3 and N_stop = 1 is 3.324011745391104
# Average roll over all turns and sims for N_roll = 4 and N_stop = 1 is 3.3219370572475793
# Average roll over all turns and sims for N_roll = 5 and N_stop = 1 is 3.344902998931598
# Average roll over all turns and sims for N_roll = 6 and N_stop = 1 is 3.3494924111508393
# Average roll over all turns and sims for N_roll = 7 and N_stop = 1 is 3.32804506153799
# Average roll over all turns and sims for N_roll = 8 and N_stop = 1 is 3.323605466904742
# Average roll over all turns and sims for N_roll = 9 and N_stop = 1 is 3.3178528626088553
# Average roll over all turns and sims for N_roll = 10 and N_stop = 1 is 3.333969198924838
# Average roll over all turns and sims for N_roll = 11 and N_stop = 1 is 3.356983459490431
# Average roll over all turns and sims for N_roll = 12 and N_stop = 1 is 3.3506971171922317
# Average roll over all turns and sims for N_roll = 13 and N_stop = 1 is 3.335600494676979
# Average roll over all turns and sims for N_roll = 14 and N_stop = 1 is 3.3364662983265534
# Average roll over all turns and sims for N_roll = 15 and N_stop = 1 is 3.3352598995134315
# Average roll over all turns and sims for N_roll = 16 and N_stop = 1 is 3.3260732428254975
# Average roll over all turns and sims for N_roll = 17 and N_stop = 1 is 3.35152308051868
# Average roll over all turns and sims for N_roll = 18 and N_stop = 1 is 3.320332176373505
# Average roll over all turns and sims for N_roll = 19 and N_stop = 1 is 3.3389626546451416
# Average roll over all turns and sims for N_roll = 20 and N_stop = 1 is 3.326717117763442
# Average roll over all turns and sims for N_roll = 21 and N_stop = 1 is 3.3172103242223185
# Average roll over all turns and sims for N_roll = 22 and N_stop = 1 is 3.3856052764341973
# Average roll over all turns and sims for N_roll = 23 and N_stop = 1 is 3.3412288467431144
# Average roll over all turns and sims for N_roll = 24 and N_stop = 1 is 3.334216975780927
# Average roll over all turns and sims for N_roll = 25 and N_stop = 1 is 3.330832729845952
# Average roll over all turns and sims for N_roll = 26 and N_stop = 1 is 3.327787412189421
# Average roll over all turns and sims for N_roll = 27 and N_stop = 1 is 3.33419142384376
# Average roll over all turns and sims for N_roll = 28 and N_stop = 1 is 3.34115381519478
# Average roll over all turns and sims for N_roll = 29 and N_stop = 1 is 3.362903973978864
# Average roll over all turns and sims for N_roll = 30 and N_stop = 1 is 3.344311523604576
# Average roll over all turns and sims for N_roll = 31 and N_stop = 1 is 3.3340134868885682
# Average roll over all turns and sims for N_roll = 32 and N_stop = 1 is 3.3298073626288205
# Average roll over all turns and sims for N_roll = 33 and N_stop = 1 is 3.3404297193959223
# Average roll over all turns and sims for N_roll = 34 and N_stop = 1 is 3.359724998276165
# Average roll over all turns and sims for N_roll = 35 and N_stop = 1 is 3.336757442246728
# Average roll over all turns and sims for N_roll = 36 and N_stop = 1 is 3.3357291014705828
# Average roll over all turns and sims for N_roll = 37 and N_stop = 1 is 3.3294203135464686
# Average roll over all turns and sims for N_roll = 38 and N_stop = 1 is 3.3321836888187755
# Average roll over all turns and sims for N_roll = 39 and N_stop = 1 is 3.3506322834724176
# Average roll over all turns and sims for N_roll = 40 and N_stop = 1 is 3.343854589572929
# Average roll over all turns and sims for N_roll = 41 and N_stop = 1 is 3.355493503153657
# Average roll over all turns and sims for N_roll = 42 and N_stop = 1 is 3.3319144013489224
# Average roll over all turns and sims for N_roll = 43 and N_stop = 1 is 3.3302813633428934
# Average roll over all turns and sims for N_roll = 44 and N_stop = 1 is 3.3557526830312336
# Average roll over all turns and sims for N_roll = 45 and N_stop = 1 is 3.3415633895184476
# Average roll over all turns and sims for N_roll = 46 and N_stop = 1 is 3.3199009690272816
# Average roll over all turns and sims for N_roll = 47 and N_stop = 1 is 3.3323542163696804
# Average roll over all turns and sims for N_roll = 48 and N_stop = 1 is 3.3374750354492515
# Average roll over all turns and sims for N_roll = 49 and N_stop = 1 is 3.327637161350725
# Average roll over all turns and sims for N_roll = 1 and N_stop = 2 is 3.3374827098857427
# Average roll over all turns and sims for N_roll = 2 and N_stop = 2 is 3.3498385503251815
# Average roll over all turns and sims for N_roll = 3 and N_stop = 2 is 3.3365778591694792
# Average roll over all turns and sims for N_roll = 4 and N_stop = 2 is 3.331858481979645
# Average roll over all turns and sims for N_roll = 5 and N_stop = 2 is 3.3346579648757397
# Average roll over all turns and sims for N_roll = 6 and N_stop = 2 is 3.336738695537937
# Average roll over all turns and sims for N_roll = 7 and N_stop = 2 is 3.318374248645341
# Average roll over all turns and sims for N_roll = 8 and N_stop = 2 is 3.329875785412151
# Average roll over all turns and sims for N_roll = 9 and N_stop = 2 is 3.345077568038889
# Average roll over all turns and sims for N_roll = 10 and N_stop = 2 is 3.331505243349662
# Average roll over all turns and sims for N_roll = 11 and N_stop = 2 is 3.3282399789363577
# Average roll over all turns and sims for N_roll = 12 and N_stop = 2 is 3.3323454295830954
# Average roll over all turns and sims for N_roll = 13 and N_stop = 2 is 3.3225210943483616
# Average roll over all turns and sims for N_roll = 14 and N_stop = 2 is 3.3334654494075657
# Average roll over all turns and sims for N_roll = 15 and N_stop = 2 is 3.3483267340521765
# Average roll over all turns and sims for N_roll = 16 and N_stop = 2 is 3.326080940219981
# Average roll over all turns and sims for N_roll = 17 and N_stop = 2 is 3.33974378508435
# Average roll over all turns and sims for N_roll = 18 and N_stop = 2 is 3.340090283840519
# Average roll over all turns and sims for N_roll = 19 and N_stop = 2 is 3.3619877922466634
# Average roll over all turns and sims for N_roll = 20 and N_stop = 2 is 3.3420291714433845
# Average roll over all turns and sims for N_roll = 21 and N_stop = 2 is 3.3320222410057982
# Average roll over all turns and sims for N_roll = 22 and N_stop = 2 is 3.336438854302408
# Average roll over all turns and sims for N_roll = 23 and N_stop = 2 is 3.3243362790742457
# Average roll over all turns and sims for N_roll = 24 and N_stop = 2 is 3.321848822454239
# Average roll over all turns and sims for N_roll = 25 and N_stop = 2 is 3.323810485302333
# Average roll over all turns and sims for N_roll = 26 and N_stop = 2 is 3.3351246848052485
# Average roll over all turns and sims for N_roll = 27 and N_stop = 2 is 3.332855559750304
# Average roll over all turns and sims for N_roll = 28 and N_stop = 2 is 3.3255399573252267
# Average roll over all turns and sims for N_roll = 29 and N_stop = 2 is 3.3354789709294907
# Average roll over all turns and sims for N_roll = 30 and N_stop = 2 is 3.352172351663418
# Average roll over all turns and sims for N_roll = 31 and N_stop = 2 is 3.325987225251111
# Average roll over all turns and sims for N_roll = 32 and N_stop = 2 is 3.340409230859361
# Average roll over all turns and sims for N_roll = 33 and N_stop = 2 is 3.3331526674222163
# Average roll over all turns and sims for N_roll = 34 and N_stop = 2 is 3.3187343434334133
# Average roll over all turns and sims for N_roll = 35 and N_stop = 2 is 3.3298223857925353
# Average roll over all turns and sims for N_roll = 36 and N_stop = 2 is 3.331615116337234
# Average roll over all turns and sims for N_roll = 37 and N_stop = 2 is 3.3316231902267703
# Average roll over all turns and sims for N_roll = 38 and N_stop = 2 is 3.3356567843348572
# Average roll over all turns and sims for N_roll = 39 and N_stop = 2 is 3.3483247346176053
# Average roll over all turns and sims for N_roll = 40 and N_stop = 2 is 3.3331489335614437
# Average roll over all turns and sims for N_roll = 41 and N_stop = 2 is 3.3406748355316918
# Average roll over all turns and sims for N_roll = 42 and N_stop = 2 is 3.327309914689386
# Average roll over all turns and sims for N_roll = 43 and N_stop = 2 is 3.32448562994964
# Average roll over all turns and sims for N_roll = 44 and N_stop = 2 is 3.3266744499922476
# Average roll over all turns and sims for N_roll = 45 and N_stop = 2 is 3.3365846514841415
# Average roll over all turns and sims for N_roll = 46 and N_stop = 2 is 3.3518382046842117
# Average roll over all turns and sims for N_roll = 47 and N_stop = 2 is 3.363337243856806
# Average roll over all turns and sims for N_roll = 48 and N_stop = 2 is 3.3349441217650133
# Average roll over all turns and sims for N_roll = 49 and N_stop = 2 is 3.3312967665467
# Average roll over all turns and sims for N_roll = 1 and N_stop = 3 is 3.3374689600068064
# Average roll over all turns and sims for N_roll = 2 and N_stop = 3 is 3.8278160345452705
# Average roll over all turns and sims for N_roll = 3 and N_stop = 3 is 3.841286785013703
# Average roll over all turns and sims for N_roll = 4 and N_stop = 3 is 3.8702428565925184
# Average roll over all turns and sims for N_roll = 5 and N_stop = 3 is 3.8486171965476914
# Average roll over all turns and sims for N_roll = 6 and N_stop = 3 is 3.8370808751516092
# Average roll over all turns and sims for N_roll = 7 and N_stop = 3 is 3.846528302445965
# Average roll over all turns and sims for N_roll = 8 and N_stop = 3 is 3.8396663148949597
# Average roll over all turns and sims for N_roll = 9 and N_stop = 3 is 3.812144815220137
# Average roll over all turns and sims for N_roll = 10 and N_stop = 3 is 3.8239379159610154
# Average roll over all turns and sims for N_roll = 11 and N_stop = 3 is 3.8482038368218654
# Average roll over all turns and sims for N_roll = 12 and N_stop = 3 is 3.840279314675769
# Average roll over all turns and sims for N_roll = 13 and N_stop = 3 is 3.8477651643388224
# Average roll over all turns and sims for N_roll = 14 and N_stop = 3 is 3.8525060189688918
# Average roll over all turns and sims for N_roll = 15 and N_stop = 3 is 3.8430803746326596
# Average roll over all turns and sims for N_roll = 16 and N_stop = 3 is 3.816242996153397
# Average roll over all turns and sims for N_roll = 17 and N_stop = 3 is 3.832547892119738
# Average roll over all turns and sims for N_roll = 18 and N_stop = 3 is 3.86815550661524
# Average roll over all turns and sims for N_roll = 19 and N_stop = 3 is 3.8134668457273535
# Average roll over all turns and sims for N_roll = 20 and N_stop = 3 is 3.8186967958925195
# Average roll over all turns and sims for N_roll = 21 and N_stop = 3 is 3.821156975327314
# Average roll over all turns and sims for N_roll = 22 and N_stop = 3 is 3.8545202695457004
# Average roll over all turns and sims for N_roll = 23 and N_stop = 3 is 3.8279365874932263
# Average roll over all turns and sims for N_roll = 24 and N_stop = 3 is 3.82646064751631
# Average roll over all turns and sims for N_roll = 25 and N_stop = 3 is 3.843364972726329
# Average roll over all turns and sims for N_roll = 26 and N_stop = 3 is 3.8208907664656806
# Average roll over all turns and sims for N_roll = 27 and N_stop = 3 is 3.8274781002750338
# Average roll over all turns and sims for N_roll = 28 and N_stop = 3 is 3.8327783941530216
# Average roll over all turns and sims for N_roll = 29 and N_stop = 3 is 3.836219465973425
# Average roll over all turns and sims for N_roll = 30 and N_stop = 3 is 3.81715417540152
# Average roll over all turns and sims for N_roll = 31 and N_stop = 3 is 3.8405395020996536
# Average roll over all turns and sims for N_roll = 32 and N_stop = 3 is 3.804159871017813
# Average roll over all turns and sims for N_roll = 33 and N_stop = 3 is 3.8428879795790447
# Average roll over all turns and sims for N_roll = 34 and N_stop = 3 is 3.843657314581063
# Average roll over all turns and sims for N_roll = 35 and N_stop = 3 is 3.8247999723311
# Average roll over all turns and sims for N_roll = 36 and N_stop = 3 is 3.856783712398127
# Average roll over all turns and sims for N_roll = 37 and N_stop = 3 is 3.8517669577178397
# Average roll over all turns and sims for N_roll = 38 and N_stop = 3 is 3.842497053070768
# Average roll over all turns and sims for N_roll = 39 and N_stop = 3 is 3.824303890499385
# Average roll over all turns and sims for N_roll = 40 and N_stop = 3 is 3.822045636395454
# Average roll over all turns and sims for N_roll = 41 and N_stop = 3 is 3.8419248038109712
# Average roll over all turns and sims for N_roll = 42 and N_stop = 3 is 3.821703400627746
# Average roll over all turns and sims for N_roll = 43 and N_stop = 3 is 3.8362735743571053
# Average roll over all turns and sims for N_roll = 44 and N_stop = 3 is 3.840141824053797
# Average roll over all turns and sims for N_roll = 45 and N_stop = 3 is 3.8292869918075727
# Average roll over all turns and sims for N_roll = 46 and N_stop = 3 is 3.8272617758265626
# Average roll over all turns and sims for N_roll = 47 and N_stop = 3 is 3.823983584558854
# Average roll over all turns and sims for N_roll = 48 and N_stop = 3 is 3.832471800199839
# Average roll over all turns and sims for N_roll = 49 and N_stop = 3 is 3.8536450220306397
# Average roll over all turns and sims for N_roll = 1 and N_stop = 4 is 3.3201964772738966
# Average roll over all turns and sims for N_roll = 2 and N_stop = 4 is 4.302322706929072
# Average roll over all turns and sims for N_roll = 3 and N_stop = 4 is 4.336854649799226
# Average roll over all turns and sims for N_roll = 4 and N_stop = 4 is 4.307851882394193
# Average roll over all turns and sims for N_roll = 5 and N_stop = 4 is 4.294628861687847
# Average roll over all turns and sims for N_roll = 6 and N_stop = 4 is 4.302423823709051
# Average roll over all turns and sims for N_roll = 7 and N_stop = 4 is 4.292348406723852
# Average roll over all turns and sims for N_roll = 8 and N_stop = 4 is 4.315612546300213
# Average roll over all turns and sims for N_roll = 9 and N_stop = 4 is 4.286880664177576
# Average roll over all turns and sims for N_roll = 10 and N_stop = 4 is 4.310956404787108
# Average roll over all turns and sims for N_roll = 11 and N_stop = 4 is 4.273294685282043
# Average roll over all turns and sims for N_roll = 12 and N_stop = 4 is 4.323868159129438
# Average roll over all turns and sims for N_roll = 13 and N_stop = 4 is 4.333144153342335
# Average roll over all turns and sims for N_roll = 14 and N_stop = 4 is 4.301671079567209
# Average roll over all turns and sims for N_roll = 15 and N_stop = 4 is 4.316001216145042
# Average roll over all turns and sims for N_roll = 16 and N_stop = 4 is 4.293739063269965
# Average roll over all turns and sims for N_roll = 17 and N_stop = 4 is 4.327287823305019
# Average roll over all turns and sims for N_roll = 18 and N_stop = 4 is 4.308906532232458
# Average roll over all turns and sims for N_roll = 19 and N_stop = 4 is 4.314854218071497
# Average roll over all turns and sims for N_roll = 20 and N_stop = 4 is 4.329918652665596
# Average roll over all turns and sims for N_roll = 21 and N_stop = 4 is 4.30755088444188
# Average roll over all turns and sims for N_roll = 22 and N_stop = 4 is 4.318210975513201
# Average roll over all turns and sims for N_roll = 23 and N_stop = 4 is 4.344345075160304
# Average roll over all turns and sims for N_roll = 24 and N_stop = 4 is 4.340711403930536
# Average roll over all turns and sims for N_roll = 25 and N_stop = 4 is 4.315176017370093
# Average roll over all turns and sims for N_roll = 26 and N_stop = 4 is 4.284498032747964
# Average roll over all turns and sims for N_roll = 27 and N_stop = 4 is 4.284858787892776
# Average roll over all turns and sims for N_roll = 28 and N_stop = 4 is 4.29578190418326
# Average roll over all turns and sims for N_roll = 29 and N_stop = 4 is 4.330019489716153
# Average roll over all turns and sims for N_roll = 30 and N_stop = 4 is 4.310056908019476
# Average roll over all turns and sims for N_roll = 31 and N_stop = 4 is 4.287203342986789
# Average roll over all turns and sims for N_roll = 32 and N_stop = 4 is 4.317640774134452
# Average roll over all turns and sims for N_roll = 33 and N_stop = 4 is 4.303989101489918
# Average roll over all turns and sims for N_roll = 34 and N_stop = 4 is 4.292363598823468
# Average roll over all turns and sims for N_roll = 35 and N_stop = 4 is 4.326458667333186
# Average roll over all turns and sims for N_roll = 36 and N_stop = 4 is 4.312509527924955
# Average roll over all turns and sims for N_roll = 37 and N_stop = 4 is 4.348406138513491
# Average roll over all turns and sims for N_roll = 38 and N_stop = 4 is 4.318154252098187
# Average roll over all turns and sims for N_roll = 39 and N_stop = 4 is 4.3019235309498605
# Average roll over all turns and sims for N_roll = 40 and N_stop = 4 is 4.305930794887021
# Average roll over all turns and sims for N_roll = 41 and N_stop = 4 is 4.308890068819351
# Average roll over all turns and sims for N_roll = 42 and N_stop = 4 is 4.324635288439185
# Average roll over all turns and sims for N_roll = 43 and N_stop = 4 is 4.3035545308621
# Average roll over all turns and sims for N_roll = 44 and N_stop = 4 is 4.31830345828687
# Average roll over all turns and sims for N_roll = 45 and N_stop = 4 is 4.2914885635545605
# Average roll over all turns and sims for N_roll = 46 and N_stop = 4 is 4.3077403782691785
# Average roll over all turns and sims for N_roll = 47 and N_stop = 4 is 4.290892578166183
# Average roll over all turns and sims for N_roll = 48 and N_stop = 4 is 4.311680658024927
# Average roll over all turns and sims for N_roll = 49 and N_stop = 4 is 4.317063839641855
# Average roll over all turns and sims for N_roll = 1 and N_stop = 5 is 3.3351860317898923
# Average roll over all turns and sims for N_roll = 2 and N_stop = 5 is 4.7539076152902116
# Average roll over all turns and sims for N_roll = 3 and N_stop = 5 is 4.856739700965778
# Average roll over all turns and sims for N_roll = 4 and N_stop = 5 is 4.8430462913318
# Average roll over all turns and sims for N_roll = 5 and N_stop = 5 is 4.8194658916727615
# Average roll over all turns and sims for N_roll = 6 and N_stop = 5 is 4.815697185807235
# Average roll over all turns and sims for N_roll = 7 and N_stop = 5 is 4.832150807194432
# Average roll over all turns and sims for N_roll = 8 and N_stop = 5 is 4.799239533442985
# Average roll over all turns and sims for N_roll = 9 and N_stop = 5 is 4.824400960168901
# Average roll over all turns and sims for N_roll = 10 and N_stop = 5 is 4.8499192325809055
# Average roll over all turns and sims for N_roll = 11 and N_stop = 5 is 4.819824851751474
# Average roll over all turns and sims for N_roll = 12 and N_stop = 5 is 4.785554765781854
# Average roll over all turns and sims for N_roll = 13 and N_stop = 5 is 4.852239594071767
# Average roll over all turns and sims for N_roll = 14 and N_stop = 5 is 4.78729100106843
# Average roll over all turns and sims for N_roll = 15 and N_stop = 5 is 4.810075587071856
# Average roll over all turns and sims for N_roll = 16 and N_stop = 5 is 4.8182463565382
# Average roll over all turns and sims for N_roll = 17 and N_stop = 5 is 4.82116054575789
# Average roll over all turns and sims for N_roll = 18 and N_stop = 5 is 4.80361598212737
# Average roll over all turns and sims for N_roll = 19 and N_stop = 5 is 4.86539734007036
# Average roll over all turns and sims for N_roll = 20 and N_stop = 5 is 4.80856065414705
# Average roll over all turns and sims for N_roll = 21 and N_stop = 5 is 4.8507141763142405
# Average roll over all turns and sims for N_roll = 22 and N_stop = 5 is 4.85353463184294
# Average roll over all turns and sims for N_roll = 23 and N_stop = 5 is 4.830291167905546
# Average roll over all turns and sims for N_roll = 24 and N_stop = 5 is 4.838426850480098
# Average roll over all turns and sims for N_roll = 25 and N_stop = 5 is 4.848247823740195
# Average roll over all turns and sims for N_roll = 26 and N_stop = 5 is 4.81010873798309
# Average roll over all turns and sims for N_roll = 27 and N_stop = 5 is 4.805668383658762
# Average roll over all turns and sims for N_roll = 28 and N_stop = 5 is 4.808954791172861
# Average roll over all turns and sims for N_roll = 29 and N_stop = 5 is 4.8299845823734975
# Average roll over all turns and sims for N_roll = 30 and N_stop = 5 is 4.822382488872956
# Average roll over all turns and sims for N_roll = 31 and N_stop = 5 is 4.855636153175537
# Average roll over all turns and sims for N_roll = 32 and N_stop = 5 is 4.861732551140372
# Average roll over all turns and sims for N_roll = 33 and N_stop = 5 is 4.850817181873427
# Average roll over all turns and sims for N_roll = 34 and N_stop = 5 is 4.87370706196275
# Average roll over all turns and sims for N_roll = 35 and N_stop = 5 is 4.832414612715158
# Average roll over all turns and sims for N_roll = 36 and N_stop = 5 is 4.860750170017763
# Average roll over all turns and sims for N_roll = 37 and N_stop = 5 is 4.827399183117945
# Average roll over all turns and sims for N_roll = 38 and N_stop = 5 is 4.7790677211542425
# Average roll over all turns and sims for N_roll = 39 and N_stop = 5 is 4.809952360679512
# Average roll over all turns and sims for N_roll = 40 and N_stop = 5 is 4.830116402878409
# Average roll over all turns and sims for N_roll = 41 and N_stop = 5 is 4.803280246821652
# Average roll over all turns and sims for N_roll = 42 and N_stop = 5 is 4.857503113741408
# Average roll over all turns and sims for N_roll = 43 and N_stop = 5 is 4.828910394716107
# Average roll over all turns and sims for N_roll = 44 and N_stop = 5 is 4.8459748102005875
# Average roll over all turns and sims for N_roll = 45 and N_stop = 5 is 4.818205486253309
# Average roll over all turns and sims for N_roll = 46 and N_stop = 5 is 4.817926327772518
# Average roll over all turns and sims for N_roll = 47 and N_stop = 5 is 4.784802703455859
# Average roll over all turns and sims for N_roll = 48 and N_stop = 5 is 4.815399259424529
# Average roll over all turns and sims for N_roll = 49 and N_stop = 5 is 4.83446617652509
# Average roll over all turns and sims for N_roll = 1 and N_stop = 6 is 3.3221927471667616
# Average roll over all turns and sims for N_roll = 2 and N_stop = 6 is 5.222575426352818
# Average roll over all turns and sims for N_roll = 3 and N_stop = 6 is 5.4127748921120515
# Average roll over all turns and sims for N_roll = 4 and N_stop = 6 is 5.386835222680752
# Average roll over all turns and sims for N_roll = 5 and N_stop = 6 is 5.401983572797739
# Average roll over all turns and sims for N_roll = 6 and N_stop = 6 is 5.373253556200507
# Average roll over all turns and sims for N_roll = 7 and N_stop = 6 is 5.386411695918678
# Average roll over all turns and sims for N_roll = 8 and N_stop = 6 is 5.42722217226312
# Average roll over all turns and sims for N_roll = 9 and N_stop = 6 is 5.4058090081746375
# Average roll over all turns and sims for N_roll = 10 and N_stop = 6 is 5.391660826904172
# Average roll over all turns and sims for N_roll = 11 and N_stop = 6 is 5.392206139223106
# Average roll over all turns and sims for N_roll = 12 and N_stop = 6 is 5.3689394002617075
# Average roll over all turns and sims for N_roll = 13 and N_stop = 6 is 5.352728895838901
# Average roll over all turns and sims for N_roll = 14 and N_stop = 6 is 5.349102660247341
# Average roll over all turns and sims for N_roll = 15 and N_stop = 6 is 5.356556271404536
# Average roll over all turns and sims for N_roll = 16 and N_stop = 6 is 5.358928152906091
# Average roll over all turns and sims for N_roll = 17 and N_stop = 6 is 5.417148729590367
# Average roll over all turns and sims for N_roll = 18 and N_stop = 6 is 5.424951677526208
# Average roll over all turns and sims for N_roll = 19 and N_stop = 6 is 5.399714039855296
# Average roll over all turns and sims for N_roll = 20 and N_stop = 6 is 5.405351170380553
# Average roll over all turns and sims for N_roll = 21 and N_stop = 6 is 5.369286219617624
# Average roll over all turns and sims for N_roll = 22 and N_stop = 6 is 5.455802423573028
# Average roll over all turns and sims for N_roll = 23 and N_stop = 6 is 5.419572353859126
# Average roll over all turns and sims for N_roll = 24 and N_stop = 6 is 5.333937371632717
# Average roll over all turns and sims for N_roll = 25 and N_stop = 6 is 5.335167244502577
# Average roll over all turns and sims for N_roll = 26 and N_stop = 6 is 5.3865719457891945
# Average roll over all turns and sims for N_roll = 27 and N_stop = 6 is 5.398581411783065
# Average roll over all turns and sims for N_roll = 28 and N_stop = 6 is 5.41706515213333
# Average roll over all turns and sims for N_roll = 29 and N_stop = 6 is 5.370473123042974
# Average roll over all turns and sims for N_roll = 30 and N_stop = 6 is 5.338403716388908
# Average roll over all turns and sims for N_roll = 31 and N_stop = 6 is 5.407066849871899
# Average roll over all turns and sims for N_roll = 32 and N_stop = 6 is 5.4016654057616
# Average roll over all turns and sims for N_roll = 33 and N_stop = 6 is 5.390598071417387
# Average roll over all turns and sims for N_roll = 34 and N_stop = 6 is 5.343500707134885
# Average roll over all turns and sims for N_roll = 35 and N_stop = 6 is 5.371428347071585
# Average roll over all turns and sims for N_roll = 36 and N_stop = 6 is 5.395555353680128
# Average roll over all turns and sims for N_roll = 37 and N_stop = 6 is 5.399513267307693
# Average roll over all turns and sims for N_roll = 38 and N_stop = 6 is 5.374542216088254
# Average roll over all turns and sims for N_roll = 39 and N_stop = 6 is 5.397307715083623
# Average roll over all turns and sims for N_roll = 40 and N_stop = 6 is 5.356587464269082
# Average roll over all turns and sims for N_roll = 41 and N_stop = 6 is 5.431699196133452
# Average roll over all turns and sims for N_roll = 42 and N_stop = 6 is 5.402501691403538
# Average roll over all turns and sims for N_roll = 43 and N_stop = 6 is 5.348675929458759
# Average roll over all turns and sims for N_roll = 44 and N_stop = 6 is 5.332809694845945
# Average roll over all turns and sims for N_roll = 45 and N_stop = 6 is 5.376829281384824
# Average roll over all turns and sims for N_roll = 46 and N_stop = 6 is 5.346683125386976
# Average roll over all turns and sims for N_roll = 47 and N_stop = 6 is 5.423334301406844
# Average roll over all turns and sims for N_roll = 48 and N_stop = 6 is 5.346721135796788
# Average roll over all turns and sims for N_roll = 49 and N_stop = 6 is 5.347351044802351
# Average roll over all turns and sims for N_roll = 1 and N_stop = 7 is 3.3610122618891802
# Average roll over all turns and sims for N_roll = 2 and N_stop = 7 is 5.535236461592068
# Average roll over all turns and sims for N_roll = 3 and N_stop = 7 is 6.002802870105519
# Average roll over all turns and sims for N_roll = 4 and N_stop = 7 is 6.0292512180953475
# Average roll over all turns and sims for N_roll = 5 and N_stop = 7 is 5.953604381225461
# Average roll over all turns and sims for N_roll = 6 and N_stop = 7 is 5.9826440556890725
# Average roll over all turns and sims for N_roll = 7 and N_stop = 7 is 5.921459734303393
# Average roll over all turns and sims for N_roll = 8 and N_stop = 7 is 5.964305823898361
# Average roll over all turns and sims for N_roll = 9 and N_stop = 7 is 5.929509635871709
# Average roll over all turns and sims for N_roll = 10 and N_stop = 7 is 5.998643437532241
# Average roll over all turns and sims for N_roll = 11 and N_stop = 7 is 5.980384960437172
# Average roll over all turns and sims for N_roll = 12 and N_stop = 7 is 6.051204671829817
# Average roll over all turns and sims for N_roll = 13 and N_stop = 7 is 6.019134358790943
# Average roll over all turns and sims for N_roll = 14 and N_stop = 7 is 5.9560458684735496
# Average roll over all turns and sims for N_roll = 15 and N_stop = 7 is 5.974804241938103
# Average roll over all turns and sims for N_roll = 16 and N_stop = 7 is 5.943375024743406
# Average roll over all turns and sims for N_roll = 17 and N_stop = 7 is 5.990145730840664
# Average roll over all turns and sims for N_roll = 18 and N_stop = 7 is 6.035465225949532
# Average roll over all turns and sims for N_roll = 19 and N_stop = 7 is 5.995816305676106
# Average roll over all turns and sims for N_roll = 20 and N_stop = 7 is 5.97070994194332
# Average roll over all turns and sims for N_roll = 21 and N_stop = 7 is 5.979523364467719
# Average roll over all turns and sims for N_roll = 22 and N_stop = 7 is 5.986050050665673
# Average roll over all turns and sims for N_roll = 23 and N_stop = 7 is 5.952444160175167
# Average roll over all turns and sims for N_roll = 24 and N_stop = 7 is 5.982530606499966
# Average roll over all turns and sims for N_roll = 25 and N_stop = 7 is 6.04725896226933
# Average roll over all turns and sims for N_roll = 26 and N_stop = 7 is 5.9742591246084285
# Average roll over all turns and sims for N_roll = 27 and N_stop = 7 is 6.024631981793229
# Average roll over all turns and sims for N_roll = 28 and N_stop = 7 is 6.025243353047098
# Average roll over all turns and sims for N_roll = 29 and N_stop = 7 is 6.035880355669916
# Average roll over all turns and sims for N_roll = 30 and N_stop = 7 is 5.955799896123997
# Average roll over all turns and sims for N_roll = 31 and N_stop = 7 is 6.014186250405813
# Average roll over all turns and sims for N_roll = 32 and N_stop = 7 is 5.956380821867551
# Average roll over all turns and sims for N_roll = 33 and N_stop = 7 is 6.0154946408298455
# Average roll over all turns and sims for N_roll = 34 and N_stop = 7 is 5.9834263014052125
# Average roll over all turns and sims for N_roll = 35 and N_stop = 7 is 5.952447894265235
# Average roll over all turns and sims for N_roll = 36 and N_stop = 7 is 5.9351083399393705
# Average roll over all turns and sims for N_roll = 37 and N_stop = 7 is 6.007322014735106
# Average roll over all turns and sims for N_roll = 38 and N_stop = 7 is 5.941482619710944
# Average roll over all turns and sims for N_roll = 39 and N_stop = 7 is 5.9786282094053105
# Average roll over all turns and sims for N_roll = 40 and N_stop = 7 is 6.018602696431871
# Average roll over all turns and sims for N_roll = 41 and N_stop = 7 is 5.981497269351317
# Average roll over all turns and sims for N_roll = 42 and N_stop = 7 is 5.923053861195269
# Average roll over all turns and sims for N_roll = 43 and N_stop = 7 is 6.023324918862998
# Average roll over all turns and sims for N_roll = 44 and N_stop = 7 is 6.000870880399941
# Average roll over all turns and sims for N_roll = 45 and N_stop = 7 is 6.020537779842238
# Average roll over all turns and sims for N_roll = 46 and N_stop = 7 is 5.9565064775154495
# Average roll over all turns and sims for N_roll = 47 and N_stop = 7 is 6.037152608681697
# Average roll over all turns and sims for N_roll = 48 and N_stop = 7 is 5.985876458872597
# Average roll over all turns and sims for N_roll = 49 and N_stop = 7 is 5.997660493813048
# Average roll over all turns and sims for N_roll = 1 and N_stop = 8 is 3.3338171075761625
# Average roll over all turns and sims for N_roll = 2 and N_stop = 8 is 5.584291480065656
# Average roll over all turns and sims for N_roll = 3 and N_stop = 8 is 6.239519082339009
# Average roll over all turns and sims for N_roll = 4 and N_stop = 8 is 6.182386801337096
# Average roll over all turns and sims for N_roll = 5 and N_stop = 8 is 6.308396077973603
# Average roll over all turns and sims for N_roll = 6 and N_stop = 8 is 6.279286545081395
# Average roll over all turns and sims for N_roll = 7 and N_stop = 8 is 6.295808719944765
# Average roll over all turns and sims for N_roll = 8 and N_stop = 8 is 6.236273901490718
# Average roll over all turns and sims for N_roll = 9 and N_stop = 8 is 6.288112227838043
# Average roll over all turns and sims for N_roll = 10 and N_stop = 8 is 6.314316368203647
# Average roll over all turns and sims for N_roll = 11 and N_stop = 8 is 6.25743480939985
# Average roll over all turns and sims for N_roll = 12 and N_stop = 8 is 6.246912679878285
# Average roll over all turns and sims for N_roll = 13 and N_stop = 8 is 6.278406034728979
# Average roll over all turns and sims for N_roll = 14 and N_stop = 8 is 6.258705327371484
# Average roll over all turns and sims for N_roll = 15 and N_stop = 8 is 6.272382483568061
# Average roll over all turns and sims for N_roll = 16 and N_stop = 8 is 6.296922687187358
# Average roll over all turns and sims for N_roll = 17 and N_stop = 8 is 6.248181271404749
# Average roll over all turns and sims for N_roll = 18 and N_stop = 8 is 6.283724578341113
# Average roll over all turns and sims for N_roll = 19 and N_stop = 8 is 6.196387241600758
# Average roll over all turns and sims for N_roll = 20 and N_stop = 8 is 6.317264282942115
# Average roll over all turns and sims for N_roll = 21 and N_stop = 8 is 6.2405204242765535
# Average roll over all turns and sims for N_roll = 22 and N_stop = 8 is 6.2276559621294965
# Average roll over all turns and sims for N_roll = 23 and N_stop = 8 is 6.245910979245599
# Average roll over all turns and sims for N_roll = 24 and N_stop = 8 is 6.260481184092193
# Average roll over all turns and sims for N_roll = 25 and N_stop = 8 is 6.231639299155344
# Average roll over all turns and sims for N_roll = 26 and N_stop = 8 is 6.282126186727629
# Average roll over all turns and sims for N_roll = 27 and N_stop = 8 is 6.217107372102259
# Average roll over all turns and sims for N_roll = 28 and N_stop = 8 is 6.2168486924716975
# Average roll over all turns and sims for N_roll = 29 and N_stop = 8 is 6.175352773011242
# Average roll over all turns and sims for N_roll = 30 and N_stop = 8 is 6.237695175061997
# Average roll over all turns and sims for N_roll = 31 and N_stop = 8 is 6.247266557114554
# Average roll over all turns and sims for N_roll = 32 and N_stop = 8 is 6.2723440049800265
# Average roll over all turns and sims for N_roll = 33 and N_stop = 8 is 6.258674367815022
# Average roll over all turns and sims for N_roll = 34 and N_stop = 8 is 6.254045994480174
# Average roll over all turns and sims for N_roll = 35 and N_stop = 8 is 6.252854582678384
# Average roll over all turns and sims for N_roll = 36 and N_stop = 8 is 6.2596386453641175
# Average roll over all turns and sims for N_roll = 37 and N_stop = 8 is 6.245685968305822
# Average roll over all turns and sims for N_roll = 38 and N_stop = 8 is 6.309591864163785
# Average roll over all turns and sims for N_roll = 39 and N_stop = 8 is 6.269633045186115
# Average roll over all turns and sims for N_roll = 40 and N_stop = 8 is 6.27174303774593
# Average roll over all turns and sims for N_roll = 41 and N_stop = 8 is 6.25285719792305
# Average roll over all turns and sims for N_roll = 42 and N_stop = 8 is 6.207117270869535
# Average roll over all turns and sims for N_roll = 43 and N_stop = 8 is 6.253547496499424
# Average roll over all turns and sims for N_roll = 44 and N_stop = 8 is 6.198512497570119
# Average roll over all turns and sims for N_roll = 45 and N_stop = 8 is 6.282155076069853
# Average roll over all turns and sims for N_roll = 46 and N_stop = 8 is 6.242120972115508
# Average roll over all turns and sims for N_roll = 47 and N_stop = 8 is 6.20512070800366
# Average roll over all turns and sims for N_roll = 48 and N_stop = 8 is 6.282645406639317
# Average roll over all turns and sims for N_roll = 49 and N_stop = 8 is 6.272357016348322
# Average roll over all turns and sims for N_roll = 1 and N_stop = 9 is 3.333435494704142
# Average roll over all turns and sims for N_roll = 2 and N_stop = 9 is 5.56907583321768
# Average roll over all turns and sims for N_roll = 3 and N_stop = 9 is 6.5769813010568665
# Average roll over all turns and sims for N_roll = 4 and N_stop = 9 is 6.617165559936177
# Average roll over all turns and sims for N_roll = 5 and N_stop = 9 is 6.53226511944157
# Average roll over all turns and sims for N_roll = 6 and N_stop = 9 is 6.535878539130525
# Average roll over all turns and sims for N_roll = 7 and N_stop = 9 is 6.645943248597514
# Average roll over all turns and sims for N_roll = 8 and N_stop = 9 is 6.582901633796269
# Average roll over all turns and sims for N_roll = 9 and N_stop = 9 is 6.525189371400398
# Average roll over all turns and sims for N_roll = 10 and N_stop = 9 is 6.655169021947431
# Average roll over all turns and sims for N_roll = 11 and N_stop = 9 is 6.634435990996097
# Average roll over all turns and sims for N_roll = 12 and N_stop = 9 is 6.571842454322748
# Average roll over all turns and sims for N_roll = 13 and N_stop = 9 is 6.625616947964532
# Average roll over all turns and sims for N_roll = 14 and N_stop = 9 is 6.6871653233820005
# Average roll over all turns and sims for N_roll = 15 and N_stop = 9 is 6.514527271385414
# Average roll over all turns and sims for N_roll = 16 and N_stop = 9 is 6.553736878300658
# Average roll over all turns and sims for N_roll = 17 and N_stop = 9 is 6.696006403262263
# Average roll over all turns and sims for N_roll = 18 and N_stop = 9 is 6.6022181496357355
# Average roll over all turns and sims for N_roll = 19 and N_stop = 9 is 6.56652684536201
# Average roll over all turns and sims for N_roll = 20 and N_stop = 9 is 6.649208339284354
# Average roll over all turns and sims for N_roll = 21 and N_stop = 9 is 6.534454120443048
# Average roll over all turns and sims for N_roll = 22 and N_stop = 9 is 6.619727579747149
# Average roll over all turns and sims for N_roll = 23 and N_stop = 9 is 6.60375203742514
# Average roll over all turns and sims for N_roll = 24 and N_stop = 9 is 6.538079596336225
# Average roll over all turns and sims for N_roll = 25 and N_stop = 9 is 6.539986876574698
# Average roll over all turns and sims for N_roll = 26 and N_stop = 9 is 6.6689106471876025
# Average roll over all turns and sims for N_roll = 27 and N_stop = 9 is 6.565725241044764
# Average roll over all turns and sims for N_roll = 28 and N_stop = 9 is 6.554037292770845
# Average roll over all turns and sims for N_roll = 29 and N_stop = 9 is 6.505044492036797
# Average roll over all turns and sims for N_roll = 30 and N_stop = 9 is 6.666565340915204
# Average roll over all turns and sims for N_roll = 31 and N_stop = 9 is 6.6388534699971045
# Average roll over all turns and sims for N_roll = 32 and N_stop = 9 is 6.582301755330133
# Average roll over all turns and sims for N_roll = 33 and N_stop = 9 is 6.5454606775765685
# Average roll over all turns and sims for N_roll = 34 and N_stop = 9 is 6.570936206184757
# Average roll over all turns and sims for N_roll = 35 and N_stop = 9 is 6.491404544968805
# Average roll over all turns and sims for N_roll = 36 and N_stop = 9 is 6.545935849486429
# Average roll over all turns and sims for N_roll = 37 and N_stop = 9 is 6.671205596234547
# Average roll over all turns and sims for N_roll = 38 and N_stop = 9 is 6.615588655521622
# Average roll over all turns and sims for N_roll = 39 and N_stop = 9 is 6.719291446422448
# Average roll over all turns and sims for N_roll = 40 and N_stop = 9 is 6.650429765026891
# Average roll over all turns and sims for N_roll = 41 and N_stop = 9 is 6.556747530261703
# Average roll over all turns and sims for N_roll = 42 and N_stop = 9 is 6.585977549815241
# Average roll over all turns and sims for N_roll = 43 and N_stop = 9 is 6.5351365137108886
# Average roll over all turns and sims for N_roll = 44 and N_stop = 9 is 6.546698707878957
# Average roll over all turns and sims for N_roll = 45 and N_stop = 9 is 6.499192960923815
# Average roll over all turns and sims for N_roll = 46 and N_stop = 9 is 6.553449507037516
# Average roll over all turns and sims for N_roll = 47 and N_stop = 9 is 6.612849912200208
# Average roll over all turns and sims for N_roll = 48 and N_stop = 9 is 6.566449796883836
# Average roll over all turns and sims for N_roll = 49 and N_stop = 9 is 6.514203371774419
# Average roll over all turns and sims for N_roll = 1 and N_stop = 10 is 3.347898558268184
# Average roll over all turns and sims for N_roll = 2 and N_stop = 10 is 5.562979051390039
# Average roll over all turns and sims for N_roll = 3 and N_stop = 10 is 6.6984880640506335
# Average roll over all turns and sims for N_roll = 4 and N_stop = 10 is 6.93991505193568
# Average roll over all turns and sims for N_roll = 5 and N_stop = 10 is 6.908105769246265
# Average roll over all turns and sims for N_roll = 6 and N_stop = 10 is 6.917361457538984
# Average roll over all turns and sims for N_roll = 7 and N_stop = 10 is 6.889391696950821
# Average roll over all turns and sims for N_roll = 8 and N_stop = 10 is 6.863148858602225
# Average roll over all turns and sims for N_roll = 9 and N_stop = 10 is 6.868285992020353
# Average roll over all turns and sims for N_roll = 10 and N_stop = 10 is 6.883000763806272
# Average roll over all turns and sims for N_roll = 11 and N_stop = 10 is 6.899048275199354
# Average roll over all turns and sims for N_roll = 12 and N_stop = 10 is 6.9271352426326045
# Average roll over all turns and sims for N_roll = 13 and N_stop = 10 is 7.008717863157193
# Average roll over all turns and sims for N_roll = 14 and N_stop = 10 is 6.766977974370823
# Average roll over all turns and sims for N_roll = 15 and N_stop = 10 is 6.857578679176892
# Average roll over all turns and sims for N_roll = 16 and N_stop = 10 is 6.829906975853349
# Average roll over all turns and sims for N_roll = 17 and N_stop = 10 is 6.9029057481135965
# Average roll over all turns and sims for N_roll = 18 and N_stop = 10 is 6.988609633444521
# Average roll over all turns and sims for N_roll = 19 and N_stop = 10 is 6.86445804501683
# Average roll over all turns and sims for N_roll = 20 and N_stop = 10 is 6.900456552904668
# Average roll over all turns and sims for N_roll = 21 and N_stop = 10 is 6.93711075454765
# Average roll over all turns and sims for N_roll = 22 and N_stop = 10 is 6.870977662998727
# Average roll over all turns and sims for N_roll = 23 and N_stop = 10 is 6.886454768259238
# Average roll over all turns and sims for N_roll = 24 and N_stop = 10 is 6.908025904026381
# Average roll over all turns and sims for N_roll = 25 and N_stop = 10 is 6.89622556799552
# Average roll over all turns and sims for N_roll = 26 and N_stop = 10 is 6.940514703329068
# Average roll over all turns and sims for N_roll = 27 and N_stop = 10 is 6.846240373689207
# Average roll over all turns and sims for N_roll = 28 and N_stop = 10 is 6.896393480316415
# Average roll over all turns and sims for N_roll = 29 and N_stop = 10 is 6.857464345609907
# Average roll over all turns and sims for N_roll = 30 and N_stop = 10 is 6.849090200924777
# Average roll over all turns and sims for N_roll = 31 and N_stop = 10 is 6.91220445861422
# Average roll over all turns and sims for N_roll = 32 and N_stop = 10 is 6.810211085267764
# Average roll over all turns and sims for N_roll = 33 and N_stop = 10 is 6.860486038971251
# Average roll over all turns and sims for N_roll = 34 and N_stop = 10 is 6.990152035346434
# Average roll over all turns and sims for N_roll = 35 and N_stop = 10 is 6.92976625380704
# Average roll over all turns and sims for N_roll = 36 and N_stop = 10 is 6.882043904404281
# Average roll over all turns and sims for N_roll = 37 and N_stop = 10 is 6.907398360728735
# Average roll over all turns and sims for N_roll = 38 and N_stop = 10 is 6.908542559772011
# Average roll over all turns and sims for N_roll = 39 and N_stop = 10 is 6.845199107808042
# Average roll over all turns and sims for N_roll = 40 and N_stop = 10 is 6.899859297083638
# Average roll over all turns and sims for N_roll = 41 and N_stop = 10 is 6.863066887907048
# Average roll over all turns and sims for N_roll = 42 and N_stop = 10 is 6.892057607017205
# Average roll over all turns and sims for N_roll = 43 and N_stop = 10 is 6.887300001264817
# Average roll over all turns and sims for N_roll = 44 and N_stop = 10 is 6.854440887037292
# Average roll over all turns and sims for N_roll = 45 and N_stop = 10 is 6.918409183980275
# Average roll over all turns and sims for N_roll = 46 and N_stop = 10 is 6.892659427478846
# Average roll over all turns and sims for N_roll = 47 and N_stop = 10 is 6.844586146762374
# Average roll over all turns and sims for N_roll = 48 and N_stop = 10 is 6.862902479813429
# Average roll over all turns and sims for N_roll = 49 and N_stop = 10 is 6.825495146696372
# Average roll over all turns and sims for N_roll = 1 and N_stop = 11 is 3.3478416182778545
# Average roll over all turns and sims for N_roll = 2 and N_stop = 11 is 5.553799598924708
# Average roll over all turns and sims for N_roll = 3 and N_stop = 11 is 6.7791545331582395
# Average roll over all turns and sims for N_roll = 4 and N_stop = 11 is 7.162880926469724
# Average roll over all turns and sims for N_roll = 5 and N_stop = 11 is 7.19461875925507
# Average roll over all turns and sims for N_roll = 6 and N_stop = 11 is 7.189169128445554
# Average roll over all turns and sims for N_roll = 7 and N_stop = 11 is 7.204263566050828
# Average roll over all turns and sims for N_roll = 8 and N_stop = 11 is 7.168724860773676
# Average roll over all turns and sims for N_roll = 9 and N_stop = 11 is 7.216639734807873
# Average roll over all turns and sims for N_roll = 10 and N_stop = 11 is 7.099928847278891
# Average roll over all turns and sims for N_roll = 11 and N_stop = 11 is 7.104581232795661
# Average roll over all turns and sims for N_roll = 12 and N_stop = 11 is 7.1348028856204975
# Average roll over all turns and sims for N_roll = 13 and N_stop = 11 is 7.1617787808509
# Average roll over all turns and sims for N_roll = 14 and N_stop = 11 is 7.0900921322227894
# Average roll over all turns and sims for N_roll = 15 and N_stop = 11 is 7.14139678583401
# Average roll over all turns and sims for N_roll = 16 and N_stop = 11 is 7.14080084944898
# Average roll over all turns and sims for N_roll = 17 and N_stop = 11 is 7.250773182445776
# Average roll over all turns and sims for N_roll = 18 and N_stop = 11 is 7.222870436039493
# Average roll over all turns and sims for N_roll = 19 and N_stop = 11 is 7.145683422819892
# Average roll over all turns and sims for N_roll = 20 and N_stop = 11 is 7.090623162321561
# Average roll over all turns and sims for N_roll = 21 and N_stop = 11 is 7.060253213560672
# Average roll over all turns and sims for N_roll = 22 and N_stop = 11 is 7.209799958651405
# Average roll over all turns and sims for N_roll = 23 and N_stop = 11 is 7.105335959278384
# Average roll over all turns and sims for N_roll = 24 and N_stop = 11 is 7.203916961554708
# Average roll over all turns and sims for N_roll = 25 and N_stop = 11 is 7.171260268177587
# Average roll over all turns and sims for N_roll = 26 and N_stop = 11 is 7.192153022521917
# Average roll over all turns and sims for N_roll = 27 and N_stop = 11 is 7.2624831154775356
# Average roll over all turns and sims for N_roll = 28 and N_stop = 11 is 7.129259597449289
# Average roll over all turns and sims for N_roll = 29 and N_stop = 11 is 7.138483770959506
# Average roll over all turns and sims for N_roll = 30 and N_stop = 11 is 7.17122442357567
# Average roll over all turns and sims for N_roll = 31 and N_stop = 11 is 7.135634959113613
# Average roll over all turns and sims for N_roll = 32 and N_stop = 11 is 7.127681301889713
# Average roll over all turns and sims for N_roll = 33 and N_stop = 11 is 7.195185236522896
# Average roll over all turns and sims for N_roll = 34 and N_stop = 11 is 7.206036107990503
# Average roll over all turns and sims for N_roll = 35 and N_stop = 11 is 7.204871521952963
# Average roll over all turns and sims for N_roll = 36 and N_stop = 11 is 7.179274385186593
# Average roll over all turns and sims for N_roll = 37 and N_stop = 11 is 7.142535983830705
# Average roll over all turns and sims for N_roll = 38 and N_stop = 11 is 7.317777879777075
# Average roll over all turns and sims for N_roll = 39 and N_stop = 11 is 7.235653156042678
# Average roll over all turns and sims for N_roll = 40 and N_stop = 11 is 7.1363334612513105
# Average roll over all turns and sims for N_roll = 41 and N_stop = 11 is 7.131982055110322
# Average roll over all turns and sims for N_roll = 42 and N_stop = 11 is 7.151313295978731
# Average roll over all turns and sims for N_roll = 43 and N_stop = 11 is 7.198473426022881
# Average roll over all turns and sims for N_roll = 44 and N_stop = 11 is 7.197995783970449
# Average roll over all turns and sims for N_roll = 45 and N_stop = 11 is 7.1337087059849695
# Average roll over all turns and sims for N_roll = 46 and N_stop = 11 is 7.140883772583699
# Average roll over all turns and sims for N_roll = 47 and N_stop = 11 is 7.186039533923452
# ...
# Average roll over all turns and sims for N_roll = 20 and N_stop = 96 is 2.428064109852543
# Average roll over all turns and sims for N_roll = 21 and N_stop = 96 is 2.0575495398569004
# Average roll over all turns and sims for N_roll = 22 and N_stop = 96 is 1.8815045114151345
# Average roll over all turns and sims for N_roll = 23 and N_stop = 96 is 1.7206898824291983
# Average roll over all turns and sims for N_roll = 24 and N_stop = 96 is 1.5233480716940184
# Average roll over all turns and sims for N_roll = 25 and N_stop = 96 is 1.4066682726868842
# Average roll over all turns and sims for N_roll = 26 and N_stop = 96 is 1.468857383261705
# Average roll over all turns and sims for N_roll = 27 and N_stop = 96 is 1.3952205751638416
# Average roll over all turns and sims for N_roll = 28 and N_stop = 96 is 1.3776924740718497
# Average roll over all turns and sims for N_roll = 29 and N_stop = 96 is 1.337806406107866
# Average roll over all turns and sims for N_roll = 30 and N_stop = 96 is 1.4354977019732118
# Average roll over all turns and sims for N_roll = 31 and N_stop = 96 is 1.3592153418126998
# Average roll over all turns and sims for N_roll = 32 and N_stop = 96 is 1.3969179045268882
# Average roll over all turns and sims for N_roll = 33 and N_stop = 96 is 1.3375761507802877
# Average roll over all turns and sims for N_roll = 34 and N_stop = 96 is 1.3583639646340737
# Average roll over all turns and sims for N_roll = 35 and N_stop = 96 is 1.47023602315926
# Average roll over all turns and sims for N_roll = 36 and N_stop = 96 is 1.4269671216245174
# Average roll over all turns and sims for N_roll = 37 and N_stop = 96 is 1.3392464366908
# Average roll over all turns and sims for N_roll = 38 and N_stop = 96 is 1.353497198538992
# Average roll over all turns and sims for N_roll = 39 and N_stop = 96 is 1.4091978750991117
# Average roll over all turns and sims for N_roll = 40 and N_stop = 96 is 1.4203464411060873
# Average roll over all turns and sims for N_roll = 41 and N_stop = 96 is 1.3935933423680722
# Average roll over all turns and sims for N_roll = 42 and N_stop = 96 is 1.3885713651894256
# Average roll over all turns and sims for N_roll = 43 and N_stop = 96 is 1.3647378121251879
# Average roll over all turns and sims for N_roll = 44 and N_stop = 96 is 1.3812670216117158
# Average roll over all turns and sims for N_roll = 45 and N_stop = 96 is 1.5449879177237131
# Average roll over all turns and sims for N_roll = 46 and N_stop = 96 is 1.3559053574538698
# Average roll over all turns and sims for N_roll = 47 and N_stop = 96 is 1.2880452081638165
# Average roll over all turns and sims for N_roll = 48 and N_stop = 96 is 1.4898577562303243
# Average roll over all turns and sims for N_roll = 49 and N_stop = 96 is 1.3470301827766742
# Average roll over all turns and sims for N_roll = 1 and N_stop = 97 is 3.3460808149650223
# Average roll over all turns and sims for N_roll = 2 and N_stop = 97 is 5.5814950891480635
# Average roll over all turns and sims for N_roll = 3 and N_stop = 97 is 7.0220101959134436
# Average roll over all turns and sims for N_roll = 4 and N_stop = 97 is 7.824659403588282
# Average roll over all turns and sims for N_roll = 5 and N_stop = 97 is 8.217807223004042
# Average roll over all turns and sims for N_roll = 6 and N_stop = 97 is 8.238093211545477
# Average roll over all turns and sims for N_roll = 7 and N_stop = 97 is 8.122627098987897
# Average roll over all turns and sims for N_roll = 8 and N_stop = 97 is 7.804635775112729
# Average roll over all turns and sims for N_roll = 9 and N_stop = 97 is 7.01548935034324
# Average roll over all turns and sims for N_roll = 10 and N_stop = 97 is 6.871730350757041
# Average roll over all turns and sims for N_roll = 11 and N_stop = 97 is 6.01021683383585
# Average roll over all turns and sims for N_roll = 12 and N_stop = 97 is 5.614377395284589
# Average roll over all turns and sims for N_roll = 13 and N_stop = 97 is 5.379224064295175
# Average roll over all turns and sims for N_roll = 14 and N_stop = 97 is 4.816432130191436
# Average roll over all turns and sims for N_roll = 15 and N_stop = 97 is 4.240274603524007
# Average roll over all turns and sims for N_roll = 16 and N_stop = 97 is 3.722138627089748
# Average roll over all turns and sims for N_roll = 17 and N_stop = 97 is 3.3144203139247193
# Average roll over all turns and sims for N_roll = 18 and N_stop = 97 is 3.0879021510919387
# Average roll over all turns and sims for N_roll = 19 and N_stop = 97 is 2.756852241304555
# Average roll over all turns and sims for N_roll = 20 and N_stop = 97 is 2.3652382791500948
# Average roll over all turns and sims for N_roll = 21 and N_stop = 97 is 2.068002960963766
# Average roll over all turns and sims for N_roll = 22 and N_stop = 97 is 1.8826150940875197
# Average roll over all turns and sims for N_roll = 23 and N_stop = 97 is 1.6518209767461727
# Average roll over all turns and sims for N_roll = 24 and N_stop = 97 is 1.4897838209585559
# Average roll over all turns and sims for N_roll = 25 and N_stop = 97 is 1.4810542270135274
# Average roll over all turns and sims for N_roll = 26 and N_stop = 97 is 1.3710132307890914
# Average roll over all turns and sims for N_roll = 27 and N_stop = 97 is 1.364300872106651
# Average roll over all turns and sims for N_roll = 28 and N_stop = 97 is 1.3185184985813942
# Average roll over all turns and sims for N_roll = 29 and N_stop = 97 is 1.3482460491490997
# Average roll over all turns and sims for N_roll = 30 and N_stop = 97 is 1.4306591463501233
# Average roll over all turns and sims for N_roll = 31 and N_stop = 97 is 1.2693641192387968
# Average roll over all turns and sims for N_roll = 32 and N_stop = 97 is 1.456407430533516
# Average roll over all turns and sims for N_roll = 33 and N_stop = 97 is 1.3786809085826763
# Average roll over all turns and sims for N_roll = 34 and N_stop = 97 is 1.3103296574679126
# Average roll over all turns and sims for N_roll = 35 and N_stop = 97 is 1.3586160678817074
# Average roll over all turns and sims for N_roll = 36 and N_stop = 97 is 1.38602643868259
# Average roll over all turns and sims for N_roll = 37 and N_stop = 97 is 1.3392213021833623
# Average roll over all turns and sims for N_roll = 38 and N_stop = 97 is 1.389954814460894
# Average roll over all turns and sims for N_roll = 39 and N_stop = 97 is 1.3320786392311461
# Average roll over all turns and sims for N_roll = 40 and N_stop = 97 is 1.333863131671991
# Average roll over all turns and sims for N_roll = 41 and N_stop = 97 is 1.3689167450480153
# Average roll over all turns and sims for N_roll = 42 and N_stop = 97 is 1.4144564826365782
# Average roll over all turns and sims for N_roll = 43 and N_stop = 97 is 1.3062810666294988
# Average roll over all turns and sims for N_roll = 44 and N_stop = 97 is 1.3702360677823902
# Average roll over all turns and sims for N_roll = 45 and N_stop = 97 is 1.402075081734249
# Average roll over all turns and sims for N_roll = 46 and N_stop = 97 is 1.3977583935137514
# Average roll over all turns and sims for N_roll = 47 and N_stop = 97 is 1.2705010563065704
# Average roll over all turns and sims for N_roll = 48 and N_stop = 97 is 1.2502433460613882
# Average roll over all turns and sims for N_roll = 49 and N_stop = 97 is 1.367565670765182
# Average roll over all turns and sims for N_roll = 1 and N_stop = 98 is 3.325832752017641
# Average roll over all turns and sims for N_roll = 2 and N_stop = 98 is 5.603557652764839
# Average roll over all turns and sims for N_roll = 3 and N_stop = 98 is 6.949166761323834
# Average roll over all turns and sims for N_roll = 4 and N_stop = 98 is 7.808921787446968
# Average roll over all turns and sims for N_roll = 5 and N_stop = 98 is 8.184418938281139
# Average roll over all turns and sims for N_roll = 6 and N_stop = 98 is 8.052338748108978
# Average roll over all turns and sims for N_roll = 7 and N_stop = 98 is 8.14837396841215
# Average roll over all turns and sims for N_roll = 8 and N_stop = 98 is 7.607552632834122
# Average roll over all turns and sims for N_roll = 9 and N_stop = 98 is 7.248713578086243
# Average roll over all turns and sims for N_roll = 10 and N_stop = 98 is 6.7532476731312485
# Average roll over all turns and sims for N_roll = 11 and N_stop = 98 is 6.1832089833868915
# Average roll over all turns and sims for N_roll = 12 and N_stop = 98 is 5.58210808979384
# Average roll over all turns and sims for N_roll = 13 and N_stop = 98 is 4.993462212499986
# Average roll over all turns and sims for N_roll = 14 and N_stop = 98 is 4.601829639125404
# Average roll over all turns and sims for N_roll = 15 and N_stop = 98 is 4.100429030046237
# Average roll over all turns and sims for N_roll = 16 and N_stop = 98 is 4.062081447357172
# Average roll over all turns and sims for N_roll = 17 and N_stop = 98 is 3.2874139583456037
# Average roll over all turns and sims for N_roll = 18 and N_stop = 98 is 2.921238019569963
# Average roll over all turns and sims for N_roll = 19 and N_stop = 98 is 2.7858744487924643
# Average roll over all turns and sims for N_roll = 20 and N_stop = 98 is 2.293311049384184
# Average roll over all turns and sims for N_roll = 21 and N_stop = 98 is 2.2017080416444603
# Average roll over all turns and sims for N_roll = 22 and N_stop = 98 is 1.8525056448958133
# Average roll over all turns and sims for N_roll = 23 and N_stop = 98 is 1.6747651420487029
# Average roll over all turns and sims for N_roll = 24 and N_stop = 98 is 1.5371530916736094
# Average roll over all turns and sims for N_roll = 25 and N_stop = 98 is 1.3933210961341573
# Average roll over all turns and sims for N_roll = 26 and N_stop = 98 is 1.3577342293220735
# Average roll over all turns and sims for N_roll = 27 and N_stop = 98 is 1.3702834398253771
# Average roll over all turns and sims for N_roll = 28 and N_stop = 98 is 1.2768800358520425
# Average roll over all turns and sims for N_roll = 29 and N_stop = 98 is 1.301996898865848
# Average roll over all turns and sims for N_roll = 30 and N_stop = 98 is 1.2693801242579819
# Average roll over all turns and sims for N_roll = 31 and N_stop = 98 is 1.332894734669341
# Average roll over all turns and sims for N_roll = 32 and N_stop = 98 is 1.3679763504278608
# Average roll over all turns and sims for N_roll = 33 and N_stop = 98 is 1.2279857066735869
# Average roll over all turns and sims for N_roll = 34 and N_stop = 98 is 1.24818787968966
# Average roll over all turns and sims for N_roll = 35 and N_stop = 98 is 1.347880585142339
# Average roll over all turns and sims for N_roll = 36 and N_stop = 98 is 1.2641563815517616
# Average roll over all turns and sims for N_roll = 37 and N_stop = 98 is 1.2823971923573412
# Average roll over all turns and sims for N_roll = 38 and N_stop = 98 is 1.2551952592154418
# Average roll over all turns and sims for N_roll = 39 and N_stop = 98 is 1.2420032677475994
# Average roll over all turns and sims for N_roll = 40 and N_stop = 98 is 1.2480057063148489
# Average roll over all turns and sims for N_roll = 41 and N_stop = 98 is 1.2232625090263962
# Average roll over all turns and sims for N_roll = 42 and N_stop = 98 is 1.3500207083350355
# Average roll over all turns and sims for N_roll = 43 and N_stop = 98 is 1.3625373754816914
# Average roll over all turns and sims for N_roll = 44 and N_stop = 98 is 1.366126515646701
# Average roll over all turns and sims for N_roll = 45 and N_stop = 98 is 1.3616100525382415
# Average roll over all turns and sims for N_roll = 46 and N_stop = 98 is 1.3461706708989762
# Average roll over all turns and sims for N_roll = 47 and N_stop = 98 is 1.1780322903435023
# Average roll over all turns and sims for N_roll = 48 and N_stop = 98 is 1.2694248724559132
# Average roll over all turns and sims for N_roll = 49 and N_stop = 98 is 1.2593160819642646
# Average roll over all turns and sims for N_roll = 1 and N_stop = 99 is 3.342420978443465
# Average roll over all turns and sims for N_roll = 2 and N_stop = 99 is 5.5394889626424
# Average roll over all turns and sims for N_roll = 3 and N_stop = 99 is 6.961717820879686
# Average roll over all turns and sims for N_roll = 4 and N_stop = 99 is 7.667703883378908
# Average roll over all turns and sims for N_roll = 5 and N_stop = 99 is 8.225389158517068
# Average roll over all turns and sims for N_roll = 6 and N_stop = 99 is 7.942908933990684
# Average roll over all turns and sims for N_roll = 7 and N_stop = 99 is 8.065443219944887
# Average roll over all turns and sims for N_roll = 8 and N_stop = 99 is 7.717458145740652
# Average roll over all turns and sims for N_roll = 9 and N_stop = 99 is 7.116043854366087
# Average roll over all turns and sims for N_roll = 10 and N_stop = 99 is 6.819039190074549
# Average roll over all turns and sims for N_roll = 11 and N_stop = 99 is 6.437283502662683
# Average roll over all turns and sims for N_roll = 12 and N_stop = 99 is 5.750397223272978
# Average roll over all turns and sims for N_roll = 13 and N_stop = 99 is 5.035200969812165
# Average roll over all turns and sims for N_roll = 14 and N_stop = 99 is 4.738989124868758
# Average roll over all turns and sims for N_roll = 15 and N_stop = 99 is 4.229123507885351
# Average roll over all turns and sims for N_roll = 16 and N_stop = 99 is 3.7917066532411177
# Average roll over all turns and sims for N_roll = 17 and N_stop = 99 is 3.310079188670773
# Average roll over all turns and sims for N_roll = 18 and N_stop = 99 is 3.0467785682986976
# Average roll over all turns and sims for N_roll = 19 and N_stop = 99 is 2.7462019314608193
# Average roll over all turns and sims for N_roll = 20 and N_stop = 99 is 2.354128584594213
# Average roll over all turns and sims for N_roll = 21 and N_stop = 99 is 2.071653936278695
# Average roll over all turns and sims for N_roll = 22 and N_stop = 99 is 1.8552452453945802
# Average roll over all turns and sims for N_roll = 23 and N_stop = 99 is 1.7286792259646497
# Average roll over all turns and sims for N_roll = 24 and N_stop = 99 is 1.3467458042777198
# Average roll over all turns and sims for N_roll = 25 and N_stop = 99 is 1.3841214255856678
# Average roll over all turns and sims for N_roll = 26 and N_stop = 99 is 1.3005469305855129
# Average roll over all turns and sims for N_roll = 27 and N_stop = 99 is 1.2513902366663456
# Average roll over all turns and sims for N_roll = 28 and N_stop = 99 is 1.2855768147175002
# Average roll over all turns and sims for N_roll = 29 and N_stop = 99 is 1.170487686627491
# Average roll over all turns and sims for N_roll = 30 and N_stop = 99 is 1.2592999562015506
# Average roll over all turns and sims for N_roll = 31 and N_stop = 99 is 1.3116818764386249
# Average roll over all turns and sims for N_roll = 32 and N_stop = 99 is 1.3841041531742886
# Average roll over all turns and sims for N_roll = 33 and N_stop = 99 is 1.3849567720909952
# Average roll over all turns and sims for N_roll = 34 and N_stop = 99 is 1.2497476271515766
# Average roll over all turns and sims for N_roll = 35 and N_stop = 99 is 1.230097662611221
# Average roll over all turns and sims for N_roll = 36 and N_stop = 99 is 1.2397236116633727
# Average roll over all turns and sims for N_roll = 37 and N_stop = 99 is 1.2134498040932844
# Average roll over all turns and sims for N_roll = 38 and N_stop = 99 is 1.317761959942789
# Average roll over all turns and sims for N_roll = 39 and N_stop = 99 is 1.2107712293971944
# Average roll over all turns and sims for N_roll = 40 and N_stop = 99 is 1.1877016985138753
# Average roll over all turns and sims for N_roll = 41 and N_stop = 99 is 1.3296742504777197
# Average roll over all turns and sims for N_roll = 42 and N_stop = 99 is 1.2794797422188726
# Average roll over all turns and sims for N_roll = 43 and N_stop = 99 is 1.1888593842956252
# Average roll over all turns and sims for N_roll = 44 and N_stop = 99 is 1.2130242106850675
# Average roll over all turns and sims for N_roll = 45 and N_stop = 99 is 1.2892866291012697
# Average roll over all turns and sims for N_roll = 46 and N_stop = 99 is 1.382473730085787
# Average roll over all turns and sims for N_roll = 47 and N_stop = 99 is 1.263539145395542
# Average roll over all turns and sims for N_roll = 48 and N_stop = 99 is 1.2180864204131128
# Average roll over all turns and sims for N_roll = 49 and N_stop = 99 is 1.2446002390941948

# %%
#print(df)

# Create a 3D surface plot
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
c = df['Avg_roll']/max(df['Avg_roll'])

ax.set_xlabel('N_stop')
ax.set_ylabel('N_roll')
ax.set_zlabel('Average_roll')

fig.colorbar(ax.scatter(df['N_stop'], df['N_roll'], df['Avg_roll'], c=c, cmap='viridis', linewidth=0.5), label='Average roll')

plt.show()

# %%
# plot the average roll vs. N_stop for the entire simulation
plt.figure(figsize=(10, 8))
plt.plot(df['N_stop'], df['Avg_roll'], '.')

# %%
# plot the average roll vs. N_roll for the entire simulation
plt.figure(figsize=(10, 8))
plt.plot(df['N_roll'], df['Avg_roll'], '.')

# %%
# Testing the game_play2 function
debug1 = True
debug2 = True
avg = game_play3(6,20,100)
print(avg)
# Out:
# Turn 1
# Player 1 score: 0
# Player 2 score: 0
# Player 2 turn
# Roll: 4
# Number of rolls: 1
# Player 2 score: 4
# Roll: 3
# Number of rolls: 2
# Player 2 score: 7
# Roll: 1
# Number of rolls: 3
# Player 2 loses turn
# Player 2 turn over
#
# Turn 2
# Player 1 score: 0
# Player 2 score: 0
# Player 1 turn
# Roll: 5
# Number of rolls: 1
# Player 1 score: 5
# Roll: 5
# Number of rolls: 2
# Player 1 score: 10
# Roll: 2
# Number of rolls: 3
# Player 1 score: 12
# Roll: 5
# Number of rolls: 4
# Player 1 score: 17
# Roll: 2
# Number of rolls: 5
# Player 1 score: 19
# Roll: 6
# Number of rolls: 6
# Player 1 score: 25
# Player 1 turn over
#
# Turn 3
# Player 1 score: 25
# Player 2 score: 0
# Player 2 turn
# Roll: 2
# Number of rolls: 1
# Player 2 score: 2
# Roll: 1
# Number of rolls: 2
# Player 2 loses turn
# Player 2 turn over
#
# Turn 4
# Player 1 score: 25
# Player 2 score: 0
# Player 1 turn
# Roll: 4
# Number of rolls: 1
# Player 1 score: 29
# Roll: 6
# Number of rolls: 2
# Player 1 score: 35
# Roll: 2
# Number of rolls: 3
# Player 1 score: 37
# Roll: 4
# Number of rolls: 4
# Player 1 score: 41
# Roll: 6
# Number of rolls: 5
# Player 1 score: 47
# Player 1 turn over
#
# Turn 5
# Player 1 score: 47
# Player 2 score: 0
# Player 2 turn
# Roll: 6
# Number of rolls: 1
# Player 2 score: 6
# Roll: 1
# Number of rolls: 2
# Player 2 loses turn
# Player 2 turn over
#
# Turn 6
# Player 1 score: 47
# Player 2 score: 0
# Player 1 turn
# Roll: 2
# Number of rolls: 1
# Player 1 score: 49
# Roll: 6
# Number of rolls: 2
# Player 1 score: 55
# Roll: 5
# Number of rolls: 3
# Player 1 score: 60
# Roll: 3
# Number of rolls: 4
# Player 1 score: 63
# Roll: 3
# Number of rolls: 5
# Player 1 score: 66
# Roll: 4
# Number of rolls: 6
# Player 1 score: 70
# Player 1 turn over
#
# Turn 7
# Player 1 score: 70
# Player 2 score: 0
# Player 2 turn
# Roll: 3
# Number of rolls: 1
# Player 2 score: 3
# Roll: 5
# Number of rolls: 2
# Player 2 score: 8
# Roll: 6
# Number of rolls: 3
# Player 2 score: 14
# Roll: 2
# Number of rolls: 4
# Player 2 score: 16
# Roll: 3
# Number of rolls: 5
# Player 2 score: 19
# Roll: 3
# Number of rolls: 6
# Player 2 score: 22
# Player 2 turn over
#
# Turn 8
# Player 1 score: 70
# Player 2 score: 22
# Player 1 turn
# Roll: 3
# Number of rolls: 1
# Player 1 score: 73
# Roll: 4
# Number of rolls: 2
# Player 1 score: 77
# Roll: 1
# Number of rolls: 3
# Player 1 loses turn
# Player 1 turn over
#
# Turn 9
# Player 1 score: 70
# Player 2 score: 22
# Player 2 turn
# Roll: 1
# Number of rolls: 1
# Player 2 loses turn
# Player 2 turn over
#
# Turn 10
# Player 1 score: 70
# Player 2 score: 22
# Player 1 turn
# Roll: 5
# Number of rolls: 1
# Player 1 score: 75
# Roll: 1
# Number of rolls: 2
# Player 1 loses turn
# Player 1 turn over
#
# Turn 11
# Player 1 score: 70
# Player 2 score: 22
# Player 2 turn
# Roll: 2
# Number of rolls: 1
# Player 2 score: 24
# Roll: 5
# Number of rolls: 2
# Player 2 score: 29
# Roll: 2
# Number of rolls: 3
# Player 2 score: 31
# Roll: 3
# Number of rolls: 4
# Player 2 score: 34
# Roll: 1
# Number of rolls: 5
# Player 2 loses turn
# Player 2 turn over
#
# Turn 12
# Player 1 score: 70
# Player 2 score: 22
# Player 1 turn
# Roll: 1
# Number of rolls: 1
# Player 1 loses turn
# Player 1 turn over
#
# Turn 13
# Player 1 score: 70
# Player 2 score: 22
# Player 2 turn
# Roll: 5
# Number of rolls: 1
# Player 2 score: 27
# Roll: 6
# Number of rolls: 2
# Player 2 score: 33
# Roll: 3
# Number of rolls: 3
# Player 2 score: 36
# Roll: 4
# Number of rolls: 4
# Player 2 score: 40
# Roll: 4
# Number of rolls: 5
# Player 2 score: 44
# Player 2 turn over
#
# Turn 14
# Player 1 score: 70
# Player 2 score: 44
# Player 1 turn
# Roll: 6
# Number of rolls: 1
# Player 1 score: 76
# Roll: 5
# Number of rolls: 2
# Player 1 score: 81
# Roll: 5
# Number of rolls: 3
# Player 1 score: 86
# Roll: 6
# Number of rolls: 4
# Player 1 score: 92
# Player 1 turn over
#
# Turn 15
# Player 1 score: 92
# Player 2 score: 44
# Player 2 turn
# Roll: 4
# Number of rolls: 1
# Player 2 score: 48
# Roll: 6
# Number of rolls: 2
# Player 2 score: 54
# Roll: 1
# Number of rolls: 3
# Player 2 loses turn
# Player 2 turn over
#
# Turn 16
# Player 1 score: 92
# Player 2 score: 44
# Player 1 turn
# Roll: 1
# Number of rolls: 1
# Player 1 loses turn
# Player 1 turn over
#
# Turn 17
# Player 1 score: 92
# Player 2 score: 44
# Player 2 turn
# Roll: 6
# Number of rolls: 1
# Player 2 score: 50
# Roll: 2
# Number of rolls: 2
# Player 2 score: 52
# Roll: 6
# Number of rolls: 3
# Player 2 score: 58
# Roll: 3
# Number of rolls: 4
# Player 2 score: 61
# Roll: 1
# Number of rolls: 5
# Player 2 loses turn
# Player 2 turn over
#
# Turn 18
# Player 1 score: 92
# Player 2 score: 44
# Player 1 turn
# Roll: 4
# Number of rolls: 1
# Player 1 score: 96
# Roll: 1
# Number of rolls: 2
# Player 1 loses turn
# Player 1 turn over
#
# Turn 19
# Player 1 score: 92
# Player 2 score: 44
# Player 2 turn
# Roll: 2
# Number of rolls: 1
# Player 2 score: 46
# Roll: 3
# Number of rolls: 2
# Player 2 score: 49
# Roll: 3
# Number of rolls: 3
# Player 2 score: 52
# Roll: 5
# Number of rolls: 4
# Player 2 score: 57
# Roll: 2
# Number of rolls: 5
# Player 2 score: 59
# Roll: 4
# Number of rolls: 6
# Player 2 score: 63
# Player 2 turn over
#
# Turn 20
# Player 1 score: 92
# Player 2 score: 63
# Player 1 turn
# Roll: 2
# Number of rolls: 1
# Player 1 score: 94
# Roll: 4
# Number of rolls: 2
# Player 1 score: 98
# Roll: 5
# Number of rolls: 3
# Player 1 score: 103
# Player 1 turn over
#
# Final score: Player 1: 103, Player 2: 63
# Player 1 wins!
# Game took 20 turns
# 8.3
