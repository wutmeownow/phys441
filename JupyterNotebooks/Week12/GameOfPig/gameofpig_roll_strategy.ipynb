# %% [markdown]
# ### Game of Pig
#
# Rules:
#
# 1. Two players take turns rolling a single die as many times as they wish. Each roll adds a score equal to the number rolled to the player's total.
# 2. If a player rolls a 1, their score for that turn is zero, and their turn ends.
# 3. At any point during a player's turn, they can choose to stop rolling and keep their score. The first player to reach 100 wins.
#
# That's it! Let's play.
#
# There are two basic strategies for this game.  The first is known as roll-based strategy, where you roll a set number of times on each turn (unless you lose).  The second is known as score-based strategy, where you roll until you reach a certain score, and then stop.
#
# Let's investigate the roll-based strategy.

# %%
# The usual libraries
import random
import matplotlib.pyplot as plt
import numpy as np


# A couple of debug flags to control print statements
debug1 = False
debug2 = False

# Number of games to simulate for each configuration
nsims = 10000

# %% [markdown]
# Now, let's look at the roll-based strategy.  In this strategy, we will roll a fixed number of times on each turn.  We will consider the same four end scores as above, and will consider the average roll per turn as a function of the number of rolls per turn.

# %%
# function to play an entire game of pig
# N_roll is the number of rolls per turn
# end_score is the score at which the game ends
# returns the average roll per turn

debug1 = False
debug2 = False

def game_play2(N_roll,end_score):

    # Initialize the score (for each of two players) and turn number within the game
    score = [0,0]
    turn = 0

    # Play the game - keep going until one player reaches the end score
    while score[0] < end_score and score[1] < end_score:

        # Initialize the score for this player during this turn and increment turn number
        turn_score = 0
        turn += 1

        if debug2:
            print("Turn", turn)
            for i in range(2):
                print("Player", i+1, "score:", score[i])
            print("Player", turn%2+1, "turn")

        roll = 0
        n_rolls = 0
        # Keep rolling until you roll a 1 or reach N_stop
        while roll != 1 and n_rolls < N_roll and score[turn%2] < end_score:

            roll = random.randint(1,6)
            n_rolls += 1

            if debug2:
                print("Roll:", roll)
                print("Number of rolls:", n_rolls)

            if roll == 1:
                if debug2:
                    print("Player", turn%2+1, "loses turn")
                # If you roll a 1, you lose all points for this turn and your turn is over
                score[turn%2] = score[turn%2] - turn_score
                break
            else:
                score[turn%2] += roll
                if debug2:
                    print("Player", turn%2+1, "score:", score[turn%2])
                #
                turn_score += roll

        if debug2:
            print("Player", turn%2+1, "turn over")
            print()

    if debug1:
        print(f"Final score: Player 1: {score[0]}, Player 2: {score[1]}")
        print(f"Player {np.argmax(score)+1} wins!")
        print(f"Game took {turn} turns")

    return 2.0*np.mean(score)/turn

# %%
# consider four different end scores .. 50, 100, 200, 500.  For each, plot the average roll vs. N_stop
end_score2 = [50, 100, 200, 500]

# initialize an array to hold the four different arrays of average roll vs. N_stop for the four different end scores.  Each array will have 49 elements, one for each N_stop from 1 to 49
avg_array_sum2 = []

for j in range(4):
    avg_array2 = []
    for nroll in range(1,20):
        sum_avg = 0
        for i in range(nsims):
            avg = game_play2(nroll,end_score2[j])
            sum_avg += avg
            #print(f"Average roll over all turns = {avg}")

        print(f"Average roll over all turns and sims for N_roll = {nroll} is {sum_avg/nsims}")
        avg_array2.append(sum_avg/nsims)

    avg_array_sum2.append(avg_array2)
# Out:
# Average roll over all turns and sims for N_roll = 1 is 3.368467268877315
# Average roll over all turns and sims for N_roll = 2 is 5.627714093402784
# Average roll over all turns and sims for N_roll = 3 is 7.1525505655692
# Average roll over all turns and sims for N_roll = 4 is 8.20285108214697
# Average roll over all turns and sims for N_roll = 5 is 8.782195460711128
# Average roll over all turns and sims for N_roll = 6 is 9.397897319453389
# Average roll over all turns and sims for N_roll = 7 is 9.932369770893647
# Average roll over all turns and sims for N_roll = 8 is 9.762463516927971
# Average roll over all turns and sims for N_roll = 9 is 9.365931200189442
# Average roll over all turns and sims for N_roll = 10 is 9.13713653150104
# Average roll over all turns and sims for N_roll = 11 is 9.393885535496699
# Average roll over all turns and sims for N_roll = 12 is 10.635319093712695
# Average roll over all turns and sims for N_roll = 13 is 11.960920868688005
# Average roll over all turns and sims for N_roll = 14 is 12.802737492005557
# Average roll over all turns and sims for N_roll = 15 is 13.0788815095898
# Average roll over all turns and sims for N_roll = 16 is 13.166894414031354
# Average roll over all turns and sims for N_roll = 17 is 13.039807814707936
# Average roll over all turns and sims for N_roll = 18 is 13.043896433119748
# Average roll over all turns and sims for N_roll = 19 is 12.830477432068438
# Average roll over all turns and sims for N_roll = 1 is 3.3557853375291766
# Average roll over all turns and sims for N_roll = 2 is 5.600769107344823
# Average roll over all turns and sims for N_roll = 3 is 7.065421857831681
# Average roll over all turns and sims for N_roll = 4 is 7.952883651681924
# Average roll over all turns and sims for N_roll = 5 is 8.448416218414602
# Average roll over all turns and sims for N_roll = 6 is 8.66903514104655
# Average roll over all turns and sims for N_roll = 7 is 8.71578275899002
# Average roll over all turns and sims for N_roll = 8 is 8.594013125305045
# Average roll over all turns and sims for N_roll = 9 is 8.532329248616406
# Average roll over all turns and sims for N_roll = 10 is 8.167310569642545
# Average roll over all turns and sims for N_roll = 11 is 7.794348293002024
# Average roll over all turns and sims for N_roll = 12 is 7.466490476554514
# Average roll over all turns and sims for N_roll = 13 is 7.378286538869498
# Average roll over all turns and sims for N_roll = 14 is 7.18887548794676
# Average roll over all turns and sims for N_roll = 15 is 7.015741858527751
# Average roll over all turns and sims for N_roll = 16 is 6.715803333766763
# Average roll over all turns and sims for N_roll = 17 is 6.406873100442452
# Average roll over all turns and sims for N_roll = 18 is 6.002279134644342
# Average roll over all turns and sims for N_roll = 19 is 5.73241224698228
# Average roll over all turns and sims for N_roll = 1 is 3.339148935356276
# Average roll over all turns and sims for N_roll = 2 is 5.583072675194854
# Average roll over all turns and sims for N_roll = 3 is 7.012267304531335
# Average roll over all turns and sims for N_roll = 4 is 7.850836082478651
# Average roll over all turns and sims for N_roll = 5 is 8.260498619992415
# Average roll over all turns and sims for N_roll = 6 is 8.367338605136087
# Average roll over all turns and sims for N_roll = 7 is 8.228639545363775
# Average roll over all turns and sims for N_roll = 8 is 8.006816759236882
# Average roll over all turns and sims for N_roll = 9 is 7.69421162125674
# Average roll over all turns and sims for N_roll = 10 is 7.194455327218219
# Average roll over all turns and sims for N_roll = 11 is 6.809349485942775
# Average roll over all turns and sims for N_roll = 12 is 6.288959220352408
# Average roll over all turns and sims for N_roll = 13 is 5.842888392675817
# Average roll over all turns and sims for N_roll = 14 is 5.45152611458582
# Average roll over all turns and sims for N_roll = 15 is 5.024478272690028
# Average roll over all turns and sims for N_roll = 16 is 4.480701257238954
# Average roll over all turns and sims for N_roll = 17 is 4.1495139726279255
# Average roll over all turns and sims for N_roll = 18 is 3.9445437440595867
# Average roll over all turns and sims for N_roll = 19 is 3.6563830721580577
# Average roll over all turns and sims for N_roll = 1 is 3.3373669118034655
# Average roll over all turns and sims for N_roll = 2 is 5.5687052474390315
# Average roll over all turns and sims for N_roll = 3 is 6.959362381142722
# Average roll over all turns and sims for N_roll = 4 is 7.773989911310275
# Average roll over all turns and sims for N_roll = 5 is 8.120351930928313
# Average roll over all turns and sims for N_roll = 6 is 8.169106450438452
# Average roll over all turns and sims for N_roll = 7 is 7.986675705985949
# Average roll over all turns and sims for N_roll = 8 is 7.644189721934506
# Average roll over all turns and sims for N_roll = 9 is 7.220452205398475
# Average roll over all turns and sims for N_roll = 10 is 6.714608206931191
# Average roll over all turns and sims for N_roll = 11 is 6.230861010402294
# Average roll over all turns and sims for N_roll = 12 is 5.716316308634427
# Average roll over all turns and sims for N_roll = 13 is 5.2111045195422845
# Average roll over all turns and sims for N_roll = 14 is 4.705612302368915
# Average roll over all turns and sims for N_roll = 15 is 4.220335323929074
# Average roll over all turns and sims for N_roll = 16 is 3.8168891170150068
# Average roll over all turns and sims for N_roll = 17 is 3.4113306607172773
# Average roll over all turns and sims for N_roll = 18 is 3.024512719940093
# Average roll over all turns and sims for N_roll = 19 is 2.7034659880728302

# %%
# plot the average roll vs. N_stop for each of the four end scores
fig, ax = plt.subplots(1,1, figsize=(12,12))
for j in range(4):
    ax.plot(range(1,20), avg_array_sum2[j], label=f"End score = {end_score2[j]}")
    ax.set_xlabel("N_roll")
    ax.set_ylabel("Average roll")
    ax.set_title("Average roll vs. N_roll")

# calculate the theoretical average roll per turn for each N_roll and add to the plot
nroll = np.arange(1, 20)
prob = (5/6)**nroll * 4 * nroll

ax.plot(nroll, prob, '.--', label='Theoretical')
ax.legend()

# %%
# Testing the game_play2 function
debug1 = True
debug2 = True
avg = game_play2(3,100)
print(avg)
# Out:
# Turn 1
# Player 1 score: 0
# Player 2 score: 0
# Player 2 turn
# Roll: 6
# Number of rolls: 1
# Player 2 score: 6
# Roll: 6
# Number of rolls: 2
# Player 2 score: 12
# Roll: 4
# Number of rolls: 3
# Player 2 score: 16
# Player 2 turn over
#
# Turn 2
# Player 1 score: 0
# Player 2 score: 16
# Player 1 turn
# Roll: 3
# Number of rolls: 1
# Player 1 score: 3
# Roll: 3
# Number of rolls: 2
# Player 1 score: 6
# Roll: 5
# Number of rolls: 3
# Player 1 score: 11
# Player 1 turn over
#
# Turn 3
# Player 1 score: 11
# Player 2 score: 16
# Player 2 turn
# Roll: 1
# Number of rolls: 1
# Player 2 loses turn
# Player 2 turn over
#
# Turn 4
# Player 1 score: 11
# Player 2 score: 16
# Player 1 turn
# Roll: 4
# Number of rolls: 1
# Player 1 score: 15
# Roll: 3
# Number of rolls: 2
# Player 1 score: 18
# Roll: 1
# Number of rolls: 3
# Player 1 loses turn
# Player 1 turn over
#
# Turn 5
# Player 1 score: 11
# Player 2 score: 16
# Player 2 turn
# Roll: 3
# Number of rolls: 1
# Player 2 score: 19
# Roll: 6
# Number of rolls: 2
# Player 2 score: 25
# Roll: 1
# Number of rolls: 3
# Player 2 loses turn
# Player 2 turn over
#
# Turn 6
# Player 1 score: 11
# Player 2 score: 16
# Player 1 turn
# Roll: 3
# Number of rolls: 1
# Player 1 score: 14
# Roll: 6
# Number of rolls: 2
# Player 1 score: 20
# Roll: 6
# Number of rolls: 3
# Player 1 score: 26
# Player 1 turn over
#
# Turn 7
# Player 1 score: 26
# Player 2 score: 16
# Player 2 turn
# Roll: 4
# Number of rolls: 1
# Player 2 score: 20
# Roll: 6
# Number of rolls: 2
# Player 2 score: 26
# Roll: 3
# Number of rolls: 3
# Player 2 score: 29
# Player 2 turn over
#
# Turn 8
# Player 1 score: 26
# Player 2 score: 29
# Player 1 turn
# Roll: 3
# Number of rolls: 1
# Player 1 score: 29
# Roll: 2
# Number of rolls: 2
# Player 1 score: 31
# Roll: 6
# Number of rolls: 3
# Player 1 score: 37
# Player 1 turn over
#
# Turn 9
# Player 1 score: 37
# Player 2 score: 29
# Player 2 turn
# Roll: 5
# Number of rolls: 1
# Player 2 score: 34
# Roll: 6
# Number of rolls: 2
# Player 2 score: 40
# Roll: 5
# Number of rolls: 3
# Player 2 score: 45
# Player 2 turn over
#
# Turn 10
# Player 1 score: 37
# Player 2 score: 45
# Player 1 turn
# Roll: 2
# Number of rolls: 1
# Player 1 score: 39
# Roll: 3
# Number of rolls: 2
# Player 1 score: 42
# Roll: 5
# Number of rolls: 3
# Player 1 score: 47
# Player 1 turn over
#
# Turn 11
# Player 1 score: 47
# Player 2 score: 45
# Player 2 turn
# Roll: 6
# Number of rolls: 1
# Player 2 score: 51
# Roll: 6
# Number of rolls: 2
# Player 2 score: 57
# Roll: 6
# Number of rolls: 3
# Player 2 score: 63
# Player 2 turn over
#
# Turn 12
# Player 1 score: 47
# Player 2 score: 63
# Player 1 turn
# Roll: 3
# Number of rolls: 1
# Player 1 score: 50
# Roll: 2
# Number of rolls: 2
# Player 1 score: 52
# Roll: 5
# Number of rolls: 3
# Player 1 score: 57
# Player 1 turn over
#
# Turn 13
# Player 1 score: 57
# Player 2 score: 63
# Player 2 turn
# Roll: 2
# Number of rolls: 1
# Player 2 score: 65
# Roll: 2
# Number of rolls: 2
# Player 2 score: 67
# Roll: 4
# Number of rolls: 3
# Player 2 score: 71
# Player 2 turn over
#
# Turn 14
# Player 1 score: 57
# Player 2 score: 71
# Player 1 turn
# Roll: 3
# Number of rolls: 1
# Player 1 score: 60
# Roll: 5
# Number of rolls: 2
# Player 1 score: 65
# Roll: 3
# Number of rolls: 3
# Player 1 score: 68
# Player 1 turn over
#
# Turn 15
# Player 1 score: 68
# Player 2 score: 71
# Player 2 turn
# Roll: 6
# Number of rolls: 1
# Player 2 score: 77
# Roll: 5
# Number of rolls: 2
# Player 2 score: 82
# Roll: 2
# Number of rolls: 3
# Player 2 score: 84
# Player 2 turn over
#
# Turn 16
# Player 1 score: 68
# Player 2 score: 84
# Player 1 turn
# Roll: 1
# Number of rolls: 1
# Player 1 loses turn
# Player 1 turn over
#
# Turn 17
# Player 1 score: 68
# Player 2 score: 84
# Player 2 turn
# Roll: 5
# Number of rolls: 1
# Player 2 score: 89
# Roll: 4
# Number of rolls: 2
# Player 2 score: 93
# Roll: 6
# Number of rolls: 3
# Player 2 score: 99
# Player 2 turn over
#
# Turn 18
# Player 1 score: 68
# Player 2 score: 99
# Player 1 turn
# Roll: 1
# Number of rolls: 1
# Player 1 loses turn
# Player 1 turn over
#
# Turn 19
# Player 1 score: 68
# Player 2 score: 99
# Player 2 turn
# Roll: 3
# Number of rolls: 1
# Player 2 score: 102
# Player 2 turn over
#
# Final score: Player 1: 68, Player 2: 102
# Player 2 wins!
# Game took 19 turns
# 8.947368421052632
