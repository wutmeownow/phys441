# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# i = 89
# i = 1186060307891929990
# i = 12000700000025339936491

x = []
y = []

for i in range(196):
    i_orig = i
    x.append(i_orig)
    count = 0

    #print (i)
    while True:
        count = count + 1
        i_reversed = int(str(i)[::-1])
        i = i + i_reversed
        #print (i)
        if (str(i) == str(i)[::-1]):
            #print ('----')
            break
        
    print ('Done: ',i_orig,i,count)
    y.append(count)
    
plt.plot(x,y,'.')
# Out:
# Done:  0 0 1
# Done:  1 2 1
# Done:  2 4 1
# Done:  3 6 1
# Done:  4 8 1
# Done:  5 11 2
# Done:  6 33 2
# Done:  7 55 2
# Done:  8 77 2
# Done:  9 99 2
# Done:  10 11 1
# Done:  11 22 1
# Done:  12 33 1
# Done:  13 44 1
# Done:  14 55 1
# Done:  15 66 1
# Done:  16 77 1
# Done:  17 88 1
# Done:  18 99 1
# Done:  19 121 2
# Done:  20 22 1
# Done:  21 33 1
# Done:  22 44 1
# Done:  23 55 1
# Done:  24 66 1
# Done:  25 77 1
# Done:  26 88 1
# Done:  27 99 1
# Done:  28 121 2
# Done:  29 121 1
# Done:  30 33 1
# Done:  31 44 1
# Done:  32 55 1
# Done:  33 66 1
# Done:  34 77 1
# Done:  35 88 1
# Done:  36 99 1
# Done:  37 121 2
# Done:  38 121 1
# Done:  39 363 2
# Done:  40 44 1
# Done:  41 55 1
# Done:  42 66 1
# Done:  43 77 1
# Done:  44 88 1
# Done:  45 99 1
# Done:  46 121 2
# Done:  47 121 1
# Done:  48 363 2
# Done:  49 484 2
# Done:  50 55 1
# Done:  51 66 1
# Done:  52 77 1
# Done:  53 88 1
# Done:  54 99 1
# Done:  55 121 2
# Done:  56 121 1
# Done:  57 363 2
# ...

# %% [markdown]
# Here is an equation:
#
# \begin{equation}
# x = 1
# \end{equation}

# %% [markdown]
# Here is another set of equations:
#
# \begin{eqnarray}
# x' &=& &x \sin\phi &+& z \cos\phi \\
# z' &=& - &x \cos\phi &+& z \sin\phi \\
# \end{eqnarray}
