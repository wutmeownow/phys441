# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
N = 50
tau = 0.02
L = 1.0
h = L/N
c = 1.0

print('Time to move one grid spacing is ',h/c)

coeff = -c*tau/(2.0*h)

print ('Wave circles system in ', L/(c*tau),' steps.')

print ('Coefficient = ',coeff)

print ('Lax stability criterion tau_max = ', h/c)

nStep = 500
# Out:
# Time to move one grid spacing is  0.02
# Wave circles system in  52.631578947368425  steps.
# Coefficient =  -0.475
# Lax stability criterion tau_max =  0.02

# %%
#
# Initial conditions
#
sigma = 0.1
k_wave = np.pi/sigma
x = np.arange(N)*h - L/2.0

a = np.empty(N)
for i in range(N):
    a[i]=np.cos(k_wave*x[i]) * np.exp(-x[i]**2/(2.0*sigma**2))
    
ip = np.arange(N) + 1
ip[N-1] = 0
im = np.arange(N) - 1
im[0] = N-1

# %%
iplot = 1
nplots = 50

# %%
aplot = np.empty((N,nplots))
tplot = np.empty(nplots)
aplot[:,0] = np.copy(a)
tplot[0] = 0
plotStep = nStep/nplots + 1

for istep in range(nStep):
    
    a[:] = 0.5*(a[ip]+a[im]) + coeff*(a[ip]-a[im]) # Lax method ... replace a_i^n with average of +/- values
    
    if (istep+1) % plotStep < 1:
        aplot[:,iplot] = np.copy(a)
        tplot[iplot] = (istep+1)*tau
        iplot += 1
        print (istep,' out of ',nStep,' steps completed')
# Out:
# 10  out of  500  steps completed
# 21  out of  500  steps completed
# 32  out of  500  steps completed
# 43  out of  500  steps completed
# 54  out of  500  steps completed
# 65  out of  500  steps completed
# 76  out of  500  steps completed
# 87  out of  500  steps completed
# 98  out of  500  steps completed
# 109  out of  500  steps completed
# 120  out of  500  steps completed
# 131  out of  500  steps completed
# 142  out of  500  steps completed
# 153  out of  500  steps completed
# 164  out of  500  steps completed
# 175  out of  500  steps completed
# 186  out of  500  steps completed
# 197  out of  500  steps completed
# 208  out of  500  steps completed
# 219  out of  500  steps completed
# 230  out of  500  steps completed
# 241  out of  500  steps completed
# 252  out of  500  steps completed
# 263  out of  500  steps completed
# 274  out of  500  steps completed
# 285  out of  500  steps completed
# 296  out of  500  steps completed
# 307  out of  500  steps completed
# 318  out of  500  steps completed
# 329  out of  500  steps completed
# 340  out of  500  steps completed
# 351  out of  500  steps completed
# 362  out of  500  steps completed
# 373  out of  500  steps completed
# 384  out of  500  steps completed
# 395  out of  500  steps completed
# 406  out of  500  steps completed
# 417  out of  500  steps completed
# 428  out of  500  steps completed
# 439  out of  500  steps completed
# 450  out of  500  steps completed
# 461  out of  500  steps completed
# 472  out of  500  steps completed
# 483  out of  500  steps completed
# 494  out of  500  steps completed

# %%
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D

# %%
fig = plt.figure()
ax = fig.gca(projection = '3d')
Tp, Xp = np.meshgrid(tplot[0:iplot], x)
ax.plot_surface(Tp,Xp,aplot[:,0:iplot],rstride=1,cstride=1,cmap=cm.gray)
ax.view_init(elev=30.,azim=190.)
ax.set_xlabel('Time')
ax.set_ylabel('Position')
ax.set_zlabel('Amplitude')
plt.show()

# %%
plt.plot(x,aplot[:,0],'-',x,a,'--')
plt.legend(['Initial ','Final'])
plt.xlabel('x')
plt.ylabel('a(x,t)')
plt.show()
