# %%
from ROOT import TCanvas
from ROOT import TGraph, TGraphErrors
from ROOT import gStyle
from array import array
import numpy as np
import math

xcanvas = 1000
ycanvas = 800

c1 = TCanvas( 'c1', 'Pendulum Amplitude vs. Time', 0, 0, xcanvas, ycanvas )
c1.SetGridx()
c1.SetGridy()
c1.GetFrame().SetFillColor( 21 )
c1.GetFrame().SetBorderMode(-1 )
c1.GetFrame().SetBorderSize( 5 )
c2 = TCanvas( 'c2', 'Pendulum Period vs. Time', 0, 0, xcanvas, ycanvas )
c2.SetGridx()
c2.SetGridy()
c2.GetFrame().SetFillColor( 21 )
c2.GetFrame().SetBorderMode(-1 )
c2.GetFrame().SetBorderSize( 5 )
# Out:
# Welcome to JupyROOT 6.12/06

# %%
# Initial Conditions
length = 9.807
method = 2 # 1 = Euler, 2 = Verlet
theta0 = 45
theta = theta0*math.pi/180.0
omega = 0

# Other constants
gravity = 9.807 # gravitional acceleration
g_over_L = gravity/length
time = 0.0
irev = 0.0
tau = 0.001 

Pi = math.pi

# %%
Cd = 0.50
area = Pi*0.10*0.10
mass = 1.0
rho = 1.2
air_const = 0.5*Cd*rho*area/mass

norm_omega = sqrt(omega*omega)

# %%
accel = -g_over_L*math.sin(theta)-air_const
theta_old = theta - omega*tau + 0.5*tau*tau*accel
print (accel, theta, theta_old)
# Out:
# -0.7071067811865475 0.7853981633974483 0.7853978098440577

# %%
tau = 0.001 # timestep in seconds
nStep = 4000000 # number of steps

t_plot = array('d')
th_plot = array('d')
period = array('d')
trev = array('d')

# %%
for iStep in range(1,nStep+1):
    t_plot.append(time)
    th_plot.append(theta*180/Pi)
    time = time + tau
    accel = -g_over_L*math.sin(theta)
    
    if (method == 1):
        theta_old = theta
        theta = theta + tau*omega
        omega = omega + tau*accel
    else:
        theta_new = 2*theta - theta_old + tau*tau*accel
        theta_old = theta
        theta = theta_new
    
    if (theta*theta_old < 0):
        print ("Turning point at time t = %f" % time)
        if (irev == 0):
            time_old = time
        else:
            period.append(2*(time - time_old))
            trev.append(time)
            time_old = time
        irev = irev + 1
# Out:
# Turning point at time t = 1.634000
# Turning point at time t = 4.901000
# Turning point at time t = 8.168000
# Turning point at time t = 11.436000
# Turning point at time t = 14.703000
# Turning point at time t = 17.970000
# Turning point at time t = 21.237000
# Turning point at time t = 24.504000
# Turning point at time t = 27.771000
# Turning point at time t = 31.039000
# Turning point at time t = 34.306000
# Turning point at time t = 37.573000
# Turning point at time t = 40.840000
# Turning point at time t = 44.107000
# Turning point at time t = 47.375000
# Turning point at time t = 50.642000
# Turning point at time t = 53.909000
# Turning point at time t = 57.176000
# Turning point at time t = 60.443000
# Turning point at time t = 63.710000
# Turning point at time t = 66.978000
# Turning point at time t = 70.245000
# Turning point at time t = 73.512000
# Turning point at time t = 76.779000
# Turning point at time t = 80.046000
# Turning point at time t = 83.313000
# Turning point at time t = 86.581000
# Turning point at time t = 89.848000
# Turning point at time t = 93.115000
# Turning point at time t = 96.382000
# Turning point at time t = 99.649000
# Turning point at time t = 102.916000
# Turning point at time t = 106.184000
# Turning point at time t = 109.451000
# Turning point at time t = 112.718000
# Turning point at time t = 115.985000
# Turning point at time t = 119.252000
# Turning point at time t = 122.519000
# Turning point at time t = 125.787000
# Turning point at time t = 129.054000
# Turning point at time t = 132.321000
# Turning point at time t = 135.588000
# Turning point at time t = 138.855000
# Turning point at time t = 142.123000
# Turning point at time t = 145.390000
# Turning point at time t = 148.657000
# Turning point at time t = 151.924000
# Turning point at time t = 155.191000
# Turning point at time t = 158.458000
# Turning point at time t = 161.726000
# Turning point at time t = 164.993000
# Turning point at time t = 168.260000
# Turning point at time t = 171.527000
# Turning point at time t = 174.794000
# Turning point at time t = 178.061000
# Turning point at time t = 181.329000
# Turning point at time t = 184.596000
# Turning point at time t = 187.863000
# Turning point at time t = 191.130000
# Turning point at time t = 194.397000
# Turning point at time t = 197.664000
# Turning point at time t = 200.932000
# Turning point at time t = 204.199000
# Turning point at time t = 207.466000
# Turning point at time t = 210.733000
# Turning point at time t = 214.000000
# Turning point at time t = 217.267000
# Turning point at time t = 220.535000
# Turning point at time t = 223.802000
# Turning point at time t = 227.069000
# Turning point at time t = 230.336000
# Turning point at time t = 233.603000
# Turning point at time t = 236.871000
# Turning point at time t = 240.138000
# Turning point at time t = 243.405000
# Turning point at time t = 246.672000
# Turning point at time t = 249.939000
# Turning point at time t = 253.206000
# Turning point at time t = 256.474000
# Turning point at time t = 259.741000
# Turning point at time t = 263.008000
# Turning point at time t = 266.275000
# Turning point at time t = 269.542000
# Turning point at time t = 272.809000
# Turning point at time t = 276.077000
# Turning point at time t = 279.344000
# Turning point at time t = 282.611000
# Turning point at time t = 285.878000
# Turning point at time t = 289.145000
# Turning point at time t = 292.412000
# Turning point at time t = 295.680000
# Turning point at time t = 298.947000
# Turning point at time t = 302.214000
# Turning point at time t = 305.481000
# Turning point at time t = 308.748000
# Turning point at time t = 312.015000
# Turning point at time t = 315.283000
# Turning point at time t = 318.550000
# Turning point at time t = 321.817000
# Turning point at time t = 325.084000
# Turning point at time t = 328.351000
# Turning point at time t = 331.619000
# Turning point at time t = 334.886000
# Turning point at time t = 338.153000
# Turning point at time t = 341.420000
# Turning point at time t = 344.687000
# Turning point at time t = 347.954000
# Turning point at time t = 351.222000
# Turning point at time t = 354.489000
# Turning point at time t = 357.756000
# Turning point at time t = 361.023000
# Turning point at time t = 364.290000
# Turning point at time t = 367.557000
# Turning point at time t = 370.825000
# Turning point at time t = 374.092000
# Turning point at time t = 377.359000
# Turning point at time t = 380.626000
# Turning point at time t = 383.893000
# Turning point at time t = 387.160000
# Turning point at time t = 390.428000
# Turning point at time t = 393.695000
# Turning point at time t = 396.962000
# Turning point at time t = 400.229000
# Turning point at time t = 403.496000
# Turning point at time t = 406.763000
# Turning point at time t = 410.031000
# Turning point at time t = 413.298000
# Turning point at time t = 416.565000
# Turning point at time t = 419.832000
# Turning point at time t = 423.099000
# Turning point at time t = 426.367000
# Turning point at time t = 429.634000
# Turning point at time t = 432.901000
# Turning point at time t = 436.168000
# Turning point at time t = 439.435000
# Turning point at time t = 442.702000
# Turning point at time t = 445.970000
# Turning point at time t = 449.237000
# Turning point at time t = 452.504000
# Turning point at time t = 455.771000
# Turning point at time t = 459.038000
# Turning point at time t = 462.305000
# Turning point at time t = 465.573000
# Turning point at time t = 468.840000
# Turning point at time t = 472.107000
# Turning point at time t = 475.374000
# Turning point at time t = 478.641000
# Turning point at time t = 481.908000
# Turning point at time t = 485.176000
# Turning point at time t = 488.443000
# Turning point at time t = 491.710000
# Turning point at time t = 494.977000
# Turning point at time t = 498.244000
# Turning point at time t = 501.511000
# Turning point at time t = 504.779000
# Turning point at time t = 508.046000
# Turning point at time t = 511.313000
# Turning point at time t = 514.580000
# Turning point at time t = 517.847000
# Turning point at time t = 521.115000
# Turning point at time t = 524.382000
# Turning point at time t = 527.649000
# Turning point at time t = 530.916000
# Turning point at time t = 534.183000
# Turning point at time t = 537.450000
# Turning point at time t = 540.718000
# Turning point at time t = 543.985000
# Turning point at time t = 547.252000
# Turning point at time t = 550.519000
# Turning point at time t = 553.786000
# Turning point at time t = 557.053000
# Turning point at time t = 560.321000
# Turning point at time t = 563.588000
# Turning point at time t = 566.855000
# Turning point at time t = 570.122000
# Turning point at time t = 573.389000
# Turning point at time t = 576.656000
# Turning point at time t = 579.924000
# Turning point at time t = 583.191000
# Turning point at time t = 586.458000
# Turning point at time t = 589.725000
# Turning point at time t = 592.992000
# Turning point at time t = 596.259000
# Turning point at time t = 599.527000
# Turning point at time t = 602.794000
# Turning point at time t = 606.061000
# Turning point at time t = 609.328000
# Turning point at time t = 612.595000
# Turning point at time t = 615.863000
# Turning point at time t = 619.130000
# Turning point at time t = 622.397000
# Turning point at time t = 625.664000
# Turning point at time t = 628.931000
# Turning point at time t = 632.198000
# Turning point at time t = 635.466000
# Turning point at time t = 638.733000
# Turning point at time t = 642.000000
# Turning point at time t = 645.267000
# Turning point at time t = 648.534000
# Turning point at time t = 651.801000
# Turning point at time t = 655.069000
# Turning point at time t = 658.336000
# Turning point at time t = 661.603000
# Turning point at time t = 664.870000
# Turning point at time t = 668.137000
# Turning point at time t = 671.404000
# Turning point at time t = 674.672000
# Turning point at time t = 677.939000
# Turning point at time t = 681.206000
# Turning point at time t = 684.473000
# Turning point at time t = 687.740000
# Turning point at time t = 691.007000
# Turning point at time t = 694.275000
# Turning point at time t = 697.542000
# Turning point at time t = 700.809000
# Turning point at time t = 704.076000
# Turning point at time t = 707.343000
# Turning point at time t = 710.611000
# Turning point at time t = 713.878000
# Turning point at time t = 717.145000
# Turning point at time t = 720.412000
# Turning point at time t = 723.679000
# Turning point at time t = 726.946000
# Turning point at time t = 730.214000
# Turning point at time t = 733.481000
# Turning point at time t = 736.748000
# Turning point at time t = 740.015000
# Turning point at time t = 743.282000
# Turning point at time t = 746.549000
# Turning point at time t = 749.817000
# Turning point at time t = 753.084000
# Turning point at time t = 756.351000
# Turning point at time t = 759.618000
# Turning point at time t = 762.885000
# Turning point at time t = 766.152000
# Turning point at time t = 769.420000
# Turning point at time t = 772.687000
# Turning point at time t = 775.954000
# Turning point at time t = 779.221000
# Turning point at time t = 782.488000
# Turning point at time t = 785.755000
# Turning point at time t = 789.023000
# Turning point at time t = 792.290000
# Turning point at time t = 795.557000
# Turning point at time t = 798.824000
# Turning point at time t = 802.091000
# Turning point at time t = 805.359000
# Turning point at time t = 808.626000
# Turning point at time t = 811.893000
# Turning point at time t = 815.160000
# Turning point at time t = 818.427000
# Turning point at time t = 821.694000
# Turning point at time t = 824.962000
# Turning point at time t = 828.229000
# Turning point at time t = 831.496000
# Turning point at time t = 834.763000
# Turning point at time t = 838.030000
# Turning point at time t = 841.297000
# Turning point at time t = 844.565000
# Turning point at time t = 847.832000
# Turning point at time t = 851.099000
# Turning point at time t = 854.366000
# Turning point at time t = 857.633000
# Turning point at time t = 860.900000
# Turning point at time t = 864.168000
# Turning point at time t = 867.435000
# Turning point at time t = 870.702000
# Turning point at time t = 873.969000
# Turning point at time t = 877.236000
# Turning point at time t = 880.503000
# Turning point at time t = 883.771000
# Turning point at time t = 887.038000
# Turning point at time t = 890.305000
# Turning point at time t = 893.572000
# Turning point at time t = 896.839000
# Turning point at time t = 900.107000
# Turning point at time t = 903.374000
# Turning point at time t = 906.641000
# Turning point at time t = 909.908000
# Turning point at time t = 913.175000
# Turning point at time t = 916.442000
# Turning point at time t = 919.710000
# Turning point at time t = 922.977000
# Turning point at time t = 926.244000
# Turning point at time t = 929.511000
# Turning point at time t = 932.778000
# Turning point at time t = 936.045000
# Turning point at time t = 939.313000
# Turning point at time t = 942.580000
# Turning point at time t = 945.847000
# Turning point at time t = 949.114000
# Turning point at time t = 952.381000
# Turning point at time t = 955.648000
# Turning point at time t = 958.916000
# Turning point at time t = 962.183000
# Turning point at time t = 965.450000
# Turning point at time t = 968.717000
# Turning point at time t = 971.984000
# Turning point at time t = 975.251000
# Turning point at time t = 978.519000
# Turning point at time t = 981.786000
# Turning point at time t = 985.053000
# Turning point at time t = 988.320000
# Turning point at time t = 991.587000
# Turning point at time t = 994.855000
# Turning point at time t = 998.122000
# Turning point at time t = 1001.389000
# Turning point at time t = 1004.656000
# Turning point at time t = 1007.923000
# Turning point at time t = 1011.190000
# Turning point at time t = 1014.458000
# Turning point at time t = 1017.725000
# Turning point at time t = 1020.992000
# Turning point at time t = 1024.259000
# Turning point at time t = 1027.526000
# Turning point at time t = 1030.793000
# Turning point at time t = 1034.061000
# Turning point at time t = 1037.328000
# Turning point at time t = 1040.595000
# Turning point at time t = 1043.862000
# Turning point at time t = 1047.129000
# Turning point at time t = 1050.396000
# Turning point at time t = 1053.664000
# Turning point at time t = 1056.931000
# Turning point at time t = 1060.198000
# Turning point at time t = 1063.465000
# Turning point at time t = 1066.732000
# Turning point at time t = 1069.999000
# Turning point at time t = 1073.267000
# Turning point at time t = 1076.534000
# Turning point at time t = 1079.801000
# Turning point at time t = 1083.068000
# Turning point at time t = 1086.335000
# Turning point at time t = 1089.603000
# Turning point at time t = 1092.870000
# Turning point at time t = 1096.137000
# Turning point at time t = 1099.404000
# Turning point at time t = 1102.671000
# Turning point at time t = 1105.938000
# Turning point at time t = 1109.206000
# Turning point at time t = 1112.473000
# Turning point at time t = 1115.740000
# Turning point at time t = 1119.007000
# Turning point at time t = 1122.274000
# Turning point at time t = 1125.541000
# Turning point at time t = 1128.809000
# Turning point at time t = 1132.076000
# Turning point at time t = 1135.343000
# Turning point at time t = 1138.610000
# Turning point at time t = 1141.877000
# Turning point at time t = 1145.144000
# Turning point at time t = 1148.412000
# Turning point at time t = 1151.679000
# Turning point at time t = 1154.946000
# Turning point at time t = 1158.213000
# Turning point at time t = 1161.480000
# Turning point at time t = 1164.747000
# Turning point at time t = 1168.015000
# Turning point at time t = 1171.282000
# Turning point at time t = 1174.549000
# Turning point at time t = 1177.816000
# Turning point at time t = 1181.083000
# Turning point at time t = 1184.351000
# Turning point at time t = 1187.618000
# Turning point at time t = 1190.885000
# Turning point at time t = 1194.152000
# Turning point at time t = 1197.419000
# Turning point at time t = 1200.686000
# Turning point at time t = 1203.954000
# Turning point at time t = 1207.221000
# Turning point at time t = 1210.488000
# Turning point at time t = 1213.755000
# Turning point at time t = 1217.022000
# Turning point at time t = 1220.289000
# Turning point at time t = 1223.557000
# Turning point at time t = 1226.824000
# Turning point at time t = 1230.091000
# Turning point at time t = 1233.358000
# Turning point at time t = 1236.625000
# Turning point at time t = 1239.892000
# Turning point at time t = 1243.160000
# Turning point at time t = 1246.427000
# Turning point at time t = 1249.694000
# Turning point at time t = 1252.961000
# Turning point at time t = 1256.228000
# Turning point at time t = 1259.495000
# Turning point at time t = 1262.763000
# Turning point at time t = 1266.030000
# Turning point at time t = 1269.297000
# Turning point at time t = 1272.564000
# Turning point at time t = 1275.831000
# Turning point at time t = 1279.099000
# Turning point at time t = 1282.366000
# Turning point at time t = 1285.633000
# Turning point at time t = 1288.900000
# Turning point at time t = 1292.167000
# Turning point at time t = 1295.434000
# Turning point at time t = 1298.702000
# Turning point at time t = 1301.969000
# Turning point at time t = 1305.236000
# Turning point at time t = 1308.503000
# Turning point at time t = 1311.770000
# Turning point at time t = 1315.037000
# Turning point at time t = 1318.305000
# Turning point at time t = 1321.572000
# Turning point at time t = 1324.839000
# Turning point at time t = 1328.106000
# Turning point at time t = 1331.373000
# Turning point at time t = 1334.640000
# Turning point at time t = 1337.908000
# Turning point at time t = 1341.175000
# Turning point at time t = 1344.442000
# Turning point at time t = 1347.709000
# Turning point at time t = 1350.976000
# Turning point at time t = 1354.243000
# Turning point at time t = 1357.511000
# Turning point at time t = 1360.778000
# Turning point at time t = 1364.045000
# Turning point at time t = 1367.312000
# Turning point at time t = 1370.579000
# Turning point at time t = 1373.847000
# Turning point at time t = 1377.114000
# Turning point at time t = 1380.381000
# Turning point at time t = 1383.648000
# Turning point at time t = 1386.915000
# Turning point at time t = 1390.182000
# Turning point at time t = 1393.450000
# Turning point at time t = 1396.717000
# Turning point at time t = 1399.984000
# Turning point at time t = 1403.251000
# Turning point at time t = 1406.518000
# Turning point at time t = 1409.785000
# Turning point at time t = 1413.053000
# Turning point at time t = 1416.320000
# Turning point at time t = 1419.587000
# Turning point at time t = 1422.854000
# Turning point at time t = 1426.121000
# Turning point at time t = 1429.388000
# Turning point at time t = 1432.656000
# Turning point at time t = 1435.923000
# Turning point at time t = 1439.190000
# Turning point at time t = 1442.457000
# Turning point at time t = 1445.724000
# Turning point at time t = 1448.991000
# Turning point at time t = 1452.259000
# Turning point at time t = 1455.526000
# Turning point at time t = 1458.793000
# Turning point at time t = 1462.060000
# Turning point at time t = 1465.327000
# Turning point at time t = 1468.595000
# Turning point at time t = 1471.862000
# Turning point at time t = 1475.129000
# Turning point at time t = 1478.396000
# Turning point at time t = 1481.663000
# Turning point at time t = 1484.930000
# Turning point at time t = 1488.198000
# Turning point at time t = 1491.465000
# Turning point at time t = 1494.732000
# Turning point at time t = 1497.999000
# Turning point at time t = 1501.266000
# Turning point at time t = 1504.533000
# Turning point at time t = 1507.801000
# Turning point at time t = 1511.068000
# Turning point at time t = 1514.335000
# Turning point at time t = 1517.602000
# Turning point at time t = 1520.869000
# Turning point at time t = 1524.136000
# Turning point at time t = 1527.404000
# Turning point at time t = 1530.671000
# Turning point at time t = 1533.938000
# Turning point at time t = 1537.205000
# Turning point at time t = 1540.472000
# Turning point at time t = 1543.740000
# Turning point at time t = 1547.007000
# Turning point at time t = 1550.274000
# Turning point at time t = 1553.541000
# Turning point at time t = 1556.808000
# Turning point at time t = 1560.075000
# Turning point at time t = 1563.343000
# Turning point at time t = 1566.610000
# Turning point at time t = 1569.877000
# Turning point at time t = 1573.144000
# Turning point at time t = 1576.411000
# Turning point at time t = 1579.678000
# Turning point at time t = 1582.946000
# Turning point at time t = 1586.213000
# Turning point at time t = 1589.480000
# Turning point at time t = 1592.747000
# Turning point at time t = 1596.014000
# Turning point at time t = 1599.281000
# Turning point at time t = 1602.549000
# Turning point at time t = 1605.816000
# Turning point at time t = 1609.083000
# Turning point at time t = 1612.350000
# Turning point at time t = 1615.617000
# Turning point at time t = 1618.884000
# Turning point at time t = 1622.152000
# Turning point at time t = 1625.419000
# Turning point at time t = 1628.686000
# Turning point at time t = 1631.953000
# Turning point at time t = 1635.220000
# Turning point at time t = 1638.488000
# Turning point at time t = 1641.755000
# Turning point at time t = 1645.022000
# Turning point at time t = 1648.289000
# Turning point at time t = 1651.556000
# Turning point at time t = 1654.823000
# Turning point at time t = 1658.091000
# Turning point at time t = 1661.358000
# Turning point at time t = 1664.625000
# Turning point at time t = 1667.892000
# Turning point at time t = 1671.159000
# Turning point at time t = 1674.426000
# Turning point at time t = 1677.694000
# Turning point at time t = 1680.961000
# Turning point at time t = 1684.228000
# Turning point at time t = 1687.495000
# Turning point at time t = 1690.762000
# Turning point at time t = 1694.029000
# Turning point at time t = 1697.297000
# Turning point at time t = 1700.564000
# Turning point at time t = 1703.831000
# Turning point at time t = 1707.098000
# Turning point at time t = 1710.365000
# Turning point at time t = 1713.632000
# Turning point at time t = 1716.900000
# Turning point at time t = 1720.167000
# Turning point at time t = 1723.434000
# Turning point at time t = 1726.701000
# Turning point at time t = 1729.968000
# Turning point at time t = 1733.236000
# Turning point at time t = 1736.503000
# Turning point at time t = 1739.770000
# Turning point at time t = 1743.037000
# Turning point at time t = 1746.304000
# Turning point at time t = 1749.571000
# Turning point at time t = 1752.839000
# Turning point at time t = 1756.106000
# Turning point at time t = 1759.373000
# Turning point at time t = 1762.640000
# Turning point at time t = 1765.907000
# Turning point at time t = 1769.174000
# Turning point at time t = 1772.442000
# Turning point at time t = 1775.709000
# Turning point at time t = 1778.976000
# Turning point at time t = 1782.243000
# Turning point at time t = 1785.510000
# Turning point at time t = 1788.777000
# Turning point at time t = 1792.045000
# Turning point at time t = 1795.312000
# Turning point at time t = 1798.579000
# Turning point at time t = 1801.846000
# Turning point at time t = 1805.113000
# Turning point at time t = 1808.380000
# Turning point at time t = 1811.648000
# Turning point at time t = 1814.915000
# Turning point at time t = 1818.182000
# Turning point at time t = 1821.449000
# Turning point at time t = 1824.716000
# Turning point at time t = 1827.984000
# Turning point at time t = 1831.251000
# Turning point at time t = 1834.518000
# Turning point at time t = 1837.785000
# Turning point at time t = 1841.052000
# Turning point at time t = 1844.319000
# Turning point at time t = 1847.587000
# Turning point at time t = 1850.854000
# Turning point at time t = 1854.121000
# Turning point at time t = 1857.388000
# Turning point at time t = 1860.655000
# Turning point at time t = 1863.922000
# Turning point at time t = 1867.190000
# Turning point at time t = 1870.457000
# Turning point at time t = 1873.724000
# Turning point at time t = 1876.991000
# Turning point at time t = 1880.258000
# Turning point at time t = 1883.525000
# Turning point at time t = 1886.793000
# Turning point at time t = 1890.060000
# Turning point at time t = 1893.327000
# Turning point at time t = 1896.594000
# Turning point at time t = 1899.861000
# Turning point at time t = 1903.128000
# Turning point at time t = 1906.396000
# Turning point at time t = 1909.663000
# Turning point at time t = 1912.930000
# Turning point at time t = 1916.197000
# Turning point at time t = 1919.464000
# Turning point at time t = 1922.732000
# Turning point at time t = 1925.999000
# Turning point at time t = 1929.266000
# Turning point at time t = 1932.533000
# Turning point at time t = 1935.800000
# Turning point at time t = 1939.067000
# Turning point at time t = 1942.335000
# Turning point at time t = 1945.602000
# Turning point at time t = 1948.869000
# Turning point at time t = 1952.136000
# Turning point at time t = 1955.403000
# Turning point at time t = 1958.670000
# Turning point at time t = 1961.938000
# Turning point at time t = 1965.205000
# Turning point at time t = 1968.472000
# Turning point at time t = 1971.739000
# Turning point at time t = 1975.006000
# Turning point at time t = 1978.273000
# Turning point at time t = 1981.541000
# Turning point at time t = 1984.808000
# Turning point at time t = 1988.075000
# Turning point at time t = 1991.342000
# Turning point at time t = 1994.609000
# Turning point at time t = 1997.876000
# Turning point at time t = 2001.144000
# Turning point at time t = 2004.411000
# Turning point at time t = 2007.678000
# Turning point at time t = 2010.945000
# Turning point at time t = 2014.212000
# Turning point at time t = 2017.480000
# Turning point at time t = 2020.747000
# Turning point at time t = 2024.014000
# Turning point at time t = 2027.281000
# Turning point at time t = 2030.548000
# Turning point at time t = 2033.815000
# Turning point at time t = 2037.083000
# Turning point at time t = 2040.350000
# Turning point at time t = 2043.617000
# Turning point at time t = 2046.884000
# Turning point at time t = 2050.151000
# Turning point at time t = 2053.418000
# Turning point at time t = 2056.686000
# Turning point at time t = 2059.953000
# Turning point at time t = 2063.220000
# Turning point at time t = 2066.487000
# Turning point at time t = 2069.754000
# Turning point at time t = 2073.021000
# Turning point at time t = 2076.289000
# Turning point at time t = 2079.556000
# Turning point at time t = 2082.823000
# Turning point at time t = 2086.090000
# Turning point at time t = 2089.357000
# Turning point at time t = 2092.624000
# Turning point at time t = 2095.892000
# Turning point at time t = 2099.159000
# Turning point at time t = 2102.426000
# Turning point at time t = 2105.693000
# Turning point at time t = 2108.960000
# Turning point at time t = 2112.228000
# Turning point at time t = 2115.495000
# Turning point at time t = 2118.762000
# Turning point at time t = 2122.029000
# Turning point at time t = 2125.296000
# Turning point at time t = 2128.563000
# Turning point at time t = 2131.831000
# Turning point at time t = 2135.098000
# Turning point at time t = 2138.365000
# Turning point at time t = 2141.632000
# Turning point at time t = 2144.899000
# Turning point at time t = 2148.166000
# Turning point at time t = 2151.434000
# Turning point at time t = 2154.701000
# Turning point at time t = 2157.968000
# Turning point at time t = 2161.235000
# Turning point at time t = 2164.502000
# Turning point at time t = 2167.769000
# Turning point at time t = 2171.037000
# Turning point at time t = 2174.304000
# Turning point at time t = 2177.571000
# Turning point at time t = 2180.838000
# Turning point at time t = 2184.105000
# Turning point at time t = 2187.372000
# Turning point at time t = 2190.640000
# Turning point at time t = 2193.907000
# Turning point at time t = 2197.174000
# Turning point at time t = 2200.441000
# Turning point at time t = 2203.708000
# Turning point at time t = 2206.976000
# Turning point at time t = 2210.243000
# Turning point at time t = 2213.510000
# Turning point at time t = 2216.777000
# Turning point at time t = 2220.044000
# Turning point at time t = 2223.311000
# Turning point at time t = 2226.579000
# Turning point at time t = 2229.846000
# Turning point at time t = 2233.113000
# Turning point at time t = 2236.380000
# Turning point at time t = 2239.647000
# Turning point at time t = 2242.914000
# Turning point at time t = 2246.182000
# Turning point at time t = 2249.449000
# Turning point at time t = 2252.716000
# Turning point at time t = 2255.983000
# Turning point at time t = 2259.250000
# Turning point at time t = 2262.517000
# Turning point at time t = 2265.785000
# Turning point at time t = 2269.052000
# Turning point at time t = 2272.319000
# Turning point at time t = 2275.586000
# Turning point at time t = 2278.853000
# Turning point at time t = 2282.120000
# Turning point at time t = 2285.388000
# Turning point at time t = 2288.655000
# Turning point at time t = 2291.922000
# Turning point at time t = 2295.189000
# Turning point at time t = 2298.456000
# Turning point at time t = 2301.724000
# Turning point at time t = 2304.991000
# Turning point at time t = 2308.258000
# Turning point at time t = 2311.525000
# Turning point at time t = 2314.792000
# Turning point at time t = 2318.059000
# Turning point at time t = 2321.327000
# Turning point at time t = 2324.594000
# Turning point at time t = 2327.861000
# Turning point at time t = 2331.128000
# Turning point at time t = 2334.395000
# Turning point at time t = 2337.662000
# Turning point at time t = 2340.930000
# Turning point at time t = 2344.197000
# Turning point at time t = 2347.464000
# Turning point at time t = 2350.731000
# Turning point at time t = 2353.998000
# Turning point at time t = 2357.265000
# Turning point at time t = 2360.533000
# Turning point at time t = 2363.800000
# Turning point at time t = 2367.067000
# Turning point at time t = 2370.334000
# Turning point at time t = 2373.601000
# Turning point at time t = 2376.868000
# Turning point at time t = 2380.136000
# Turning point at time t = 2383.403000
# Turning point at time t = 2386.670000
# Turning point at time t = 2389.937000
# Turning point at time t = 2393.204000
# Turning point at time t = 2396.472000
# Turning point at time t = 2399.739000
# Turning point at time t = 2403.006000
# Turning point at time t = 2406.273000
# Turning point at time t = 2409.540000
# Turning point at time t = 2412.807000
# Turning point at time t = 2416.075000
# Turning point at time t = 2419.342000
# Turning point at time t = 2422.609000
# Turning point at time t = 2425.876000
# Turning point at time t = 2429.143000
# Turning point at time t = 2432.410000
# Turning point at time t = 2435.678000
# Turning point at time t = 2438.945000
# Turning point at time t = 2442.212000
# Turning point at time t = 2445.479000
# Turning point at time t = 2448.746000
# Turning point at time t = 2452.013000
# Turning point at time t = 2455.281000
# Turning point at time t = 2458.548000
# Turning point at time t = 2461.815000
# Turning point at time t = 2465.082000
# Turning point at time t = 2468.349000
# Turning point at time t = 2471.616000
# Turning point at time t = 2474.884000
# Turning point at time t = 2478.151000
# Turning point at time t = 2481.418000
# Turning point at time t = 2484.685000
# Turning point at time t = 2487.952000
# Turning point at time t = 2491.220000
# Turning point at time t = 2494.487000
# Turning point at time t = 2497.754000
# Turning point at time t = 2501.021000
# Turning point at time t = 2504.288000
# Turning point at time t = 2507.555000
# Turning point at time t = 2510.823000
# Turning point at time t = 2514.090000
# Turning point at time t = 2517.357000
# Turning point at time t = 2520.624000
# Turning point at time t = 2523.891000
# Turning point at time t = 2527.158000
# Turning point at time t = 2530.426000
# Turning point at time t = 2533.693000
# Turning point at time t = 2536.960000
# Turning point at time t = 2540.227000
# Turning point at time t = 2543.494000
# Turning point at time t = 2546.761000
# Turning point at time t = 2550.029000
# Turning point at time t = 2553.296000
# Turning point at time t = 2556.563000
# Turning point at time t = 2559.830000
# Turning point at time t = 2563.097000
# Turning point at time t = 2566.364000
# Turning point at time t = 2569.632000
# Turning point at time t = 2572.899000
# Turning point at time t = 2576.166000
# Turning point at time t = 2579.433000
# Turning point at time t = 2582.700000
# Turning point at time t = 2585.968000
# Turning point at time t = 2589.235000
# Turning point at time t = 2592.502000
# Turning point at time t = 2595.769000
# Turning point at time t = 2599.036000
# Turning point at time t = 2602.303000
# Turning point at time t = 2605.571000
# Turning point at time t = 2608.838000
# Turning point at time t = 2612.105000
# Turning point at time t = 2615.372000
# Turning point at time t = 2618.639000
# Turning point at time t = 2621.906000
# Turning point at time t = 2625.174000
# Turning point at time t = 2628.441000
# Turning point at time t = 2631.708000
# Turning point at time t = 2634.975000
# Turning point at time t = 2638.242000
# Turning point at time t = 2641.509000
# Turning point at time t = 2644.777000
# Turning point at time t = 2648.044000
# Turning point at time t = 2651.311000
# Turning point at time t = 2654.578000
# Turning point at time t = 2657.845000
# Turning point at time t = 2661.112000
# Turning point at time t = 2664.380000
# Turning point at time t = 2667.647000
# Turning point at time t = 2670.914000
# Turning point at time t = 2674.181000
# Turning point at time t = 2677.448000
# Turning point at time t = 2680.716000
# Turning point at time t = 2683.983000
# Turning point at time t = 2687.250000
# Turning point at time t = 2690.517000
# Turning point at time t = 2693.784000
# Turning point at time t = 2697.051000
# Turning point at time t = 2700.319000
# Turning point at time t = 2703.586000
# Turning point at time t = 2706.853000
# Turning point at time t = 2710.120000
# Turning point at time t = 2713.387000
# Turning point at time t = 2716.654000
# Turning point at time t = 2719.922000
# Turning point at time t = 2723.189000
# Turning point at time t = 2726.456000
# Turning point at time t = 2729.723000
# Turning point at time t = 2732.990000
# Turning point at time t = 2736.257000
# Turning point at time t = 2739.525000
# Turning point at time t = 2742.792000
# Turning point at time t = 2746.059000
# Turning point at time t = 2749.326000
# Turning point at time t = 2752.593000
# Turning point at time t = 2755.860000
# Turning point at time t = 2759.128000
# Turning point at time t = 2762.395000
# Turning point at time t = 2765.662000
# Turning point at time t = 2768.929000
# Turning point at time t = 2772.196000
# Turning point at time t = 2775.464000
# Turning point at time t = 2778.731000
# Turning point at time t = 2781.998000
# Turning point at time t = 2785.265000
# Turning point at time t = 2788.532000
# Turning point at time t = 2791.799000
# Turning point at time t = 2795.067000
# Turning point at time t = 2798.334000
# Turning point at time t = 2801.601000
# Turning point at time t = 2804.868000
# Turning point at time t = 2808.135000
# Turning point at time t = 2811.402000
# Turning point at time t = 2814.670000
# Turning point at time t = 2817.937000
# Turning point at time t = 2821.204000
# Turning point at time t = 2824.471000
# Turning point at time t = 2827.738000
# Turning point at time t = 2831.005000
# Turning point at time t = 2834.273000
# Turning point at time t = 2837.540000
# Turning point at time t = 2840.807000
# Turning point at time t = 2844.074000
# Turning point at time t = 2847.341000
# Turning point at time t = 2850.608000
# Turning point at time t = 2853.876000
# Turning point at time t = 2857.143000
# Turning point at time t = 2860.410000
# Turning point at time t = 2863.677000
# Turning point at time t = 2866.944000
# Turning point at time t = 2870.212000
# Turning point at time t = 2873.479000
# Turning point at time t = 2876.746000
# Turning point at time t = 2880.013000
# Turning point at time t = 2883.280000
# Turning point at time t = 2886.547000
# Turning point at time t = 2889.815000
# Turning point at time t = 2893.082000
# Turning point at time t = 2896.349000
# Turning point at time t = 2899.616000
# Turning point at time t = 2902.883000
# Turning point at time t = 2906.150000
# Turning point at time t = 2909.418000
# Turning point at time t = 2912.685000
# Turning point at time t = 2915.952000
# Turning point at time t = 2919.219000
# Turning point at time t = 2922.486000
# Turning point at time t = 2925.753000
# Turning point at time t = 2929.021000
# Turning point at time t = 2932.288000
# Turning point at time t = 2935.555000
# Turning point at time t = 2938.822000
# Turning point at time t = 2942.089000
# Turning point at time t = 2945.356000
# Turning point at time t = 2948.624000
# Turning point at time t = 2951.891000
# Turning point at time t = 2955.158000
# Turning point at time t = 2958.425000
# Turning point at time t = 2961.692000
# Turning point at time t = 2964.960000
# Turning point at time t = 2968.227000
# Turning point at time t = 2971.494000
# Turning point at time t = 2974.761000
# Turning point at time t = 2978.028000
# Turning point at time t = 2981.295000
# Turning point at time t = 2984.563000
# Turning point at time t = 2987.830000
# Turning point at time t = 2991.097000
# Turning point at time t = 2994.364000
# Turning point at time t = 2997.631000
# Turning point at time t = 3000.898000
# Turning point at time t = 3004.166000
# Turning point at time t = 3007.433000
# Turning point at time t = 3010.700000
# Turning point at time t = 3013.967000
# Turning point at time t = 3017.234000
# Turning point at time t = 3020.501000
# Turning point at time t = 3023.769000
# Turning point at time t = 3027.036000
# Turning point at time t = 3030.303000
# Turning point at time t = 3033.570000
# Turning point at time t = 3036.837000
# Turning point at time t = 3040.105000
# Turning point at time t = 3043.372000
# Turning point at time t = 3046.639000
# Turning point at time t = 3049.906000
# Turning point at time t = 3053.173000
# Turning point at time t = 3056.440000
# Turning point at time t = 3059.708000
# Turning point at time t = 3062.975000
# Turning point at time t = 3066.242000
# Turning point at time t = 3069.509000
# Turning point at time t = 3072.776000
# Turning point at time t = 3076.043000
# Turning point at time t = 3079.311000
# Turning point at time t = 3082.578000
# Turning point at time t = 3085.845000
# Turning point at time t = 3089.112000
# Turning point at time t = 3092.379000
# Turning point at time t = 3095.646000
# Turning point at time t = 3098.914000
# Turning point at time t = 3102.181000
# Turning point at time t = 3105.448000
# Turning point at time t = 3108.715000
# Turning point at time t = 3111.982000
# Turning point at time t = 3115.249000
# Turning point at time t = 3118.517000
# Turning point at time t = 3121.784000
# Turning point at time t = 3125.051000
# Turning point at time t = 3128.318000
# Turning point at time t = 3131.585000
# Turning point at time t = 3134.853000
# Turning point at time t = 3138.120000
# Turning point at time t = 3141.387000
# Turning point at time t = 3144.654000
# Turning point at time t = 3147.921000
# Turning point at time t = 3151.188000
# Turning point at time t = 3154.456000
# Turning point at time t = 3157.723000
# Turning point at time t = 3160.990000
# Turning point at time t = 3164.257000
# Turning point at time t = 3167.524000
# Turning point at time t = 3170.791000
# Turning point at time t = 3174.059000
# Turning point at time t = 3177.326000
# Turning point at time t = 3180.593000
# Turning point at time t = 3183.860000
# Turning point at time t = 3187.127000
# Turning point at time t = 3190.394000
# Turning point at time t = 3193.662000
# Turning point at time t = 3196.929000
# Turning point at time t = 3200.196000
# Turning point at time t = 3203.463000
# Turning point at time t = 3206.730000
# Turning point at time t = 3209.997000
# Turning point at time t = 3213.265000
# Turning point at time t = 3216.532000
# Turning point at time t = 3219.799000
# Turning point at time t = 3223.066000
# Turning point at time t = 3226.333000
# Turning point at time t = 3229.601000
# Turning point at time t = 3232.868000
# Turning point at time t = 3236.135000
# Turning point at time t = 3239.402000
# Turning point at time t = 3242.669000
# Turning point at time t = 3245.936000
# Turning point at time t = 3249.204000
# Turning point at time t = 3252.471000
# Turning point at time t = 3255.738000
# Turning point at time t = 3259.005000
# Turning point at time t = 3262.272000
# Turning point at time t = 3265.539000
# Turning point at time t = 3268.807000
# Turning point at time t = 3272.074000
# Turning point at time t = 3275.341000
# Turning point at time t = 3278.608000
# Turning point at time t = 3281.875000
# Turning point at time t = 3285.142000
# Turning point at time t = 3288.410000
# Turning point at time t = 3291.677000
# Turning point at time t = 3294.944000
# Turning point at time t = 3298.211000
# Turning point at time t = 3301.478000
# Turning point at time t = 3304.745000
# Turning point at time t = 3308.013000
# Turning point at time t = 3311.280000
# Turning point at time t = 3314.547000
# Turning point at time t = 3317.814000
# Turning point at time t = 3321.081000
# Turning point at time t = 3324.349000
# Turning point at time t = 3327.616000
# Turning point at time t = 3330.883000
# Turning point at time t = 3334.150000
# Turning point at time t = 3337.417000
# Turning point at time t = 3340.684000
# Turning point at time t = 3343.952000
# Turning point at time t = 3347.219000
# Turning point at time t = 3350.486000
# Turning point at time t = 3353.753000
# Turning point at time t = 3357.020000
# Turning point at time t = 3360.287000
# Turning point at time t = 3363.555000
# Turning point at time t = 3366.822000
# Turning point at time t = 3370.089000
# Turning point at time t = 3373.356000
# Turning point at time t = 3376.623000
# Turning point at time t = 3379.890000
# Turning point at time t = 3383.158000
# Turning point at time t = 3386.425000
# Turning point at time t = 3389.692000
# Turning point at time t = 3392.959000
# Turning point at time t = 3396.226000
# Turning point at time t = 3399.493000
# Turning point at time t = 3402.761000
# Turning point at time t = 3406.028000
# Turning point at time t = 3409.295000
# Turning point at time t = 3412.562000
# Turning point at time t = 3415.829000
# Turning point at time t = 3419.097000
# Turning point at time t = 3422.364000
# Turning point at time t = 3425.631000
# Turning point at time t = 3428.898000
# Turning point at time t = 3432.165000
# Turning point at time t = 3435.432000
# Turning point at time t = 3438.700000
# Turning point at time t = 3441.967000
# Turning point at time t = 3445.234000
# Turning point at time t = 3448.501000
# Turning point at time t = 3451.768000
# Turning point at time t = 3455.035000
# Turning point at time t = 3458.303000
# Turning point at time t = 3461.570000
# Turning point at time t = 3464.837000
# Turning point at time t = 3468.104000
# Turning point at time t = 3471.371000
# Turning point at time t = 3474.638000
# Turning point at time t = 3477.906000
# Turning point at time t = 3481.173000
# Turning point at time t = 3484.440000
# Turning point at time t = 3487.707000
# Turning point at time t = 3490.974000
# Turning point at time t = 3494.241000
# Turning point at time t = 3497.509000
# Turning point at time t = 3500.776000
# Turning point at time t = 3504.043000
# Turning point at time t = 3507.310000
# Turning point at time t = 3510.577000
# Turning point at time t = 3513.845000
# Turning point at time t = 3517.112000
# Turning point at time t = 3520.379000
# Turning point at time t = 3523.646000
# Turning point at time t = 3526.913000
# Turning point at time t = 3530.180000
# Turning point at time t = 3533.448000
# Turning point at time t = 3536.715000
# Turning point at time t = 3539.982000
# Turning point at time t = 3543.249000
# Turning point at time t = 3546.516000
# Turning point at time t = 3549.783000
# Turning point at time t = 3553.051000
# Turning point at time t = 3556.318000
# Turning point at time t = 3559.585000
# Turning point at time t = 3562.852000
# Turning point at time t = 3566.119000
# Turning point at time t = 3569.386000
# Turning point at time t = 3572.654000
# Turning point at time t = 3575.921000
# Turning point at time t = 3579.188000
# Turning point at time t = 3582.455000
# Turning point at time t = 3585.722000
# Turning point at time t = 3588.989000
# Turning point at time t = 3592.257000
# Turning point at time t = 3595.524000
# Turning point at time t = 3598.791000
# Turning point at time t = 3602.058000
# Turning point at time t = 3605.325000
# Turning point at time t = 3608.593000
# Turning point at time t = 3611.860000
# Turning point at time t = 3615.127000
# Turning point at time t = 3618.394000
# Turning point at time t = 3621.661000
# Turning point at time t = 3624.928000
# Turning point at time t = 3628.196000
# Turning point at time t = 3631.463000
# Turning point at time t = 3634.730000
# Turning point at time t = 3637.997000
# Turning point at time t = 3641.264000
# Turning point at time t = 3644.531000
# Turning point at time t = 3647.799000
# Turning point at time t = 3651.066000
# Turning point at time t = 3654.333000
# Turning point at time t = 3657.600000
# Turning point at time t = 3660.867000
# Turning point at time t = 3664.134000
# Turning point at time t = 3667.402000
# Turning point at time t = 3670.669000
# Turning point at time t = 3673.936000
# Turning point at time t = 3677.203000
# Turning point at time t = 3680.470000
# Turning point at time t = 3683.737000
# Turning point at time t = 3687.005000
# Turning point at time t = 3690.272000
# Turning point at time t = 3693.539000
# Turning point at time t = 3696.806000
# Turning point at time t = 3700.073000
# Turning point at time t = 3703.341000
# Turning point at time t = 3706.608000
# Turning point at time t = 3709.875000
# Turning point at time t = 3713.142000
# Turning point at time t = 3716.409000
# Turning point at time t = 3719.676000
# Turning point at time t = 3722.944000
# Turning point at time t = 3726.211000
# Turning point at time t = 3729.478000
# Turning point at time t = 3732.745000
# Turning point at time t = 3736.012000
# Turning point at time t = 3739.279000
# Turning point at time t = 3742.547000
# Turning point at time t = 3745.814000
# Turning point at time t = 3749.081000
# Turning point at time t = 3752.348000
# Turning point at time t = 3755.615000
# Turning point at time t = 3758.882000
# Turning point at time t = 3762.150000
# Turning point at time t = 3765.417000
# Turning point at time t = 3768.684000
# Turning point at time t = 3771.951000
# Turning point at time t = 3775.218000
# Turning point at time t = 3778.485000
# Turning point at time t = 3781.753000
# Turning point at time t = 3785.020000
# Turning point at time t = 3788.287000
# Turning point at time t = 3791.554000
# Turning point at time t = 3794.821000
# Turning point at time t = 3798.089000
# Turning point at time t = 3801.356000
# Turning point at time t = 3804.623000
# Turning point at time t = 3807.890000
# Turning point at time t = 3811.157000
# Turning point at time t = 3814.424000
# Turning point at time t = 3817.692000
# Turning point at time t = 3820.959000
# Turning point at time t = 3824.226000
# Turning point at time t = 3827.493000
# Turning point at time t = 3830.760000
# Turning point at time t = 3834.027000
# Turning point at time t = 3837.295000
# Turning point at time t = 3840.562000
# Turning point at time t = 3843.829000
# Turning point at time t = 3847.096000
# Turning point at time t = 3850.363000
# Turning point at time t = 3853.630000
# Turning point at time t = 3856.898000
# Turning point at time t = 3860.165000
# Turning point at time t = 3863.432000
# Turning point at time t = 3866.699000
# Turning point at time t = 3869.966000
# Turning point at time t = 3873.233000
# Turning point at time t = 3876.501000
# Turning point at time t = 3879.768000
# Turning point at time t = 3883.035000
# Turning point at time t = 3886.302000
# Turning point at time t = 3889.569000
# Turning point at time t = 3892.837000
# Turning point at time t = 3896.104000
# Turning point at time t = 3899.371000
# Turning point at time t = 3902.638000
# Turning point at time t = 3905.905000
# Turning point at time t = 3909.172000
# Turning point at time t = 3912.440000
# Turning point at time t = 3915.707000
# Turning point at time t = 3918.974000
# Turning point at time t = 3922.241000
# Turning point at time t = 3925.508000
# Turning point at time t = 3928.775000
# Turning point at time t = 3932.043000
# Turning point at time t = 3935.310000
# Turning point at time t = 3938.577000
# Turning point at time t = 3941.844000
# Turning point at time t = 3945.111000
# Turning point at time t = 3948.378000
# Turning point at time t = 3951.646000
# Turning point at time t = 3954.913000
# Turning point at time t = 3958.180000
# Turning point at time t = 3961.447000
# Turning point at time t = 3964.714000
# Turning point at time t = 3967.981000
# Turning point at time t = 3971.249000
# Turning point at time t = 3974.516000
# Turning point at time t = 3977.783000
# Turning point at time t = 3981.050000
# Turning point at time t = 3984.317000
# Turning point at time t = 3987.585000
# Turning point at time t = 3990.852000
# Turning point at time t = 3994.119000
# Turning point at time t = 3997.386000

# %%
nPeriod = int(irev - 1)
print (nPeriod)
# Out:
# 1223

# %%
gr = TGraph(nStep,t_plot,th_plot)
grr = TGraph(nPeriod,trev,period)

# %%
gr.SetMarkerColor(4)
grr.SetMarkerColor(4)
gr.SetMarkerStyle(21)
grr.SetMarkerStyle(22)
gr.SetTitle("Pendulum Amplitude vs. Time")
gr.GetXaxis().SetTitle("Time")
gr.GetYaxis().SetTitle("Amplitude")
grr.SetTitle("Pendulum Period vs. Time")
grr.GetXaxis().SetTitle("Time")
grr.GetYaxis().SetTitle("Period")

c1.cd()
gr.Draw("AP")
c1.Draw()

# %%
c2.cd()
grr.Draw("AP")
c2.Draw()

# %%
AvePeriod = 0.0
ErrorBar = 0.0
for i in range(1,nPeriod+1):
    AvePeriod = AvePeriod + period[i-1]
AvePeriod = AvePeriod/nPeriod
for i in range(1,nPeriod+1):
    ErrorBar = ErrorBar + (period[i-1]-AvePeriod)*(period[i-1]-AvePeriod)
ErrorBar = math.sqrt(ErrorBar/(nPeriod*(nPeriod-1)))
print("Average Period = %f +/- %f" % (AvePeriod,ErrorBar))
# Out:
# Average Period = 6.534345 +/- 0.000022

# %%
t0=theta0*Pi/180.0
t_infinite = 2.0*Pi/math.sqrt(g_over_L)*(1.0+t0*t0/16.0+math.pow(t0,4)*11.0/3072.0+math.pow(t0,6)*173.0/737280.0)
error_infinite = 2.0*Pi/math.sqrt(g_over_L)*math.pow(t0,8)*22931.0/1321205760.0

# %%
print("Infinite series prediction = %f +/- %f" % (t_infinite,error_infinite))
# Out:
# Infinite series prediction = 6.534329 +/- 0.000016

# %%
x = array('d')
y = array('d')
ex = array('d')
ey = array('d')
npoints = 2
x.append(1)
x.append(2)
ex.append(0)
ex.append(0)
y.append(AvePeriod)
y.append(t_infinite)
ey.append(ErrorBar)
ey.append(error_infinite)

c3 = TCanvas("c3","c3",100,0,800,600)
gr3 = TGraphErrors(npoints,x,y,ex,ey)
gr3.SetMarkerStyle(21)
gr3.SetTitle("Theory vs. Simulation")
gr3.GetXaxis().SetTitle("1=Sim,2=Theory")
gr3.GetYaxis().SetTitle("Average Period (s)")
gr3.Draw("AP")
c3.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c3
